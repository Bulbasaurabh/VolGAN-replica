# %%
# === 1) Imports & Params ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Optional

TRADING_DAYS_PER_MONTH = 21
GAMMA_FLOOR = 1e-6  # vega floor for stability in hedge ratio

# Paths (adjust if needed)
OPTIONS_PARQUET = "data/options_dataset.parquet"
OM_UNDERLYING_CSV = "data/spx.csv"

pd.set_option('display.width', 160)
pd.set_option('display.max_columns', 50)

# %%
# === 2) Load SPX options & basic cleaning ===
df = pd.read_parquet(OPTIONS_PARQUET)
keep_cols = ['ticker','date','exdate','cp_flag','strike_price','best_bid','best_offer',
             'volume','open_interest','impl_volatility','delta','gamma','vega','theta']
df = df[keep_cols].copy()
df['date'] = pd.to_datetime(df['date'])
df['exdate'] = pd.to_datetime(df['exdate'])

df = df[df['ticker'] == 'SPX'].copy()

# Mid, dte
df['mid'] = (df['best_bid'] + df['best_offer']) / 2.0
df['dte'] = (df['exdate'] - df['date']).dt.days

# Fix OPRA strike scaling (1,505,000 -> 1505.0 typical)
if df['strike_price'].median() > 1e4:
    df['strike_price'] = df['strike_price'] / 1000.0

print("Options rows:", len(df))
df.head()
# Out:
# Options rows: 36251366
#   ticker       date     exdate cp_flag  strike_price  best_bid  best_offer  volume  open_interest  impl_volatility     delta     gamma       vega      theta  \
# 0    SPX 2000-01-03 2000-01-22       P        1505.0    55.250      57.250       0             50         0.212891 -0.734362  0.004767  105.97850 -162.13980
# 1    SPX 2000-01-03 2000-01-22       P        1545.0    89.625      91.625       0              0         0.233571 -0.858130  0.002975   72.57848  -92.56329
# 2    SPX 2000-01-03 2000-03-18       C         750.0   706.500     708.500       0           1916              NaN       NaN       NaN        NaN        NaN
# 3    SPX 2000-01-03 2000-09-16       C        1450.0   135.750     137.750       0           2365         0.229435  0.608151  0.001353  461.04910 -109.55640
# 4    SPX 2000-01-03 2000-06-17       P        1350.0    40.750      42.750     290          14570         0.252872 -0.256190  0.001296  313.84440  -67.94785
#
#        mid  dte
# 0   56.250   19
# 1   90.625   19
# 2  707.500   75
# 3  136.750  257
# 4   41.750  166

# %%
# === 3) Load OptionMetrics OMunderlying.csv as spot ===
# Expected columns: secid,date,ticker,index_flag,low,high,open,close,volume
spot_df = pd.read_csv(OM_UNDERLYING_CSV)
spot_df['date'] = pd.to_datetime(spot_df['date'])
spot_df = spot_df[spot_df['ticker'] == 'SPX'].copy()

# Use 'close' as the index level (spot)
spot_df = spot_df[['date','close']].rename(columns={'close':'spot'}).sort_values('date')
spot_df = spot_df.drop_duplicates(subset=['date'], keep='last').reset_index(drop=True)

print("Spot rows:", len(spot_df), "| range:", spot_df['date'].min().date(), "→", spot_df['date'].max().date())
spot_df.head()
# Out:
# Spot rows: 5954 | range: 2000-01-03 → 2023-08-31
#         date     spot
# 0 2000-01-03  1455.22
# 1 2000-01-04  1399.42
# 2 2000-01-05  1402.11
# 3 2000-01-06  1403.45
# 4 2000-01-07  1441.47

# %%
# === 4) Merge spot into options; compute moneyness; filter ~1M tenor ===
df = df.merge(spot_df, on='date', how='inner')
df['moneyness'] = df['strike_price'] / df['spot']

# Keep ~1M options: dte around 21 trading days (use a calendar-day band 15–35)
df_1m = df[(df['dte'] >= 15) & (df['dte'] <= 35)].copy()

# Quality screens
df_1m = df_1m.replace([np.inf, -np.inf], np.nan)
df_1m = df_1m.dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
df_1m = df_1m[df_1m['best_offer'] >= df_1m['best_bid']].copy()
df_1m['spread'] = (df_1m['best_offer'] - df_1m['best_bid']).clip(lower=0)
df_1m['rel_spread'] = (df_1m['spread'] / df_1m['mid']).replace([np.inf,-np.inf], np.nan)

liq_mask = (
    (df_1m['mid'] > 0.05) &
    (df_1m['rel_spread'] <= 0.35) &
    df_1m['delta'].between(-1.1, 1.1) &
    (df_1m['gamma'].abs() > 0)   # gamma is positive for vanilla options; guard against zeros
)
df_1m = df_1m[liq_mask].copy()

cols_keep = ['date','exdate','cp_flag','strike_price','spot','moneyness','dte','mid',
             'best_bid','best_offer','volume','open_interest','delta','gamma','spread','rel_spread']
df_1m = df_1m[cols_keep].sort_values(['date','dte','strike_price']).reset_index(drop=True)

print("1M rows:", len(df_1m), "| date range:", df_1m['date'].min().date(), "→", df_1m['date'].max().date())
df_1m.head(10)
# Out:
# 1M rows: 5686826 | date range: 2000-01-03 → 2023-08-31
#         date     exdate cp_flag  strike_price     spot  moneyness  dte       mid  best_bid  best_offer  volume  open_interest     delta     gamma  spread  \
# 0 2000-01-03 2000-01-22       P        1275.0  1455.22   0.876156   19    2.0000     1.750       2.250     585          23785 -0.041295  0.000763   0.500
# 1 2000-01-03 2000-01-22       P        1300.0  1455.22   0.893336   19    2.6250     2.250       3.000    3572          26621 -0.055490  0.001036   0.750
# 2 2000-01-03 2000-01-22       P        1325.0  1455.22   0.910515   19    3.8125     3.500       4.125    1406          30757 -0.079749  0.001446   0.625
# 3 2000-01-03 2000-01-22       C        1325.0  1455.22   0.910515   19  134.5000   133.500     135.500     315          29529  0.983012  0.000628   2.000
# 4 2000-01-03 2000-01-22       C        1350.0  1455.22   0.927695   19  111.1250   110.125     112.125     112          20500  0.939732  0.001609   2.000
# 5 2000-01-03 2000-01-22       P        1350.0  1455.22   0.927695   19    5.1875     4.875       5.500     819          24413 -0.109956  0.001978   0.625
# 6 2000-01-03 2000-01-22       C        1375.0  1455.22   0.944874   19   88.5000    87.500      89.500       6           7885  0.884385  0.002631   2.000
# 7 2000-01-03 2000-01-22       P        1375.0  1455.22   0.944874   19    6.9375     6.750       7.125    2633          18270 -0.150684  0.002706   0.375
# 8 2000-01-03 2000-01-22       C        1380.0  1455.22   0.948310   19   84.0000    83.000      85.000       4             13  0.872528  0.002851   2.000
# 9 2000-01-03 2000-01-22       P        1380.0  1455.22   0.948310   19    8.1250     7.625       8.625      69           1458 -0.168821  0.002871   1.000
#
#    rel_spread
# 0    0.250000
# 1    0.285714
# 2    0.163934
# 3    0.014870
# 4    0.017998
# 5    0.120482
# 6    0.022599
# 7    0.054054
# 8    0.023810
# 9    0.123077

# %%
# === 5) Utilities (small, testable) ===
def choose_strike_for_m0(spot0: float, m0: float, available_strikes: np.ndarray) -> float:
    target = float(m0) * float(spot0)
    idx = np.abs(available_strikes - target).argmin()
    K = float(available_strikes[idx])
    print(f"[choose_strike_for_m0] spot0={spot0:.4f}, m0={m0:.3f}, target={target:.4f} -> K={K}")
    return K

def nearest_atm_strike(spot0: float, available_strikes: np.ndarray) -> float:
    idx = np.abs(available_strikes - float(spot0)).argmin()
    K = float(available_strikes[idx])
    print(f"[nearest_atm_strike] spot0={spot0:.4f} -> K_ATM={K}")
    return K

def pick_one(day_df: pd.DataFrame, strike: float, cp_flag: str) -> Optional[pd.Series]:
    sub = day_df[(day_df['strike_price'] == strike) & (day_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[pick_one] MISSING leg for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[pick_one] All candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[pick_one] No clean candidate after filters for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[pick_one] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, "
          f"mid={chosen['mid']:.4f}, delta={chosen['delta']:.4f}, gamma={chosen['gamma']:.6e}, "
          f"spread={chosen['spread']:.4f}, OI={int(chosen['open_interest'])}, vol={int(chosen['volume'])}")
    return chosen

def fetch_next_row(next_df, strike, cp_flag):
    sub = next_df[(next_df['strike_price'] == strike) & (next_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[next fetch] MISSING next-day row for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[next fetch] All next-day candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[next fetch] No clean next-day candidate for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[next fetch] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, mid={chosen['mid']:.4f}")
    return chosen

def half_spread(row: pd.Series) -> float:
    return float(max(0.0, (row['best_offer'] - row['best_bid']) / 2.0))

def pnl_from_price_change(qty: float, price_t: float, price_t1: float) -> float:
    return float(qty) * (float(price_t1) - float(price_t))

def self_financing_rebalance_cost(prev_qty: float, new_qty: float, half_spread_val: float) -> float:
    return abs(float(new_qty - prev_qty)) * float(half_spread_val)

# %%
# === 6A) Window builder ===
def get_window_dates(df_all: pd.DataFrame, start_idx: int) -> list[pd.Timestamp] | None:
    dates = np.sort(df_all['date'].unique())
    if start_idx + TRADING_DAYS_PER_MONTH >= len(dates):
        print(f"[get_window_dates] Not enough dates from start_idx={start_idx}.")
        return None
    days = list(dates[start_idx : start_idx + TRADING_DAYS_PER_MONTH + 1])
    print(f"[get_window_dates] start={pd.Timestamp(days[0]).date()} end={pd.Timestamp(days[-1]).date()} len={len(days)}")
    return days

# %%
# === 6B) One day step ===
def one_day_step(df_all: pd.DataFrame,
                 d: pd.Timestamp, d_next: pd.Timestamp,
                 K_straddle: float, K_hedge: float,
                 phi_opt_prev: float, phi_under_prev: float) -> dict | None:
    day = df_all[df_all['date'] == d].copy()
    day_next = df_all[df_all['date'] == d_next].copy()
    if day.empty or day_next.empty:
        print(f="[one_day_step] Missing day data at {d} or {d_next}")
        return None

    row_C = pick_one(day, K_straddle, 'C')
    row_P = pick_one(day, K_straddle, 'P')
    row_H = pick_one(day, K_hedge, 'C')
    if row_H is None:
        row_H = pick_one(day, K_hedge, 'P')

    if (row_C is None) or (row_P is None) or (row_H is None):
        print("[one_day_step] Missing leg(s) at current day.")
        return None

    # Position greeks (straddle: long 1C + 1P)
    psi_C, psi_P = 1.0, 1.0
    V_t   = psi_C*row_C['mid'] + psi_P*row_P['mid']
    dV_t  = psi_C*row_C['delta'] + psi_P*row_P['delta']
    gV_t  = psi_C*row_C['gamma'] + psi_P*row_P['gamma']

    dH_t  = row_H['delta']
    gH_t  = row_H['gamma']

    vals = [V_t, dV_t, gV_t, dH_t, gH_t, row_H['mid']]
    if not all(np.isfinite(v) for v in vals):
        print(f"[one_day_step] Non-finite greeks/prices at {pd.Timestamp(d).date()} — abort window.")
        return None

    # Stabilize very small hedge gamma
    gH_eff = np.sign(gH_t) * max(abs(gH_t) if np.isfinite(gH_t) else 0.0, GAMMA_FLOOR)
    if not np.isfinite(gV_t):
        print(f"[one_day_step] Portfolio gamma NaN at {pd.Timestamp(d).date()} — abort window.")
        return None

    # Gamma hedge via option; residual delta via underlying
    phi_opt   = (gV_t / gH_eff) if not np.isclose(gH_eff, 0.0) else 0.0
    phi_under = dV_t - phi_opt * dH_t

    # Next-day marks
    row_C_next = fetch_next_row(day_next, row_C['strike_price'], 'C')
    row_P_next = fetch_next_row(day_next, row_P['strike_price'], 'P')
    row_H_next = fetch_next_row(day_next, row_H['strike_price'], row_H['cp_flag'])
    if (row_C_next is None) or (row_P_next is None) or (row_H_next is None):
        print("[one_day_step] Missing next-day leg(s).")
        return None

    s_t  = float(row_C['spot']);  s_t1 = float(row_C_next['spot'])
    hs_H = half_spread(row_H)

    pnl_opt    = pnl_from_price_change(phi_opt, row_H['mid'], row_H_next['mid'])
    pnl_under  = pnl_from_price_change(phi_under, s_t, s_t1)
    cost_opt   = self_financing_rebalance_cost(phi_opt_prev, phi_opt, hs_H)
    cost_under = 0.0  # same as before

    pnl_unhedged = (psi_C*(row_C_next['mid'] - row_C['mid']) +
                    psi_P*(row_P_next['mid'] - row_P['mid']))

    return dict(
        date=pd.Timestamp(d), spot=s_t,
        K_straddle=K_straddle, K_hedge=K_hedge,
        V_t=float(V_t), dV_t=float(dV_t), gV_t=float(gV_t),
        H_cp=row_H['cp_flag'], H_mid=float(row_H['mid']), dH_t=float(dH_t), gH_t=float(gH_t), gH_eff=float(gH_eff),
        phi_opt=float(phi_opt), phi_under=float(phi_under),
        cost_opt=float(cost_opt), cost_under=float(cost_under),
        pnl_opt=float(pnl_opt), pnl_under=float(pnl_under), pnl_unhedged=float(pnl_unhedged)
    )

# %%
# === 6C) Single window runner ===
def run_single_window(df_all: pd.DataFrame, start_idx: int, m0: float) -> dict | None:
    days = get_window_dates(df_all, start_idx)
    if days is None:
        return None
    d0 = pd.Timestamp(days[0])
    day0 = df_all[df_all['date'] == d0].copy()
    if day0.empty:
        print(f"[run_single_window] No rows on start day {d0}.")
        return None

    spot0 = float(day0['spot'].iloc[0])
    strikes0 = np.sort(day0['strike_price'].unique())
    K_straddle = choose_strike_for_m0(spot0, m0, strikes0)
    K_hedge    = nearest_atm_strike(spot0, strikes0)

    phi_opt_prev = 0.0; phi_under_prev = 0.0
    records = []; V0 = None; Pi_t = None

    for t in range(len(days)-1):
        d, d_next = pd.Timestamp(days[t]), pd.Timestamp(days[t+1])
        print(f"[day {t+1}/{len(days)-1}] {d.date()} -> {d_next.date()}")
        step = one_day_step(df_all, d, d_next, K_straddle, K_hedge, phi_opt_prev, phi_under_prev)
        if step is None:
            print("[run_single_window] Step failed; abort window.")
            return None

        if V0 is None:
            V0 = step['V_t']; Pi_t = V0; print(f"[init] V0=Π0={V0:.6f}")

        Pi_t1 = (Pi_t + step['pnl_opt'] + step['pnl_under'] - step['cost_opt'] - step['cost_under'])
        step['Pi_t'] = float(Pi_t); step['Pi_t1'] = float(Pi_t1)
        records.append(step)

        phi_opt_prev   = step['phi_opt']
        phi_under_prev = step['phi_under']
        Pi_t = Pi_t1

    # Final valuation
    last_day = pd.Timestamp(days[-2]); final_day = pd.Timestamp(days[-1])
    day_last  = df_all[df_all['date'] == last_day]
    day_final = df_all[df_all['date'] == final_day]

    row_C_last = pick_one(day_last, K_straddle, 'C');  row_C_fin = fetch_next_row(day_final, K_straddle, 'C')
    row_P_last = pick_one(day_last, K_straddle, 'P');  row_P_fin = fetch_next_row(day_final, K_straddle, 'P')
    if (row_C_last is None) or (row_P_last is None) or (row_C_fin is None) or (row_P_fin is None):
        print("[run_single_window] Final valuation missing legs.")
        return None

    V_T = float(row_C_fin['mid'] + row_P_fin['mid'])
    Pi_T = float(records[-1]['Pi_t1'])
    tracking_error = V_T - Pi_T
    pnl_unhedged_total = V_T - float(records[0]['V_t'])
    pnl_hedged_total   = Pi_T - float(records[0]['V_t'])

    timeline = pd.DataFrame(records).sort_values('date').reset_index(drop=True)
    summary = dict(
        start=days[0], end=days[-1], m0=float(m0),
        K_straddle=float(K_straddle), K_hedge=float(K_hedge),
        V0=float(records[0]['V_t']), V_T=float(V_T),
        Pi_T=float(Pi_T),
        tracking_error=float(tracking_error),
        pnl_unhedged=float(pnl_unhedged_total),
        pnl_hedged=float(pnl_hedged_total)
    )
    print(f"[window done] m0={m0}, Z_T={tracking_error:.6f}, V_T={V_T:.6f}, Π_T={Pi_T:.6f}")
    return dict(timeline=timeline, summary=summary)

# %%
# === 7) Multi-window experiment ===
def run_experiment_verbose(df_all: pd.DataFrame, m0_list: list[float], max_windows: int = 52, stop_on_fail: bool = False) -> pd.DataFrame:
    dates = np.sort(df_all['date'].unique())
    start_indices = list(range(0, len(dates) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
    start_indices = start_indices[:max_windows]
    results = []
    for m0 in m0_list:
        print(f"\n===== m0={m0} =====")
        for i, si in enumerate(start_indices, 1):
            print(f"\n--- Window {i}/{len(start_indices)} (start_idx={si}) ---")
            out = run_single_window(df_all, si, m0)
            if out is None:
                print(f"[run_experiment_verbose] Window failed for m0={m0}, start_idx={si}.")
                if stop_on_fail:
                    return pd.DataFrame(results)
                else:
                    continue
            results.append(out['summary'])
    return pd.DataFrame(results)

# %%
# === 8) Summaries ===
def summarize_results_verbose(results_df: pd.DataFrame) -> pd.DataFrame:
    if results_df is None or results_df.empty:
        print("[summarize_results_verbose] No results to summarize."); return pd.DataFrame()
    g = results_df.groupby('m0')
    out = g['tracking_error'].agg(['mean','median','std']).rename(columns={'std':'std_dev'})
    out['VaR_5pct']   = g['tracking_error'].quantile(0.05)
    out['VaR_2p5pct'] = g['tracking_error'].quantile(0.025)
    out['VaR_1pct']   = g['tracking_error'].quantile(0.01)
    return out

# %%
# === A) Backtest range: from 2021-01-01 to end ===
start_backtest = pd.Timestamp("2020-01-01")
df_1m_bt = df_1m[df_1m['date'] >= start_backtest].copy().sort_values('date')
print("Backtest:", df_1m_bt['date'].min().date(), "→", df_1m_bt['date'].max().date(), "| rows:", len(df_1m_bt))

dates_bt = np.sort(df_1m_bt['date'].unique())
start_indices_bt = list(range(0, len(dates_bt) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
max_windows_bt = len(start_indices_bt)
print("Candidate windows in range:", max_windows_bt)
# Out:
# Backtest: 2020-01-02 → 2023-08-31 | rows: 2956159
# Candidate windows in range: 43

# %%
# === B/C) Run experiment ===
m0_list = [0.75, 0.8, 0.9, 1.1, 1.2, 1.25]
results_df = run_experiment_verbose(df_1m_bt, m0_list=m0_list, max_windows=max_windows_bt, stop_on_fail=False)
print("Results shape:", results_df.shape)
results_df.sort_values(['m0','end']).head(12)
# Out:
# ===== m0=0.75 =====
#
# --- Window 1/43 (start_idx=0) ---
# [get_window_dates] start=2020-01-02 end=2020-02-03 len=22
# [choose_strike_for_m0] spot0=3257.8500, m0=0.750, target=2443.3875 -> K=2450.0
# [nearest_atm_strike] spot0=3257.8500 -> K_ATM=3260.0
# [day 1/21] 2020-01-02 -> 2020-01-03
# [pick_one] MISSING leg for cp=C, K=2450.0
# [pick_one] cp=P, K=2450.0, dte=34, mid=0.3000, delta=-0.0028, gamma=2.500000e-05, spread=0.1000, OI=0, vol=0
# [pick_one] cp=C, K=3260.0, dte=22, mid=28.6000, delta=0.4970, gamma=5.434000e-03, spread=0.4000, OI=1934, vol=190
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=0.
#
# --- Window 2/43 (start_idx=21) ---
# [get_window_dates] start=2020-02-03 end=2020-03-04 len=22
# [choose_strike_for_m0] spot0=3248.9200, m0=0.750, target=2436.6900 -> K=2440.0
# [nearest_atm_strike] spot0=3248.9200 -> K_ATM=3250.0
# [day 1/21] 2020-02-03 -> 2020-02-04
# [pick_one] MISSING leg for cp=C, K=2440.0
# [pick_one] cp=P, K=2440.0, dte=18, mid=0.3000, delta=-0.0028, gamma=2.500000e-05, spread=0.1000, OI=1242, vol=1080
# [pick_one] cp=C, K=3250.0, dte=21, mid=45.2000, delta=0.4955, gamma=3.392000e-03, spread=0.4000, OI=827, vol=63
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=21.
#
# --- Window 3/43 (start_idx=42) ---
# [get_window_dates] start=2020-03-04 end=2020-04-02 len=22
# [choose_strike_for_m0] spot0=3130.1200, m0=0.750, target=2347.5900 -> K=2350.0
# [nearest_atm_strike] spot0=3130.1200 -> K_ATM=3130.0
# [day 1/21] 2020-03-04 -> 2020-03-05
# [pick_one] cp=C, K=2350.0, dte=21, mid=780.1000, delta=0.9798, gamma=1.030000e-04, spread=12.2000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=2.6750, delta=-0.0164, gamma=9.400000e-05, spread=0.2500, OI=202, vol=0
# [pick_one] cp=C, K=3130.0, dte=21, mid=77.5000, delta=0.5066, gamma=2.014000e-03, spread=1.6000, OI=14, vol=1
# [next fetch] cp=C, K=2350.0, dte=22, mid=679.0500
# [next fetch] cp=P, K=2350.0, dte=22, mid=7.9000
# [next fetch] cp=C, K=3130.0, dte=22, mid=48.0500
# [init] V0=Π0=782.775000
# [day 2/21] 2020-03-05 -> 2020-03-06
# [pick_one] cp=C, K=2350.0, dte=22, mid=679.0500, delta=0.9618, gamma=1.820000e-04, spread=9.5000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=7.9000, delta=-0.0405, gamma=1.910000e-04, spread=0.6000, OI=509, vol=902
# [pick_one] cp=C, K=3130.0, dte=22, mid=48.0500, delta=0.3338, gamma=1.603000e-03, spread=1.5000, OI=177, vol=29
# [next fetch] cp=C, K=2350.0, dte=21, mid=633.9000
# [next fetch] cp=P, K=2350.0, dte=21, mid=8.8500
# [next fetch] cp=C, K=3130.0, dte=21, mid=26.2500
# [day 3/21] 2020-03-06 -> 2020-03-09
# [pick_one] cp=C, K=2350.0, dte=21, mid=633.9000, delta=0.9491, gamma=2.330000e-04, spread=10.4000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=8.8500, delta=-0.0465, gamma=2.230000e-04, spread=0.7000, OI=1399, vol=1054
# [pick_one] cp=C, K=3130.0, dte=21, mid=26.2500, delta=0.2331, gamma=1.535000e-03, spread=1.3000, OI=202, vol=14
# [next fetch] cp=C, K=2350.0, dte=21, mid=431.1000
# [next fetch] cp=P, K=2350.0, dte=21, mid=35.4000
# [next fetch] cp=C, K=3130.0, dte=21, mid=6.2500
# [day 4/21] 2020-03-09 -> 2020-03-10
# [pick_one] cp=C, K=2350.0, dte=21, mid=431.1000, delta=0.8545, gamma=5.210000e-04, spread=14.0000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=35.4000, delta=-0.1457, gamma=5.210000e-04, spread=2.0000, OI=136, vol=3
# [pick_one] cp=C, K=3130.0, dte=21, mid=6.2500, delta=0.0643, gamma=5.470000e-04, spread=0.9000, OI=66, vol=6
# [next fetch] cp=C, K=2350.0, dte=21, mid=536.8500
# [next fetch] cp=P, K=2350.0, dte=21, mid=15.9500
# [next fetch] cp=C, K=3130.0, dte=21, mid=12.6000
# [day 5/21] 2020-03-10 -> 2020-03-11
# [pick_one] cp=C, K=2350.0, dte=21, mid=536.8500, delta=0.9228, gamma=3.310000e-04, spread=8.5000, OI=2, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=15.9500, delta=-0.0774, gamma=3.370000e-04, spread=0.7000, OI=1156, vol=4951
# [pick_one] cp=C, K=3130.0, dte=21, mid=12.6000, delta=0.1251, gamma=9.840000e-04, spread=0.8000, OI=728, vol=1
# [next fetch] cp=C, K=2350.0, dte=21, mid=429.1500
# [next fetch] cp=P, K=2350.0, dte=21, mid=32.6000
# [next fetch] cp=C, K=3130.0, dte=21, mid=4.8500
# [day 6/21] 2020-03-11 -> 2020-03-12
# [pick_one] cp=C, K=2350.0, dte=21, mid=429.1500, delta=0.8511, gamma=5.260000e-04, spread=10.3000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=32.6000, delta=-0.1406, gamma=5.270000e-04, spread=2.2000, OI=18, vol=0
# [pick_one] cp=C, K=3130.0, dte=21, mid=4.8500, delta=0.0538, gamma=4.980000e-04, spread=1.3000, OI=25, vol=0
# [next fetch] cp=C, K=2350.0, dte=22, mid=262.8500
# [next fetch] cp=P, K=2350.0, dte=22, mid=135.3000
# [next fetch] MISSING next-day row for cp=C, K=3130.0
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=42.
#
# --- Window 4/43 (start_idx=63) ---
# [get_window_dates] start=2020-04-02 end=2020-05-04 len=22
# [choose_strike_for_m0] spot0=2526.9000, m0=0.750, target=1895.1750 -> K=1900.0
# [nearest_atm_strike] spot0=2526.9000 -> K_ATM=2525.0
# [day 1/21] 2020-04-02 -> 2020-04-03
# [pick_one] cp=C, K=1900.0, dte=22, mid=630.7500, delta=0.9514, gamma=2.150000e-04, spread=8.9000, OI=1, vol=0
# [pick_one] cp=P, K=1900.0, dte=22, mid=8.1500, delta=-0.0427, gamma=2.070000e-04, spread=0.5000, OI=218, vol=17
# [pick_one] cp=C, K=2525.0, dte=20, mid=107.6500, delta=0.5164, gamma=1.452000e-03, spread=1.5000, OI=837, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=589.4500
# [next fetch] cp=P, K=1900.0, dte=21, mid=6.1000
# [next fetch] cp=C, K=2525.0, dte=21, mid=80.2000
# [init] V0=Π0=638.900000
# [day 2/21] 2020-04-03 -> 2020-04-06
# [pick_one] cp=C, K=1900.0, dte=21, mid=589.4500, delta=0.9625, gamma=2.010000e-04, spread=9.5000, OI=1, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=6.1000, delta=-0.0369, gamma=2.070000e-04, spread=0.4000, OI=221, vol=502
# [pick_one] cp=C, K=2525.0, dte=21, mid=80.2000, delta=0.4533, gamma=1.597000e-03, spread=1.6000, OI=49, vol=70
# [next fetch] cp=C, K=1900.0, dte=21, mid=766.3000
# [next fetch] cp=P, K=1900.0, dte=21, mid=3.2000
# [next fetch] cp=C, K=2525.0, dte=21, mid=194.0500
# [day 3/21] 2020-04-06 -> 2020-04-07
# [pick_one] cp=C, K=1900.0, dte=21, mid=766.3000, delta=0.9808, gamma=1.010000e-04, spread=10.0000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=3.2000, delta=-0.0185, gamma=1.010000e-04, spread=0.4000, OI=116, vol=3
# [pick_one] cp=C, K=2525.0, dte=21, mid=194.0500, delta=0.7079, gamma=1.194000e-03, spread=3.1000, OI=13, vol=0
# [next fetch] cp=C, K=1900.0, dte=20, mid=764.2000
# [next fetch] cp=P, K=1900.0, dte=22, mid=3.9500
# [next fetch] cp=C, K=2525.0, dte=22, mid=200.9500
# [day 4/21] 2020-04-07 -> 2020-04-08
# [pick_one] cp=C, K=1900.0, dte=20, mid=764.2000, delta=0.9776, gamma=1.140000e-04, spread=13.2000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=22, mid=3.9500, delta=-0.0217, gamma=1.120000e-04, spread=0.3000, OI=508, vol=0
# [pick_one] cp=C, K=2525.0, dte=22, mid=200.9500, delta=0.6927, gamma=1.125000e-03, spread=2.9000, OI=203, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=846.3500
# [next fetch] cp=P, K=1900.0, dte=21, mid=2.0500
# [next fetch] cp=C, K=2525.0, dte=21, mid=260.6500
# [day 5/21] 2020-04-08 -> 2020-04-09
# [pick_one] cp=C, K=1900.0, dte=21, mid=846.3500, delta=0.9841, gamma=7.300000e-05, spread=13.3000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=2.0500, delta=-0.0120, gamma=6.700000e-05, spread=0.4000, OI=508, vol=10
# [pick_one] cp=C, K=2525.0, dte=21, mid=260.6500, delta=0.7809, gamma=9.270000e-04, spread=2.9000, OI=203, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=889.7000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.4750
# [next fetch] cp=C, K=2525.0, dte=21, mid=295.9000
# [day 6/21] 2020-04-09 -> 2020-04-13
# [pick_one] cp=C, K=1900.0, dte=21, mid=889.7000, delta=0.9868, gamma=6.400000e-05, spread=10.8000, OI=2, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.4750, delta=-0.0089, gamma=5.200000e-05, spread=0.1500, OI=9903, vol=21
# [pick_one] cp=C, K=2525.0, dte=21, mid=295.9000, delta=0.8191, gamma=8.140000e-04, spread=1.8000, OI=3525, vol=3460
# [next fetch] cp=C, K=1900.0, dte=21, mid=861.7000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.2000
# [next fetch] cp=C, K=2525.0, dte=21, mid=271.8000
# [day 7/21] 2020-04-13 -> 2020-04-14
# [pick_one] cp=C, K=1900.0, dte=21, mid=861.7000, delta=0.9995, gamma=3.000000e-06, spread=12.6000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.2000, delta=-0.0078, gamma=4.900000e-05, spread=0.2000, OI=83, vol=0
# [pick_one] cp=C, K=2525.0, dte=21, mid=271.8000, delta=0.8054, gamma=8.950000e-04, spread=2.0000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=20, mid=941.4000
# [next fetch] cp=P, K=1900.0, dte=20, mid=0.8750
# [next fetch] cp=C, K=2525.0, dte=22, mid=338.5500
# [day 8/21] 2020-04-14 -> 2020-04-15
# [pick_one] cp=C, K=1900.0, dte=20, mid=941.4000, delta=0.9946, gamma=2.300000e-05, spread=12.4000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=20, mid=0.8750, delta=-0.0056, gamma=3.400000e-05, spread=0.1500, OI=83, vol=1
# [pick_one] cp=C, K=2525.0, dte=22, mid=338.5500, delta=0.8640, gamma=6.760000e-04, spread=1.7000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=883.4000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.5750
# [next fetch] cp=C, K=2525.0, dte=21, mid=288.8000
# [day 9/21] 2020-04-15 -> 2020-04-16
# [pick_one] cp=C, K=1900.0, dte=21, mid=883.4000, delta=0.9903, gamma=5.200000e-05, spread=10.6000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.5750, delta=-0.0094, gamma=5.400000e-05, spread=0.1500, OI=2, vol=0
# [pick_one] cp=C, K=2525.0, dte=21, mid=288.8000, delta=0.8212, gamma=8.360000e-04, spread=1.6000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=20, mid=901.0500
# [next fetch] cp=P, K=1900.0, dte=22, mid=1.6000
# [next fetch] cp=C, K=2525.0, dte=22, mid=305.1000
# [day 10/21] 2020-04-16 -> 2020-04-17
# [pick_one] cp=C, K=1900.0, dte=20, mid=901.0500, delta=0.9936, gamma=4.000000e-05, spread=3.3000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=22, mid=1.6000, delta=-0.0094, gamma=5.300000e-05, spread=0.2000, OI=1701, vol=0
# [pick_one] cp=C, K=2525.0, dte=22, mid=305.1000, delta=0.8286, gamma=7.860000e-04, spread=1.6000, OI=278, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=968.9000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.2000
# [next fetch] cp=C, K=2525.0, dte=21, mid=362.3000
# [day 11/21] 2020-04-17 -> 2020-04-20
# [pick_one] cp=C, K=1900.0, dte=21, mid=968.9000, delta=0.9911, gamma=3.600000e-05, spread=3.6000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.2000, delta=-0.0070, gamma=3.900000e-05, spread=0.2000, OI=1701, vol=194
# [pick_one] cp=C, K=2525.0, dte=21, mid=362.3000, delta=0.8810, gamma=6.070000e-04, spread=1.6000, OI=278, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=925.1500
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.8250
# [next fetch] cp=C, K=2525.0, dte=21, mid=328.2000
# [day 12/21] 2020-04-20 -> 2020-04-21
# [pick_one] cp=C, K=1900.0, dte=21, mid=925.1500, delta=0.9915, gamma=4.800000e-05, spread=11.3000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.8250, delta=-0.0101, gamma=5.400000e-05, spread=0.2500, OI=403, vol=0
# [pick_one] cp=C, K=2525.0, dte=21, mid=328.2000, delta=0.8420, gamma=7.210000e-04, spread=2.0000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=22, mid=840.9000
# [next fetch] cp=P, K=1900.0, dte=20, mid=2.0250
# [next fetch] cp=C, K=2525.0, dte=22, mid=260.8000
# [day 13/21] 2020-04-21 -> 2020-04-22
# [pick_one] cp=C, K=1900.0, dte=22, mid=840.9000, delta=0.9807, gamma=9.300000e-05, spread=9.6000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=20, mid=2.0250, delta=-0.0120, gamma=6.800000e-05, spread=0.2500, OI=403, vol=2
# [pick_one] cp=C, K=2525.0, dte=22, mid=260.8000, delta=0.7656, gamma=9.220000e-04, spread=2.0000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=897.5000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.7250
# [next fetch] cp=C, K=2525.0, dte=21, mid=301.3500
# [day 14/21] 2020-04-22 -> 2020-04-23
# [pick_one] cp=C, K=1900.0, dte=21, mid=897.5000, delta=0.9890, gamma=5.400000e-05, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.7250, delta=-0.0100, gamma=5.500000e-05, spread=0.2500, OI=179, vol=0
# [pick_one] cp=C, K=2525.0, dte=21, mid=301.3500, delta=0.8291, gamma=7.950000e-04, spread=1.7000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=22, mid=897.9500
# [next fetch] cp=P, K=1900.0, dte=22, mid=1.8500
# [next fetch] cp=C, K=2525.0, dte=22, mid=301.1000
# [day 15/21] 2020-04-23 -> 2020-04-24
# [pick_one] cp=C, K=1900.0, dte=22, mid=897.9500, delta=0.9912, gamma=4.800000e-05, spread=4.3000, OI=16, vol=0
# [pick_one] cp=P, K=1900.0, dte=22, mid=1.8500, delta=-0.0105, gamma=5.700000e-05, spread=0.1000, OI=12069, vol=56
# [pick_one] cp=C, K=2525.0, dte=22, mid=301.1000, delta=0.8327, gamma=7.950000e-04, spread=2.0000, OI=867, vol=79
# [next fetch] cp=C, K=1900.0, dte=21, mid=929.9000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.0250
# [next fetch] cp=C, K=2525.0, dte=21, mid=321.6500
# [day 16/21] 2020-04-24 -> 2020-04-27
# [pick_one] cp=C, K=1900.0, dte=21, mid=929.9000, delta=0.9949, gamma=1.900000e-05, spread=6.0000, OI=16, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.0250, delta=-0.0064, gamma=3.800000e-05, spread=0.1500, OI=12068, vol=69
# [pick_one] cp=C, K=2525.0, dte=21, mid=321.6500, delta=0.8805, gamma=6.910000e-04, spread=1.9000, OI=867, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=976.7000
# [next fetch] cp=P, K=1900.0, dte=21, mid=0.8250
# [next fetch] cp=C, K=2525.0, dte=21, mid=363.7000
# [day 17/21] 2020-04-27 -> 2020-04-28
# [pick_one] cp=C, K=1900.0, dte=21, mid=976.7000, delta=0.9932, gamma=3.300000e-05, spread=12.4000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=0.8250, delta=-0.0051, gamma=3.100000e-05, spread=0.1500, OI=144, vol=1
# [pick_one] cp=C, K=2525.0, dte=21, mid=363.7000, delta=0.9082, gamma=5.600000e-04, spread=12.6000, OI=1, vol=0
# [next fetch] cp=C, K=1900.0, dte=22, mid=961.0000
# [next fetch] cp=P, K=1900.0, dte=20, mid=0.9000
# [next fetch] cp=C, K=2525.0, dte=20, mid=348.0500
# [day 18/21] 2020-04-28 -> 2020-04-29
# [pick_one] cp=C, K=1900.0, dte=22, mid=961.0000, delta=0.9951, gamma=2.500000e-05, spread=13.2000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=20, mid=0.9000, delta=-0.0056, gamma=3.300000e-05, spread=0.2000, OI=144, vol=0
# [pick_one] cp=C, K=2525.0, dte=20, mid=348.0500, delta=0.9100, gamma=5.840000e-04, spread=10.3000, OI=1, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=1033.3500
# [next fetch] cp=P, K=1900.0, dte=21, mid=0.8500
# [next fetch] cp=C, K=2525.0, dte=21, mid=417.4500
# [day 19/21] 2020-04-29 -> 2020-04-30
# [pick_one] cp=C, K=1900.0, dte=21, mid=1033.3500, delta=0.9924, gamma=2.900000e-05, spread=3.3000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=0.8500, delta=-0.0050, gamma=2.800000e-05, spread=0.2000, OI=0, vol=0
# [pick_one] cp=C, K=2525.0, dte=21, mid=417.4500, delta=0.9280, gamma=4.320000e-04, spread=3.3000, OI=0, vol=1
# [next fetch] cp=C, K=1900.0, dte=22, mid=1012.2000
# [next fetch] cp=P, K=1900.0, dte=22, mid=1.0750
# [next fetch] cp=C, K=2525.0, dte=22, mid=400.3000
# [day 20/21] 2020-04-30 -> 2020-05-01
# [pick_one] cp=C, K=1900.0, dte=22, mid=1012.2000, delta=0.9965, gamma=2.100000e-05, spread=6.4000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=22, mid=1.0750, delta=-0.0061, gamma=3.400000e-05, spread=0.1500, OI=192, vol=2
# [pick_one] cp=C, K=2525.0, dte=22, mid=400.3000, delta=0.9121, gamma=4.980000e-04, spread=5.6000, OI=30, vol=0
# [next fetch] cp=C, K=1900.0, dte=21, mid=922.9000
# [next fetch] cp=P, K=1900.0, dte=21, mid=1.5750
# [next fetch] cp=C, K=2525.0, dte=21, mid=319.7500
# [day 21/21] 2020-05-01 -> 2020-05-04
# [pick_one] cp=C, K=1900.0, dte=21, mid=922.9000, delta=0.9897, gamma=4.100000e-05, spread=5.0000, OI=0, vol=0
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.5750, delta=-0.0090, gamma=5.000000e-05, spread=0.1500, OI=184, vol=79
# [pick_one] cp=C, K=2525.0, dte=21, mid=319.7500, delta=0.8571, gamma=7.240000e-04, spread=4.7000, OI=30, vol=0
# [next fetch] cp=C, K=1900.0, dte=22, mid=936.1000
# [next fetch] cp=P, K=1900.0, dte=22, mid=1.1750
# [next fetch] cp=C, K=2525.0, dte=22, mid=327.7000
# [pick_one] cp=C, K=1900.0, dte=21, mid=922.9000, delta=0.9897, gamma=4.100000e-05, spread=5.0000, OI=0, vol=0
# [next fetch] cp=C, K=1900.0, dte=22, mid=936.1000
# [pick_one] cp=P, K=1900.0, dte=21, mid=1.5750, delta=-0.0090, gamma=5.000000e-05, spread=0.1500, OI=184, vol=79
# [next fetch] cp=P, K=1900.0, dte=22, mid=1.1750
# [window done] m0=0.75, Z_T=-8.388350, V_T=937.275000, Π_T=945.663350
#
# --- Window 5/43 (start_idx=84) ---
# [get_window_dates] start=2020-05-04 end=2020-06-03 len=22
# [choose_strike_for_m0] spot0=2842.7400, m0=0.750, target=2132.0550 -> K=2130.0
# [nearest_atm_strike] spot0=2842.7400 -> K_ATM=2845.0
# [day 1/21] 2020-05-04 -> 2020-05-05
# [pick_one] cp=C, K=2130.0, dte=18, mid=707.4500, delta=0.9822, gamma=9.800000e-05, spread=3.1000, OI=0, vol=0
# [pick_one] cp=P, K=2130.0, dte=18, mid=2.2750, delta=-0.0156, gamma=1.010000e-04, spread=0.1500, OI=60, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=77.8000, delta=0.4944, gamma=1.920000e-03, spread=0.8000, OI=0, vol=0
# [next fetch] cp=C, K=2130.0, dte=24, mid=734.8000
# [next fetch] cp=P, K=2130.0, dte=24, mid=2.4500
# [next fetch] cp=C, K=2845.0, dte=21, mid=87.4000
# [init] V0=Π0=709.725000
# [day 2/21] 2020-05-05 -> 2020-05-06
# [pick_one] cp=C, K=2130.0, dte=24, mid=734.8000, delta=0.9816, gamma=9.900000e-05, spread=3.4000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=24, mid=2.4500, delta=-0.0160, gamma=9.800000e-05, spread=0.2000, OI=160, vol=42
# [pick_one] cp=C, K=2845.0, dte=21, mid=87.4000, delta=0.5496, gamma=2.010000e-03, spread=1.0000, OI=0, vol=0
# [next fetch] cp=C, K=2130.0, dte=23, mid=716.0500
# [next fetch] cp=P, K=2130.0, dte=23, mid=2.2250
# [next fetch] cp=C, K=2845.0, dte=21, mid=77.6500
# [day 3/21] 2020-05-06 -> 2020-05-07
# [pick_one] cp=C, K=2130.0, dte=23, mid=716.0500, delta=0.9824, gamma=1.000000e-04, spread=2.7000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=23, mid=2.2250, delta=-0.0152, gamma=9.800000e-05, spread=0.1500, OI=202, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=77.6500, delta=0.5119, gamma=2.036000e-03, spread=0.7000, OI=3, vol=0
# [next fetch] cp=C, K=2130.0, dte=22, mid=744.5000
# [next fetch] cp=P, K=2130.0, dte=22, mid=1.6500
# [next fetch] cp=C, K=2845.0, dte=22, mid=94.2500
# [day 4/21] 2020-05-07 -> 2020-05-08
# [pick_one] cp=C, K=2130.0, dte=22, mid=744.5000, delta=0.9862, gamma=7.400000e-05, spread=2.8000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=22, mid=1.6500, delta=-0.0117, gamma=7.800000e-05, spread=0.1000, OI=202, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=94.2500, delta=0.5681, gamma=1.952000e-03, spread=0.7000, OI=595, vol=0
# [next fetch] cp=C, K=2130.0, dte=21, mid=793.9000
# [next fetch] cp=P, K=2130.0, dte=21, mid=0.8750
# [next fetch] cp=C, K=2845.0, dte=21, mid=117.6500
# [day 5/21] 2020-05-08 -> 2020-05-11
# [pick_one] cp=C, K=2130.0, dte=21, mid=793.9000, delta=0.9901, gamma=5.200000e-05, spread=4.0000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=21, mid=0.8750, delta=-0.0067, gamma=4.900000e-05, spread=0.1500, OI=202, vol=2
# [pick_one] cp=C, K=2845.0, dte=21, mid=117.6500, delta=0.6767, gamma=1.948000e-03, spread=0.9000, OI=595, vol=2
# [next fetch] cp=C, K=2130.0, dte=18, mid=800.2000
# [next fetch] cp=P, K=2130.0, dte=18, mid=0.5250
# [next fetch] cp=C, K=2845.0, dte=21, mid=120.3500
# [day 6/21] 2020-05-11 -> 2020-05-12
# [pick_one] cp=C, K=2130.0, dte=18, mid=800.2000, delta=0.9982, gamma=1.600000e-05, spread=4.8000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=18, mid=0.5250, delta=-0.0044, gamma=3.500000e-05, spread=0.1500, OI=200, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=120.3500, delta=0.6962, gamma=1.964000e-03, spread=1.3000, OI=1, vol=0
# [next fetch] cp=C, K=2130.0, dte=17, mid=741.3500
# [next fetch] cp=P, K=2130.0, dte=17, mid=0.7750
# [next fetch] cp=C, K=2845.0, dte=20, mid=87.1500
# [day 7/21] 2020-05-12 -> 2020-05-13
# [pick_one] cp=C, K=2130.0, dte=17, mid=741.3500, delta=0.9915, gamma=6.300000e-05, spread=5.7000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=17, mid=0.7750, delta=-0.0065, gamma=5.200000e-05, spread=0.1500, OI=200, vol=0
# [pick_one] cp=C, K=2845.0, dte=20, mid=87.1500, delta=0.5673, gamma=2.117000e-03, spread=0.9000, OI=1, vol=0
# [next fetch] cp=C, K=2130.0, dte=16, mid=689.3500
# [next fetch] cp=P, K=2130.0, dte=16, mid=1.0000
# [next fetch] cp=C, K=2845.0, dte=21, mid=65.7500
# [day 8/21] 2020-05-13 -> 2020-05-14
# [pick_one] cp=C, K=2130.0, dte=16, mid=689.3500, delta=0.9926, gamma=5.800000e-05, spread=5.9000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=16, mid=1.0000, delta=-0.0085, gamma=6.800000e-05, spread=0.2000, OI=200, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=65.7500, delta=0.4602, gamma=2.033000e-03, spread=0.9000, OI=0, vol=1
# [next fetch] cp=C, K=2130.0, dte=15, mid=712.1500
# [next fetch] cp=P, K=2130.0, dte=15, mid=0.5250
# [next fetch] cp=C, K=2845.0, dte=22, mid=77.6000
# [day 9/21] 2020-05-14 -> 2020-05-15
# [pick_one] cp=C, K=2130.0, dte=15, mid=712.1500, delta=0.9932, gamma=3.000000e-05, spread=5.1000, OI=214, vol=0
# [pick_one] cp=P, K=2130.0, dte=15, mid=0.5250, delta=-0.0049, gamma=4.400000e-05, spread=0.1500, OI=200, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=77.6000, delta=0.5036, gamma=1.982000e-03, spread=0.8000, OI=63, vol=10
# [next fetch] cp=C, K=2130.0, dte=35, mid=730.2000
# [next fetch] cp=P, K=2130.0, dte=35, mid=4.5000
# [next fetch] cp=C, K=2845.0, dte=21, mid=83.5000
# [day 10/21] 2020-05-15 -> 2020-05-18
# [pick_one] cp=C, K=2130.0, dte=35, mid=730.2000, delta=0.9819, gamma=9.800000e-05, spread=9.6000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=35, mid=4.5000, delta=-0.0251, gamma=1.310000e-04, spread=0.2000, OI=106, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=83.5000, delta=0.5440, gamma=2.076000e-03, spread=1.0000, OI=73, vol=5
# [next fetch] cp=C, K=2130.0, dte=32, mid=821.7000
# [next fetch] cp=P, K=2130.0, dte=32, mid=2.6250
# [next fetch] cp=C, K=2845.0, dte=21, mid=140.5500
# [day 11/21] 2020-05-18 -> 2020-05-19
# [pick_one] cp=C, K=2130.0, dte=32, mid=821.7000, delta=0.9759, gamma=1.050000e-04, spread=13.6000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=32, mid=2.6250, delta=-0.0152, gamma=8.300000e-05, spread=0.1500, OI=118, vol=1
# [pick_one] cp=C, K=2845.0, dte=21, mid=140.5500, delta=0.7157, gamma=1.711000e-03, spread=0.9000, OI=5, vol=4
# [next fetch] cp=C, K=2130.0, dte=31, mid=795.8500
# [next fetch] cp=P, K=2130.0, dte=31, mid=2.9250
# [next fetch] cp=C, K=2845.0, dte=20, mid=120.9000
# [day 12/21] 2020-05-19 -> 2020-05-20
# [pick_one] cp=C, K=2130.0, dte=31, mid=795.8500, delta=0.9732, gamma=1.210000e-04, spread=12.3000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=31, mid=2.9250, delta=-0.0171, gamma=9.300000e-05, spread=0.1500, OI=117, vol=0
# [pick_one] cp=C, K=2845.0, dte=20, mid=120.9000, delta=0.6707, gamma=1.878000e-03, spread=1.0000, OI=3, vol=0
# [next fetch] cp=C, K=2130.0, dte=30, mid=838.6500
# [next fetch] cp=P, K=2130.0, dte=30, mid=1.7250
# [next fetch] cp=C, K=2845.0, dte=21, mid=155.0000
# [day 13/21] 2020-05-20 -> 2020-05-21
# [pick_one] cp=C, K=2130.0, dte=30, mid=838.6500, delta=0.9851, gamma=7.300000e-05, spread=15.3000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=30, mid=1.7250, delta=-0.0108, gamma=6.400000e-05, spread=0.1500, OI=117, vol=111
# [pick_one] cp=C, K=2845.0, dte=21, mid=155.0000, delta=0.7449, gamma=1.593000e-03, spread=1.0000, OI=0, vol=0
# [next fetch] cp=C, K=2130.0, dte=29, mid=814.8000
# [next fetch] cp=P, K=2130.0, dte=29, mid=1.8250
# [next fetch] cp=C, K=2845.0, dte=22, mid=140.6500
# [day 14/21] 2020-05-21 -> 2020-05-22
# [pick_one] cp=C, K=2130.0, dte=29, mid=814.8000, delta=0.9931, gamma=4.000000e-05, spread=15.0000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=29, mid=1.8250, delta=-0.0116, gamma=7.000000e-05, spread=0.1500, OI=212, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=140.6500, delta=0.6999, gamma=1.675000e-03, spread=0.9000, OI=71, vol=0
# [next fetch] cp=C, K=2130.0, dte=28, mid=820.3500
# [next fetch] cp=P, K=2130.0, dte=28, mid=1.5000
# [next fetch] cp=C, K=2845.0, dte=21, mid=141.0000
# [day 15/21] 2020-05-22 -> 2020-05-26
# [pick_one] cp=C, K=2130.0, dte=28, mid=820.3500, delta=0.9909, gamma=4.800000e-05, spread=11.5000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=28, mid=1.5000, delta=-0.0099, gamma=6.200000e-05, spread=0.1000, OI=212, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=141.0000, delta=0.7167, gamma=1.707000e-03, spread=1.0000, OI=71, vol=0
# [next fetch] cp=C, K=2130.0, dte=24, mid=854.8500
# [next fetch] cp=P, K=2130.0, dte=24, mid=1.2250
# [next fetch] cp=C, K=2845.0, dte=22, mid=170.7000
# [day 16/21] 2020-05-26 -> 2020-05-27
# [pick_one] cp=C, K=2130.0, dte=24, mid=854.8500, delta=0.9924, gamma=3.600000e-05, spread=10.9000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=24, mid=1.2250, delta=-0.0081, gamma=5.100000e-05, spread=0.1500, OI=212, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=170.7000, delta=0.7593, gamma=1.454000e-03, spread=0.8000, OI=0, vol=0
# [next fetch] cp=C, K=2130.0, dte=23, mid=901.9500
# [next fetch] cp=P, K=2130.0, dte=23, mid=0.9250
# [next fetch] cp=C, K=2845.0, dte=21, mid=208.4500
# [day 17/21] 2020-05-27 -> 2020-05-28
# [pick_one] cp=C, K=2130.0, dte=23, mid=901.9500, delta=0.9936, gamma=3.200000e-05, spread=4.1000, OI=39, vol=0
# [pick_one] cp=P, K=2130.0, dte=23, mid=0.9250, delta=-0.0062, gamma=4.000000e-05, spread=0.1500, OI=212, vol=1
# [pick_one] cp=C, K=2845.0, dte=21, mid=208.4500, delta=0.8196, gamma=1.196000e-03, spread=0.7000, OI=0, vol=3
# [next fetch] cp=C, K=2130.0, dte=22, mid=900.9000
# [next fetch] cp=P, K=2130.0, dte=22, mid=1.0250
# [next fetch] cp=C, K=2845.0, dte=22, mid=209.1500
# [day 18/21] 2020-05-28 -> 2020-05-29
# [pick_one] cp=C, K=2130.0, dte=22, mid=900.9000, delta=0.9842, gamma=7.500000e-05, spread=14.4000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=22, mid=1.0250, delta=-0.0068, gamma=4.200000e-05, spread=0.1500, OI=213, vol=0
# [pick_one] cp=C, K=2845.0, dte=22, mid=209.1500, delta=0.8038, gamma=1.196000e-03, spread=1.3000, OI=7028, vol=0
# [next fetch] cp=C, K=2130.0, dte=21, mid=915.5500
# [next fetch] cp=P, K=2130.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=2845.0, dte=21, mid=219.1500
# [day 19/21] 2020-05-29 -> 2020-06-01
# [pick_one] cp=C, K=2130.0, dte=21, mid=915.5500, delta=0.9913, gamma=5.000000e-05, spread=13.9000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=21, mid=0.8000, delta=-0.0055, gamma=3.600000e-05, spread=0.1000, OI=220, vol=0
# [pick_one] cp=C, K=2845.0, dte=21, mid=219.1500, delta=0.8353, gamma=1.129000e-03, spread=1.7000, OI=7028, vol=8
# [next fetch] cp=C, K=2130.0, dte=18, mid=924.5000
# [next fetch] cp=P, K=2130.0, dte=18, mid=0.6500
# [next fetch] cp=C, K=2845.0, dte=18, mid=225.8500
# [day 20/21] 2020-06-01 -> 2020-06-02
# [pick_one] cp=C, K=2130.0, dte=18, mid=924.5000, delta=0.9928, gamma=4.000000e-05, spread=13.6000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=18, mid=0.6500, delta=-0.0046, gamma=3.100000e-05, spread=0.1000, OI=213, vol=0
# [pick_one] cp=C, K=2845.0, dte=18, mid=225.8500, delta=0.8506, gamma=1.078000e-03, spread=1.1000, OI=7028, vol=0
# [next fetch] cp=C, K=2130.0, dte=17, mid=945.3500
# [next fetch] cp=P, K=2130.0, dte=17, mid=0.4500
# [next fetch] cp=C, K=2845.0, dte=24, mid=250.1000
# [day 21/21] 2020-06-02 -> 2020-06-03
# [pick_one] cp=C, K=2130.0, dte=17, mid=945.3500, delta=0.9965, gamma=1.400000e-05, spread=13.7000, OI=213, vol=0
# [pick_one] cp=P, K=2130.0, dte=17, mid=0.4500, delta=-0.0033, gamma=2.300000e-05, spread=0.1000, OI=213, vol=0
# [pick_one] cp=C, K=2845.0, dte=24, mid=250.1000, delta=0.8459, gamma=9.680000e-04, spread=0.6000, OI=25, vol=0
# [next fetch] cp=C, K=2130.0, dte=16, mid=988.5500
# [next fetch] cp=P, K=2130.0, dte=16, mid=0.3000
# [next fetch] cp=C, K=2845.0, dte=23, mid=286.0500
# [pick_one] cp=C, K=2130.0, dte=17, mid=945.3500, delta=0.9965, gamma=1.400000e-05, spread=13.7000, OI=213, vol=0
# [next fetch] cp=C, K=2130.0, dte=16, mid=988.5500
# [pick_one] cp=P, K=2130.0, dte=17, mid=0.4500, delta=-0.0033, gamma=2.300000e-05, spread=0.1000, OI=213, vol=0
# [next fetch] cp=P, K=2130.0, dte=16, mid=0.3000
# [window done] m0=0.75, Z_T=6.038158, V_T=988.850000, Π_T=982.811842
#
# --- Window 6/43 (start_idx=105) ---
# [get_window_dates] start=2020-06-03 end=2020-07-02 len=22
# [choose_strike_for_m0] spot0=3122.8700, m0=0.750, target=2342.1525 -> K=2340.0
# [nearest_atm_strike] spot0=3122.8700 -> K_ATM=3125.0
# [day 1/21] 2020-06-03 -> 2020-06-04
# [pick_one] cp=C, K=2340.0, dte=16, mid=778.5500, delta=0.9942, gamma=3.600000e-05, spread=5.5000, OI=4027, vol=0
# [pick_one] cp=P, K=2340.0, dte=16, mid=0.6000, delta=-0.0051, gamma=4.100000e-05, spread=0.1000, OI=4842, vol=2
# [pick_one] cp=C, K=3125.0, dte=21, mid=56.7500, delta=0.4899, gamma=2.634000e-03, spread=0.7000, OI=285, vol=7
# [next fetch] cp=C, K=2340.0, dte=26, mid=767.4500
# [next fetch] cp=P, K=2340.0, dte=26, mid=1.7250
# [next fetch] cp=C, K=3125.0, dte=22, mid=54.5000
# [init] V0=Π0=779.150000
# [day 2/21] 2020-06-04 -> 2020-06-05
# [pick_one] cp=C, K=2340.0, dte=26, mid=767.4500, delta=0.9852, gamma=8.000000e-05, spread=6.1000, OI=95, vol=0
# [pick_one] cp=P, K=2340.0, dte=26, mid=1.7250, delta=-0.0119, gamma=7.700000e-05, spread=0.1500, OI=234, vol=0
# [pick_one] cp=C, K=3125.0, dte=22, mid=54.5000, delta=0.4628, gamma=2.500000e-03, spread=0.6000, OI=2209, vol=1754
# [next fetch] cp=C, K=2340.0, dte=25, mid=848.5000
# [next fetch] cp=P, K=2340.0, dte=25, mid=1.1000
# [next fetch] cp=C, K=3125.0, dte=21, mid=102.3000
# [day 3/21] 2020-06-05 -> 2020-06-08
# [pick_one] cp=C, K=2340.0, dte=25, mid=848.5000, delta=0.9884, gamma=5.800000e-05, spread=6.2000, OI=95, vol=0
# [pick_one] cp=P, K=2340.0, dte=25, mid=1.1000, delta=-0.0077, gamma=5.000000e-05, spread=0.1000, OI=234, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=102.3000, delta=0.6569, gamma=2.188000e-03, spread=2.0000, OI=3400, vol=410
# [next fetch] cp=C, K=2340.0, dte=22, mid=887.8500
# [next fetch] cp=P, K=2340.0, dte=22, mid=0.9000
# [next fetch] cp=C, K=3125.0, dte=21, mid=136.2000
# [day 4/21] 2020-06-08 -> 2020-06-09
# [pick_one] cp=C, K=2340.0, dte=22, mid=887.8500, delta=0.9930, gamma=3.600000e-05, spread=6.3000, OI=95, vol=49
# [pick_one] cp=P, K=2340.0, dte=22, mid=0.9000, delta=-0.0063, gamma=4.100000e-05, spread=0.1000, OI=234, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=136.2000, delta=0.7186, gamma=1.782000e-03, spread=0.8000, OI=144, vol=11
# [next fetch] cp=C, K=2340.0, dte=21, mid=867.8000
# [next fetch] cp=P, K=2340.0, dte=21, mid=0.8750
# [next fetch] cp=C, K=3125.0, dte=21, mid=126.0500
# [day 5/21] 2020-06-09 -> 2020-06-10
# [pick_one] cp=C, K=2340.0, dte=21, mid=867.8000, delta=0.9966, gamma=2.700000e-05, spread=5.8000, OI=95, vol=0
# [pick_one] cp=P, K=2340.0, dte=21, mid=0.8750, delta=-0.0063, gamma=4.200000e-05, spread=0.1500, OI=234, vol=15
# [pick_one] cp=C, K=3125.0, dte=21, mid=126.0500, delta=0.6746, gamma=1.818000e-03, spread=0.7000, OI=7387, vol=3
# [next fetch] cp=C, K=2340.0, dte=20, mid=850.9000
# [next fetch] cp=P, K=2340.0, dte=20, mid=0.8000
# [next fetch] cp=C, K=3125.0, dte=21, mid=113.7500
# [day 6/21] 2020-06-10 -> 2020-06-11
# [pick_one] cp=C, K=2340.0, dte=20, mid=850.9000, delta=0.9935, gamma=4.400000e-05, spread=6.0000, OI=70, vol=0
# [pick_one] cp=P, K=2340.0, dte=20, mid=0.8000, delta=-0.0059, gamma=4.200000e-05, spread=0.1000, OI=234, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=113.7500, delta=0.6432, gamma=1.913000e-03, spread=0.9000, OI=3, vol=0
# [next fetch] cp=C, K=2340.0, dte=19, mid=672.8000
# [next fetch] cp=P, K=2340.0, dte=19, mid=7.2000
# [next fetch] cp=C, K=3125.0, dte=21, mid=42.2000
# [day 7/21] 2020-06-11 -> 2020-06-12
# [pick_one] cp=C, K=2340.0, dte=19, mid=672.8000, delta=0.9503, gamma=2.150000e-04, spread=5.6000, OI=70, vol=1
# [pick_one] cp=P, K=2340.0, dte=19, mid=7.2000, delta=-0.0385, gamma=1.890000e-04, spread=0.4000, OI=234, vol=30
# [pick_one] cp=C, K=3125.0, dte=21, mid=42.2000, delta=0.3076, gamma=1.579000e-03, spread=1.0000, OI=396, vol=204
# [next fetch] cp=C, K=2340.0, dte=18, mid=706.9500
# [next fetch] cp=P, K=2340.0, dte=18, mid=2.8500
# [next fetch] cp=C, K=3125.0, dte=20, mid=45.8500
# [day 8/21] 2020-06-12 -> 2020-06-15
# [pick_one] cp=C, K=2340.0, dte=18, mid=706.9500, delta=0.9697, gamma=1.550000e-04, spread=6.5000, OI=69, vol=0
# [pick_one] cp=P, K=2340.0, dte=18, mid=2.8500, delta=-0.0189, gamma=1.160000e-04, spread=0.2000, OI=204, vol=0
# [pick_one] cp=C, K=3125.0, dte=20, mid=45.8500, delta=0.3524, gamma=1.858000e-03, spread=1.3000, OI=570, vol=52
# [next fetch] cp=C, K=2340.0, dte=15, mid=721.6500
# [next fetch] cp=P, K=2340.0, dte=15, mid=1.7000
# [next fetch] cp=C, K=3125.0, dte=21, mid=51.5000
# [day 9/21] 2020-06-15 -> 2020-06-16
# [pick_one] cp=C, K=2340.0, dte=15, mid=721.6500, delta=0.9862, gamma=8.200000e-05, spread=6.7000, OI=69, vol=0
# [pick_one] cp=P, K=2340.0, dte=15, mid=1.7000, delta=-0.0125, gamma=8.600000e-05, spread=0.2000, OI=204, vol=10
# [pick_one] cp=C, K=3125.0, dte=21, mid=51.5000, delta=0.3838, gamma=1.918000e-03, spread=0.8000, OI=170, vol=208
# [next fetch] cp=C, K=2340.0, dte=31, mid=778.5000
# [next fetch] cp=P, K=2340.0, dte=31, mid=5.5500
# [next fetch] cp=C, K=3125.0, dte=20, mid=79.7500
# [day 10/21] 2020-06-16 -> 2020-06-17
# [pick_one] cp=C, K=2340.0, dte=31, mid=778.5000, delta=0.9806, gamma=9.400000e-05, spread=15.0000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=31, mid=5.5500, delta=-0.0280, gamma=1.310000e-04, spread=0.3000, OI=304, vol=147
# [pick_one] cp=C, K=3125.0, dte=20, mid=79.7500, delta=0.4979, gamma=1.900000e-03, spread=0.9000, OI=283, vol=31
# [next fetch] cp=C, K=2340.0, dte=30, mid=778.4000
# [next fetch] cp=P, K=2340.0, dte=30, mid=5.2000
# [next fetch] cp=C, K=3125.0, dte=21, mid=77.6500
# [day 11/21] 2020-06-17 -> 2020-06-18
# [pick_one] cp=C, K=2340.0, dte=30, mid=778.4000, delta=0.9731, gamma=1.290000e-04, spread=16.2000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=30, mid=5.2000, delta=-0.0269, gamma=1.290000e-04, spread=0.2000, OI=255, vol=84
# [pick_one] cp=C, K=3125.0, dte=21, mid=77.6500, delta=0.4919, gamma=1.917000e-03, spread=0.7000, OI=22, vol=0
# [next fetch] cp=C, K=2340.0, dte=29, mid=773.1000
# [next fetch] cp=P, K=2340.0, dte=29, mid=4.1000
# [next fetch] cp=C, K=3125.0, dte=22, mid=74.7500
# [day 12/21] 2020-06-18 -> 2020-06-19
# [pick_one] cp=C, K=2340.0, dte=29, mid=773.1000, delta=0.9780, gamma=1.090000e-04, spread=13.0000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=29, mid=4.1000, delta=-0.0227, gamma=1.170000e-04, spread=0.2000, OI=279, vol=0
# [pick_one] cp=C, K=3125.0, dte=22, mid=74.7500, delta=0.4839, gamma=1.941000e-03, spread=0.7000, OI=339, vol=38
# [next fetch] cp=C, K=2340.0, dte=28, mid=763.3500
# [next fetch] cp=P, K=2340.0, dte=28, mid=4.2000
# [next fetch] cp=C, K=3125.0, dte=21, mid=67.5000
# [day 13/21] 2020-06-19 -> 2020-06-22
# [pick_one] cp=C, K=2340.0, dte=28, mid=763.3500, delta=0.9723, gamma=1.350000e-04, spread=13.3000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=28, mid=4.2000, delta=-0.0234, gamma=1.220000e-04, spread=0.2000, OI=275, vol=1
# [pick_one] cp=C, K=3125.0, dte=21, mid=67.5000, delta=0.4595, gamma=1.981000e-03, spread=1.0000, OI=368, vol=4
# [next fetch] cp=C, K=2340.0, dte=25, mid=777.9000
# [next fetch] cp=P, K=2340.0, dte=25, mid=3.1000
# [next fetch] cp=C, K=3125.0, dte=21, mid=70.6000
# [day 14/21] 2020-06-22 -> 2020-06-23
# [pick_one] cp=C, K=2340.0, dte=25, mid=777.9000, delta=0.9789, gamma=1.070000e-04, spread=12.0000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=25, mid=3.1000, delta=-0.0184, gamma=1.020000e-04, spread=0.2000, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=70.6000, delta=0.4909, gamma=2.109000e-03, spread=0.6000, OI=111, vol=13
# [next fetch] cp=C, K=2340.0, dte=24, mid=794.0500
# [next fetch] cp=P, K=2340.0, dte=24, mid=2.5750
# [next fetch] cp=C, K=3125.0, dte=22, mid=81.1500
# [day 15/21] 2020-06-23 -> 2020-06-24
# [pick_one] cp=C, K=2340.0, dte=24, mid=794.0500, delta=0.9788, gamma=1.080000e-04, spread=15.3000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=24, mid=2.5750, delta=-0.0157, gamma=9.000000e-05, spread=0.1500, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=22, mid=81.1500, delta=0.5232, gamma=2.022000e-03, spread=1.1000, OI=780, vol=52
# [next fetch] cp=C, K=2340.0, dte=23, mid=712.6000
# [next fetch] cp=P, K=2340.0, dte=23, mid=3.4500
# [next fetch] cp=C, K=3125.0, dte=21, mid=45.7500
# [day 16/21] 2020-06-24 -> 2020-06-25
# [pick_one] cp=C, K=2340.0, dte=23, mid=712.6000, delta=0.9735, gamma=1.390000e-04, spread=17.4000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=23, mid=3.4500, delta=-0.0215, gamma=1.250000e-04, spread=0.3000, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=45.7500, delta=0.3597, gamma=1.932000e-03, spread=4.9000, OI=832, vol=0
# [next fetch] cp=C, K=2340.0, dte=22, mid=741.2000
# [next fetch] cp=P, K=2340.0, dte=22, mid=2.6250
# [next fetch] cp=C, K=3125.0, dte=22, mid=53.4000
# [day 17/21] 2020-06-25 -> 2020-06-26
# [pick_one] cp=C, K=2340.0, dte=22, mid=741.2000, delta=0.9827, gamma=9.700000e-05, spread=17.8000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=22, mid=2.6250, delta=-0.0169, gamma=1.020000e-04, spread=0.1500, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=22, mid=53.4000, delta=0.4131, gamma=2.104000e-03, spread=0.8000, OI=5749, vol=104
# [next fetch] cp=C, K=2340.0, dte=21, mid=669.5000
# [next fetch] cp=P, K=2340.0, dte=21, mid=3.7000
# [next fetch] cp=C, K=3125.0, dte=21, mid=27.7500
# [day 18/21] 2020-06-26 -> 2020-06-29
# [pick_one] cp=C, K=2340.0, dte=21, mid=669.5000, delta=0.9855, gamma=1.010000e-04, spread=14.2000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=21, mid=3.7000, delta=-0.0238, gamma=1.420000e-04, spread=0.2000, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=27.7500, delta=0.2664, gamma=1.864000e-03, spread=1.7000, OI=5730, vol=2541
# [next fetch] cp=C, K=2340.0, dte=18, mid=707.2000
# [next fetch] cp=P, K=2340.0, dte=18, mid=2.1750
# [next fetch] cp=C, K=3125.0, dte=21, mid=34.7000
# [day 19/21] 2020-06-29 -> 2020-06-30
# [pick_one] cp=C, K=2340.0, dte=18, mid=707.2000, delta=0.9846, gamma=8.900000e-05, spread=3.8000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=18, mid=2.1750, delta=-0.0153, gamma=1.000000e-04, spread=0.1500, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=34.7000, delta=0.3274, gamma=2.168000e-03, spread=0.6000, OI=223, vol=14
# [next fetch] cp=C, K=2340.0, dte=17, mid=759.1500
# [next fetch] cp=P, K=2340.0, dte=17, mid=1.7250
# [next fetch] cp=C, K=3125.0, dte=20, mid=52.7500
# [day 20/21] 2020-06-30 -> 2020-07-01
# [pick_one] cp=C, K=2340.0, dte=17, mid=759.1500, delta=0.9883, gamma=7.300000e-05, spread=4.7000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=17, mid=1.7250, delta=-0.0121, gamma=7.900000e-05, spread=0.1500, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=20, mid=52.7500, delta=0.4439, gamma=2.411000e-03, spread=0.9000, OI=233, vol=18
# [next fetch] cp=C, K=2340.0, dte=16, mid=775.0000
# [next fetch] cp=P, K=2340.0, dte=16, mid=1.2250
# [next fetch] cp=C, K=3125.0, dte=21, mid=59.4000
# [day 21/21] 2020-07-01 -> 2020-07-02
# [pick_one] cp=C, K=2340.0, dte=16, mid=775.0000, delta=0.9856, gamma=8.300000e-05, spread=15.2000, OI=4, vol=0
# [pick_one] cp=P, K=2340.0, dte=16, mid=1.2250, delta=-0.0091, gamma=6.300000e-05, spread=0.1500, OI=275, vol=0
# [pick_one] cp=C, K=3125.0, dte=21, mid=59.4000, delta=0.4803, gamma=2.434000e-03, spread=1.0000, OI=40, vol=0
# [next fetch] cp=C, K=2340.0, dte=15, mid=786.6000
# [next fetch] cp=P, K=2340.0, dte=15, mid=1.1000
# [next fetch] cp=C, K=3125.0, dte=22, mid=67.7500
# [pick_one] cp=C, K=2340.0, dte=16, mid=775.0000, delta=0.9856, gamma=8.300000e-05, spread=15.2000, OI=4, vol=0
# [next fetch] cp=C, K=2340.0, dte=15, mid=786.6000
# [pick_one] cp=P, K=2340.0, dte=16, mid=1.2250, delta=-0.0091, gamma=6.300000e-05, spread=0.1500, OI=275, vol=0
# [next fetch] cp=P, K=2340.0, dte=15, mid=1.1000
# [window done] m0=0.75, Z_T=6.831138, V_T=787.700000, Π_T=780.868862
#
# --- Window 7/43 (start_idx=126) ---
# [get_window_dates] start=2020-07-02 end=2020-08-03 len=22
# [choose_strike_for_m0] spot0=3130.0100, m0=0.750, target=2347.5075 -> K=2350.0
# [nearest_atm_strike] spot0=3130.0100 -> K_ATM=3130.0
# [day 1/21] 2020-07-02 -> 2020-07-06
# [pick_one] cp=C, K=2350.0, dte=22, mid=777.1500, delta=0.9864, gamma=7.700000e-05, spread=6.7000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=2.0250, delta=-0.0133, gamma=8.200000e-05, spread=0.1500, OI=916, vol=1
# [pick_one] cp=C, K=3130.0, dte=22, mid=64.7500, delta=0.4991, gamma=2.370000e-03, spread=0.7000, OI=197, vol=53
# [next fetch] cp=C, K=2350.0, dte=21, mid=826.6500
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.2250
# [next fetch] cp=C, K=3130.0, dte=21, mid=94.7500
# [init] V0=Π0=779.175000
# [day 2/21] 2020-07-06 -> 2020-07-07
# [pick_one] cp=C, K=2350.0, dte=21, mid=826.6500, delta=0.9900, gamma=5.700000e-05, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.2250, delta=-0.0085, gamma=5.600000e-05, spread=0.1500, OI=235, vol=4
# [pick_one] cp=C, K=3130.0, dte=21, mid=94.7500, delta=0.6125, gamma=2.170000e-03, spread=1.3000, OI=19, vol=17
# [next fetch] cp=C, K=2350.0, dte=22, mid=794.8500
# [next fetch] cp=P, K=2350.0, dte=20, mid=1.3500
# [next fetch] cp=C, K=3130.0, dte=22, mid=81.7000
# [day 3/21] 2020-07-07 -> 2020-07-08
# [pick_one] cp=C, K=2350.0, dte=22, mid=794.8500, delta=0.9889, gamma=6.800000e-05, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=20, mid=1.3500, delta=-0.0096, gamma=6.400000e-05, spread=0.1000, OI=239, vol=0
# [pick_one] cp=C, K=3130.0, dte=22, mid=81.7000, delta=0.5400, gamma=2.109000e-03, spread=0.6000, OI=96, vol=0
# [next fetch] cp=C, K=2350.0, dte=21, mid=817.7000
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.2750
# [next fetch] cp=C, K=3130.0, dte=21, mid=91.7500
# [day 4/21] 2020-07-08 -> 2020-07-09
# [pick_one] cp=C, K=2350.0, dte=21, mid=817.7000, delta=0.9974, gamma=1.700000e-05, spread=15.0000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.2750, delta=-0.0089, gamma=5.900000e-05, spread=0.1500, OI=199, vol=3
# [pick_one] cp=C, K=3130.0, dte=21, mid=91.7500, delta=0.5938, gamma=2.150000e-03, spread=0.7000, OI=96, vol=0
# [next fetch] cp=C, K=2350.0, dte=22, mid=801.2000
# [next fetch] cp=P, K=2350.0, dte=22, mid=1.6250
# [next fetch] cp=C, K=3130.0, dte=22, mid=86.9500
# [day 5/21] 2020-07-09 -> 2020-07-10
# [pick_one] cp=C, K=2350.0, dte=22, mid=801.2000, delta=0.9890, gamma=6.600000e-05, spread=6.2000, OI=4, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=1.6250, delta=-0.0110, gamma=7.000000e-05, spread=0.1500, OI=12717, vol=18
# [pick_one] cp=C, K=3130.0, dte=22, mid=86.9500, delta=0.5527, gamma=2.048000e-03, spread=0.7000, OI=820, vol=12
# [next fetch] cp=C, K=2350.0, dte=21, mid=835.7000
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.1000
# [next fetch] cp=C, K=3130.0, dte=21, mid=104.2500
# [day 6/21] 2020-07-10 -> 2020-07-13
# [pick_one] cp=C, K=2350.0, dte=21, mid=835.7000, delta=0.9947, gamma=3.900000e-05, spread=4.0000, OI=4, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.1000, delta=-0.0078, gamma=5.200000e-05, spread=0.1000, OI=12693, vol=18
# [pick_one] cp=C, K=3130.0, dte=21, mid=104.2500, delta=0.6287, gamma=2.035000e-03, spread=0.5000, OI=827, vol=80
# [next fetch] cp=C, K=2350.0, dte=21, mid=806.7500
# [next fetch] cp=P, K=2350.0, dte=21, mid=2.2500
# [next fetch] cp=C, K=3130.0, dte=21, mid=94.2500
# [day 7/21] 2020-07-13 -> 2020-07-14
# [pick_one] cp=C, K=2350.0, dte=21, mid=806.7500, delta=0.9907, gamma=6.200000e-05, spread=15.3000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=2.2500, delta=-0.0140, gamma=8.200000e-05, spread=0.2000, OI=270, vol=0
# [pick_one] cp=C, K=3130.0, dte=21, mid=94.2500, delta=0.5628, gamma=1.936000e-03, spread=1.9000, OI=26, vol=2
# [next fetch] cp=C, K=2350.0, dte=22, mid=848.1500
# [next fetch] cp=P, K=2350.0, dte=20, mid=1.4750
# [next fetch] cp=C, K=3130.0, dte=20, mid=115.8500
# [day 8/21] 2020-07-14 -> 2020-07-15
# [pick_one] cp=C, K=2350.0, dte=22, mid=848.1500, delta=0.9965, gamma=2.800000e-05, spread=14.9000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=20, mid=1.4750, delta=-0.0097, gamma=6.000000e-05, spread=0.0500, OI=270, vol=0
# [pick_one] cp=C, K=3130.0, dte=20, mid=115.8500, delta=0.6482, gamma=1.895000e-03, spread=0.7000, OI=27, vol=55
# [next fetch] cp=C, K=2350.0, dte=21, mid=875.8000
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.2750
# [next fetch] cp=C, K=3130.0, dte=21, mid=135.7500
# [day 9/21] 2020-07-15 -> 2020-07-16
# [pick_one] cp=C, K=2350.0, dte=21, mid=875.8000, delta=0.9920, gamma=4.700000e-05, spread=17.2000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.2750, delta=-0.0084, gamma=5.200000e-05, spread=0.1500, OI=270, vol=90
# [pick_one] cp=C, K=3130.0, dte=21, mid=135.7500, delta=0.6934, gamma=1.732000e-03, spread=0.9000, OI=6, vol=4
# [next fetch] cp=C, K=2350.0, dte=22, mid=864.0000
# [next fetch] cp=P, K=2350.0, dte=22, mid=1.5500
# [next fetch] cp=C, K=3130.0, dte=22, mid=128.2000
# [day 10/21] 2020-07-16 -> 2020-07-17
# [pick_one] cp=C, K=2350.0, dte=22, mid=864.0000, delta=0.9915, gamma=4.900000e-05, spread=4.2000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=1.5500, delta=-0.0099, gamma=5.900000e-05, spread=0.1000, OI=742, vol=90
# [pick_one] cp=C, K=3130.0, dte=22, mid=128.2000, delta=0.6714, gamma=1.775000e-03, spread=0.6000, OI=22, vol=194
# [next fetch] cp=C, K=2350.0, dte=21, mid=875.0000
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.2000
# [next fetch] cp=C, K=3130.0, dte=21, mid=129.8000
# [day 11/21] 2020-07-17 -> 2020-07-20
# [pick_one] cp=C, K=2350.0, dte=21, mid=875.0000, delta=0.9917, gamma=5.000000e-05, spread=4.0000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.2000, delta=-0.0080, gamma=5.000000e-05, spread=0.1000, OI=742, vol=0
# [pick_one] cp=C, K=3130.0, dte=21, mid=129.8000, delta=0.7045, gamma=1.844000e-03, spread=1.8000, OI=214, vol=9
# [next fetch] cp=C, K=2350.0, dte=23, mid=904.3500
# [next fetch] cp=P, K=2350.0, dte=23, mid=1.0750
# [next fetch] cp=C, K=3130.0, dte=21, mid=150.5500
# [day 12/21] 2020-07-20 -> 2020-07-21
# [pick_one] cp=C, K=2350.0, dte=23, mid=904.3500, delta=0.9873, gamma=6.700000e-05, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=23, mid=1.0750, delta=-0.0071, gamma=4.500000e-05, spread=0.1500, OI=240, vol=0
# [pick_one] cp=C, K=3130.0, dte=21, mid=150.5500, delta=0.7540, gamma=1.666000e-03, spread=0.9000, OI=9, vol=4
# [next fetch] cp=C, K=2350.0, dte=22, mid=902.7500
# [next fetch] cp=P, K=2350.0, dte=22, mid=1.0750
# [next fetch] cp=C, K=3130.0, dte=20, mid=150.8000
# [day 13/21] 2020-07-21 -> 2020-07-22
# [pick_one] cp=C, K=2350.0, dte=22, mid=902.7500, delta=0.9950, gamma=2.600000e-05, spread=15.7000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=1.0750, delta=-0.0071, gamma=4.400000e-05, spread=0.1500, OI=240, vol=0
# [pick_one] cp=C, K=3130.0, dte=20, mid=150.8000, delta=0.7551, gamma=1.661000e-03, spread=0.8000, OI=13, vol=0
# [next fetch] cp=C, K=2350.0, dte=21, mid=925.2500
# [next fetch] cp=P, K=2350.0, dte=21, mid=0.9500
# [next fetch] cp=C, K=3130.0, dte=21, mid=168.1000
# [day 14/21] 2020-07-22 -> 2020-07-23
# [pick_one] cp=C, K=2350.0, dte=21, mid=925.2500, delta=0.9925, gamma=4.200000e-05, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=0.9500, delta=-0.0063, gamma=4.000000e-05, spread=0.1000, OI=240, vol=91
# [pick_one] cp=C, K=3130.0, dte=21, mid=168.1000, delta=0.7870, gamma=1.510000e-03, spread=0.6000, OI=0, vol=11
# [next fetch] cp=C, K=2350.0, dte=20, mid=883.0000
# [next fetch] cp=P, K=2350.0, dte=22, mid=1.4500
# [next fetch] cp=C, K=3130.0, dte=22, mid=139.3000
# [day 15/21] 2020-07-23 -> 2020-07-24
# [pick_one] cp=C, K=2350.0, dte=20, mid=883.0000, delta=0.9921, gamma=4.400000e-05, spread=3.0000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=22, mid=1.4500, delta=-0.0092, gamma=5.500000e-05, spread=0.1000, OI=2662, vol=0
# [pick_one] cp=C, K=3130.0, dte=22, mid=139.3000, delta=0.7055, gamma=1.713000e-03, spread=0.8000, OI=365, vol=0
# [next fetch] cp=C, K=2350.0, dte=21, mid=862.4500
# [next fetch] cp=P, K=2350.0, dte=21, mid=1.1000
# [next fetch] cp=C, K=3130.0, dte=21, mid=121.1000
# [day 16/21] 2020-07-24 -> 2020-07-27
# [pick_one] cp=C, K=2350.0, dte=21, mid=862.4500, delta=0.9933, gamma=3.800000e-05, spread=3.1000, OI=0, vol=0
# [pick_one] cp=P, K=2350.0, dte=21, mid=1.1000, delta=-0.0075, gamma=4.900000e-05, spread=0.1000, OI=2662, vol=313
# [pick_one] cp=C, K=3130.0, dte=21, mid=121.1000, delta=0.6820, gamma=1.916000e-03, spread=0.8000, OI=365, vol=2
# [next fetch] cp=C, K=2350.0, dte=23, mid=886.0000
# [next fetch] cp=P, K=2350.0, dte=23, mid=1.0250
# ...
# [get_window_dates] start=2021-12-31 end=2022-02-01 len=22
# [choose_strike_for_m0] spot0=4766.1800, m0=1.250, target=5957.7250 -> K=5225.0
# [nearest_atm_strike] spot0=4766.1800 -> K_ATM=4765.0
# [day 1/21] 2021-12-31 -> 2022-01-03
# [pick_one] cp=C, K=5225.0, dte=35, mid=0.4750, delta=0.0080, gamma=1.220000e-04, spread=0.1500, OI=1, vol=0
# [pick_one] MISSING leg for cp=P, K=5225.0
# [pick_one] cp=C, K=4765.0, dte=21, mid=57.2000, delta=0.5133, gamma=2.845000e-03, spread=0.8000, OI=825, vol=31
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=504.
#
# --- Window 26/43 (start_idx=525) ---
# [get_window_dates] start=2022-02-01 end=2022-03-03 len=22
# [choose_strike_for_m0] spot0=4546.5400, m0=1.250, target=5683.1750 -> K=5700.0
# [nearest_atm_strike] spot0=4546.5400 -> K_ATM=4545.0
# [day 1/21] 2022-02-01 -> 2022-02-02
# [pick_one] MISSING leg for cp=C, K=5700.0
# [pick_one] cp=P, K=5700.0, dte=17, mid=1156.7500, delta=-0.9943, gamma=3.600000e-05, spread=9.5000, OI=1, vol=0
# [pick_one] cp=C, K=4545.0, dte=21, mid=75.0500, delta=0.5047, gamma=2.096000e-03, spread=0.7000, OI=0, vol=11
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=525.
#
# --- Window 27/43 (start_idx=546) ---
# [get_window_dates] start=2022-03-03 end=2022-04-01 len=22
# [choose_strike_for_m0] spot0=4363.4900, m0=1.250, target=5454.3625 -> K=5300.0
# [nearest_atm_strike] spot0=4363.4900 -> K_ATM=4365.0
# [day 1/21] 2022-03-03 -> 2022-03-04
# [pick_one] MISSING leg for cp=C, K=5300.0
# [pick_one] cp=P, K=5300.0, dte=15, mid=945.1000, delta=-0.9975, gamma=4.000000e-06, spread=7.0000, OI=13, vol=0
# [pick_one] cp=C, K=4365.0, dte=22, mid=108.6500, delta=0.4968, gamma=1.391000e-03, spread=0.7000, OI=159, vol=151
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=546.
#
# --- Window 28/43 (start_idx=567) ---
# [get_window_dates] start=2022-04-01 end=2022-05-03 len=22
# [choose_strike_for_m0] spot0=4545.8600, m0=1.250, target=5682.3250 -> K=5700.0
# [nearest_atm_strike] spot0=4545.8600 -> K_ATM=4545.0
# [day 1/21] 2022-04-01 -> 2022-04-04
# [pick_one] MISSING leg for cp=C, K=5700.0
# [pick_one] cp=P, K=5700.0, dte=28, mid=1154.2500, delta=-0.9965, gamma=2.600000e-05, spread=8.1000, OI=2, vol=0
# [pick_one] cp=C, K=4545.0, dte=21, mid=65.3000, delta=0.5092, gamma=2.452000e-03, spread=0.6000, OI=189, vol=230
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=567.
#
# --- Window 29/43 (start_idx=588) ---
# [get_window_dates] start=2022-05-03 end=2022-06-02 len=22
# [choose_strike_for_m0] spot0=4175.4800, m0=1.250, target=5219.3500 -> K=5160.0
# [nearest_atm_strike] spot0=4175.4800 -> K_ATM=4175.0
# [day 1/21] 2022-05-03 -> 2022-05-04
# [pick_one] MISSING leg for cp=C, K=5160.0
# [pick_one] cp=P, K=5160.0, dte=17, mid=987.0500, delta=-0.9987, gamma=6.000000e-06, spread=8.7000, OI=0, vol=0
# [pick_one] cp=C, K=4175.0, dte=20, mid=101.2000, delta=0.5076, gamma=1.549000e-03, spread=0.6000, OI=18, vol=4
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=588.
#
# --- Window 30/43 (start_idx=609) ---
# [get_window_dates] start=2022-06-02 end=2022-07-05 len=22
# [choose_strike_for_m0] spot0=4176.8200, m0=1.250, target=5221.0250 -> K=5075.0
# [nearest_atm_strike] spot0=4176.8200 -> K_ATM=4175.0
# [day 1/21] 2022-06-02 -> 2022-06-03
# [pick_one] MISSING leg for cp=C, K=5075.0
# [pick_one] cp=P, K=5075.0, dte=15, mid=899.4500, delta=-0.9992, gamma=2.000000e-06, spread=7.1000, OI=5, vol=0
# [pick_one] cp=C, K=4175.0, dte=22, mid=91.6000, delta=0.5114, gamma=1.738000e-03, spread=0.6000, OI=259, vol=187
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=609.
#
# --- Window 31/43 (start_idx=630) ---
# [get_window_dates] start=2022-07-05 end=2022-08-03 len=22
# [choose_strike_for_m0] spot0=3831.3900, m0=1.250, target=4789.2375 -> K=4500.0
# [nearest_atm_strike] spot0=3831.3900 -> K_ATM=3830.0
# [day 1/21] 2022-07-05 -> 2022-07-06
# [pick_one] MISSING leg for cp=C, K=4500.0
# [pick_one] cp=P, K=4500.0, dte=31, mid=669.6000, delta=-0.9969, gamma=2.200000e-05, spread=12.8000, OI=0, vol=0
# [pick_one] cp=C, K=3830.0, dte=20, mid=88.4000, delta=0.5093, gamma=1.786000e-03, spread=0.6000, OI=22, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=630.
#
# --- Window 32/43 (start_idx=651) ---
# [get_window_dates] start=2022-08-03 end=2022-09-01 len=22
# [choose_strike_for_m0] spot0=4155.1700, m0=1.250, target=5193.9625 -> K=5200.0
# [nearest_atm_strike] spot0=4155.1700 -> K_ATM=4155.0
# [day 1/21] 2022-08-03 -> 2022-08-04
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=19, mid=1042.9000, delta=-0.9976, gamma=1.600000e-05, spread=6.8000, OI=0, vol=0
# [pick_one] cp=C, K=4155.0, dte=21, mid=74.0500, delta=0.5114, gamma=2.164000e-03, spread=0.5000, OI=0, vol=32
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=651.
#
# --- Window 33/43 (start_idx=672) ---
# [get_window_dates] start=2022-09-01 end=2022-10-03 len=22
# [choose_strike_for_m0] spot0=3966.8500, m0=1.250, target=4958.5625 -> K=4960.0
# [nearest_atm_strike] spot0=3966.8500 -> K_ATM=3965.0
# [day 1/21] 2022-09-01 -> 2022-09-02
# [pick_one] MISSING leg for cp=C, K=4960.0
# [pick_one] cp=P, K=4960.0, dte=29, mid=990.1000, delta=-0.9928, gamma=4.600000e-05, spread=6.6000, OI=2, vol=0
# [pick_one] cp=C, K=3965.0, dte=20, mid=85.1500, delta=0.5135, gamma=1.883000e-03, spread=0.5000, OI=22, vol=49
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=672.
#
# --- Window 34/43 (start_idx=693) ---
# [get_window_dates] start=2022-10-03 end=2022-11-01 len=22
# [choose_strike_for_m0] spot0=3678.4300, m0=1.250, target=4598.0375 -> K=4600.0
# [nearest_atm_strike] spot0=3678.4300 -> K_ATM=3680.0
# [day 1/21] 2022-10-03 -> 2022-10-04
# [pick_one] MISSING leg for cp=C, K=4600.0
# [pick_one] cp=P, K=4600.0, dte=21, mid=918.4000, delta=-0.9932, gamma=5.100000e-05, spread=8.4000, OI=0, vol=0
# [pick_one] cp=C, K=3680.0, dte=21, mid=94.0500, delta=0.5132, gamma=1.693000e-03, spread=0.5000, OI=5, vol=3
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=693.
#
# --- Window 35/43 (start_idx=714) ---
# [get_window_dates] start=2022-11-01 end=2022-12-01 len=22
# [choose_strike_for_m0] spot0=3856.1000, m0=1.250, target=4820.1250 -> K=4800.0
# [nearest_atm_strike] spot0=3856.1000 -> K_ATM=3855.0
# [day 1/21] 2022-11-01 -> 2022-11-02
# [pick_one] MISSING leg for cp=C, K=4800.0
# [pick_one] cp=P, K=4800.0, dte=20, mid=937.4000, delta=-0.9982, gamma=1.600000e-05, spread=5.8000, OI=0, vol=0
# [pick_one] cp=C, K=3855.0, dte=21, mid=97.6500, delta=0.5232, gamma=1.682000e-03, spread=0.5000, OI=5, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=714.
#
# --- Window 36/43 (start_idx=735) ---
# [get_window_dates] start=2022-12-01 end=2023-01-03 len=22
# [choose_strike_for_m0] spot0=4076.5700, m0=1.250, target=5095.7125 -> K=5000.0
# [nearest_atm_strike] spot0=4076.5700 -> K_ATM=4075.0
# [day 1/21] 2022-12-01 -> 2022-12-02
# [pick_one] MISSING leg for cp=C, K=5000.0
# [pick_one] cp=P, K=5000.0, dte=21, mid=912.7500, delta=-0.9992, gamma=1.100000e-05, spread=12.7000, OI=0, vol=0
# [pick_one] cp=C, K=4075.0, dte=21, mid=81.3000, delta=0.5309, gamma=2.084000e-03, spread=0.6000, OI=46, vol=6
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=735.
#
# --- Window 37/43 (start_idx=756) ---
# [get_window_dates] start=2023-01-03 end=2023-02-02 len=22
# [choose_strike_for_m0] spot0=3824.1400, m0=1.250, target=4780.1750 -> K=4800.0
# [nearest_atm_strike] spot0=3824.1400 -> K_ATM=3825.0
# [day 1/21] 2023-01-03 -> 2023-01-04
# [pick_one] MISSING leg for cp=C, K=4800.0
# [pick_one] cp=P, K=4800.0, dte=21, mid=965.2500, delta=-0.9993, gamma=8.000000e-06, spread=6.5000, OI=0, vol=0
# [pick_one] cp=C, K=3825.0, dte=21, mid=80.4500, delta=0.5255, gamma=2.070000e-03, spread=0.5000, OI=19, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=756.
#
# --- Window 38/43 (start_idx=777) ---
# [get_window_dates] start=2023-02-02 end=2023-03-06 len=22
# [choose_strike_for_m0] spot0=4179.7600, m0=1.250, target=5224.7000 -> K=5225.0
# [nearest_atm_strike] spot0=4179.7600 -> K_ATM=4180.0
# [day 1/21] 2023-02-02 -> 2023-02-03
# [pick_one] MISSING leg for cp=C, K=5225.0
# [pick_one] cp=P, K=5225.0, dte=15, mid=1043.1500, delta=-0.9811, gamma=1.030000e-04, spread=13.7000, OI=4, vol=0
# [pick_one] cp=C, K=4180.0, dte=21, mid=65.7500, delta=0.5199, gamma=2.510000e-03, spread=0.7000, OI=0, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=777.
#
# --- Window 39/43 (start_idx=798) ---
# [get_window_dates] start=2023-03-06 end=2023-04-04 len=22
# [choose_strike_for_m0] spot0=4048.4200, m0=1.250, target=5060.5250 -> K=5025.0
# [nearest_atm_strike] spot0=4048.4200 -> K_ATM=4050.0
# [day 1/21] 2023-03-06 -> 2023-03-07
# [pick_one] MISSING leg for cp=C, K=5025.0
# [pick_one] cp=P, K=5025.0, dte=25, mid=963.0000, delta=-0.9985, gamma=1.500000e-05, spread=6.0000, OI=3, vol=0
# [pick_one] cp=C, K=4050.0, dte=21, mid=72.9500, delta=0.5248, gamma=2.288000e-03, spread=0.5000, OI=26, vol=3
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=798.
#
# --- Window 40/43 (start_idx=819) ---
# [get_window_dates] start=2023-04-04 end=2023-05-04 len=22
# [choose_strike_for_m0] spot0=4100.6000, m0=1.250, target=5125.7500 -> K=5150.0
# [nearest_atm_strike] spot0=4100.6000 -> K_ATM=4100.0
# [day 1/21] 2023-04-04 -> 2023-04-05
# [pick_one] MISSING leg for cp=C, K=5150.0
# [pick_one] cp=P, K=5150.0, dte=17, mid=1041.2500, delta=-0.9963, gamma=3.000000e-05, spread=9.3000, OI=2, vol=0
# [pick_one] cp=C, K=4100.0, dte=21, mid=63.4000, delta=0.5307, gamma=2.688000e-03, spread=0.4000, OI=17, vol=4
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=819.
#
# --- Window 41/43 (start_idx=840) ---
# [get_window_dates] start=2023-05-04 end=2023-06-05 len=22
# [choose_strike_for_m0] spot0=4061.2200, m0=1.250, target=5076.5250 -> K=5075.0
# [nearest_atm_strike] spot0=4061.2200 -> K_ATM=4060.0
# [day 1/21] 2023-05-04 -> 2023-05-05
# [pick_one] MISSING leg for cp=C, K=5075.0
# [pick_one] cp=P, K=5075.0, dte=15, mid=1007.3000, delta=-0.9876, gamma=8.000000e-05, spread=8.2000, OI=1, vol=0
# [pick_one] cp=C, K=4060.0, dte=21, mid=73.0500, delta=0.5321, gamma=2.334000e-03, spread=0.5000, OI=4, vol=10
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=840.
#
# --- Window 42/43 (start_idx=861) ---
# [get_window_dates] start=2023-06-05 end=2023-07-06 len=22
# [choose_strike_for_m0] spot0=4273.7900, m0=1.250, target=5342.2375 -> K=5400.0
# [nearest_atm_strike] spot0=4273.7900 -> K_ATM=4275.0
# [day 1/21] 2023-06-05 -> 2023-06-06
# [pick_one] MISSING leg for cp=C, K=5400.0
# [pick_one] cp=P, K=5400.0, dte=21, mid=1112.1000, delta=-0.9978, gamma=2.000000e-05, spread=7.6000, OI=0, vol=0
# [pick_one] cp=C, K=4275.0, dte=21, mid=51.7000, delta=0.5399, gamma=3.402000e-03, spread=0.4000, OI=167, vol=10
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=861.
#
# --- Window 43/43 (start_idx=882) ---
# [get_window_dates] start=2023-07-06 end=2023-08-04 len=22
# [choose_strike_for_m0] spot0=4411.5900, m0=1.250, target=5514.4875 -> K=4800.0
# [nearest_atm_strike] spot0=4411.5900 -> K_ATM=4410.0
# [day 1/21] 2023-07-06 -> 2023-07-07
# [pick_one] cp=C, K=4800.0, dte=27, mid=0.3000, delta=0.0065, gamma=1.290000e-04, spread=0.1000, OI=3, vol=1
# [pick_one] cp=P, K=4800.0, dte=26, mid=372.0000, delta=-0.9995, gamma=1.700000e-05, spread=10.6000, OI=0, vol=0
# [pick_one] cp=C, K=4410.0, dte=21, mid=60.5500, delta=0.5468, gamma=2.955000e-03, spread=0.5000, OI=37, vol=3
# [next fetch] cp=C, K=4800.0, dte=32, mid=0.3000
# [next fetch] cp=P, K=4800.0, dte=21, mid=388.7000
# [next fetch] cp=C, K=4410.0, dte=21, mid=50.1000
# [init] V0=Π0=372.300000
# [day 2/21] 2023-07-07 -> 2023-07-10
# [pick_one] cp=C, K=4800.0, dte=32, mid=0.3000, delta=0.0064, gamma=1.230000e-04, spread=0.1000, OI=0, vol=3
# [pick_one] cp=P, K=4800.0, dte=21, mid=388.7000, delta=-0.9871, gamma=2.010000e-04, spread=5.6000, OI=0, vol=0
# [pick_one] cp=C, K=4410.0, dte=21, mid=50.1000, delta=0.5087, gamma=3.206000e-03, spread=0.4000, OI=458, vol=172
# [next fetch] cp=C, K=4800.0, dte=22, mid=0.1750
# [next fetch] cp=P, K=4800.0, dte=21, mid=381.1500
# [next fetch] cp=C, K=4410.0, dte=21, mid=54.6000
# [day 3/21] 2023-07-10 -> 2023-07-11
# [pick_one] cp=C, K=4800.0, dte=22, mid=0.1750, delta=0.0042, gamma=9.000000e-05, spread=0.0500, OI=718, vol=0
# [pick_one] cp=P, K=4800.0, dte=21, mid=381.1500, delta=-0.9624, gamma=4.060000e-04, spread=5.9000, OI=14, vol=0
# [pick_one] cp=C, K=4410.0, dte=21, mid=54.6000, delta=0.5402, gamma=3.223000e-03, spread=0.4000, OI=1031, vol=110
# [next fetch] cp=C, K=4800.0, dte=22, mid=0.3000
# [next fetch] MISSING next-day row for cp=P, K=4800.0
# [next fetch] cp=C, K=4410.0, dte=21, mid=77.5500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=882.
# Results shape: (84, 11)
#         start        end    m0  K_straddle  K_hedge        V0       V_T         Pi_T  tracking_error  pnl_unhedged  pnl_hedged
# 0  2020-04-02 2020-05-04  0.75      1900.0   2525.0   638.900   937.275   945.663350       -8.388350       298.375  306.763350
# 1  2020-05-04 2020-06-03  0.75      2130.0   2845.0   709.725   988.850   982.811842        6.038158       279.125  273.086842
# 2  2020-06-03 2020-07-02  0.75      2340.0   3125.0   779.150   787.700   780.868862        6.831138         8.550    1.718862
# 3  2020-07-02 2020-08-03  0.75      2350.0   3130.0   779.175   944.225   940.653246        3.571754       165.050  161.478246
# 4  2020-10-30 2020-12-01  0.75      2450.0   3270.0   821.300  1210.900  1201.313511        9.586489       389.600  380.013511
# 5  2020-12-31 2021-02-02  0.75      2820.0   3755.0   938.175  1006.150  1005.509218        0.640782        67.975   67.334218
# 6  2021-03-04 2021-04-05  0.75      2825.0   3770.0   944.550  1249.950  1246.373894        3.576106       305.400  301.823894
# 7  2021-05-04 2021-06-03  0.75      3125.0   4165.0  1037.325  1067.750  1063.333515        4.416485        30.425   26.008515
# 8  2021-08-03 2021-09-01  0.75      3320.0   4425.0  1098.500  1199.775  1197.549707        2.225293       101.275   99.049707
# 9  2021-09-01 2021-10-01  0.75      3390.0   4525.0  1130.000   965.150   964.873314        0.276686      -164.850 -165.126686
# 10 2021-11-01 2021-12-01  0.75      3460.0   4615.0  1148.300  1065.950  1050.808049       15.141951       -82.350  -97.491951
# 11 2021-12-31 2022-02-01  0.75      3575.0   4765.0  1197.625   970.825   979.752932       -8.927932      -226.800 -217.872068

# %%
# === D) Summary table ===
summary_tbl = summarize_results_verbose(results_df)
summary_tbl
# Out:
#            mean    median    std_dev   VaR_5pct  VaR_2p5pct   VaR_1pct
# m0
# 0.75   3.310080  3.576106   6.897158  -8.550224   -8.739078  -8.852390
# 0.80   2.760921  3.266963   7.585656  -9.282489  -10.364610 -11.013882
# 0.90  12.590129  8.291211  20.689845  -9.389842  -11.593008 -18.631667
# 1.10   2.460275 -5.580129  30.330205 -28.719595  -30.638559 -31.789938
# 1.20   8.940345  8.940345        NaN   8.940345    8.940345   8.940345

# %%
# === E) Plot: per-window PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['pnl_unhedged'], label='Unhedged PnL')
plt.plot(res['end'], res['pnl_hedged'], label='Hedged PnL')
plt.title('Per-Window PnL (Unhedged vs Hedged)')
plt.xlabel('Window End Date'); plt.ylabel('PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === F) Plot: cumulative PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
res['cum_unhedged'] = res['pnl_unhedged'].cumsum()
res['cum_hedged']   = res['pnl_hedged'].cumsum()
plt.figure()
plt.plot(res['end'], res['cum_unhedged'], label='Cumulative Unhedged')
plt.plot(res['end'], res['cum_hedged'], label='Cumulative Hedged')
plt.title('Cumulative PnL over Non-overlapping Windows')
plt.xlabel('Window End Date'); plt.ylabel('Cumulative PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === G) Plots: tracking error ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['tracking_error'])
plt.title('Tracking Error Z_T per Window'); plt.xlabel('Window End Date'); plt.ylabel('Z_T (index pts)')
plt.xticks(rotation=30); plt.tight_layout(); plt.show()

plt.figure()
results_df.boxplot(column='tracking_error', by='m0')
plt.title('Tracking Error by m0'); plt.suptitle(''); plt.xlabel('m0'); plt.ylabel('Z_T (index pts)')
plt.tight_layout(); plt.show()

# %%
# === Helper: get day-level timeline for a chosen results row ===
def get_timeline_for_row(df_slice, results, idx=0):
    row = results.iloc[idx]
    dates_arr = np.sort(df_slice['date'].unique())
    si = int(np.where(dates_arr == pd.Timestamp(row['start']))[0][0])
    out = run_single_window(df_slice, start_idx=si, m0=float(row['m0']))
    if out is None:
        raise RuntimeError("Window failed; check console logs for the failing day/leg.")
    return out['timeline'], out['summary']

# Example:
# tl, summ = get_timeline_for_row(df_1m_bt, results_df, idx=0)
# tl.head()

# %%
plt.figure()
results_df['tracking_error'].hist(bins=50)
plt.title('Tracking Error Distribution (All Windows)')
plt.xlabel('Z_T (index pts)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
