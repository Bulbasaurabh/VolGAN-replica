# %%
# === 1) Imports & Params ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Optional

TRADING_DAYS_PER_MONTH = 21
GAMMA_FLOOR = 1e-6  # vega floor for stability in hedge ratio

# Paths (adjust if needed)
OPTIONS_PARQUET = "../data/options_dataset.parquet"
OM_UNDERLYING_CSV = "../data/OMunderlying.csv"

pd.set_option('display.width', 160)
pd.set_option('display.max_columns', 50)

# %%
# === 2) Load SPX options & basic cleaning ===
df = pd.read_parquet(OPTIONS_PARQUET)
keep_cols = ['ticker','date','exdate','cp_flag','strike_price','best_bid','best_offer',
             'volume','open_interest','impl_volatility','delta','gamma','vega','theta']
df = df[keep_cols].copy()
df['date'] = pd.to_datetime(df['date'])
df['exdate'] = pd.to_datetime(df['exdate'])

df = df[df['ticker'] == 'SPX'].copy()

# Mid, dte
df['mid'] = (df['best_bid'] + df['best_offer']) / 2.0
df['dte'] = (df['exdate'] - df['date']).dt.days

# Fix OPRA strike scaling (1,505,000 -> 1505.0 typical)
if df['strike_price'].median() > 1e4:
    df['strike_price'] = df['strike_price'] / 1000.0

print("Options rows:", len(df))
df.head()
# Out:
# Options rows: 36251366
#   ticker       date     exdate cp_flag  strike_price  best_bid  best_offer  volume  open_interest  impl_volatility     delta     gamma       vega      theta  \
# 0    SPX 2000-01-03 2000-01-22       P        1505.0    55.250      57.250       0             50         0.212891 -0.734362  0.004767  105.97850 -162.13980
# 1    SPX 2000-01-03 2000-01-22       P        1545.0    89.625      91.625       0              0         0.233571 -0.858130  0.002975   72.57848  -92.56329
# 2    SPX 2000-01-03 2000-03-18       C         750.0   706.500     708.500       0           1916              NaN       NaN       NaN        NaN        NaN
# 3    SPX 2000-01-03 2000-09-16       C        1450.0   135.750     137.750       0           2365         0.229435  0.608151  0.001353  461.04910 -109.55640
# 4    SPX 2000-01-03 2000-06-17       P        1350.0    40.750      42.750     290          14570         0.252872 -0.256190  0.001296  313.84440  -67.94785
#
#        mid  dte
# 0   56.250   19
# 1   90.625   19
# 2  707.500   75
# 3  136.750  257
# 4   41.750  166

# %%
# === 3) Load OptionMetrics OMunderlying.csv as spot ===
# Expected columns: secid,date,ticker,index_flag,low,high,open,close,volume
spot_df = pd.read_csv(OM_UNDERLYING_CSV)
spot_df['date'] = pd.to_datetime(spot_df['date'])
spot_df = spot_df[spot_df['ticker'] == 'SPX'].copy()

# Use 'close' as the index level (spot)
spot_df = spot_df[['date','close']].rename(columns={'close':'spot'}).sort_values('date')
spot_df = spot_df.drop_duplicates(subset=['date'], keep='last').reset_index(drop=True)

print("Spot rows:", len(spot_df), "| range:", spot_df['date'].min().date(), "→", spot_df['date'].max().date())
spot_df.head()
# Out:
# Spot rows: 5954 | range: 2000-01-03 → 2023-08-31
#         date     spot
# 0 2000-01-03  1455.22
# 1 2000-01-04  1399.42
# 2 2000-01-05  1402.11
# 3 2000-01-06  1403.45
# 4 2000-01-07  1441.47

# %%
# === 4) Merge spot into options; compute moneyness; filter ~1M tenor ===
df = df.merge(spot_df, on='date', how='inner')
df['moneyness'] = df['strike_price'] / df['spot']

# Keep ~1M options: dte around 21 trading days (use a calendar-day band 15–35)
df_1m = df[(df['dte'] >= 15) & (df['dte'] <= 35)].copy()

# Quality screens
df_1m = df_1m.replace([np.inf, -np.inf], np.nan)
df_1m = df_1m.dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
df_1m = df_1m[df_1m['best_offer'] >= df_1m['best_bid']].copy()
df_1m['spread'] = (df_1m['best_offer'] - df_1m['best_bid']).clip(lower=0)
df_1m['rel_spread'] = (df_1m['spread'] / df_1m['mid']).replace([np.inf,-np.inf], np.nan)

liq_mask = (
    (df_1m['mid'] > 0.05) &
    (df_1m['rel_spread'] <= 0.35) &
    df_1m['delta'].between(-1.1, 1.1) &
    (df_1m['gamma'].abs() > 0)   # gamma is positive for vanilla options; guard against zeros
)
df_1m = df_1m[liq_mask].copy()

cols_keep = ['date','exdate','cp_flag','strike_price','spot','moneyness','dte','mid',
             'best_bid','best_offer','volume','open_interest','delta','gamma','spread','rel_spread']
df_1m = df_1m[cols_keep].sort_values(['date','dte','strike_price']).reset_index(drop=True)

print("1M rows:", len(df_1m), "| date range:", df_1m['date'].min().date(), "→", df_1m['date'].max().date())
df_1m.head(10)
# Out:
# 1M rows: 5686826 | date range: 2000-01-03 → 2023-08-31
#         date     exdate cp_flag  strike_price     spot  moneyness  dte       mid  best_bid  best_offer  volume  open_interest     delta     gamma  spread  \
# 0 2000-01-03 2000-01-22       P        1275.0  1455.22   0.876156   19    2.0000     1.750       2.250     585          23785 -0.041295  0.000763   0.500
# 1 2000-01-03 2000-01-22       P        1300.0  1455.22   0.893336   19    2.6250     2.250       3.000    3572          26621 -0.055490  0.001036   0.750
# 2 2000-01-03 2000-01-22       P        1325.0  1455.22   0.910515   19    3.8125     3.500       4.125    1406          30757 -0.079749  0.001446   0.625
# 3 2000-01-03 2000-01-22       C        1325.0  1455.22   0.910515   19  134.5000   133.500     135.500     315          29529  0.983012  0.000628   2.000
# 4 2000-01-03 2000-01-22       C        1350.0  1455.22   0.927695   19  111.1250   110.125     112.125     112          20500  0.939732  0.001609   2.000
# 5 2000-01-03 2000-01-22       P        1350.0  1455.22   0.927695   19    5.1875     4.875       5.500     819          24413 -0.109956  0.001978   0.625
# 6 2000-01-03 2000-01-22       C        1375.0  1455.22   0.944874   19   88.5000    87.500      89.500       6           7885  0.884385  0.002631   2.000
# 7 2000-01-03 2000-01-22       P        1375.0  1455.22   0.944874   19    6.9375     6.750       7.125    2633          18270 -0.150684  0.002706   0.375
# 8 2000-01-03 2000-01-22       C        1380.0  1455.22   0.948310   19   84.0000    83.000      85.000       4             13  0.872528  0.002851   2.000
# 9 2000-01-03 2000-01-22       P        1380.0  1455.22   0.948310   19    8.1250     7.625       8.625      69           1458 -0.168821  0.002871   1.000
#
#    rel_spread
# 0    0.250000
# 1    0.285714
# 2    0.163934
# 3    0.014870
# 4    0.017998
# 5    0.120482
# 6    0.022599
# 7    0.054054
# 8    0.023810
# 9    0.123077

# %%
# === 5) Utilities (small, testable) ===
def choose_strike_for_m0(spot0: float, m0: float, available_strikes: np.ndarray) -> float:
    target = float(m0) * float(spot0)
    idx = np.abs(available_strikes - target).argmin()
    K = float(available_strikes[idx])
    print(f"[choose_strike_for_m0] spot0={spot0:.4f}, m0={m0:.3f}, target={target:.4f} -> K={K}")
    return K

def nearest_atm_strike(spot0: float, available_strikes: np.ndarray) -> float:
    idx = np.abs(available_strikes - float(spot0)).argmin()
    K = float(available_strikes[idx])
    print(f"[nearest_atm_strike] spot0={spot0:.4f} -> K_ATM={K}")
    return K

def pick_one(day_df: pd.DataFrame, strike: float, cp_flag: str) -> Optional[pd.Series]:
    sub = day_df[(day_df['strike_price'] == strike) & (day_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[pick_one] MISSING leg for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[pick_one] All candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[pick_one] No clean candidate after filters for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[pick_one] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, "
          f"mid={chosen['mid']:.4f}, delta={chosen['delta']:.4f}, gamma={chosen['gamma']:.6e}, "
          f"spread={chosen['spread']:.4f}, OI={int(chosen['open_interest'])}, vol={int(chosen['volume'])}")
    return chosen

def fetch_next_row(next_df, strike, cp_flag):
    sub = next_df[(next_df['strike_price'] == strike) & (next_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[next fetch] MISSING next-day row for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','gamma','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[next fetch] All next-day candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[next fetch] No clean next-day candidate for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[next fetch] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, mid={chosen['mid']:.4f}")
    return chosen

def half_spread(row: pd.Series) -> float:
    return float(max(0.0, (row['best_offer'] - row['best_bid']) / 2.0))

def pnl_from_price_change(qty: float, price_t: float, price_t1: float) -> float:
    return float(qty) * (float(price_t1) - float(price_t))

def self_financing_rebalance_cost(prev_qty: float, new_qty: float, half_spread_val: float) -> float:
    return abs(float(new_qty - prev_qty)) * float(half_spread_val)

# %%
# === 6A) Window builder ===
def get_window_dates(df_all: pd.DataFrame, start_idx: int) -> list[pd.Timestamp] | None:
    dates = np.sort(df_all['date'].unique())
    if start_idx + TRADING_DAYS_PER_MONTH >= len(dates):
        print(f"[get_window_dates] Not enough dates from start_idx={start_idx}.")
        return None
    days = list(dates[start_idx : start_idx + TRADING_DAYS_PER_MONTH + 1])
    print(f"[get_window_dates] start={pd.Timestamp(days[0]).date()} end={pd.Timestamp(days[-1]).date()} len={len(days)}")
    return days

# %%
# === 6B) One day step ===
def one_day_step(df_all: pd.DataFrame,
                 d: pd.Timestamp, d_next: pd.Timestamp,
                 K_straddle: float, K_hedge: float,
                 phi_opt_prev: float, phi_under_prev: float) -> dict | None:
    day = df_all[df_all['date'] == d].copy()
    day_next = df_all[df_all['date'] == d_next].copy()
    if day.empty or day_next.empty:
        print(f="[one_day_step] Missing day data at {d} or {d_next}")
        return None

    row_C = pick_one(day, K_straddle, 'C')
    row_P = pick_one(day, K_straddle, 'P')
    row_H = pick_one(day, K_hedge, 'C')
    if row_H is None:
        row_H = pick_one(day, K_hedge, 'P')

    if (row_C is None) or (row_P is None) or (row_H is None):
        print("[one_day_step] Missing leg(s) at current day.")
        return None

    # Position greeks (straddle: long 1C + 1P)
    psi_C, psi_P = 1.0, 1.0
    V_t   = psi_C*row_C['mid'] + psi_P*row_P['mid']
    dV_t  = psi_C*row_C['delta'] + psi_P*row_P['delta']
    gV_t  = psi_C*row_C['gamma'] + psi_P*row_P['gamma']

    dH_t  = row_H['delta']
    gH_t  = row_H['gamma']

    vals = [V_t, dV_t, gV_t, dH_t, gH_t, row_H['mid']]
    if not all(np.isfinite(v) for v in vals):
        print(f"[one_day_step] Non-finite greeks/prices at {pd.Timestamp(d).date()} — abort window.")
        return None

    # Stabilize very small hedge gamma
    gH_eff = np.sign(gH_t) * max(abs(gH_t) if np.isfinite(gH_t) else 0.0, GAMMA_FLOOR)
    if not np.isfinite(gV_t):
        print(f"[one_day_step] Portfolio gamma NaN at {pd.Timestamp(d).date()} — abort window.")
        return None

    # Gamma hedge via option; residual delta via underlying
    phi_opt   = (gV_t / gH_eff) if not np.isclose(gH_eff, 0.0) else 0.0
    phi_under = dV_t - phi_opt * dH_t

    # Next-day marks
    row_C_next = fetch_next_row(day_next, row_C['strike_price'], 'C')
    row_P_next = fetch_next_row(day_next, row_P['strike_price'], 'P')
    row_H_next = fetch_next_row(day_next, row_H['strike_price'], row_H['cp_flag'])
    if (row_C_next is None) or (row_P_next is None) or (row_H_next is None):
        print("[one_day_step] Missing next-day leg(s).")
        return None

    s_t  = float(row_C['spot']);  s_t1 = float(row_C_next['spot'])
    hs_H = half_spread(row_H)

    pnl_opt    = pnl_from_price_change(phi_opt, row_H['mid'], row_H_next['mid'])
    pnl_under  = pnl_from_price_change(phi_under, s_t, s_t1)
    cost_opt   = self_financing_rebalance_cost(phi_opt_prev, phi_opt, hs_H)
    cost_under = 0.0  # same as before

    pnl_unhedged = (psi_C*(row_C_next['mid'] - row_C['mid']) +
                    psi_P*(row_P_next['mid'] - row_P['mid']))

    return dict(
        date=pd.Timestamp(d), spot=s_t,
        K_straddle=K_straddle, K_hedge=K_hedge,
        V_t=float(V_t), dV_t=float(dV_t), gV_t=float(gV_t),
        H_cp=row_H['cp_flag'], H_mid=float(row_H['mid']), dH_t=float(dH_t), gH_t=float(gH_t), gH_eff=float(gH_eff),
        phi_opt=float(phi_opt), phi_under=float(phi_under),
        cost_opt=float(cost_opt), cost_under=float(cost_under),
        pnl_opt=float(pnl_opt), pnl_under=float(pnl_under), pnl_unhedged=float(pnl_unhedged)
    )

# %%
# === 6C) Single window runner ===
def run_single_window(df_all: pd.DataFrame, start_idx: int, m0: float) -> dict | None:
    days = get_window_dates(df_all, start_idx)
    if days is None:
        return None
    d0 = pd.Timestamp(days[0])
    day0 = df_all[df_all['date'] == d0].copy()
    if day0.empty:
        print(f"[run_single_window] No rows on start day {d0}.")
        return None

    spot0 = float(day0['spot'].iloc[0])
    strikes0 = np.sort(day0['strike_price'].unique())
    K_straddle = choose_strike_for_m0(spot0, m0, strikes0)
    K_hedge    = nearest_atm_strike(spot0, strikes0)

    phi_opt_prev = 0.0; phi_under_prev = 0.0
    records = []; V0 = None; Pi_t = None

    for t in range(len(days)-1):
        d, d_next = pd.Timestamp(days[t]), pd.Timestamp(days[t+1])
        print(f"[day {t+1}/{len(days)-1}] {d.date()} -> {d_next.date()}")
        step = one_day_step(df_all, d, d_next, K_straddle, K_hedge, phi_opt_prev, phi_under_prev)
        if step is None:
            print("[run_single_window] Step failed; abort window.")
            return None

        if V0 is None:
            V0 = step['V_t']; Pi_t = V0; print(f"[init] V0=Π0={V0:.6f}")

        Pi_t1 = (Pi_t + step['pnl_opt'] + step['pnl_under'] - step['cost_opt'] - step['cost_under'])
        step['Pi_t'] = float(Pi_t); step['Pi_t1'] = float(Pi_t1)
        records.append(step)

        phi_opt_prev   = step['phi_opt']
        phi_under_prev = step['phi_under']
        Pi_t = Pi_t1

    # Final valuation
    last_day = pd.Timestamp(days[-2]); final_day = pd.Timestamp(days[-1])
    day_last  = df_all[df_all['date'] == last_day]
    day_final = df_all[df_all['date'] == final_day]

    row_C_last = pick_one(day_last, K_straddle, 'C');  row_C_fin = fetch_next_row(day_final, K_straddle, 'C')
    row_P_last = pick_one(day_last, K_straddle, 'P');  row_P_fin = fetch_next_row(day_final, K_straddle, 'P')
    if (row_C_last is None) or (row_P_last is None) or (row_C_fin is None) or (row_P_fin is None):
        print("[run_single_window] Final valuation missing legs.")
        return None

    V_T = float(row_C_fin['mid'] + row_P_fin['mid'])
    Pi_T = float(records[-1]['Pi_t1'])
    tracking_error = V_T - Pi_T
    pnl_unhedged_total = V_T - float(records[0]['V_t'])
    pnl_hedged_total   = Pi_T - float(records[0]['V_t'])

    timeline = pd.DataFrame(records).sort_values('date').reset_index(drop=True)
    summary = dict(
        start=days[0], end=days[-1], m0=float(m0),
        K_straddle=float(K_straddle), K_hedge=float(K_hedge),
        V0=float(records[0]['V_t']), V_T=float(V_T),
        Pi_T=float(Pi_T),
        tracking_error=float(tracking_error),
        pnl_unhedged=float(pnl_unhedged_total),
        pnl_hedged=float(pnl_hedged_total)
    )
    print(f"[window done] m0={m0}, Z_T={tracking_error:.6f}, V_T={V_T:.6f}, Π_T={Pi_T:.6f}")
    return dict(timeline=timeline, summary=summary)

# %%
# === 7) Multi-window experiment ===
def run_experiment_verbose(df_all: pd.DataFrame, m0_list: list[float], max_windows: int = 52, stop_on_fail: bool = False) -> pd.DataFrame:
    dates = np.sort(df_all['date'].unique())
    start_indices = list(range(0, len(dates) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
    start_indices = start_indices[:max_windows]
    results = []
    for m0 in m0_list:
        print(f"\n===== m0={m0} =====")
        for i, si in enumerate(start_indices, 1):
            print(f"\n--- Window {i}/{len(start_indices)} (start_idx={si}) ---")
            out = run_single_window(df_all, si, m0)
            if out is None:
                print(f"[run_experiment_verbose] Window failed for m0={m0}, start_idx={si}.")
                if stop_on_fail:
                    return pd.DataFrame(results)
                else:
                    continue
            results.append(out['summary'])
    return pd.DataFrame(results)

# %%
# === 8) Summaries ===
def summarize_results_verbose(results_df: pd.DataFrame) -> pd.DataFrame:
    if results_df is None or results_df.empty:
        print("[summarize_results_verbose] No results to summarize."); return pd.DataFrame()
    g = results_df.groupby('m0')
    out = g['tracking_error'].agg(['mean','median','std']).rename(columns={'std':'std_dev'})
    out['VaR_5pct']   = g['tracking_error'].quantile(0.05)
    out['VaR_2p5pct'] = g['tracking_error'].quantile(0.025)
    out['VaR_1pct']   = g['tracking_error'].quantile(0.01)
    return out

# %%
# === A) Backtest range: from 2021-01-01 to end ===
start_backtest = pd.Timestamp("2021-01-01")
df_1m_bt = df_1m[df_1m['date'] >= start_backtest].copy().sort_values('date')
print("Backtest:", df_1m_bt['date'].min().date(), "→", df_1m_bt['date'].max().date(), "| rows:", len(df_1m_bt))

dates_bt = np.sort(df_1m_bt['date'].unique())
start_indices_bt = list(range(0, len(dates_bt) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
max_windows_bt = len(start_indices_bt)
print("Candidate windows in range:", max_windows_bt)
# Out:
# Backtest: 2021-01-04 → 2023-08-31 | rows: 2179948
# Candidate windows in range: 31

# %%
# === B/C) Run experiment ===
m0_list = [0.75, 0.8, 0.9, 1.1, 1.2, 1.25]
results_df = run_experiment_verbose(df_1m_bt, m0_list=m0_list, max_windows=max_windows_bt, stop_on_fail=False)
print("Results shape:", results_df.shape)
results_df.sort_values(['m0','end']).head(12)
# Out:
# ===== m0=0.75 =====
#
# --- Window 1/31 (start_idx=0) ---
# [get_window_dates] start=2021-01-04 end=2021-02-03 len=22
# [choose_strike_for_m0] spot0=3700.6500, m0=0.750, target=2775.4875 -> K=2775.0
# [nearest_atm_strike] spot0=3700.6500 -> K_ATM=3700.0
# [day 1/21] 2021-01-04 -> 2021-01-05
# [pick_one] cp=C, K=2775.0, dte=18, mid=926.5500, delta=0.9908, gamma=5.300000e-05, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.8000, delta=-0.0106, gamma=5.900000e-05, spread=0.2000, OI=219, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=71.5500, delta=0.5101, gamma=2.226000e-03, spread=0.7000, OI=122, vol=125
# [next fetch] cp=C, K=2775.0, dte=24, mid=951.7500
# [next fetch] cp=P, K=2775.0, dte=24, mid=2.3000
# [next fetch] cp=C, K=3700.0, dte=20, mid=81.3000
# [init] V0=Π0=928.350000
# [day 2/21] 2021-01-05 -> 2021-01-06
# [pick_one] cp=C, K=2775.0, dte=24, mid=951.7500, delta=0.9878, gamma=6.100000e-05, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.3000, delta=-0.0125, gamma=6.400000e-05, spread=0.2000, OI=420, vol=96
# [pick_one] cp=C, K=3700.0, dte=20, mid=81.3000, delta=0.5679, gamma=2.300000e-03, spread=0.6000, OI=196, vol=34
# [next fetch] cp=C, K=2775.0, dte=23, mid=975.2500
# [next fetch] cp=P, K=2775.0, dte=23, mid=2.6250
# [next fetch] cp=C, K=3700.0, dte=21, mid=103.2500
# [day 3/21] 2021-01-06 -> 2021-01-07
# [pick_one] cp=C, K=2775.0, dte=23, mid=975.2500, delta=0.9857, gamma=6.800000e-05, spread=6.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=2.6250, delta=-0.0136, gamma=6.600000e-05, spread=0.2500, OI=484, vol=4
# [pick_one] cp=C, K=3700.0, dte=21, mid=103.2500, delta=0.6092, gamma=1.984000e-03, spread=1.3000, OI=13, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1030.7500
# [next fetch] cp=P, K=2775.0, dte=22, mid=1.2750
# [next fetch] cp=C, K=3700.0, dte=22, mid=139.6000
# [day 4/21] 2021-01-07 -> 2021-01-08
# [pick_one] cp=C, K=2775.0, dte=22, mid=1030.7500, delta=0.9906, gamma=4.800000e-05, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=1.2750, delta=-0.0074, gamma=4.000000e-05, spread=0.1500, OI=484, vol=9
# [pick_one] cp=C, K=3700.0, dte=22, mid=139.6000, delta=0.7149, gamma=1.745000e-03, spread=1.6000, OI=4544, vol=78
# [next fetch] cp=C, K=2775.0, dte=21, mid=1051.1000
# [next fetch] cp=P, K=2775.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=3700.0, dte=21, mid=154.3000
# [day 5/21] 2021-01-08 -> 2021-01-11
# [pick_one] cp=C, K=2775.0, dte=21, mid=1051.1000, delta=0.9931, gamma=3.800000e-05, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=0.8000, delta=-0.0050, gamma=3.000000e-05, spread=0.1000, OI=480, vol=12
# [pick_one] cp=C, K=3700.0, dte=21, mid=154.3000, delta=0.7520, gamma=1.633000e-03, spread=0.6000, OI=4547, vol=120
# [next fetch] cp=C, K=2775.0, dte=18, mid=1023.2500
# [next fetch] cp=P, K=2775.0, dte=18, mid=0.7500
# [next fetch] cp=C, K=3700.0, dte=21, mid=138.0500
# [day 6/21] 2021-01-11 -> 2021-01-12
# [pick_one] cp=C, K=2775.0, dte=18, mid=1023.2500, delta=0.9941, gamma=3.200000e-05, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=0.7500, delta=-0.0049, gamma=3.000000e-05, spread=0.1000, OI=474, vol=179
# [pick_one] cp=C, K=3700.0, dte=21, mid=138.0500, delta=0.6955, gamma=1.719000e-03, spread=0.7000, OI=201, vol=11
# [next fetch] cp=C, K=2775.0, dte=24, mid=1033.7500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.4250
# [next fetch] cp=C, K=3700.0, dte=20, mid=139.2000
# [day 7/21] 2021-01-12 -> 2021-01-13
# [pick_one] cp=C, K=2775.0, dte=24, mid=1033.7500, delta=0.9724, gamma=9.700000e-05, spread=12.7000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.4250, delta=-0.0081, gamma=4.300000e-05, spread=0.1500, OI=577, vol=0
# [pick_one] cp=C, K=3700.0, dte=20, mid=139.2000, delta=0.7065, gamma=1.731000e-03, spread=0.6000, OI=190, vol=3
# [next fetch] cp=C, K=2775.0, dte=23, mid=1036.9000
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2000
# [next fetch] cp=C, K=3700.0, dte=21, mid=144.1000
# [day 8/21] 2021-01-13 -> 2021-01-14
# [pick_one] cp=C, K=2775.0, dte=23, mid=1036.9000, delta=0.9902, gamma=4.900000e-05, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=1.2000, delta=-0.0070, gamma=3.900000e-05, spread=0.1000, OI=576, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=144.1000, delta=0.7248, gamma=1.708000e-03, spread=0.6000, OI=46, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1022.1500
# [next fetch] cp=P, K=2775.0, dte=22, mid=1.4500
# [next fetch] cp=C, K=3700.0, dte=22, mid=137.0000
# [day 9/21] 2021-01-14 -> 2021-01-15
# [pick_one] cp=C, K=2775.0, dte=22, mid=1022.1500, delta=0.9920, gamma=4.300000e-05, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=1.4500, delta=-0.0082, gamma=4.400000e-05, spread=0.1000, OI=576, vol=15
# [pick_one] cp=C, K=3700.0, dte=22, mid=137.0000, delta=0.6927, gamma=1.727000e-03, spread=13.2000, OI=2567, vol=5
# [next fetch] cp=C, K=2775.0, dte=21, mid=992.8500
# [next fetch] cp=P, K=2775.0, dte=21, mid=1.5000
# [next fetch] cp=C, K=3700.0, dte=21, mid=114.9500
# [day 10/21] 2021-01-15 -> 2021-01-19
# [pick_one] cp=C, K=2775.0, dte=21, mid=992.8500, delta=0.9945, gamma=3.200000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=1.5000, delta=-0.0087, gamma=4.700000e-05, spread=0.2000, OI=581, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=114.9500, delta=0.6458, gamma=1.914000e-03, spread=0.7000, OI=2566, vol=131
# [next fetch] cp=C, K=2775.0, dte=24, mid=1022.0500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=3700.0, dte=20, mid=133.8000
# [day 11/21] 2021-01-19 -> 2021-01-20
# [pick_one] cp=C, K=2775.0, dte=24, mid=1022.0500, delta=0.9914, gamma=4.200000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.7750, delta=-0.0096, gamma=4.900000e-05, spread=0.1500, OI=237, vol=96
# [pick_one] cp=C, K=3700.0, dte=20, mid=133.8000, delta=0.7065, gamma=1.803000e-03, spread=2.0000, OI=280, vol=14
# [next fetch] cp=C, K=2775.0, dte=23, mid=1076.7500
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2250
# [next fetch] cp=C, K=3700.0, dte=21, mid=176.8500
# [day 12/21] 2021-01-20 -> 2021-01-21
# [pick_one] cp=C, K=2775.0, dte=23, mid=1076.7500, delta=0.9942, gamma=3.100000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=1.2250, delta=-0.0068, gamma=3.600000e-05, spread=0.1500, OI=323, vol=22
# [pick_one] cp=C, K=3700.0, dte=21, mid=176.8500, delta=0.7870, gamma=1.444000e-03, spread=0.5000, OI=3, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1078.5500
# [next fetch] cp=P, K=2775.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=3700.0, dte=22, mid=179.1500
# [day 13/21] 2021-01-21 -> 2021-01-22
# [pick_one] cp=C, K=2775.0, dte=22, mid=1078.5500, delta=0.9954, gamma=2.700000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=0.9500, delta=-0.0056, gamma=3.100000e-05, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=22, mid=179.1500, delta=0.7830, gamma=1.423000e-03, spread=0.7000, OI=414, vol=10
# [next fetch] cp=C, K=2775.0, dte=21, mid=1069.2500
# [next fetch] cp=P, K=2775.0, dte=21, mid=1.0000
# [next fetch] cp=C, K=3700.0, dte=21, mid=169.6500
# [day 14/21] 2021-01-22 -> 2021-01-25
# [pick_one] cp=C, K=2775.0, dte=21, mid=1069.2500, delta=0.9876, gamma=5.600000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=1.0000, delta=-0.0059, gamma=3.300000e-05, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=169.6500, delta=0.7696, gamma=1.497000e-03, spread=0.5000, OI=414, vol=19
# [next fetch] cp=C, K=2775.0, dte=18, mid=1078.7500
# [next fetch] cp=P, K=2775.0, dte=18, mid=1.0000
# [next fetch] cp=C, K=3700.0, dte=22, mid=180.2500
# [day 15/21] 2021-01-25 -> 2021-01-26
# [pick_one] cp=C, K=2775.0, dte=18, mid=1078.7500, delta=0.9934, gamma=3.200000e-05, spread=6.7000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.0000, delta=-0.0058, gamma=3.200000e-05, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=22, mid=180.2500, delta=0.7773, gamma=1.409000e-03, spread=1.1000, OI=390, vol=84
# [next fetch] cp=C, K=2775.0, dte=24, mid=1071.3500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.5250
# [next fetch] cp=C, K=3700.0, dte=21, mid=174.2500
# [day 16/21] 2021-01-26 -> 2021-01-27
# [pick_one] cp=C, K=2775.0, dte=24, mid=1071.3500, delta=0.9922, gamma=3.600000e-05, spread=7.1000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.5250, delta=-0.0082, gamma=4.100000e-05, spread=0.1500, OI=2828, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=174.2500, delta=0.7704, gamma=1.454000e-03, spread=0.7000, OI=324, vol=40
# [next fetch] cp=C, K=2775.0, dte=23, mid=977.6500
# [next fetch] cp=P, K=2775.0, dte=23, mid=3.9000
# [next fetch] cp=C, K=3700.0, dte=21, mid=125.8000
# [day 17/21] 2021-01-27 -> 2021-01-28
# [pick_one] cp=C, K=2775.0, dte=23, mid=977.6500, delta=0.9838, gamma=7.300000e-05, spread=12.3000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=3.9000, delta=-0.0182, gamma=8.000000e-05, spread=0.8000, OI=2828, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=125.8000, delta=0.5922, gamma=1.553000e-03, spread=1.0000, OI=105, vol=32
# [next fetch] cp=C, K=2775.0, dte=22, mid=1017.0000
# [next fetch] cp=P, K=2775.0, dte=22, mid=3.0500
# [next fetch] cp=C, K=3700.0, dte=22, mid=145.2500
# [day 18/21] 2021-01-28 -> 2021-01-29
# [pick_one] cp=C, K=2775.0, dte=22, mid=1017.0000, delta=0.9773, gamma=8.700000e-05, spread=12.8000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=3.0500, delta=-0.0147, gamma=6.600000e-05, spread=0.3000, OI=2828, vol=237
# [pick_one] cp=C, K=3700.0, dte=22, mid=145.2500, delta=0.6527, gamma=1.520000e-03, spread=1.3000, OI=17036, vol=442
# [next fetch] cp=C, K=2775.0, dte=21, mid=943.6000
# [next fetch] cp=P, K=2775.0, dte=21, mid=3.3000
# [next fetch] cp=C, K=3700.0, dte=21, mid=100.6500
# [day 19/21] 2021-01-29 -> 2021-02-01
# [pick_one] cp=C, K=2775.0, dte=21, mid=943.6000, delta=0.9801, gamma=8.800000e-05, spread=9.0000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=3.3000, delta=-0.0167, gamma=7.900000e-05, spread=0.4000, OI=2849, vol=1
# [pick_one] cp=C, K=3700.0, dte=21, mid=100.6500, delta=0.5372, gamma=1.696000e-03, spread=1.9000, OI=16652, vol=1784
# [next fetch] cp=C, K=2775.0, dte=18, mid=1000.0500
# [next fetch] cp=P, K=2775.0, dte=18, mid=1.7500
# [next fetch] cp=C, K=3700.0, dte=21, mid=130.2000
# [day 20/21] 2021-02-01 -> 2021-02-02
# [pick_one] cp=C, K=2775.0, dte=18, mid=1000.0500, delta=0.9925, gamma=4.200000e-05, spread=5.3000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.7500, delta=-0.0097, gamma=5.100000e-05, spread=0.2000, OI=2849, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=130.2000, delta=0.6391, gamma=1.660000e-03, spread=2.0000, OI=39, vol=7
# [next fetch] cp=C, K=2775.0, dte=24, mid=1050.1000
# [next fetch] cp=P, K=2775.0, dte=24, mid=2.2750
# [next fetch] cp=C, K=3700.0, dte=22, mid=163.5500
# [day 21/21] 2021-02-02 -> 2021-02-03
# [pick_one] cp=C, K=2775.0, dte=24, mid=1050.1000, delta=0.9881, gamma=5.200000e-05, spread=4.6000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.2750, delta=-0.0114, gamma=5.400000e-05, spread=0.1500, OI=2796, vol=510
# [pick_one] cp=C, K=3700.0, dte=22, mid=163.5500, delta=0.7219, gamma=1.491000e-03, spread=0.7000, OI=57, vol=0
# [next fetch] cp=C, K=2775.0, dte=23, mid=1055.8500
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2750
# [next fetch] cp=C, K=3700.0, dte=21, mid=161.7500
# [pick_one] cp=C, K=2775.0, dte=24, mid=1050.1000, delta=0.9881, gamma=5.200000e-05, spread=4.6000, OI=0, vol=0
# [next fetch] cp=C, K=2775.0, dte=23, mid=1055.8500
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.2750, delta=-0.0114, gamma=5.400000e-05, spread=0.1500, OI=2796, vol=510
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2750
# [window done] m0=0.75, Z_T=1.586147, V_T=1057.125000, Π_T=1055.538853
#
# --- Window 2/31 (start_idx=21) ---
# [get_window_dates] start=2021-02-03 end=2021-03-05 len=22
# [choose_strike_for_m0] spot0=3830.1700, m0=0.750, target=2872.6275 -> K=2875.0
# [nearest_atm_strike] spot0=3830.1700 -> K_ATM=3830.0
# [day 1/21] 2021-02-03 -> 2021-02-04
# [pick_one] cp=C, K=2875.0, dte=23, mid=956.3000, delta=0.9897, gamma=5.500000e-05, spread=4.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.7250, delta=-0.0101, gamma=5.500000e-05, spread=0.1500, OI=120, vol=9
# [pick_one] cp=C, K=3830.0, dte=21, mid=63.4000, delta=0.5093, gamma=2.518000e-03, spread=0.6000, OI=28, vol=286
# [next fetch] cp=C, K=2875.0, dte=22, mid=989.6500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.1250
# [next fetch] cp=C, K=3830.0, dte=22, mid=83.0000
# [init] V0=Π0=958.025000
# [day 2/21] 2021-02-04 -> 2021-02-05
# [pick_one] cp=C, K=2875.0, dte=22, mid=989.6500, delta=0.9912, gamma=3.900000e-05, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.1250, delta=-0.0070, gamma=4.100000e-05, spread=0.1500, OI=129, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=83.0000, delta=0.5890, gamma=2.372000e-03, spread=0.4000, OI=647, vol=156
# [next fetch] cp=C, K=2875.0, dte=21, mid=1009.3500
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=3830.0, dte=21, mid=92.7500
# [day 3/21] 2021-02-05 -> 2021-02-08
# [pick_one] cp=C, K=2875.0, dte=21, mid=1009.3500, delta=0.9944, gamma=3.000000e-05, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.8000, delta=-0.0052, gamma=3.200000e-05, spread=0.1000, OI=129, vol=6
# [pick_one] cp=C, K=3830.0, dte=21, mid=92.7500, delta=0.6416, gamma=2.372000e-03, spread=0.5000, OI=691, vol=43
# [next fetch] cp=C, K=2875.0, dte=18, mid=1032.1500
# [next fetch] cp=P, K=2875.0, dte=18, mid=0.5500
# [next fetch] cp=C, K=3830.0, dte=21, mid=110.8000
# [day 4/21] 2021-02-08 -> 2021-02-09
# [pick_one] cp=C, K=2875.0, dte=18, mid=1032.1500, delta=0.9946, gamma=2.100000e-05, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=0.5500, delta=-0.0038, gamma=2.400000e-05, spread=0.1000, OI=123, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=110.8000, delta=0.6861, gamma=2.128000e-03, spread=0.6000, OI=258, vol=4
# [next fetch] cp=C, K=2875.0, dte=24, mid=1032.9000
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3250
# [next fetch] cp=C, K=3830.0, dte=20, mid=111.7000
# [day 5/21] 2021-02-09 -> 2021-02-10
# [pick_one] cp=C, K=2875.0, dte=24, mid=1032.9000, delta=0.9926, gamma=3.600000e-05, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3250, delta=-0.0076, gamma=4.100000e-05, spread=0.1500, OI=1152, vol=4
# [pick_one] cp=C, K=3830.0, dte=20, mid=111.7000, delta=0.6904, gamma=2.127000e-03, spread=2.4000, OI=259, vol=0
# [next fetch] cp=C, K=2875.0, dte=23, mid=1029.8500
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.4000
# [next fetch] cp=C, K=3830.0, dte=21, mid=114.1500
# [day 6/21] 2021-02-10 -> 2021-02-11
# [pick_one] cp=C, K=2875.0, dte=23, mid=1029.8500, delta=0.9930, gamma=3.200000e-05, spread=6.3000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.4000, delta=-0.0080, gamma=4.300000e-05, spread=0.2000, OI=1148, vol=41
# [pick_one] cp=C, K=3830.0, dte=21, mid=114.1500, delta=0.6708, gamma=2.016000e-03, spread=0.7000, OI=1, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=1038.1500
# [next fetch] cp=P, K=2875.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=3830.0, dte=22, mid=120.2000
# [day 7/21] 2021-02-11 -> 2021-02-12
# [pick_one] cp=C, K=2875.0, dte=22, mid=1038.1500, delta=0.9940, gamma=3.000000e-05, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=0.9500, delta=-0.0058, gamma=3.400000e-05, spread=0.2000, OI=1138, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=120.2000, delta=0.6847, gamma=1.954000e-03, spread=0.6000, OI=623, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=1058.1000
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.7750
# [next fetch] cp=C, K=3830.0, dte=21, mid=131.1000
# [day 8/21] 2021-02-12 -> 2021-02-16
# [pick_one] cp=C, K=2875.0, dte=21, mid=1058.1000, delta=0.9961, gamma=2.200000e-05, spread=5.0000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.7750, delta=-0.0049, gamma=2.900000e-05, spread=0.1500, OI=1138, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=131.1000, delta=0.7340, gamma=1.903000e-03, spread=0.6000, OI=623, vol=2
# [next fetch] cp=C, K=2875.0, dte=24, mid=1055.8000
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=20, mid=131.6500
# [day 9/21] 2021-02-16 -> 2021-02-17
# [pick_one] cp=C, K=2875.0, dte=24, mid=1055.8000, delta=0.9937, gamma=3.200000e-05, spread=5.4000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3750, delta=-0.0077, gamma=4.100000e-05, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=20, mid=131.6500, delta=0.7279, gamma=1.884000e-03, spread=1.1000, OI=18, vol=0
# [next fetch] cp=C, K=2875.0, dte=23, mid=1053.8000
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.3000
# [next fetch] cp=C, K=3830.0, dte=21, mid=130.9500
# [day 10/21] 2021-02-17 -> 2021-02-18
# [pick_one] cp=C, K=2875.0, dte=23, mid=1053.8000, delta=0.9931, gamma=3.400000e-05, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.3000, delta=-0.0074, gamma=3.900000e-05, spread=0.1000, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=130.9500, delta=0.7196, gamma=1.876000e-03, spread=0.7000, OI=0, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=1037.0500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=22, mid=122.1000
# [day 11/21] 2021-02-18 -> 2021-02-19
# [pick_one] cp=C, K=2875.0, dte=22, mid=1037.0500, delta=0.9921, gamma=3.900000e-05, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.3750, delta=-0.0078, gamma=4.200000e-05, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=122.1000, delta=0.6751, gamma=1.895000e-03, spread=0.6000, OI=70, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=1028.4000
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.0750
# [next fetch] cp=C, K=3830.0, dte=21, mid=112.4000
# [day 12/21] 2021-02-19 -> 2021-02-22
# [pick_one] cp=C, K=2875.0, dte=21, mid=1028.4000, delta=0.9924, gamma=3.700000e-05, spread=6.8000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=1.0750, delta=-0.0065, gamma=3.700000e-05, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=112.4000, delta=0.6668, gamma=2.035000e-03, spread=0.6000, OI=70, vol=0
# [next fetch] cp=C, K=2875.0, dte=18, mid=1000.4500
# [next fetch] cp=P, K=2875.0, dte=18, mid=0.9250
# [next fetch] cp=C, K=3830.0, dte=21, mid=96.4500
# [day 13/21] 2021-02-22 -> 2021-02-23
# [pick_one] cp=C, K=2875.0, dte=18, mid=1000.4500, delta=0.9981, gamma=1.200000e-05, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=0.9250, delta=-0.0059, gamma=3.600000e-05, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=96.4500, delta=0.6080, gamma=2.125000e-03, spread=7.1000, OI=39, vol=6
# [next fetch] cp=C, K=2875.0, dte=24, mid=1006.9500
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=22, mid=102.9500
# [day 14/21] 2021-02-23 -> 2021-02-24
# [pick_one] cp=C, K=2875.0, dte=24, mid=1006.9500, delta=0.9969, gamma=2.200000e-05, spread=3.9000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3750, delta=-0.0080, gamma=4.400000e-05, spread=0.1500, OI=7071, vol=2
# [pick_one] cp=C, K=3830.0, dte=22, mid=102.9500, delta=0.6184, gamma=2.033000e-03, spread=0.5000, OI=40, vol=2
# [next fetch] cp=C, K=2875.0, dte=23, mid=1048.0500
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.1250
# [next fetch] cp=C, K=3830.0, dte=21, mid=127.3000
# [day 15/21] 2021-02-24 -> 2021-02-25
# [pick_one] cp=C, K=2875.0, dte=23, mid=1048.0500, delta=0.9947, gamma=2.700000e-05, spread=5.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.1250, delta=-0.0066, gamma=3.700000e-05, spread=0.1500, OI=7071, vol=1250
# [pick_one] cp=C, K=3830.0, dte=21, mid=127.3000, delta=0.7045, gamma=1.895000e-03, spread=0.8000, OI=42, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=958.9500
# [next fetch] cp=P, K=2875.0, dte=22, mid=3.8000
# [next fetch] cp=C, K=3830.0, dte=22, mid=88.4500
# [day 16/21] 2021-02-25 -> 2021-02-26
# [pick_one] cp=C, K=2875.0, dte=22, mid=958.9500, delta=0.9795, gamma=8.900000e-05, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.8000, delta=-0.0183, gamma=8.300000e-05, spread=0.4000, OI=6913, vol=2
# [pick_one] cp=C, K=3830.0, dte=22, mid=88.4500, delta=0.5108, gamma=1.794000e-03, spread=1.3000, OI=10896, vol=4262
# [next fetch] cp=C, K=2875.0, dte=21, mid=948.9500
# [next fetch] cp=P, K=2875.0, dte=21, mid=2.5250
# [next fetch] cp=C, K=3830.0, dte=21, mid=74.5000
# [day 17/21] 2021-02-26 -> 2021-03-01
# [pick_one] cp=C, K=2875.0, dte=21, mid=948.9500, delta=0.9563, gamma=1.400000e-04, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=2.5250, delta=-0.0137, gamma=7.000000e-05, spread=0.2500, OI=6814, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=74.5000, delta=0.4754, gamma=1.907000e-03, spread=1.2000, OI=11343, vol=4807
# [next fetch] cp=C, K=2875.0, dte=18, mid=1020.1500
# [next fetch] cp=P, K=2875.0, dte=18, mid=1.1750
# [next fetch] cp=C, K=3830.0, dte=21, mid=110.3000
# [day 18/21] 2021-03-01 -> 2021-03-02
# [pick_one] cp=C, K=2875.0, dte=18, mid=1020.1500, delta=0.9916, gamma=3.700000e-05, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=1.1750, delta=-0.0070, gamma=3.900000e-05, spread=0.1500, OI=6814, vol=1
# [pick_one] cp=C, K=3830.0, dte=21, mid=110.3000, delta=0.6431, gamma=1.987000e-03, spread=0.8000, OI=295, vol=12
# [next fetch] cp=C, K=2875.0, dte=24, mid=997.2500
# [next fetch] cp=P, K=2875.0, dte=24, mid=2.2250
# [next fetch] cp=C, K=3830.0, dte=20, mid=95.3000
# [day 19/21] 2021-03-02 -> 2021-03-03
# [pick_one] cp=C, K=2875.0, dte=24, mid=997.2500, delta=0.9890, gamma=5.600000e-05, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=2.2250, delta=-0.0118, gamma=5.900000e-05, spread=0.1500, OI=1185, vol=286
# [pick_one] cp=C, K=3830.0, dte=20, mid=95.3000, delta=0.5965, gamma=2.097000e-03, spread=0.6000, OI=287, vol=9
# [next fetch] cp=C, K=2875.0, dte=23, mid=947.1000
# [next fetch] cp=P, K=2875.0, dte=23, mid=2.5750
# [next fetch] cp=C, K=3830.0, dte=21, mid=72.2000
# [day 20/21] 2021-03-03 -> 2021-03-04
# [pick_one] cp=C, K=2875.0, dte=23, mid=947.1000, delta=0.9872, gamma=6.600000e-05, spread=9.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=2.5750, delta=-0.0138, gamma=6.900000e-05, spread=0.2500, OI=1425, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=72.2000, delta=0.4892, gamma=2.065000e-03, spread=0.8000, OI=2, vol=2
# [next fetch] cp=C, K=2875.0, dte=22, mid=891.7500
# [next fetch] cp=P, K=2875.0, dte=22, mid=3.3500
# [next fetch] cp=C, K=3830.0, dte=22, mid=51.1000
# [day 21/21] 2021-03-04 -> 2021-03-05
# [pick_one] cp=C, K=2875.0, dte=22, mid=891.7500, delta=0.9798, gamma=9.100000e-05, spread=8.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.3500, delta=-0.0178, gamma=8.800000e-05, spread=0.3000, OI=1426, vol=25
# [pick_one] cp=C, K=3830.0, dte=22, mid=51.1000, delta=0.3792, gamma=1.907000e-03, spread=0.8000, OI=151, vol=138
# [next fetch] cp=C, K=2875.0, dte=21, mid=965.1000
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.7750
# [next fetch] cp=C, K=3830.0, dte=21, mid=79.5000
# [pick_one] cp=C, K=2875.0, dte=22, mid=891.7500, delta=0.9798, gamma=9.100000e-05, spread=8.1000, OI=0, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=965.1000
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.3500, delta=-0.0178, gamma=8.800000e-05, spread=0.3000, OI=1426, vol=25
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.7750
# [window done] m0=0.75, Z_T=0.853599, V_T=966.875000, Π_T=966.021401
#
# --- Window 3/31 (start_idx=42) ---
# [get_window_dates] start=2021-03-05 end=2021-04-06 len=22
# [choose_strike_for_m0] spot0=3841.9400, m0=0.750, target=2881.4550 -> K=2880.0
# [nearest_atm_strike] spot0=3841.9400 -> K_ATM=3840.0
# [day 1/21] 2021-03-05 -> 2021-03-08
# [pick_one] cp=C, K=2880.0, dte=26, mid=960.1500, delta=0.9862, gamma=6.400000e-05, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=26, mid=2.5750, delta=-0.0136, gamma=6.800000e-05, spread=0.2500, OI=102, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=73.0000, delta=0.5058, gamma=2.153000e-03, spread=0.8000, OI=225, vol=78
# [next fetch] cp=C, K=2880.0, dte=23, mid=946.9500
# [next fetch] cp=P, K=2880.0, dte=23, mid=2.2000
# [next fetch] cp=C, K=3840.0, dte=21, mid=67.9500
# [init] V0=Π0=962.725000
# [day 2/21] 2021-03-08 -> 2021-03-09
# [pick_one] cp=C, K=2880.0, dte=23, mid=946.9500, delta=0.9759, gamma=1.000000e-04, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=23, mid=2.2000, delta=-0.0123, gamma=6.400000e-05, spread=0.2000, OI=102, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=67.9500, delta=0.4719, gamma=2.072000e-03, spread=6.1000, OI=39, vol=22
# [next fetch] cp=C, K=2880.0, dte=22, mid=994.8500
# [next fetch] cp=P, K=2880.0, dte=22, mid=1.3000
# [next fetch] cp=C, K=3840.0, dte=22, mid=95.3500
# [day 3/21] 2021-03-09 -> 2021-03-10
# [pick_one] cp=C, K=2880.0, dte=22, mid=994.8500, delta=0.9908, gamma=4.700000e-05, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=22, mid=1.3000, delta=-0.0078, gamma=4.400000e-05, spread=0.2000, OI=102, vol=3
# [pick_one] cp=C, K=3840.0, dte=22, mid=95.3500, delta=0.5778, gamma=2.003000e-03, spread=0.7000, OI=436, vol=5
# [next fetch] cp=C, K=2880.0, dte=21, mid=1018.4500
# [next fetch] cp=P, K=2880.0, dte=21, mid=0.9750
# [next fetch] cp=C, K=3840.0, dte=21, mid=105.8500
# [day 4/21] 2021-03-10 -> 2021-03-11
# [pick_one] cp=C, K=2880.0, dte=21, mid=1018.4500, delta=0.9945, gamma=3.200000e-05, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=21, mid=0.9750, delta=-0.0061, gamma=3.600000e-05, spread=0.1500, OI=103, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=105.8500, delta=0.6318, gamma=2.031000e-03, spread=0.7000, OI=436, vol=0
# [next fetch] cp=C, K=2880.0, dte=20, mid=1055.3500
# [next fetch] cp=P, K=2880.0, dte=20, mid=0.6750
# [next fetch] cp=C, K=3840.0, dte=21, mid=131.4500
# [day 5/21] 2021-03-11 -> 2021-03-12
# [pick_one] cp=C, K=2880.0, dte=20, mid=1055.3500, delta=0.9960, gamma=1.900000e-05, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=20, mid=0.6750, delta=-0.0043, gamma=2.700000e-05, spread=0.1500, OI=103, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=131.4500, delta=0.7023, gamma=1.827000e-03, spread=0.7000, OI=338, vol=63
# [next fetch] cp=C, K=2880.0, dte=19, mid=1062.5500
# [next fetch] cp=P, K=2880.0, dte=35, mid=2.7500
# [next fetch] cp=C, K=3840.0, dte=20, mid=131.8500
# [day 6/21] 2021-03-12 -> 2021-03-15
# [pick_one] cp=C, K=2880.0, dte=19, mid=1062.5500, delta=0.9978, gamma=1.400000e-05, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=35, mid=2.7500, delta=-0.0131, gamma=5.800000e-05, spread=0.1000, OI=1356, vol=18
# [pick_one] cp=C, K=3840.0, dte=20, mid=131.8500, delta=0.7306, gamma=1.886000e-03, spread=0.7000, OI=316, vol=5
# [next fetch] cp=C, K=2880.0, dte=32, mid=1085.8500
# [next fetch] cp=P, K=2880.0, dte=32, mid=1.9750
# [next fetch] cp=C, K=3840.0, dte=21, mid=148.3500
# [day 7/21] 2021-03-15 -> 2021-03-16
# [pick_one] cp=C, K=2880.0, dte=32, mid=1085.8500, delta=0.9902, gamma=4.200000e-05, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=32, mid=1.9750, delta=-0.0099, gamma=4.700000e-05, spread=0.1500, OI=1356, vol=7
# [pick_one] cp=C, K=3840.0, dte=21, mid=148.3500, delta=0.7752, gamma=1.725000e-03, spread=8.1000, OI=80, vol=14
# [next fetch] cp=C, K=2880.0, dte=31, mid=1082.8000
# [next fetch] cp=P, K=2880.0, dte=31, mid=1.8250
# [next fetch] cp=C, K=3840.0, dte=20, mid=146.1000
# [day 8/21] 2021-03-16 -> 2021-03-17
# [pick_one] cp=C, K=2880.0, dte=31, mid=1082.8000, delta=0.9926, gamma=3.700000e-05, spread=8.0000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=31, mid=1.8250, delta=-0.0094, gamma=4.500000e-05, spread=0.1500, OI=1356, vol=9
# [pick_one] cp=C, K=3840.0, dte=20, mid=146.1000, delta=0.7715, gamma=1.752000e-03, spread=0.8000, OI=93, vol=7
# [next fetch] cp=C, K=2880.0, dte=30, mid=1091.6000
# [next fetch] cp=P, K=2880.0, dte=30, mid=1.6250
# [next fetch] cp=C, K=3840.0, dte=21, mid=153.6000
# [day 9/21] 2021-03-17 -> 2021-03-18
# [pick_one] cp=C, K=2880.0, dte=30, mid=1091.6000, delta=0.9935, gamma=3.100000e-05, spread=6.4000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=30, mid=1.6250, delta=-0.0085, gamma=4.200000e-05, spread=0.1500, OI=1356, vol=8
# [pick_one] cp=C, K=3840.0, dte=21, mid=153.6000, delta=0.7857, gamma=1.672000e-03, spread=1.4000, OI=3, vol=0
# [next fetch] cp=C, K=2880.0, dte=29, mid=1037.2500
# [next fetch] cp=P, K=2880.0, dte=29, mid=2.5500
# [next fetch] cp=C, K=3840.0, dte=22, mid=116.4500
# [day 10/21] 2021-03-18 -> 2021-03-19
# [pick_one] cp=C, K=2880.0, dte=29, mid=1037.2500, delta=0.9914, gamma=4.500000e-05, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=29, mid=2.5500, delta=-0.0126, gamma=5.900000e-05, spread=0.2000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=22, mid=116.4500, delta=0.6702, gamma=1.976000e-03, spread=1.3000, OI=40, vol=0
# [next fetch] cp=C, K=2880.0, dte=28, mid=1032.1500
# [next fetch] cp=P, K=2880.0, dte=28, mid=1.7500
# [next fetch] cp=C, K=3840.0, dte=21, mid=107.9000
# [day 11/21] 2021-03-19 -> 2021-03-22
# [pick_one] cp=C, K=2880.0, dte=28, mid=1032.1500, delta=0.9905, gamma=4.600000e-05, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=28, mid=1.7500, delta=-0.0095, gamma=4.800000e-05, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=107.9000, delta=0.6727, gamma=2.145000e-03, spread=0.8000, OI=40, vol=2
# [next fetch] cp=C, K=2880.0, dte=25, mid=1058.7500
# [next fetch] cp=P, K=2880.0, dte=25, mid=1.1000
# [next fetch] cp=C, K=3840.0, dte=21, mid=124.1000
# [day 12/21] 2021-03-22 -> 2021-03-23
# [pick_one] cp=C, K=2880.0, dte=25, mid=1058.7500, delta=0.9937, gamma=3.200000e-05, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=25, mid=1.1000, delta=-0.0064, gamma=3.500000e-05, spread=0.1000, OI=1356, vol=11
# [pick_one] cp=C, K=3840.0, dte=21, mid=124.1000, delta=0.7398, gamma=2.025000e-03, spread=1.0000, OI=10, vol=1
# [next fetch] cp=C, K=2880.0, dte=24, mid=1027.2500
# [next fetch] cp=P, K=2880.0, dte=24, mid=1.5750
# [next fetch] cp=C, K=3840.0, dte=20, mid=102.5500
# [day 13/21] 2021-03-23 -> 2021-03-24
# [pick_one] cp=C, K=2880.0, dte=24, mid=1027.2500, delta=0.9913, gamma=4.100000e-05, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=24, mid=1.5750, delta=-0.0088, gamma=4.600000e-05, spread=0.1500, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=20, mid=102.5500, delta=0.6683, gamma=2.243000e-03, spread=0.9000, OI=11, vol=2
# [next fetch] cp=C, K=2880.0, dte=23, mid=1011.1500
# [next fetch] cp=P, K=2880.0, dte=23, mid=1.5500
# [next fetch] cp=C, K=3840.0, dte=21, mid=94.1500
# [day 14/21] 2021-03-24 -> 2021-03-25
# [pick_one] cp=C, K=2880.0, dte=23, mid=1011.1500, delta=0.9900, gamma=5.100000e-05, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=23, mid=1.5500, delta=-0.0088, gamma=4.700000e-05, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=94.1500, delta=0.6245, gamma=2.259000e-03, spread=0.7000, OI=3, vol=1
# [next fetch] cp=C, K=2880.0, dte=22, mid=1030.7000
# [next fetch] cp=P, K=2880.0, dte=22, mid=1.2000
# [next fetch] cp=C, K=3840.0, dte=22, mid=106.4500
# [day 15/21] 2021-03-25 -> 2021-03-26
# [pick_one] cp=C, K=2880.0, dte=22, mid=1030.7000, delta=0.9936, gamma=3.600000e-05, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=22, mid=1.2000, delta=-0.0071, gamma=3.900000e-05, spread=0.1000, OI=1356, vol=15
# [pick_one] cp=C, K=3840.0, dte=22, mid=106.4500, delta=0.6715, gamma=2.172000e-03, spread=2.5000, OI=929, vol=5
# [next fetch] cp=C, K=2880.0, dte=21, mid=1087.2500
# [next fetch] cp=P, K=2880.0, dte=21, mid=0.9250
# [next fetch] cp=C, K=3840.0, dte=21, mid=149.1000
# [day 16/21] 2021-03-26 -> 2021-03-29
# [pick_one] cp=C, K=2880.0, dte=21, mid=1087.2500, delta=0.9941, gamma=2.400000e-05, spread=8.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=21, mid=0.9250, delta=-0.0054, gamma=3.000000e-05, spread=0.1500, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=149.1000, delta=0.7772, gamma=1.715000e-03, spread=7.8000, OI=928, vol=22
# [next fetch] cp=C, K=2880.0, dte=18, mid=1088.9500
# [next fetch] cp=P, K=2880.0, dte=18, mid=0.7000
# [next fetch] cp=C, K=3840.0, dte=21, mid=155.3000
# [day 17/21] 2021-03-29 -> 2021-03-30
# [pick_one] cp=C, K=2880.0, dte=18, mid=1088.9500, delta=0.9963, gamma=1.900000e-05, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=18, mid=0.7000, delta=-0.0043, gamma=2.600000e-05, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=155.3000, delta=0.7634, gamma=1.636000e-03, spread=0.8000, OI=292, vol=3
# [next fetch] cp=C, K=2880.0, dte=17, mid=1069.6000
# [next fetch] cp=P, K=2880.0, dte=17, mid=0.4500
# [next fetch] cp=C, K=3840.0, dte=20, mid=135.6500
# [day 18/21] 2021-03-30 -> 2021-03-31
# [pick_one] cp=C, K=2880.0, dte=17, mid=1069.6000, delta=0.9952, gamma=1.700000e-05, spread=7.6000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=17, mid=0.4500, delta=-0.0031, gamma=2.000000e-05, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=20, mid=135.6500, delta=0.7478, gamma=1.856000e-03, spread=0.9000, OI=292, vol=9
# [next fetch] cp=C, K=2880.0, dte=16, mid=1100.8000
# [next fetch] cp=P, K=2880.0, dte=16, mid=0.3000
# [next fetch] cp=C, K=3840.0, dte=21, mid=159.7000
# [day 19/21] 2021-03-31 -> 2021-04-01
# [pick_one] cp=C, K=2880.0, dte=16, mid=1100.8000, delta=0.9726, gamma=9.100000e-05, spread=6.8000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=16, mid=0.3000, delta=-0.0022, gamma=1.500000e-05, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=159.7000, delta=0.7676, gamma=1.595000e-03, spread=7.8000, OI=0, vol=0
# [next fetch] cp=C, K=2880.0, dte=15, mid=1138.0000
# [next fetch] MISSING next-day row for cp=P, K=2880.0
# [next fetch] cp=C, K=3840.0, dte=22, mid=192.8500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=42.
#
# --- Window 4/31 (start_idx=63) ---
# [get_window_dates] start=2021-04-06 end=2021-05-05 len=22
# [choose_strike_for_m0] spot0=4073.9400, m0=0.750, target=3055.4550 -> K=3060.0
# [nearest_atm_strike] spot0=4073.9400 -> K_ATM=4075.0
# [day 1/21] 2021-04-06 -> 2021-04-07
# [pick_one] cp=C, K=3060.0, dte=24, mid=1010.2500, delta=0.9939, gamma=3.100000e-05, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=24, mid=1.0000, delta=-0.0063, gamma=3.700000e-05, spread=0.1000, OI=73, vol=33
# [pick_one] cp=C, K=4075.0, dte=20, mid=47.0500, delta=0.4893, gamma=3.206000e-03, spread=0.5000, OI=1603, vol=61
# [next fetch] cp=C, K=3060.0, dte=23, mid=1017.5500
# [next fetch] cp=P, K=3060.0, dte=23, mid=0.6750
# [next fetch] cp=C, K=4075.0, dte=21, mid=51.7500
# [init] V0=Π0=1011.250000
# [day 2/21] 2021-04-07 -> 2021-04-08
# [pick_one] cp=C, K=3060.0, dte=23, mid=1017.5500, delta=0.9968, gamma=1.800000e-05, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=23, mid=0.6750, delta=-0.0045, gamma=2.900000e-05, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=21, mid=51.7500, delta=0.5141, gamma=3.149000e-03, spread=0.5000, OI=246, vol=53
# [next fetch] cp=C, K=3060.0, dte=22, mid=1034.9000
# [next fetch] cp=P, K=3060.0, dte=22, mid=0.5750
# [next fetch] cp=C, K=4075.0, dte=22, mid=64.4500
# [day 3/21] 2021-04-08 -> 2021-04-09
# [pick_one] cp=C, K=3060.0, dte=22, mid=1034.9000, delta=0.9959, gamma=2.200000e-05, spread=4.8000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=22, mid=0.5750, delta=-0.0039, gamma=2.500000e-05, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=22, mid=64.4500, delta=0.5633, gamma=2.891000e-03, spread=0.5000, OI=3528, vol=125
# [next fetch] cp=C, K=3060.0, dte=21, mid=1066.2000
# [next fetch] cp=P, K=3060.0, dte=21, mid=0.4000
# [next fetch] cp=C, K=4075.0, dte=21, mid=84.7500
# [day 4/21] 2021-04-09 -> 2021-04-12
# [pick_one] cp=C, K=3060.0, dte=21, mid=1066.2000, delta=0.9991, gamma=2.000000e-06, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=21, mid=0.4000, delta=-0.0028, gamma=1.900000e-05, spread=0.1000, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=21, mid=84.7500, delta=0.6498, gamma=2.646000e-03, spread=0.7000, OI=4212, vol=28
# [next fetch] cp=C, K=3060.0, dte=18, mid=1068.3500
# [next fetch] MISSING next-day row for cp=P, K=3060.0
# [next fetch] cp=C, K=4075.0, dte=21, mid=86.3500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=63.
#
# --- Window 5/31 (start_idx=84) ---
# [get_window_dates] start=2021-05-05 end=2021-06-04 len=22
# [choose_strike_for_m0] spot0=4167.5900, m0=0.750, target=3125.6925 -> K=3125.0
# [nearest_atm_strike] spot0=4167.5900 -> K_ATM=4170.0
# [day 1/21] 2021-05-05 -> 2021-05-06
# [pick_one] cp=C, K=3125.0, dte=23, mid=1037.2000, delta=0.9943, gamma=2.700000e-05, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=1.0750, delta=-0.0065, gamma=3.700000e-05, spread=0.1500, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=54.4000, delta=0.4852, gamma=2.728000e-03, spread=0.4000, OI=20, vol=17
# [next fetch] cp=C, K=3125.0, dte=22, mid=1069.6500
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.0000
# [next fetch] cp=C, K=4170.0, dte=22, mid=73.7500
# [init] V0=Π0=1038.275000
# [day 2/21] 2021-05-06 -> 2021-05-07
# [pick_one] cp=C, K=3125.0, dte=22, mid=1069.6500, delta=0.9928, gamma=3.100000e-05, spread=6.9000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.0000, delta=-0.0060, gamma=3.400000e-05, spread=0.1000, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=73.7500, delta=0.5680, gamma=2.549000e-03, spread=0.5000, OI=136, vol=23
# [next fetch] cp=C, K=3125.0, dte=21, mid=1103.5500
# [next fetch] cp=P, K=3125.0, dte=21, mid=0.5750
# [next fetch] cp=C, K=4170.0, dte=21, mid=92.1000
# [day 3/21] 2021-05-07 -> 2021-05-10
# [pick_one] cp=C, K=3125.0, dte=21, mid=1103.5500, delta=0.9970, gamma=1.400000e-05, spread=3.5000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=0.5750, delta=-0.0037, gamma=2.300000e-05, spread=0.1500, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=92.1000, delta=0.6607, gamma=2.479000e-03, spread=0.6000, OI=142, vol=20
# [next fetch] cp=C, K=3125.0, dte=18, mid=1061.2500
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.8500
# [next fetch] cp=C, K=4170.0, dte=22, mid=69.8000
# [day 4/21] 2021-05-10 -> 2021-05-11
# [pick_one] cp=C, K=3125.0, dte=18, mid=1061.2500, delta=0.9949, gamma=2.700000e-05, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.8500, delta=-0.0053, gamma=3.100000e-05, spread=0.1000, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=69.8000, delta=0.5470, gamma=2.553000e-03, spread=0.6000, OI=50, vol=3
# [next fetch] cp=C, K=3125.0, dte=24, mid=1024.7500
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=4170.0, dte=21, mid=54.0000
# [day 5/21] 2021-05-11 -> 2021-05-12
# [pick_one] cp=C, K=3125.0, dte=24, mid=1024.7500, delta=0.9896, gamma=4.900000e-05, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.7750, delta=-0.0098, gamma=5.000000e-05, spread=0.1500, OI=549, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=54.0000, delta=0.4526, gamma=2.452000e-03, spread=0.8000, OI=52, vol=2
# [next fetch] cp=C, K=3125.0, dte=23, mid=942.6000
# [next fetch] cp=P, K=3125.0, dte=23, mid=4.5000
# [next fetch] cp=C, K=4170.0, dte=21, mid=30.9000
# [day 6/21] 2021-05-12 -> 2021-05-13
# [pick_one] cp=C, K=3125.0, dte=23, mid=942.6000, delta=0.9782, gamma=9.500000e-05, spread=7.0000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=4.5000, delta=-0.0213, gamma=9.400000e-05, spread=0.2000, OI=549, vol=139
# [pick_one] cp=C, K=4170.0, dte=21, mid=30.9000, delta=0.2845, gamma=1.901000e-03, spread=0.8000, OI=61, vol=11
# [next fetch] cp=C, K=3125.0, dte=22, mid=987.3000
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.9250
# [next fetch] cp=C, K=4170.0, dte=22, mid=41.7500
# [day 7/21] 2021-05-13 -> 2021-05-14
# [pick_one] cp=C, K=3125.0, dte=22, mid=987.3000, delta=0.9900, gamma=5.200000e-05, spread=4.6000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.9250, delta=-0.0108, gamma=5.600000e-05, spread=0.1500, OI=568, vol=36
# [pick_one] cp=C, K=4170.0, dte=22, mid=41.7500, delta=0.3701, gamma=2.253000e-03, spread=0.5000, OI=220, vol=69
# [next fetch] cp=C, K=3125.0, dte=21, mid=1047.7500
# [next fetch] cp=P, K=3125.0, dte=21, mid=1.0250
# [next fetch] cp=C, K=4170.0, dte=21, mid=58.6000
# [day 8/21] 2021-05-14 -> 2021-05-17
# [pick_one] cp=C, K=3125.0, dte=21, mid=1047.7500, delta=0.9935, gamma=3.400000e-05, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=1.0250, delta=-0.0062, gamma=3.500000e-05, spread=0.1500, OI=512, vol=200
# [pick_one] cp=C, K=4170.0, dte=21, mid=58.6000, delta=0.5117, gamma=2.754000e-03, spread=0.6000, OI=223, vol=25
# [next fetch] cp=C, K=3125.0, dte=18, mid=1035.9500
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.7500
# [next fetch] cp=C, K=4170.0, dte=21, mid=53.2500
# [day 9/21] 2021-05-17 -> 2021-05-18
# [pick_one] cp=C, K=3125.0, dte=18, mid=1035.9500, delta=0.9954, gamma=2.500000e-05, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.7500, delta=-0.0049, gamma=3.000000e-05, spread=0.1000, OI=614, vol=60
# [pick_one] cp=C, K=4170.0, dte=21, mid=53.2500, delta=0.4801, gamma=2.742000e-03, spread=0.5000, OI=54, vol=3
# [next fetch] cp=C, K=3125.0, dte=24, mid=1005.1000
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=4170.0, dte=22, mid=41.7500
# [day 10/21] 2021-05-18 -> 2021-05-19
# [pick_one] cp=C, K=3125.0, dte=24, mid=1005.1000, delta=0.9888, gamma=5.700000e-05, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.7750, delta=-0.0099, gamma=5.200000e-05, spread=0.1500, OI=133, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=41.7500, delta=0.3979, gamma=2.560000e-03, spread=0.5000, OI=722, vol=21
# [next fetch] cp=C, K=3125.0, dte=23, mid=987.8000
# [next fetch] cp=P, K=3125.0, dte=23, mid=2.0750
# [next fetch] cp=C, K=4170.0, dte=21, mid=33.8000
# [day 11/21] 2021-05-19 -> 2021-05-20
# [pick_one] cp=C, K=3125.0, dte=23, mid=987.8000, delta=0.9910, gamma=4.500000e-05, spread=4.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=2.0750, delta=-0.0114, gamma=5.900000e-05, spread=0.1500, OI=133, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=33.8000, delta=0.3516, gamma=2.552000e-03, spread=0.6000, OI=732, vol=22
# [next fetch] cp=C, K=3125.0, dte=22, mid=1029.8000
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.4250
# [next fetch] cp=C, K=4170.0, dte=20, mid=48.4500
# [day 12/21] 2021-05-20 -> 2021-05-21
# [pick_one] cp=C, K=3125.0, dte=22, mid=1029.8000, delta=0.9909, gamma=4.200000e-05, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.4250, delta=-0.0082, gamma=4.400000e-05, spread=0.1500, OI=133, vol=20
# [pick_one] cp=C, K=4170.0, dte=20, mid=48.4500, delta=0.4601, gamma=2.815000e-03, spread=0.5000, OI=734, vol=33
# [next fetch] cp=C, K=3125.0, dte=21, mid=1027.6500
# [next fetch] cp=P, K=3125.0, dte=21, mid=1.1250
# [next fetch] cp=C, K=4170.0, dte=21, mid=48.8000
# [day 13/21] 2021-05-21 -> 2021-05-24
# [pick_one] cp=C, K=3125.0, dte=21, mid=1027.6500, delta=0.9937, gamma=3.200000e-05, spread=7.3000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=1.1250, delta=-0.0068, gamma=3.900000e-05, spread=0.1500, OI=148, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=48.8000, delta=0.4563, gamma=2.756000e-03, spread=0.4000, OI=358, vol=55
# [next fetch] cp=C, K=3125.0, dte=18, mid=1070.6000
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.6500
# [next fetch] cp=C, K=4170.0, dte=21, mid=66.4500
# [day 14/21] 2021-05-24 -> 2021-05-25
# [pick_one] cp=C, K=3125.0, dte=18, mid=1070.6000, delta=0.9950, gamma=2.700000e-05, spread=3.8000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.6500, delta=-0.0042, gamma=2.600000e-05, spread=0.1000, OI=148, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=66.4500, delta=0.5772, gamma=2.904000e-03, spread=0.5000, OI=234, vol=4
# [next fetch] cp=C, K=3125.0, dte=17, mid=1061.1000
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=4170.0, dte=20, mid=60.1000
# [day 15/21] 2021-05-25 -> 2021-05-26
# [pick_one] cp=C, K=3125.0, dte=17, mid=1061.1000, delta=0.9973, gamma=1.600000e-05, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.3750, delta=-0.0077, gamma=4.100000e-05, spread=0.1500, OI=4390, vol=40
# [pick_one] cp=C, K=4170.0, dte=20, mid=60.1000, delta=0.5511, gamma=3.007000e-03, spread=0.6000, OI=230, vol=40
# [next fetch] cp=C, K=3125.0, dte=23, mid=1066.4000
# [next fetch] cp=P, K=3125.0, dte=23, mid=1.0000
# [next fetch] cp=C, K=4170.0, dte=21, mid=64.5500
# [day 16/21] 2021-05-26 -> 2021-05-27
# [pick_one] cp=C, K=3125.0, dte=23, mid=1066.4000, delta=0.9950, gamma=2.400000e-05, spread=4.8000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=1.0000, delta=-0.0060, gamma=3.400000e-05, spread=0.1000, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=64.5500, delta=0.5682, gamma=2.924000e-03, spread=0.5000, OI=50, vol=24
# [next fetch] cp=C, K=3125.0, dte=22, mid=1077.3000
# [next fetch] cp=P, K=3125.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=4170.0, dte=22, mid=70.9000
# [day 17/21] 2021-05-27 -> 2021-05-28
# [pick_one] cp=C, K=3125.0, dte=22, mid=1077.3000, delta=0.9928, gamma=3.800000e-05, spread=4.8000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=0.9500, delta=-0.0057, gamma=3.200000e-05, spread=0.1000, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=70.9000, delta=0.5971, gamma=2.852000e-03, spread=0.6000, OI=11780, vol=2
# [next fetch] cp=C, K=3125.0, dte=21, mid=1078.5000
# [next fetch] cp=P, K=3125.0, dte=21, mid=0.8250
# [next fetch] cp=C, K=4170.0, dte=21, mid=69.3500
# [day 18/21] 2021-05-28 -> 2021-06-01
# [pick_one] cp=C, K=3125.0, dte=21, mid=1078.5000, delta=0.9959, gamma=2.300000e-05, spread=5.4000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=0.8250, delta=-0.0051, gamma=3.000000e-05, spread=0.1500, OI=4352, vol=3
# [pick_one] cp=C, K=4170.0, dte=21, mid=69.3500, delta=0.6071, gamma=2.983000e-03, spread=0.7000, OI=11779, vol=204
# [next fetch] cp=C, K=3125.0, dte=17, mid=1073.2000
# [next fetch] cp=P, K=3125.0, dte=17, mid=0.6750
# [next fetch] cp=C, K=4170.0, dte=20, mid=68.8500
# [day 19/21] 2021-06-01 -> 2021-06-02
# [pick_one] cp=C, K=3125.0, dte=17, mid=1073.2000, delta=0.9952, gamma=2.300000e-05, spread=4.4000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=17, mid=0.6750, delta=-0.0043, gamma=2.600000e-05, spread=0.1500, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=20, mid=68.8500, delta=0.5869, gamma=2.867000e-03, spread=0.5000, OI=57, vol=2
# [next fetch] cp=C, K=3125.0, dte=16, mid=1080.9000
# [next fetch] cp=P, K=3125.0, dte=16, mid=0.4500
# [next fetch] cp=C, K=4170.0, dte=21, mid=73.7500
# [day 20/21] 2021-06-02 -> 2021-06-03
# [pick_one] cp=C, K=3125.0, dte=16, mid=1080.9000, delta=0.9972, gamma=1.500000e-05, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=16, mid=0.4500, delta=-0.0031, gamma=2.000000e-05, spread=0.1000, OI=690, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=73.7500, delta=0.6108, gamma=2.823000e-03, spread=0.7000, OI=7, vol=5
# [next fetch] cp=C, K=3125.0, dte=15, mid=1067.3500
# [next fetch] cp=P, K=3125.0, dte=15, mid=0.4000
# [next fetch] cp=C, K=4170.0, dte=22, mid=69.1500
# [day 21/21] 2021-06-03 -> 2021-06-04
# [pick_one] cp=C, K=3125.0, dte=15, mid=1067.3500, delta=0.9995, gamma=3.000000e-06, spread=4.1000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=15, mid=0.4000, delta=-0.0028, gamma=1.900000e-05, spread=0.1000, OI=4352, vol=1
# [pick_one] cp=C, K=4170.0, dte=22, mid=69.1500, delta=0.5671, gamma=2.719000e-03, spread=0.5000, OI=135, vol=7
# [next fetch] cp=C, K=3125.0, dte=26, mid=1102.7500
# [next fetch] cp=P, K=3125.0, dte=26, mid=0.9750
# [next fetch] cp=C, K=4170.0, dte=21, mid=88.6500
# [pick_one] cp=C, K=3125.0, dte=15, mid=1067.3500, delta=0.9995, gamma=3.000000e-06, spread=4.1000, OI=1684, vol=0
# [next fetch] cp=C, K=3125.0, dte=26, mid=1102.7500
# [pick_one] cp=P, K=3125.0, dte=15, mid=0.4000, delta=-0.0028, gamma=1.900000e-05, spread=0.1000, OI=4352, vol=1
# [next fetch] cp=P, K=3125.0, dte=26, mid=0.9750
# [window done] m0=0.75, Z_T=5.395580, V_T=1103.725000, Π_T=1098.329420
#
# --- Window 6/31 (start_idx=105) ---
# [get_window_dates] start=2021-06-04 end=2021-07-06 len=22
# [choose_strike_for_m0] spot0=4229.8900, m0=0.750, target=3172.4175 -> K=3170.0
# [nearest_atm_strike] spot0=4229.8900 -> K_ATM=4230.0
# [day 1/21] 2021-06-04 -> 2021-06-07
# [pick_one] cp=C, K=3170.0, dte=26, mid=1058.5000, delta=0.9943, gamma=3.000000e-05, spread=3.8000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=26, mid=1.0750, delta=-0.0064, gamma=3.600000e-05, spread=0.1500, OI=550, vol=0
# ...
# [nearest_atm_strike] spot0=4630.6500 -> K_ATM=4630.0
# [day 1/21] 2021-11-02 -> 2021-11-03
# [pick_one] MISSING leg for cp=C, K=5800.0
# [pick_one] cp=P, K=5800.0, dte=17, mid=1173.4500, delta=-0.9988, gamma=4.000000e-06, spread=6.3000, OI=137, vol=0
# [pick_one] cp=C, K=4630.0, dte=22, mid=51.5000, delta=0.4932, gamma=2.969000e-03, spread=0.4000, OI=173, vol=59
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=210.
#
# --- Window 12/31 (start_idx=231) ---
# [get_window_dates] start=2021-12-02 end=2022-01-03 len=22
# [choose_strike_for_m0] spot0=4577.1000, m0=1.250, target=5721.3750 -> K=5350.0
# [nearest_atm_strike] spot0=4577.1000 -> K_ATM=4575.0
# [day 1/21] 2021-12-02 -> 2021-12-03
# [pick_one] MISSING leg for cp=C, K=5350.0
# [pick_one] cp=P, K=5350.0, dte=15, mid=784.2500, delta=-0.9950, gamma=3.000000e-05, spread=15.1000, OI=0, vol=0
# [pick_one] cp=C, K=4575.0, dte=21, mid=92.4000, delta=0.4947, gamma=1.638000e-03, spread=1.0000, OI=176, vol=53
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=231.
#
# --- Window 13/31 (start_idx=252) ---
# [get_window_dates] start=2022-01-03 end=2022-02-02 len=22
# [choose_strike_for_m0] spot0=4796.5600, m0=1.250, target=5995.7000 -> K=6000.0
# [nearest_atm_strike] spot0=4796.5600 -> K_ATM=4795.0
# [day 1/21] 2022-01-03 -> 2022-01-04
# [pick_one] MISSING leg for cp=C, K=6000.0
# [pick_one] cp=P, K=6000.0, dte=21, mid=1208.9500, delta=-0.9983, gamma=2.000000e-06, spread=7.5000, OI=0, vol=0
# [pick_one] cp=C, K=4795.0, dte=21, mid=48.5500, delta=0.4910, gamma=3.132000e-03, spread=0.5000, OI=14, vol=27
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=252.
#
# --- Window 14/31 (start_idx=273) ---
# [get_window_dates] start=2022-02-02 end=2022-03-04 len=22
# [choose_strike_for_m0] spot0=4589.3800, m0=1.250, target=5736.7250 -> K=5700.0
# [nearest_atm_strike] spot0=4589.3800 -> K_ATM=4590.0
# [day 1/21] 2022-02-02 -> 2022-02-03
# [pick_one] MISSING leg for cp=C, K=5700.0
# [pick_one] cp=P, K=5700.0, dte=26, mid=1117.8500, delta=-0.9954, gamma=2.300000e-05, spread=6.5000, OI=1, vol=0
# [pick_one] cp=C, K=4590.0, dte=21, mid=68.3000, delta=0.4916, gamma=2.213000e-03, spread=0.8000, OI=27, vol=25
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=273.
#
# --- Window 15/31 (start_idx=294) ---
# [get_window_dates] start=2022-03-04 end=2022-04-04 len=22
# [choose_strike_for_m0] spot0=4328.8700, m0=1.250, target=5411.0875 -> K=5130.0
# [nearest_atm_strike] spot0=4328.8700 -> K_ATM=4330.0
# [day 1/21] 2022-03-04 -> 2022-03-07
# [pick_one] MISSING leg for cp=C, K=5130.0
# [pick_one] cp=P, K=5130.0, dte=27, mid=803.8000, delta=-0.9985, gamma=8.000000e-06, spread=6.4000, OI=0, vol=0
# [pick_one] cp=C, K=4330.0, dte=21, mid=112.8000, delta=0.5081, gamma=1.388000e-03, spread=0.6000, OI=67, vol=139
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=294.
#
# --- Window 16/31 (start_idx=315) ---
# [get_window_dates] start=2022-04-04 end=2022-05-04 len=22
# [choose_strike_for_m0] spot0=4582.6400, m0=1.250, target=5728.3000 -> K=5800.0
# [nearest_atm_strike] spot0=4582.6400 -> K_ATM=4585.0
# [day 1/21] 2022-04-04 -> 2022-04-05
# [pick_one] MISSING leg for cp=C, K=5800.0
# [pick_one] cp=P, K=5800.0, dte=28, mid=1221.4500, delta=-0.9968, gamma=1.600000e-05, spread=7.9000, OI=0, vol=0
# [pick_one] cp=C, K=4585.0, dte=21, mid=54.5000, delta=0.4877, gamma=2.752000e-03, spread=0.6000, OI=5, vol=8
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=315.
#
# --- Window 17/31 (start_idx=336) ---
# [get_window_dates] start=2022-05-04 end=2022-06-03 len=22
# [choose_strike_for_m0] spot0=4300.1700, m0=1.250, target=5375.2125 -> K=5375.0
# [nearest_atm_strike] spot0=4300.1700 -> K_ATM=4300.0
# [day 1/21] 2022-05-04 -> 2022-05-05
# [pick_one] MISSING leg for cp=C, K=5375.0
# [pick_one] cp=P, K=5375.0, dte=16, mid=1079.4000, delta=-0.9849, gamma=8.400000e-05, spread=16.0000, OI=4, vol=0
# [pick_one] cp=C, K=4300.0, dte=21, mid=90.4000, delta=0.5053, gamma=1.731000e-03, spread=0.6000, OI=688, vol=249
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=336.
#
# --- Window 18/31 (start_idx=357) ---
# [get_window_dates] start=2022-06-03 end=2022-07-06 len=22
# [choose_strike_for_m0] spot0=4108.5400, m0=1.250, target=5135.6750 -> K=4900.0
# [nearest_atm_strike] spot0=4108.5400 -> K_ATM=4110.0
# [day 1/21] 2022-06-03 -> 2022-06-06
# [pick_one] MISSING leg for cp=C, K=4900.0
# [pick_one] cp=P, K=4900.0, dte=35, mid=792.2500, delta=-0.9974, gamma=1.600000e-05, spread=7.3000, OI=0, vol=0
# [pick_one] cp=C, K=4110.0, dte=21, mid=88.9000, delta=0.5061, gamma=1.763000e-03, spread=0.6000, OI=169, vol=49
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=357.
#
# --- Window 19/31 (start_idx=378) ---
# [get_window_dates] start=2022-07-06 end=2022-08-04 len=22
# [choose_strike_for_m0] spot0=3845.0800, m0=1.250, target=4806.3500 -> K=4800.0
# [nearest_atm_strike] spot0=3845.0800 -> K_ATM=3845.0
# [day 1/21] 2022-07-06 -> 2022-07-07
# [pick_one] MISSING leg for cp=C, K=4800.0
# [pick_one] cp=P, K=4800.0, dte=19, mid=954.3500, delta=-0.9986, gamma=9.000000e-06, spread=7.5000, OI=0, vol=0
# [pick_one] cp=C, K=3845.0, dte=21, mid=93.1000, delta=0.5122, gamma=1.708000e-03, spread=0.6000, OI=1, vol=3
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=378.
#
# --- Window 20/31 (start_idx=399) ---
# [get_window_dates] start=2022-08-04 end=2022-09-02 len=22
# [choose_strike_for_m0] spot0=4151.9400, m0=1.250, target=5189.9250 -> K=5200.0
# [nearest_atm_strike] spot0=4151.9400 -> K_ATM=4150.0
# [day 1/21] 2022-08-04 -> 2022-08-05
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=22, mid=1049.2000, delta=-0.9931, gamma=4.100000e-05, spread=7.0000, OI=0, vol=0
# [pick_one] cp=C, K=4150.0, dte=22, mid=77.2500, delta=0.5085, gamma=2.052000e-03, spread=0.5000, OI=2564, vol=411
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=399.
#
# --- Window 21/31 (start_idx=420) ---
# [get_window_dates] start=2022-09-02 end=2022-10-04 len=22
# [choose_strike_for_m0] spot0=3924.2600, m0=1.250, target=4905.3250 -> K=4910.0
# [nearest_atm_strike] spot0=3924.2600 -> K_ATM=3925.0
# [day 1/21] 2022-09-02 -> 2022-09-06
# [pick_one] MISSING leg for cp=C, K=4910.0
# [pick_one] cp=P, K=4910.0, dte=28, mid=987.2000, delta=-0.9924, gamma=4.200000e-05, spread=7.4000, OI=0, vol=0
# [pick_one] cp=C, K=3925.0, dte=21, mid=86.5000, delta=0.5024, gamma=1.788000e-03, spread=0.6000, OI=10, vol=31
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=420.
#
# --- Window 22/31 (start_idx=441) ---
# [get_window_dates] start=2022-10-04 end=2022-11-02 len=22
# [choose_strike_for_m0] spot0=3790.9300, m0=1.250, target=4738.6625 -> K=4740.0
# [nearest_atm_strike] spot0=3790.9300 -> K_ATM=3790.0
# [day 1/21] 2022-10-04 -> 2022-10-05
# [pick_one] MISSING leg for cp=C, K=4740.0
# [pick_one] cp=P, K=4740.0, dte=17, mid=949.2000, delta=-0.9889, gamma=7.300000e-05, spread=17.6000, OI=0, vol=0
# [pick_one] cp=C, K=3790.0, dte=20, mid=90.1500, delta=0.5130, gamma=1.770000e-03, spread=2.9000, OI=23, vol=18
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=441.
#
# --- Window 23/31 (start_idx=462) ---
# [get_window_dates] start=2022-11-02 end=2022-12-02 len=22
# [choose_strike_for_m0] spot0=3759.6900, m0=1.250, target=4699.6125 -> K=4600.0
# [nearest_atm_strike] spot0=3759.6900 -> K_ATM=3760.0
# [day 1/21] 2022-11-02 -> 2022-11-03
# [pick_one] cp=C, K=4600.0, dte=29, mid=0.2250, delta=0.0029, gamma=3.300000e-05, spread=0.0500, OI=9, vol=0
# [pick_one] MISSING leg for cp=P, K=4600.0
# [pick_one] cp=C, K=3760.0, dte=21, mid=95.6000, delta=0.5238, gamma=1.721000e-03, spread=2.6000, OI=12, vol=0
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=462.
#
# --- Window 24/31 (start_idx=483) ---
# [get_window_dates] start=2022-12-02 end=2023-01-04 len=22
# [choose_strike_for_m0] spot0=4071.7000, m0=1.250, target=5089.6250 -> K=5000.0
# [nearest_atm_strike] spot0=4071.7000 -> K_ATM=4070.0
# [day 1/21] 2022-12-02 -> 2022-12-05
# [pick_one] MISSING leg for cp=C, K=5000.0
# [pick_one] cp=P, K=5000.0, dte=20, mid=918.4000, delta=-0.9982, gamma=2.000000e-05, spread=5.6000, OI=0, vol=0
# [pick_one] cp=C, K=4070.0, dte=21, mid=77.2500, delta=0.5312, gamma=2.199000e-03, spread=0.9000, OI=268, vol=43
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=483.
#
# --- Window 25/31 (start_idx=504) ---
# [get_window_dates] start=2023-01-04 end=2023-02-03 len=22
# [choose_strike_for_m0] spot0=3852.9700, m0=1.250, target=4816.2125 -> K=4825.0
# [nearest_atm_strike] spot0=3852.9700 -> K_ATM=3855.0
# [day 1/21] 2023-01-04 -> 2023-01-05
# [pick_one] MISSING leg for cp=C, K=4825.0
# [pick_one] cp=P, K=4825.0, dte=16, mid=967.7000, delta=-0.9932, gamma=5.100000e-05, spread=2.8000, OI=5, vol=2
# [pick_one] cp=C, K=3855.0, dte=21, mid=75.0000, delta=0.5155, gamma=2.159000e-03, spread=0.6000, OI=0, vol=8
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=504.
#
# --- Window 26/31 (start_idx=525) ---
# [get_window_dates] start=2023-02-03 end=2023-03-07 len=22
# [choose_strike_for_m0] spot0=4136.4800, m0=1.250, target=5170.6000 -> K=5200.0
# [nearest_atm_strike] spot0=4136.4800 -> K_ATM=4135.0
# [day 1/21] 2023-02-03 -> 2023-02-06
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=21, mid=1055.5500, delta=-0.9878, gamma=7.500000e-05, spread=5.1000, OI=0, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=68.9500, delta=0.5285, gamma=2.452000e-03, spread=0.5000, OI=155, vol=20
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=525.
#
# --- Window 27/31 (start_idx=546) ---
# [get_window_dates] start=2023-03-07 end=2023-04-05 len=22
# [choose_strike_for_m0] spot0=3986.3700, m0=1.250, target=4982.9625 -> K=5000.0
# [nearest_atm_strike] spot0=3986.3700 -> K_ATM=3985.0
# [day 1/21] 2023-03-07 -> 2023-03-08
# [pick_one] MISSING leg for cp=C, K=5000.0
# [pick_one] cp=P, K=5000.0, dte=21, mid=1003.8000, delta=-0.9936, gamma=4.900000e-05, spread=2.8000, OI=0, vol=0
# [pick_one] cp=C, K=3985.0, dte=21, mid=77.4500, delta=0.5296, gamma=2.181000e-03, spread=0.5000, OI=6, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=546.
#
# --- Window 28/31 (start_idx=567) ---
# [get_window_dates] start=2023-04-05 end=2023-05-05 len=22
# [choose_strike_for_m0] spot0=4090.3800, m0=1.250, target=5112.9750 -> K=5100.0
# [nearest_atm_strike] spot0=4090.3800 -> K_ATM=4090.0
# [day 1/21] 2023-04-05 -> 2023-04-06
# [pick_one] MISSING leg for cp=C, K=5100.0
# [pick_one] cp=P, K=5100.0, dte=23, mid=997.1000, delta=-0.9958, gamma=3.500000e-05, spread=3.2000, OI=1, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=64.4000, delta=0.5320, gamma=2.656000e-03, spread=0.4000, OI=1, vol=1
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=567.
#
# --- Window 29/31 (start_idx=588) ---
# [get_window_dates] start=2023-05-05 end=2023-06-06 len=22
# [choose_strike_for_m0] spot0=4136.2500, m0=1.250, target=5170.3125 -> K=5200.0
# [nearest_atm_strike] spot0=4136.2500 -> K_ATM=4135.0
# [day 1/21] 2023-05-05 -> 2023-05-08
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=21, mid=1055.9500, delta=-0.9780, gamma=1.140000e-04, spread=5.5000, OI=1, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=58.9500, delta=0.5348, gamma=2.931000e-03, spread=0.5000, OI=220, vol=19
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=588.
#
# --- Window 30/31 (start_idx=609) ---
# [get_window_dates] start=2023-06-06 end=2023-07-07 len=22
# [choose_strike_for_m0] spot0=4283.8500, m0=1.250, target=5354.8125 -> K=4710.0
# [nearest_atm_strike] spot0=4283.8500 -> K_ATM=4285.0
# [day 1/21] 2023-06-06 -> 2023-06-07
# [pick_one] cp=C, K=4710.0, dte=24, mid=0.1750, delta=0.0039, gamma=7.900000e-05, spread=0.0500, OI=0, vol=1
# [pick_one] MISSING leg for cp=P, K=4710.0
# [pick_one] cp=C, K=4285.0, dte=21, mid=51.1000, delta=0.5415, gamma=3.459000e-03, spread=0.4000, OI=2, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=609.
#
# --- Window 31/31 (start_idx=630) ---
# [get_window_dates] start=2023-07-07 end=2023-08-07 len=22
# [choose_strike_for_m0] spot0=4398.9500, m0=1.250, target=5498.6875 -> K=5500.0
# [nearest_atm_strike] spot0=4398.9500 -> K_ATM=4400.0
# [day 1/21] 2023-07-07 -> 2023-07-10
# [pick_one] MISSING leg for cp=C, K=5500.0
# [pick_one] cp=P, K=5500.0, dte=24, mid=1085.6500, delta=-0.9892, gamma=6.900000e-05, spread=5.9000, OI=0, vol=0
# [pick_one] cp=C, K=4400.0, dte=21, mid=56.0000, delta=0.5402, gamma=3.141000e-03, spread=0.4000, OI=997, vol=106
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=630.
# Results shape: (60, 11)
#         start        end    m0  K_straddle  K_hedge        V0       V_T         Pi_T  tracking_error  pnl_unhedged  pnl_hedged
# 0  2021-01-04 2021-02-03  0.75      2775.0   3700.0   928.350  1057.125  1055.538853        1.586147       128.775  127.188853
# 1  2021-02-03 2021-03-05  0.75      2875.0   3830.0   958.025   966.875   966.021401        0.853599         8.850    7.996401
# 2  2021-05-05 2021-06-04  0.75      3125.0   4170.0  1038.275  1103.725  1098.329420        5.395580        65.450   60.054420
# 3  2021-06-04 2021-07-06  0.75      3170.0   4230.0  1059.575  1172.850  1171.171511        1.678489       113.275  111.596511
# 4  2021-08-04 2021-09-02  0.75      3300.0   4405.0  1101.500  1235.400  1234.006167        1.393833       133.900  132.506167
# 5  2021-09-02 2021-10-04  0.75      3400.0   4535.0  1135.850   903.100   901.654297        1.445703      -232.750 -234.195703
# 6  2021-11-02 2021-12-02  0.75      3475.0   4630.0  1152.475  1100.900  1097.258983        3.641017       -51.575  -55.216017
# 7  2022-01-03 2022-02-02  0.75      3600.0   4795.0  1191.800   985.325   984.240680        1.084320      -206.475 -207.559320
# 8  2022-03-04 2022-04-04  0.75      3250.0   4330.0  1083.900  1328.700  1330.976712       -2.276712       244.800  247.076712
# 9  2022-04-04 2022-05-04  0.75      3440.0   4585.0  1139.925   860.050   862.252945       -2.202945      -279.875 -277.672055
# 10 2022-05-04 2022-06-03  0.75      3225.0   4300.0  1074.325   886.025   882.811894        3.213106      -188.300 -191.513106
# 11 2022-06-03 2022-07-06  0.75      3075.0   4110.0  1034.500   772.600   768.672183        3.927817      -261.900 -265.827817

# %%
# === D) Summary table ===
summary_tbl = summarize_results_verbose(results_df)
summary_tbl
# Out:
#            mean     median    std_dev   VaR_5pct  VaR_2p5pct   VaR_1pct
# m0
# 0.75   1.927068   1.586147   2.404297  -2.232452   -2.254582  -2.267860
# 0.80   4.056931   2.392420   7.889075  -3.675767   -5.479492  -6.561728
# 0.90  13.119722   6.217184  22.521125 -17.207681  -17.294116 -17.371088
# 1.10 -15.244968 -11.963479  24.834129 -49.172144  -53.550495 -56.177505

# %%
# === E) Plot: per-window PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['pnl_unhedged'], label='Unhedged PnL')
plt.plot(res['end'], res['pnl_hedged'], label='Hedged PnL')
plt.title('Per-Window PnL (Unhedged vs Hedged)')
plt.xlabel('Window End Date'); plt.ylabel('PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === F) Plot: cumulative PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
res['cum_unhedged'] = res['pnl_unhedged'].cumsum()
res['cum_hedged']   = res['pnl_hedged'].cumsum()
plt.figure()
plt.plot(res['end'], res['cum_unhedged'], label='Cumulative Unhedged')
plt.plot(res['end'], res['cum_hedged'], label='Cumulative Hedged')
plt.title('Cumulative PnL over Non-overlapping Windows')
plt.xlabel('Window End Date'); plt.ylabel('Cumulative PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === G) Plots: tracking error ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['tracking_error'])
plt.title('Tracking Error Z_T per Window'); plt.xlabel('Window End Date'); plt.ylabel('Z_T (index pts)')
plt.xticks(rotation=30); plt.tight_layout(); plt.show()

plt.figure()
results_df.boxplot(column='tracking_error', by='m0')
plt.title('Tracking Error by m0'); plt.suptitle(''); plt.xlabel('m0'); plt.ylabel('Z_T (index pts)')
plt.tight_layout(); plt.show()

# %%
# === Helper: get day-level timeline for a chosen results row ===
def get_timeline_for_row(df_slice, results, idx=0):
    row = results.iloc[idx]
    dates_arr = np.sort(df_slice['date'].unique())
    si = int(np.where(dates_arr == pd.Timestamp(row['start']))[0][0])
    out = run_single_window(df_slice, start_idx=si, m0=float(row['m0']))
    if out is None:
        raise RuntimeError("Window failed; check console logs for the failing day/leg.")
    return out['timeline'], out['summary']

# Example:
# tl, summ = get_timeline_for_row(df_1m_bt, results_df, idx=0)
# tl.head()

# %%
plt.figure()
results_df['tracking_error'].hist(bins=50)
plt.title('Tracking Error Distribution (All Windows)')
plt.xlabel('Z_T (index pts)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# save to csv
results_df.to_csv('results_gamma.csv', index=False)
print("Delta results saved to results_gamma.csv")
# Out:
# Delta results saved to results_gamma.csv
