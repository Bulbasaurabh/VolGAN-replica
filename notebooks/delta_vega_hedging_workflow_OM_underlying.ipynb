# %% [markdown]
# # Delta–Vega Hedging (SPX) — Using OptionMetrics **OMunderlying.csv** for Spot
#
# This notebook replaces the Yahoo Finance spot with **OMunderlying.csv** (OptionMetrics) and keeps the rest of the pipeline:
# - Load options parquet (`options_dataset.parquet`), fix OPRA strike scaling.
# - Load **OMunderlying.csv** and use **`close`** as SPX spot.
# - Build non-overlapping **21-trading-day** windows (≈1 month).
# - Construct single-straddle target with \( K = m_0 S_0 \), \(m_0 \in \{0.75,0.8,0.9,1.1,1.2,1.25\}\).
# - Daily **delta–vega** rebalancing with **ATM-at-inception** hedge option + underlying.
# - Half-spread costs on the option hedge leg.
# - Backtest from **2021-01-01** to end of dataset; plots + CSV output.

# %%
# === 1) Imports & Params ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Optional

TRADING_DAYS_PER_MONTH = 21
VEGA_FLOOR = 5.0  # vega floor for stability in hedge ratio

# Paths (adjust if needed)
OPTIONS_PARQUET = "../data/options_dataset.parquet"
OM_UNDERLYING_CSV = "../data/OMunderlying.csv"

pd.set_option('display.width', 160)
pd.set_option('display.max_columns', 50)

# %%
# === 2) Load SPX options & basic cleaning ===
df = pd.read_parquet(OPTIONS_PARQUET)
keep_cols = ['ticker','date','exdate','cp_flag','strike_price','best_bid','best_offer',
             'volume','open_interest','impl_volatility','delta','gamma','vega','theta']
df = df[keep_cols].copy()
df['date'] = pd.to_datetime(df['date'])
df['exdate'] = pd.to_datetime(df['exdate'])

df = df[df['ticker'] == 'SPX'].copy()

# Mid, dte
df['mid'] = (df['best_bid'] + df['best_offer']) / 2.0
df['dte'] = (df['exdate'] - df['date']).dt.days

# Fix OPRA strike scaling (1,505,000 -> 1505.0 typical)
if df['strike_price'].median() > 1e4:
    df['strike_price'] = df['strike_price'] / 1000.0

print("Options rows:", len(df))
df.head()
# Out:
# Options rows: 36251366
#   ticker       date     exdate cp_flag  strike_price  best_bid  best_offer  volume  open_interest  impl_volatility     delta     gamma       vega      theta  \
# 0    SPX 2000-01-03 2000-01-22       P        1505.0    55.250      57.250       0             50         0.212891 -0.734362  0.004767  105.97850 -162.13980
# 1    SPX 2000-01-03 2000-01-22       P        1545.0    89.625      91.625       0              0         0.233571 -0.858130  0.002975   72.57848  -92.56329
# 2    SPX 2000-01-03 2000-03-18       C         750.0   706.500     708.500       0           1916              NaN       NaN       NaN        NaN        NaN
# 3    SPX 2000-01-03 2000-09-16       C        1450.0   135.750     137.750       0           2365         0.229435  0.608151  0.001353  461.04910 -109.55640
# 4    SPX 2000-01-03 2000-06-17       P        1350.0    40.750      42.750     290          14570         0.252872 -0.256190  0.001296  313.84440  -67.94785
#
#        mid  dte
# 0   56.250   19
# 1   90.625   19
# 2  707.500   75
# 3  136.750  257
# 4   41.750  166

# %%
# === 3) Load OptionMetrics OMunderlying.csv as spot ===
# Expected columns: secid,date,ticker,index_flag,low,high,open,close,volume
spot_df = pd.read_csv(OM_UNDERLYING_CSV)
spot_df['date'] = pd.to_datetime(spot_df['date'])
spot_df = spot_df[spot_df['ticker'] == 'SPX'].copy()

# Use 'close' as the index level (spot)
spot_df = spot_df[['date','close']].rename(columns={'close':'spot'}).sort_values('date')
spot_df = spot_df.drop_duplicates(subset=['date'], keep='last').reset_index(drop=True)

print("Spot rows:", len(spot_df), "| range:", spot_df['date'].min().date(), "→", spot_df['date'].max().date())
spot_df.head()
# Out:
# Spot rows: 5954 | range: 2000-01-03 → 2023-08-31
#         date     spot
# 0 2000-01-03  1455.22
# 1 2000-01-04  1399.42
# 2 2000-01-05  1402.11
# 3 2000-01-06  1403.45
# 4 2000-01-07  1441.47

# %%
# === 4) Merge spot into options; compute moneyness; filter ~1M tenor ===
df = df.merge(spot_df, on='date', how='inner')
df['moneyness'] = df['strike_price'] / df['spot']

# Keep ~1M options: dte around 21 trading days (use a calendar-day band 15–35)
df_1m = df[(df['dte'] >= 15) & (df['dte'] <= 35)].copy()

# Quality screens
df_1m = df_1m.replace([np.inf, -np.inf], np.nan)
df_1m = df_1m.dropna(subset=['mid','delta','vega','best_bid','best_offer'])
df_1m = df_1m[df_1m['best_offer'] >= df_1m['best_bid']].copy()
df_1m['spread'] = (df_1m['best_offer'] - df_1m['best_bid']).clip(lower=0)
df_1m['rel_spread'] = (df_1m['spread'] / df_1m['mid']).replace([np.inf,-np.inf], np.nan)

liq_mask = (
    (df_1m['mid'] > 0.05) &
    (df_1m['rel_spread'] <= 0.35) &
    df_1m['delta'].between(-1.1, 1.1) &
    (df_1m['vega'] > 0)
)
df_1m = df_1m[liq_mask].copy()

cols_keep = ['date','exdate','cp_flag','strike_price','spot','moneyness','dte','mid',
             'best_bid','best_offer','volume','open_interest','delta','vega','spread','rel_spread']
df_1m = df_1m[cols_keep].sort_values(['date','dte','strike_price']).reset_index(drop=True)

print("1M rows:", len(df_1m), "| date range:", df_1m['date'].min().date(), "→", df_1m['date'].max().date())
df_1m.head(10)
# Out:
# 1M rows: 5689084 | date range: 2000-01-03 → 2023-08-31
#         date     exdate cp_flag  strike_price     spot  moneyness  dte       mid  best_bid  best_offer  volume  open_interest     delta      vega  spread  \
# 0 2000-01-03 2000-01-22       P        1275.0  1455.22   0.876156   19    2.0000     1.750       2.250     585          23785 -0.041295  28.57753   0.500
# 1 2000-01-03 2000-01-22       P        1300.0  1455.22   0.893336   19    2.6250     2.250       3.000    3572          26621 -0.055490  36.20153   0.750
# 2 2000-01-03 2000-01-22       P        1325.0  1455.22   0.910515   19    3.8125     3.500       4.125    1406          30757 -0.079749  47.92918   0.625
# 3 2000-01-03 2000-01-22       C        1325.0  1455.22   0.910515   19  134.5000   133.500     135.500     315          29529  0.983012  13.61578   2.000
# 4 2000-01-03 2000-01-22       C        1350.0  1455.22   0.927695   19  111.1250   110.125     112.125     112          20500  0.939732  38.63064   2.000
# 5 2000-01-03 2000-01-22       P        1350.0  1455.22   0.927695   19    5.1875     4.875       5.500     819          24413 -0.109956  60.74824   0.625
# 6 2000-01-03 2000-01-22       C        1375.0  1455.22   0.944874   19   88.5000    87.500      89.500       6           7885  0.884385  62.96457   2.000
# 7 2000-01-03 2000-01-22       P        1375.0  1455.22   0.944874   19    6.9375     6.750       7.125    2633          18270 -0.150684  75.57642   0.375
# 8 2000-01-03 2000-01-22       C        1380.0  1455.22   0.948310   19   84.0000    83.000      85.000       4             13  0.872528  67.43791   2.000
# 9 2000-01-03 2000-01-22       P        1380.0  1455.22   0.948310   19    8.1250     7.625       8.625      69           1458 -0.168821  81.41239   1.000
#
#    rel_spread
# 0    0.250000
# 1    0.285714
# 2    0.163934
# 3    0.014870
# 4    0.017998
# 5    0.120482
# 6    0.022599
# 7    0.054054
# 8    0.023810
# 9    0.123077

# %%
# === 5) Utilities (small, testable) ===
def choose_strike_for_m0(spot0: float, m0: float, available_strikes: np.ndarray) -> float:
    target = float(m0) * float(spot0)
    idx = np.abs(available_strikes - target).argmin()
    K = float(available_strikes[idx])
    print(f"[choose_strike_for_m0] spot0={spot0:.4f}, m0={m0:.3f}, target={target:.4f} -> K={K}")
    return K

def nearest_atm_strike(spot0: float, available_strikes: np.ndarray) -> float:
    idx = np.abs(available_strikes - float(spot0)).argmin()
    K = float(available_strikes[idx])
    print(f"[nearest_atm_strike] spot0={spot0:.4f} -> K_ATM={K}")
    return K

def pick_one(day_df: pd.DataFrame, strike: float, cp_flag: str) -> Optional[pd.Series]:
    sub = day_df[(day_df['strike_price'] == strike) & (day_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[pick_one] MISSING leg for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','vega','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[pick_one] All candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[pick_one] No clean candidate after filters for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[pick_one] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, "
          f"mid={chosen['mid']:.4f}, delta={chosen['delta']:.4f}, vega={chosen['vega']:.4f}, "
          f"spread={chosen['spread']:.4f}, OI={int(chosen['open_interest'])}, vol={int(chosen['volume'])}")
    return chosen

def fetch_next_row(next_df, strike, cp_flag):
    sub = next_df[(next_df['strike_price'] == strike) & (next_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[next fetch] MISSING next-day row for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','vega','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[next fetch] All next-day candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[next fetch] No clean next-day candidate for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[next fetch] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, mid={chosen['mid']:.4f}")
    return chosen

def half_spread(row: pd.Series) -> float:
    return float(max(0.0, (row['best_offer'] - row['best_bid']) / 2.0))

def pnl_from_price_change(qty: float, price_t: float, price_t1: float) -> float:
    return float(qty) * (float(price_t1) - float(price_t))

def self_financing_rebalance_cost(prev_qty: float, new_qty: float, half_spread_val: float) -> float:
    return abs(float(new_qty - prev_qty)) * float(half_spread_val)

# %%
# === 6A) Window builder ===
def get_window_dates(df_all: pd.DataFrame, start_idx: int) -> list[pd.Timestamp] | None:
    dates = np.sort(df_all['date'].unique())
    if start_idx + TRADING_DAYS_PER_MONTH >= len(dates):
        print(f"[get_window_dates] Not enough dates from start_idx={start_idx}.")
        return None
    days = list(dates[start_idx : start_idx + TRADING_DAYS_PER_MONTH + 1])
    print(f"[get_window_dates] start={pd.Timestamp(days[0]).date()} end={pd.Timestamp(days[-1]).date()} len={len(days)}")
    return days

# %%
def one_day_step(
    df_all: pd.DataFrame,
    d: pd.Timestamp,
    d_next: pd.Timestamp,
    K_straddle: float,
    K_hedge: float,
    phi_opt_prev: float,
    phi_under_prev: float,
    allow_recalc: bool,
) -> dict | None:
    """
    do one step t -> t+1.
    if allow_recalc == True: recompute hedge ratios phi_opt, phi_under from Greeks today.
    if allow_recalc == False: reuse previous phi_opt_prev / phi_under_prev (no rebalance, no cost).
    """

    day = df_all[df_all['date'] == d].copy()
    day_next = df_all[df_all['date'] == d_next].copy()
    if day.empty or day_next.empty:
        print(f"[one_day_step] Missing day data at {d} or {d_next}")
        return None

    # pick straddle legs
    row_C = pick_one(day, K_straddle, 'C')
    row_P = pick_one(day, K_straddle, 'P')
    # pick hedge leg (ATM-at-inception strike, we keep using same strike for hedge instrument)
    row_H = pick_one(day, K_hedge, 'C')
    if row_H is None:
        row_H = pick_one(day, K_hedge, 'P')
    if (row_C is None) or (row_P is None) or (row_H is None):
        print("[one_day_step] Missing leg(s) at current day.")
        return None

    psi_C, psi_P = 1.0, 1.0

    # target portfolio (straddle) greeks and MTM today
    V_t   = psi_C*row_C['mid'] + psi_P*row_P['mid']
    dV_t  = psi_C*row_C['delta'] + psi_P*row_P['delta']
    kV_t  = psi_C*row_C['vega']  + psi_P*row_P['vega']

    dH_t  = row_H['delta']
    kH_t  = row_H['vega']

    vals = [V_t, dV_t, kV_t, dH_t, kH_t, row_H['mid']]
    if not all(np.isfinite(v) for v in vals):
        print(f"[one_day_step] Non-finite greeks/prices at {pd.Timestamp(d).date()} — abort window.")
        return None

    # vega floor for stability
    kH_eff = np.sign(kH_t) * max(abs(kH_t) if np.isfinite(kH_t) else 0.0, VEGA_FLOOR)
    if not np.isfinite(kV_t):
        print(f"[one_day_step] Portfolio vega NaN at {pd.Timestamp(d).date()} — abort window.")
        return None

    if allow_recalc:
        # fresh hedge ratios
        phi_opt   = (kV_t / kH_eff) if not np.isclose(kH_eff, 0.0) else 0.0
        phi_under = dV_t - phi_opt * dH_t
    else:
        # hold previous hedge, don't rebalance
        phi_opt   = phi_opt_prev
        phi_under = phi_under_prev

    # get next-day marks for pnl
    row_C_next = fetch_next_row(day_next, row_C['strike_price'], 'C')
    row_P_next = fetch_next_row(day_next, row_P['strike_price'], 'P')
    row_H_next = fetch_next_row(day_next, row_H['strike_price'], row_H['cp_flag'])
    if (row_C_next is None) or (row_P_next is None) or (row_H_next is None):
        print("[one_day_step] Missing next-day leg(s).")
        return None

    s_t  = float(row_C['spot'])
    s_t1 = float(row_C_next['spot'])

    # mark-to-market changes
    pnl_opt   = pnl_from_price_change(phi_opt,   row_H['mid'], row_H_next['mid'])
    pnl_under = pnl_from_price_change(phi_under, s_t,          s_t1)

    # trading cost:
    # - if we actually rebalanced today, pay cost on phi_opt change
    # - else no cost (you didn't trade)
    if allow_recalc:
        hs_H      = half_spread(row_H)
        cost_opt  = self_financing_rebalance_cost(phi_opt_prev, phi_opt, hs_H)
    else:
        cost_opt  = 0.0
    cost_under = 0.0  # still zero for underlying leg

    # unhedged daily pnl of the straddle
    pnl_unhedged = (psi_C*(row_C_next['mid'] - row_C['mid']) +
                    psi_P*(row_P_next['mid'] - row_P['mid']))

    return dict(
        date=pd.Timestamp(d),
        spot=s_t,
        K_straddle=K_straddle,
        K_hedge=K_hedge,
        V_t=float(V_t),
        dV_t=float(dV_t),
        kV_t=float(kV_t),
        dH_t=float(dH_t),
        kH_t=float(kH_t),
        kH_eff=float(kH_eff),
        phi_opt=float(phi_opt),
        phi_under=float(phi_under),
        cost_opt=float(cost_opt),
        cost_under=float(cost_under),
        pnl_opt=float(pnl_opt),
        pnl_under=float(pnl_under),
        pnl_unhedged=float(pnl_unhedged),
        rebalanced_today=bool(allow_recalc),
    )

# %%
def run_single_window(
    df_all: pd.DataFrame,
    start_idx: int,
    m0: float,
    rebalance_every: int = 1,  # 1=daily, 5=weekly
) -> dict | None:
    """
    Simulate one 21-trading-day window from start_idx.
    rebalance_every controls hedge frequency.
    """

    # get the day sequence
    days = get_window_dates(df_all, start_idx)
    if days is None:
        return None
    d0 = pd.Timestamp(days[0])
    day0 = df_all[df_all['date'] == d0].copy()
    if day0.empty:
        print(f"[run_single_window] No rows on start day {d0}.")
        return None

    # initial strikes
    spot0 = float(day0['spot'].iloc[0])
    strikes0 = np.sort(day0['strike_price'].unique())
    K_straddle = choose_strike_for_m0(spot0, m0, strikes0)
    K_hedge    = nearest_atm_strike(spot0, strikes0)

    # hedge positions from previous day
    phi_opt_prev   = 0.0
    phi_under_prev = 0.0

    records = []
    V0 = None
    Pi_t = None  # hedge book value Π_t

    for t in range(len(days)-1):
        d      = pd.Timestamp(days[t])
        d_next = pd.Timestamp(days[t+1])
        print(f"[day {t+1}/{len(days)-1}] {d.date()} -> {d_next.date()}")

        # only recalc hedge every rebalance_every steps
        allow_recalc = (t % rebalance_every == 0)

        step = one_day_step(
            df_all=df_all,
            d=d,
            d_next=d_next,
            K_straddle=K_straddle,
            K_hedge=K_hedge,
            phi_opt_prev=phi_opt_prev,
            phi_under_prev=phi_under_prev,
            allow_recalc=allow_recalc,
        )
        if step is None:
            print("[run_single_window] Step failed; abort window.")
            return None

        # initialize book on first day
        if V0 is None:
            V0 = step['V_t']
            Pi_t = V0
            print(f"[init] V0=Π0={V0:.6f}")

        # self-financing update of hedge book
        Pi_t1 = (
            Pi_t
            + step['pnl_opt']
            + step['pnl_under']
            - step['cost_opt']
            - step['cost_under']
        )

        # store tracking error vs target that day (pre-next-day move)
        step['Pi_t']  = float(Pi_t)
        step['Pi_t1'] = float(Pi_t1)
        step['Z_t']   = float(step['V_t'] - Pi_t)

        records.append(step)

        # carry forward hedge positions (whatever we actually hold after today)
        phi_opt_prev   = step['phi_opt']
        phi_under_prev = step['phi_under']
        Pi_t = Pi_t1

    # final valuation at expiry-ish (last day in this window)
    last_day  = pd.Timestamp(days[-2])
    final_day = pd.Timestamp(days[-1])
    day_last  = df_all[df_all['date'] == last_day]
    day_final = df_all[df_all['date'] == final_day]

    row_C_last = pick_one(day_last,  K_straddle, 'C')
    row_C_fin  = fetch_next_row(day_final, K_straddle, 'C')
    row_P_last = pick_one(day_last,  K_straddle, 'P')
    row_P_fin  = fetch_next_row(day_final, K_straddle, 'P')
    if (row_C_last is None) or (row_P_last is None) or (row_C_fin is None) or (row_P_fin is None):
        print("[run_single_window] Final valuation missing legs.")
        return None

    V_T = float(row_C_fin['mid'] + row_P_fin['mid'])
    Pi_T = float(records[-1]['Pi_t1'])

    tracking_error_T = V_T - Pi_T
    pnl_unhedged_total = V_T - float(records[0]['V_t'])
    pnl_hedged_total   = Pi_T - float(records[0]['V_t'])

    timeline = pd.DataFrame(records).sort_values('date').reset_index(drop=True)

    summary = dict(
        start=days[0],
        end=days[-1],
        m0=float(m0),
        rebalance_every=int(rebalance_every),
        K_straddle=float(K_straddle),
        K_hedge=float(K_hedge),
        V0=float(records[0]['V_t']),
        V_T=float(V_T),
        Pi_T=float(Pi_T),
        tracking_error=float(tracking_error_T),
        pnl_unhedged=float(pnl_unhedged_total),
        pnl_hedged=float(pnl_hedged_total),
    )

    print(f"[window done] m0={m0}, freq={rebalance_every}, "
          f"Z_T={tracking_error_T:.6f}, V_T={V_T:.6f}, Π_T={Pi_T:.6f}")
    return dict(timeline=timeline, summary=summary)

# %%
# === 7) Multi-window experiment ===
def run_experiment_verbose(df_all: pd.DataFrame, m0_list: list[float], max_windows: int = 52, stop_on_fail: bool = False) -> pd.DataFrame:
    dates = np.sort(df_all['date'].unique())
    start_indices = list(range(0, len(dates) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
    start_indices = start_indices[:max_windows]
    results = []
    for m0 in m0_list:
        print(f"\n===== m0={m0} =====")
        for i, si in enumerate(start_indices, 1):
            print(f"\n--- Window {i}/{len(start_indices)} (start_idx={si}) ---")
            out = run_single_window(df_all, si, m0)
            if out is None:
                print(f"[run_experiment_verbose] Window failed for m0={m0}, start_idx={si}.")
                if stop_on_fail:
                    return pd.DataFrame(results)
                else:
                    continue
            results.append(out['summary'])
    return pd.DataFrame(results)

# %%
def run_experiment_with_freqs(
    df_all: pd.DataFrame,
    m0_list: list[float],
    rebalance_list: list[int],
    max_windows: int = 52,
    stop_on_fail: bool = False,
) -> pd.DataFrame:
    """
    For each m0 and each rebalance frequency, run all non-overlapping windows.
    Returns one big results_df with columns including rebalance_every.
    """
    dates = np.sort(df_all['date'].unique())
    start_indices = list(range(
        0,
        len(dates) - TRADING_DAYS_PER_MONTH - 1,
        TRADING_DAYS_PER_MONTH
    ))
    start_indices = start_indices[:max_windows]

    results = []

    for m0 in m0_list:
        for freq in rebalance_list:
            print(f"\n===== m0={m0}, freq={freq} =====")
            for i, si in enumerate(start_indices, 1):
                print(f"\n--- Window {i}/{len(start_indices)} (start_idx={si}) ---")
                out = run_single_window(
                    df_all=df_all,
                    start_idx=si,
                    m0=m0,
                    rebalance_every=freq,
                )
                if out is None:
                    print(f"[run_experiment_with_freqs] FAILED m0={m0}, freq={freq}, start_idx={si}")
                    if stop_on_fail:
                        return pd.DataFrame(results)
                    else:
                        continue
                results.append(out['summary'])

    return pd.DataFrame(results)

# %%
# === 8) Summaries ===
def summarize_results_verbose(results_df: pd.DataFrame) -> pd.DataFrame:
    if results_df is None or results_df.empty:
        print("[summarize_results_verbose] No results to summarize."); return pd.DataFrame()
    g = results_df.groupby('m0')
    out = g['tracking_error'].agg(['mean','median','std']).rename(columns={'std':'std_dev'})
    out['VaR_5pct']   = g['tracking_error'].quantile(0.05)
    out['VaR_2p5pct'] = g['tracking_error'].quantile(0.025)
    out['VaR_1pct']   = g['tracking_error'].quantile(0.01)
    return out

# %%
# === A) Backtest range: from 2021-01-01 to end ===
start_backtest = pd.Timestamp("2021-01-01")
df_1m_bt = df_1m[df_1m['date'] >= start_backtest].copy().sort_values('date')
print("Backtest:", df_1m_bt['date'].min().date(), "→", df_1m_bt['date'].max().date(), "| rows:", len(df_1m_bt))

dates_bt = np.sort(df_1m_bt['date'].unique())
start_indices_bt = list(range(0, len(dates_bt) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
max_windows_bt = len(start_indices_bt)
print("Candidate windows in range:", max_windows_bt)
# Out:
# Backtest: 2021-01-04 → 2023-08-31 | rows: 2181138
# Candidate windows in range: 31

# %%
m0_list = [0.75, 0.8, 0.9, 1.1]
rebalance_list = [1, 5]  # 1 = daily, 5 = weekly-ish

results_df = run_experiment_with_freqs(
    df_all=df_1m_bt,
    m0_list=m0_list,
    rebalance_list=rebalance_list,
    max_windows=max_windows_bt,
    stop_on_fail=False
)

print("Results shape:", results_df.shape)
display(results_df.head())
# Out:
# ===== m0=0.75, freq=1 =====
#
# --- Window 1/31 (start_idx=0) ---
# [get_window_dates] start=2021-01-04 end=2021-02-03 len=22
# [choose_strike_for_m0] spot0=3700.6500, m0=0.750, target=2775.4875 -> K=2775.0
# [nearest_atm_strike] spot0=3700.6500 -> K_ATM=3700.0
# [day 1/21] 2021-01-04 -> 2021-01-05
# [pick_one] cp=C, K=2775.0, dte=18, mid=926.5500, delta=0.9908, vega=20.0170, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.8000, delta=-0.0106, vega=23.1292, spread=0.2000, OI=219, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=71.5500, delta=0.5101, vega=353.9398, spread=0.7000, OI=122, vol=125
# [next fetch] cp=C, K=2775.0, dte=24, mid=951.7500
# [next fetch] cp=P, K=2775.0, dte=24, mid=2.3000
# [next fetch] cp=C, K=3700.0, dte=20, mid=81.3000
# [init] V0=Π0=928.350000
# [day 2/21] 2021-01-05 -> 2021-01-06
# [pick_one] cp=C, K=2775.0, dte=24, mid=951.7500, delta=0.9878, vega=28.8009, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.3000, delta=-0.0125, vega=31.0115, spread=0.2000, OI=420, vol=96
# [pick_one] cp=C, K=3700.0, dte=20, mid=81.3000, delta=0.5679, vega=342.7756, spread=0.6000, OI=196, vol=34
# [next fetch] cp=C, K=2775.0, dte=23, mid=975.2500
# [next fetch] cp=P, K=2775.0, dte=23, mid=2.6250
# [next fetch] cp=C, K=3700.0, dte=21, mid=103.2500
# [day 3/21] 2021-01-06 -> 2021-01-07
# [pick_one] cp=C, K=2775.0, dte=23, mid=975.2500, delta=0.9857, vega=33.7799, spread=6.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=2.6250, delta=-0.0136, vega=32.7071, spread=0.2500, OI=484, vol=4
# [pick_one] cp=C, K=3700.0, dte=21, mid=103.2500, delta=0.6092, vega=345.1390, spread=1.3000, OI=13, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1030.7500
# [next fetch] cp=P, K=2775.0, dte=22, mid=1.2750
# [next fetch] cp=C, K=3700.0, dte=22, mid=139.6000
# [day 4/21] 2021-01-07 -> 2021-01-08
# [pick_one] cp=C, K=2775.0, dte=22, mid=1030.7500, delta=0.9906, vega=23.5595, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=1.2750, delta=-0.0074, vega=19.0433, spread=0.1500, OI=484, vol=9
# [pick_one] cp=C, K=3700.0, dte=22, mid=139.6000, delta=0.7149, vega=317.0779, spread=1.6000, OI=4544, vol=78
# [next fetch] cp=C, K=2775.0, dte=21, mid=1051.1000
# [next fetch] cp=P, K=2775.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=3700.0, dte=21, mid=154.3000
# [day 5/21] 2021-01-08 -> 2021-01-11
# [pick_one] cp=C, K=2775.0, dte=21, mid=1051.1000, delta=0.9931, vega=17.7215, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=0.8000, delta=-0.0050, vega=13.2379, spread=0.1000, OI=480, vol=12
# [pick_one] cp=C, K=3700.0, dte=21, mid=154.3000, delta=0.7520, vega=290.2641, spread=0.6000, OI=4547, vol=120
# [next fetch] cp=C, K=2775.0, dte=18, mid=1023.2500
# [next fetch] cp=P, K=2775.0, dte=18, mid=0.7500
# [next fetch] cp=C, K=3700.0, dte=21, mid=138.0500
# [day 6/21] 2021-01-11 -> 2021-01-12
# [pick_one] cp=C, K=2775.0, dte=18, mid=1023.2500, delta=0.9941, vega=12.8818, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=0.7500, delta=-0.0049, vega=11.8824, spread=0.1000, OI=474, vol=179
# [pick_one] cp=C, K=3700.0, dte=21, mid=138.0500, delta=0.6955, vega=318.6108, spread=0.7000, OI=201, vol=11
# [next fetch] cp=C, K=2775.0, dte=24, mid=1033.7500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.4250
# [next fetch] cp=C, K=3700.0, dte=20, mid=139.2000
# [day 7/21] 2021-01-12 -> 2021-01-13
# [pick_one] cp=C, K=2775.0, dte=24, mid=1033.7500, delta=0.9724, vega=61.8752, spread=12.7000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.4250, delta=-0.0081, vega=21.5128, spread=0.1500, OI=577, vol=0
# [pick_one] cp=C, K=3700.0, dte=20, mid=139.2000, delta=0.7065, vega=306.2859, spread=0.6000, OI=190, vol=3
# [next fetch] cp=C, K=2775.0, dte=23, mid=1036.9000
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2000
# [next fetch] cp=C, K=3700.0, dte=21, mid=144.1000
# [day 8/21] 2021-01-13 -> 2021-01-14
# [pick_one] cp=C, K=2775.0, dte=23, mid=1036.9000, delta=0.9902, vega=25.0826, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=1.2000, delta=-0.0070, vega=18.6054, spread=0.1000, OI=576, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=144.1000, delta=0.7248, vega=305.0282, spread=0.6000, OI=46, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1022.1500
# [next fetch] cp=P, K=2775.0, dte=22, mid=1.4500
# [next fetch] cp=C, K=3700.0, dte=22, mid=137.0000
# [day 9/21] 2021-01-14 -> 2021-01-15
# [pick_one] cp=C, K=2775.0, dte=22, mid=1022.1500, delta=0.9920, vega=20.5185, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=1.4500, delta=-0.0082, vega=20.9092, spread=0.1000, OI=576, vol=15
# [pick_one] cp=C, K=3700.0, dte=22, mid=137.0000, delta=0.6927, vega=327.4744, spread=13.2000, OI=2567, vol=5
# [next fetch] cp=C, K=2775.0, dte=21, mid=992.8500
# [next fetch] cp=P, K=2775.0, dte=21, mid=1.5000
# [next fetch] cp=C, K=3700.0, dte=21, mid=114.9500
# [day 10/21] 2021-01-15 -> 2021-01-19
# [pick_one] cp=C, K=2775.0, dte=21, mid=992.8500, delta=0.9945, vega=13.2811, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=1.5000, delta=-0.0087, vega=21.2408, spread=0.2000, OI=581, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=114.9500, delta=0.6458, vega=336.0163, spread=0.7000, OI=2566, vol=131
# [next fetch] cp=C, K=2775.0, dte=24, mid=1022.0500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=3700.0, dte=20, mid=133.8000
# [day 11/21] 2021-01-19 -> 2021-01-20
# [pick_one] cp=C, K=2775.0, dte=24, mid=1022.0500, delta=0.9914, vega=20.5697, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.7750, delta=-0.0096, vega=25.0779, spread=0.1500, OI=237, vol=96
# [pick_one] cp=C, K=3700.0, dte=20, mid=133.8000, delta=0.7065, vega=305.8397, spread=2.0000, OI=280, vol=14
# [next fetch] cp=C, K=2775.0, dte=23, mid=1076.7500
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2250
# [next fetch] cp=C, K=3700.0, dte=21, mid=176.8500
# [day 12/21] 2021-01-20 -> 2021-01-21
# [pick_one] cp=C, K=2775.0, dte=23, mid=1076.7500, delta=0.9942, vega=15.2380, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=1.2250, delta=-0.0068, vega=18.4733, spread=0.1500, OI=323, vol=22
# [pick_one] cp=C, K=3700.0, dte=21, mid=176.8500, delta=0.7870, vega=268.4773, spread=0.5000, OI=3, vol=0
# [next fetch] cp=C, K=2775.0, dte=22, mid=1078.5500
# [next fetch] cp=P, K=2775.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=3700.0, dte=22, mid=179.1500
# [day 13/21] 2021-01-21 -> 2021-01-22
# [pick_one] cp=C, K=2775.0, dte=22, mid=1078.5500, delta=0.9954, vega=12.4677, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=0.9500, delta=-0.0056, vega=15.0884, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=22, mid=179.1500, delta=0.7830, vega=277.8053, spread=0.7000, OI=414, vol=10
# [next fetch] cp=C, K=2775.0, dte=21, mid=1069.2500
# [next fetch] cp=P, K=2775.0, dte=21, mid=1.0000
# [next fetch] cp=C, K=3700.0, dte=21, mid=169.6500
# [day 14/21] 2021-01-22 -> 2021-01-25
# [pick_one] cp=C, K=2775.0, dte=21, mid=1069.2500, delta=0.9876, vega=29.5661, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=1.0000, delta=-0.0059, vega=15.3777, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=169.6500, delta=0.7696, vega=280.0589, spread=0.5000, OI=414, vol=19
# [next fetch] cp=C, K=2775.0, dte=18, mid=1078.7500
# [next fetch] cp=P, K=2775.0, dte=18, mid=1.0000
# [next fetch] cp=C, K=3700.0, dte=22, mid=180.2500
# [day 15/21] 2021-01-25 -> 2021-01-26
# [pick_one] cp=C, K=2775.0, dte=18, mid=1078.7500, delta=0.9934, vega=14.2595, spread=6.7000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.0000, delta=-0.0058, vega=14.1543, spread=0.1000, OI=304, vol=0
# [pick_one] cp=C, K=3700.0, dte=22, mid=180.2500, delta=0.7773, vega=281.5362, spread=1.1000, OI=390, vol=84
# [next fetch] cp=C, K=2775.0, dte=24, mid=1071.3500
# [next fetch] cp=P, K=2775.0, dte=24, mid=1.5250
# [next fetch] cp=C, K=3700.0, dte=21, mid=174.2500
# [day 16/21] 2021-01-26 -> 2021-01-27
# [pick_one] cp=C, K=2775.0, dte=24, mid=1071.3500, delta=0.9922, vega=17.9575, spread=7.1000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=1.5250, delta=-0.0082, vega=21.5677, spread=0.1500, OI=2828, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=174.2500, delta=0.7704, vega=279.3026, spread=0.7000, OI=324, vol=40
# [next fetch] cp=C, K=2775.0, dte=23, mid=977.6500
# [next fetch] cp=P, K=2775.0, dte=23, mid=3.9000
# [next fetch] cp=C, K=3700.0, dte=21, mid=125.8000
# [day 17/21] 2021-01-27 -> 2021-01-28
# [pick_one] cp=C, K=2775.0, dte=23, mid=977.6500, delta=0.9838, vega=36.4617, spread=12.3000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=23, mid=3.9000, delta=-0.0182, vega=41.2336, spread=0.8000, OI=2828, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=125.8000, delta=0.5922, vega=349.1263, spread=1.0000, OI=105, vol=32
# [next fetch] cp=C, K=2775.0, dte=22, mid=1017.0000
# [next fetch] cp=P, K=2775.0, dte=22, mid=3.0500
# [next fetch] cp=C, K=3700.0, dte=22, mid=145.2500
# [day 18/21] 2021-01-28 -> 2021-01-29
# [pick_one] cp=C, K=2775.0, dte=22, mid=1017.0000, delta=0.9773, vega=48.5058, spread=12.8000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=22, mid=3.0500, delta=-0.0147, vega=33.7697, spread=0.3000, OI=2828, vol=237
# [pick_one] cp=C, K=3700.0, dte=22, mid=145.2500, delta=0.6527, vega=335.3984, spread=1.3000, OI=17036, vol=442
# [next fetch] cp=C, K=2775.0, dte=21, mid=943.6000
# [next fetch] cp=P, K=2775.0, dte=21, mid=3.3000
# [next fetch] cp=C, K=3700.0, dte=21, mid=100.6500
# [day 19/21] 2021-01-29 -> 2021-02-01
# [pick_one] cp=C, K=2775.0, dte=21, mid=943.6000, delta=0.9801, vega=41.8961, spread=9.0000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=21, mid=3.3000, delta=-0.0167, vega=36.0134, spread=0.4000, OI=2849, vol=1
# [pick_one] cp=C, K=3700.0, dte=21, mid=100.6500, delta=0.5372, vega=345.3457, spread=1.9000, OI=16652, vol=1784
# [next fetch] cp=C, K=2775.0, dte=18, mid=1000.0500
# [next fetch] cp=P, K=2775.0, dte=18, mid=1.7500
# [next fetch] cp=C, K=3700.0, dte=21, mid=130.2000
# [day 20/21] 2021-02-01 -> 2021-02-02
# [pick_one] cp=C, K=2775.0, dte=18, mid=1000.0500, delta=0.9925, vega=16.6782, spread=5.3000, OI=102, vol=0
# [pick_one] cp=P, K=2775.0, dte=18, mid=1.7500, delta=-0.0097, vega=21.1521, spread=0.2000, OI=2849, vol=0
# [pick_one] cp=C, K=3700.0, dte=21, mid=130.2000, delta=0.6391, vega=338.7770, spread=2.0000, OI=39, vol=7
# [next fetch] cp=C, K=2775.0, dte=24, mid=1050.1000
# [next fetch] cp=P, K=2775.0, dte=24, mid=2.2750
# [next fetch] cp=C, K=3700.0, dte=22, mid=163.5500
# [day 21/21] 2021-02-02 -> 2021-02-03
# [pick_one] cp=C, K=2775.0, dte=24, mid=1050.1000, delta=0.9881, vega=28.3920, spread=4.6000, OI=0, vol=0
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.2750, delta=-0.0114, vega=29.2237, spread=0.1500, OI=2796, vol=510
# [pick_one] cp=C, K=3700.0, dte=22, mid=163.5500, delta=0.7219, vega=314.6523, spread=0.7000, OI=57, vol=0
# [next fetch] cp=C, K=2775.0, dte=23, mid=1055.8500
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2750
# [next fetch] cp=C, K=3700.0, dte=21, mid=161.7500
# [pick_one] cp=C, K=2775.0, dte=24, mid=1050.1000, delta=0.9881, vega=28.3920, spread=4.6000, OI=0, vol=0
# [next fetch] cp=C, K=2775.0, dte=23, mid=1055.8500
# [pick_one] cp=P, K=2775.0, dte=24, mid=2.2750, delta=-0.0114, vega=29.2237, spread=0.1500, OI=2796, vol=510
# [next fetch] cp=P, K=2775.0, dte=23, mid=1.2750
# [window done] m0=0.75, freq=1, Z_T=-1.396598, V_T=1057.125000, Π_T=1058.521598
#
# --- Window 2/31 (start_idx=21) ---
# [get_window_dates] start=2021-02-03 end=2021-03-05 len=22
# [choose_strike_for_m0] spot0=3830.1700, m0=0.750, target=2872.6275 -> K=2875.0
# [nearest_atm_strike] spot0=3830.1700 -> K_ATM=3830.0
# [day 1/21] 2021-02-03 -> 2021-02-04
# [pick_one] cp=C, K=2875.0, dte=23, mid=956.3000, delta=0.9897, vega=25.7522, spread=4.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.7250, delta=-0.0101, vega=25.7549, spread=0.1500, OI=120, vol=9
# [pick_one] cp=C, K=3830.0, dte=21, mid=63.4000, delta=0.5093, vega=366.4143, spread=0.6000, OI=28, vol=286
# [next fetch] cp=C, K=2875.0, dte=22, mid=989.6500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.1250
# [next fetch] cp=C, K=3830.0, dte=22, mid=83.0000
# [init] V0=Π0=958.025000
# [day 2/21] 2021-02-04 -> 2021-02-05
# [pick_one] cp=C, K=2875.0, dte=22, mid=989.6500, delta=0.9912, vega=17.7303, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.1250, delta=-0.0070, vega=18.4054, spread=0.1500, OI=129, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=83.0000, delta=0.5890, vega=368.6547, spread=0.4000, OI=647, vol=156
# [next fetch] cp=C, K=2875.0, dte=21, mid=1009.3500
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=3830.0, dte=21, mid=92.7500
# [day 3/21] 2021-02-05 -> 2021-02-08
# [pick_one] cp=C, K=2875.0, dte=21, mid=1009.3500, delta=0.9944, vega=12.9261, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.8000, delta=-0.0052, vega=13.9687, spread=0.1000, OI=129, vol=6
# [pick_one] cp=C, K=3830.0, dte=21, mid=92.7500, delta=0.6416, vega=347.7500, spread=0.5000, OI=691, vol=43
# [next fetch] cp=C, K=2875.0, dte=18, mid=1032.1500
# [next fetch] cp=P, K=2875.0, dte=18, mid=0.5500
# [next fetch] cp=C, K=3830.0, dte=21, mid=110.8000
# [day 4/21] 2021-02-08 -> 2021-02-09
# [pick_one] cp=C, K=2875.0, dte=18, mid=1032.1500, delta=0.9946, vega=8.1094, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=0.5500, delta=-0.0038, vega=9.7348, spread=0.1000, OI=123, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=110.8000, delta=0.6861, vega=331.6198, spread=0.6000, OI=258, vol=4
# [next fetch] cp=C, K=2875.0, dte=24, mid=1032.9000
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3250
# [next fetch] cp=C, K=3830.0, dte=20, mid=111.7000
# [day 5/21] 2021-02-09 -> 2021-02-10
# [pick_one] cp=C, K=2875.0, dte=24, mid=1032.9000, delta=0.9926, vega=17.5662, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3250, delta=-0.0076, vega=21.0299, spread=0.1500, OI=1152, vol=4
# [pick_one] cp=C, K=3830.0, dte=20, mid=111.7000, delta=0.6904, vega=322.2819, spread=2.4000, OI=259, vol=0
# [next fetch] cp=C, K=2875.0, dte=23, mid=1029.8500
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.4000
# [next fetch] cp=C, K=3830.0, dte=21, mid=114.1500
# [day 6/21] 2021-02-10 -> 2021-02-11
# [pick_one] cp=C, K=2875.0, dte=23, mid=1029.8500, delta=0.9930, vega=15.2435, spread=6.3000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.4000, delta=-0.0080, vega=21.4203, spread=0.2000, OI=1148, vol=41
# [pick_one] cp=C, K=3830.0, dte=21, mid=114.1500, delta=0.6708, vega=338.4449, spread=0.7000, OI=1, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=1038.1500
# [next fetch] cp=P, K=2875.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=3830.0, dte=22, mid=120.2000
# [day 7/21] 2021-02-11 -> 2021-02-12
# [pick_one] cp=C, K=2875.0, dte=22, mid=1038.1500, delta=0.9940, vega=13.6316, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=0.9500, delta=-0.0058, vega=15.8975, spread=0.2000, OI=1138, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=120.2000, delta=0.6847, vega=341.0141, spread=0.6000, OI=623, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=1058.1000
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.7750
# [next fetch] cp=C, K=3830.0, dte=21, mid=131.1000
# [day 8/21] 2021-02-12 -> 2021-02-16
# [pick_one] cp=C, K=2875.0, dte=21, mid=1058.1000, delta=0.9961, vega=9.4710, spread=5.0000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.7750, delta=-0.0049, vega=13.2840, spread=0.1500, OI=1138, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=131.1000, delta=0.7340, vega=309.2602, spread=0.6000, OI=623, vol=2
# [next fetch] cp=C, K=2875.0, dte=24, mid=1055.8000
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=20, mid=131.6500
# [day 9/21] 2021-02-16 -> 2021-02-17
# [pick_one] cp=C, K=2875.0, dte=24, mid=1055.8000, delta=0.9937, vega=16.1077, spread=5.4000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3750, delta=-0.0077, vega=21.3136, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=20, mid=131.6500, delta=0.7279, vega=305.3203, spread=1.1000, OI=18, vol=0
# [next fetch] cp=C, K=2875.0, dte=23, mid=1053.8000
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.3000
# [next fetch] cp=C, K=3830.0, dte=21, mid=130.9500
# [day 10/21] 2021-02-17 -> 2021-02-18
# [pick_one] cp=C, K=2875.0, dte=23, mid=1053.8000, delta=0.9931, vega=16.6580, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.3000, delta=-0.0074, vega=20.0903, spread=0.1000, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=130.9500, delta=0.7196, vega=317.2252, spread=0.7000, OI=0, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=1037.0500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=22, mid=122.1000
# [day 11/21] 2021-02-18 -> 2021-02-19
# [pick_one] cp=C, K=2875.0, dte=22, mid=1037.0500, delta=0.9921, vega=18.8995, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.3750, delta=-0.0078, vega=20.6140, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=22, mid=122.1000, delta=0.6751, vega=345.2526, spread=0.6000, OI=70, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=1028.4000
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.0750
# [next fetch] cp=C, K=3830.0, dte=21, mid=112.4000
# [day 12/21] 2021-02-19 -> 2021-02-22
# [pick_one] cp=C, K=2875.0, dte=21, mid=1028.4000, delta=0.9924, vega=16.9023, spread=6.8000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=1.0750, delta=-0.0065, vega=17.0421, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=112.4000, delta=0.6668, vega=339.9460, spread=0.6000, OI=70, vol=0
# [next fetch] cp=C, K=2875.0, dte=18, mid=1000.4500
# [next fetch] cp=P, K=2875.0, dte=18, mid=0.9250
# [next fetch] cp=C, K=3830.0, dte=21, mid=96.4500
# [day 13/21] 2021-02-22 -> 2021-02-23
# [pick_one] cp=C, K=2875.0, dte=18, mid=1000.4500, delta=0.9981, vega=4.2402, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=0.9250, delta=-0.0059, vega=14.4091, spread=0.1500, OI=261, vol=0
# [pick_one] cp=C, K=3830.0, dte=21, mid=96.4500, delta=0.6080, vega=357.0614, spread=7.1000, OI=39, vol=6
# [next fetch] cp=C, K=2875.0, dte=24, mid=1006.9500
# [next fetch] cp=P, K=2875.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=3830.0, dte=22, mid=102.9500
# [day 14/21] 2021-02-23 -> 2021-02-24
# [pick_one] cp=C, K=2875.0, dte=24, mid=1006.9500, delta=0.9969, vega=9.2709, spread=3.9000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=1.3750, delta=-0.0080, vega=21.4170, spread=0.1500, OI=7071, vol=2
# [pick_one] cp=C, K=3830.0, dte=22, mid=102.9500, delta=0.6184, vega=363.2824, spread=0.5000, OI=40, vol=2
# [next fetch] cp=C, K=2875.0, dte=23, mid=1048.0500
# [next fetch] cp=P, K=2875.0, dte=23, mid=1.1250
# [next fetch] cp=C, K=3830.0, dte=21, mid=127.3000
# [day 15/21] 2021-02-24 -> 2021-02-25
# [pick_one] cp=C, K=2875.0, dte=23, mid=1048.0500, delta=0.9947, vega=12.5511, spread=5.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.1250, delta=-0.0066, vega=17.8131, spread=0.1500, OI=7071, vol=1250
# [pick_one] cp=C, K=3830.0, dte=21, mid=127.3000, delta=0.7045, vega=324.6031, spread=0.8000, OI=42, vol=0
# [next fetch] cp=C, K=2875.0, dte=22, mid=958.9500
# [next fetch] cp=P, K=2875.0, dte=22, mid=3.8000
# [next fetch] cp=C, K=3830.0, dte=22, mid=88.4500
# [day 16/21] 2021-02-25 -> 2021-02-26
# [pick_one] cp=C, K=2875.0, dte=22, mid=958.9500, delta=0.9795, vega=45.5001, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.8000, delta=-0.0183, vega=41.2980, spread=0.4000, OI=6913, vol=2
# [pick_one] cp=C, K=3830.0, dte=22, mid=88.4500, delta=0.5108, vega=366.3007, spread=1.3000, OI=10896, vol=4262
# [next fetch] cp=C, K=2875.0, dte=21, mid=948.9500
# [next fetch] cp=P, K=2875.0, dte=21, mid=2.5250
# [next fetch] cp=C, K=3830.0, dte=21, mid=74.5000
# [day 17/21] 2021-02-26 -> 2021-03-01
# [pick_one] cp=C, K=2875.0, dte=21, mid=948.9500, delta=0.9563, vega=82.5321, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=2.5250, delta=-0.0137, vega=31.2841, spread=0.2500, OI=6814, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=74.5000, delta=0.4754, vega=355.2311, spread=1.2000, OI=11343, vol=4807
# [next fetch] cp=C, K=2875.0, dte=18, mid=1020.1500
# [next fetch] cp=P, K=2875.0, dte=18, mid=1.1750
# [next fetch] cp=C, K=3830.0, dte=21, mid=110.3000
# [day 18/21] 2021-03-01 -> 2021-03-02
# [pick_one] cp=C, K=2875.0, dte=18, mid=1020.1500, delta=0.9916, vega=15.1373, spread=6.1000, OI=875, vol=0
# [pick_one] cp=P, K=2875.0, dte=18, mid=1.1750, delta=-0.0070, vega=16.3941, spread=0.1500, OI=6814, vol=1
# [pick_one] cp=C, K=3830.0, dte=21, mid=110.3000, delta=0.6431, vega=347.9378, spread=0.8000, OI=295, vol=12
# [next fetch] cp=C, K=2875.0, dte=24, mid=997.2500
# [next fetch] cp=P, K=2875.0, dte=24, mid=2.2250
# [next fetch] cp=C, K=3830.0, dte=20, mid=95.3000
# [day 19/21] 2021-03-02 -> 2021-03-03
# [pick_one] cp=C, K=2875.0, dte=24, mid=997.2500, delta=0.9890, vega=28.6378, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=24, mid=2.2250, delta=-0.0118, vega=30.5140, spread=0.1500, OI=1185, vol=286
# [pick_one] cp=C, K=3830.0, dte=20, mid=95.3000, delta=0.5965, vega=350.7939, spread=0.6000, OI=287, vol=9
# [next fetch] cp=C, K=2875.0, dte=23, mid=947.1000
# [next fetch] cp=P, K=2875.0, dte=23, mid=2.5750
# [next fetch] cp=C, K=3830.0, dte=21, mid=72.2000
# [day 20/21] 2021-03-03 -> 2021-03-04
# [pick_one] cp=C, K=2875.0, dte=23, mid=947.1000, delta=0.9872, vega=31.5650, spread=9.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=2.5750, delta=-0.0138, vega=33.8203, spread=0.2500, OI=1425, vol=3
# [pick_one] cp=C, K=3830.0, dte=21, mid=72.2000, delta=0.4892, vega=365.3759, spread=0.8000, OI=2, vol=2
# [next fetch] cp=C, K=2875.0, dte=22, mid=891.7500
# [next fetch] cp=P, K=2875.0, dte=22, mid=3.3500
# [next fetch] cp=C, K=3830.0, dte=22, mid=51.1000
# [day 21/21] 2021-03-04 -> 2021-03-05
# [pick_one] cp=C, K=2875.0, dte=22, mid=891.7500, delta=0.9798, vega=42.4093, spread=8.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.3500, delta=-0.0178, vega=40.4876, spread=0.3000, OI=1426, vol=25
# [pick_one] cp=C, K=3830.0, dte=22, mid=51.1000, delta=0.3792, vega=351.6829, spread=0.8000, OI=151, vol=138
# [next fetch] cp=C, K=2875.0, dte=21, mid=965.1000
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.7750
# [next fetch] cp=C, K=3830.0, dte=21, mid=79.5000
# [pick_one] cp=C, K=2875.0, dte=22, mid=891.7500, delta=0.9798, vega=42.4093, spread=8.1000, OI=0, vol=0
# [next fetch] cp=C, K=2875.0, dte=21, mid=965.1000
# [pick_one] cp=P, K=2875.0, dte=22, mid=3.3500, delta=-0.0178, vega=40.4876, spread=0.3000, OI=1426, vol=25
# [next fetch] cp=P, K=2875.0, dte=21, mid=1.7750
# [window done] m0=0.75, freq=1, Z_T=-0.424376, V_T=966.875000, Π_T=967.299376
#
# --- Window 3/31 (start_idx=42) ---
# [get_window_dates] start=2021-03-05 end=2021-04-06 len=22
# [choose_strike_for_m0] spot0=3841.9400, m0=0.750, target=2881.4550 -> K=2880.0
# [nearest_atm_strike] spot0=3841.9400 -> K_ATM=3840.0
# [day 1/21] 2021-03-05 -> 2021-03-08
# [pick_one] cp=C, K=2880.0, dte=26, mid=960.1500, delta=0.9862, vega=33.4910, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=26, mid=2.5750, delta=-0.0136, vega=35.7524, spread=0.2500, OI=102, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=73.0000, delta=0.5058, vega=367.2378, spread=0.8000, OI=225, vol=78
# [next fetch] cp=C, K=2880.0, dte=23, mid=946.9500
# [next fetch] cp=P, K=2880.0, dte=23, mid=2.2000
# [next fetch] cp=C, K=3840.0, dte=21, mid=67.9500
# [init] V0=Π0=962.725000
# [day 2/21] 2021-03-08 -> 2021-03-09
# [pick_one] cp=C, K=2880.0, dte=23, mid=946.9500, delta=0.9759, vega=54.3053, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=23, mid=2.2000, delta=-0.0123, vega=30.5900, spread=0.2000, OI=102, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=67.9500, delta=0.4719, vega=364.7609, spread=6.1000, OI=39, vol=22
# [next fetch] cp=C, K=2880.0, dte=22, mid=994.8500
# [next fetch] cp=P, K=2880.0, dte=22, mid=1.3000
# [next fetch] cp=C, K=3840.0, dte=22, mid=95.3500
# [day 3/21] 2021-03-09 -> 2021-03-10
# [pick_one] cp=C, K=2880.0, dte=22, mid=994.8500, delta=0.9908, vega=22.2907, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=22, mid=1.3000, delta=-0.0078, vega=20.3290, spread=0.2000, OI=102, vol=3
# [pick_one] cp=C, K=3840.0, dte=22, mid=95.3500, delta=0.5778, vega=372.0459, spread=0.7000, OI=436, vol=5
# [next fetch] cp=C, K=2880.0, dte=21, mid=1018.4500
# [next fetch] cp=P, K=2880.0, dte=21, mid=0.9750
# [next fetch] cp=C, K=3840.0, dte=21, mid=105.8500
# [day 4/21] 2021-03-10 -> 2021-03-11
# [pick_one] cp=C, K=2880.0, dte=21, mid=1018.4500, delta=0.9945, vega=14.0150, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=21, mid=0.9750, delta=-0.0061, vega=16.0193, spread=0.1500, OI=103, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=105.8500, delta=0.6318, vega=352.3370, spread=0.7000, OI=436, vol=0
# [next fetch] cp=C, K=2880.0, dte=20, mid=1055.3500
# [next fetch] cp=P, K=2880.0, dte=20, mid=0.6750
# [next fetch] cp=C, K=3840.0, dte=21, mid=131.4500
# [day 5/21] 2021-03-11 -> 2021-03-12
# [pick_one] cp=C, K=2880.0, dte=20, mid=1055.3500, delta=0.9960, vega=8.0638, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=20, mid=0.6750, delta=-0.0043, vega=11.7705, spread=0.1500, OI=103, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=131.4500, delta=0.7023, vega=326.6089, spread=0.7000, OI=338, vol=63
# [next fetch] cp=C, K=2880.0, dte=19, mid=1062.5500
# [next fetch] cp=P, K=2880.0, dte=35, mid=2.7500
# [next fetch] cp=C, K=3840.0, dte=20, mid=131.8500
# [day 6/21] 2021-03-12 -> 2021-03-15
# [pick_one] cp=C, K=2880.0, dte=19, mid=1062.5500, delta=0.9978, vega=5.5279, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=35, mid=2.7500, delta=-0.0131, vega=41.0530, spread=0.1000, OI=1356, vol=18
# [pick_one] cp=C, K=3840.0, dte=20, mid=131.8500, delta=0.7306, vega=304.6778, spread=0.7000, OI=316, vol=5
# [next fetch] cp=C, K=2880.0, dte=32, mid=1085.8500
# [next fetch] cp=P, K=2880.0, dte=32, mid=1.9750
# [next fetch] cp=C, K=3840.0, dte=21, mid=148.3500
# [day 7/21] 2021-03-15 -> 2021-03-16
# [pick_one] cp=C, K=2880.0, dte=32, mid=1085.8500, delta=0.9902, vega=27.1948, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=32, mid=1.9750, delta=-0.0099, vega=31.1128, spread=0.1500, OI=1356, vol=7
# [pick_one] cp=C, K=3840.0, dte=21, mid=148.3500, delta=0.7752, vega=284.5751, spread=8.1000, OI=80, vol=14
# [next fetch] cp=C, K=2880.0, dte=31, mid=1082.8000
# [next fetch] cp=P, K=2880.0, dte=31, mid=1.8250
# [next fetch] cp=C, K=3840.0, dte=20, mid=146.1000
# [day 8/21] 2021-03-16 -> 2021-03-17
# [pick_one] cp=C, K=2880.0, dte=31, mid=1082.8000, delta=0.9926, vega=22.5903, spread=8.0000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=31, mid=1.8250, delta=-0.0094, vega=29.0642, spread=0.1500, OI=1356, vol=9
# [pick_one] cp=C, K=3840.0, dte=20, mid=146.1000, delta=0.7715, vega=280.6005, spread=0.8000, OI=93, vol=7
# [next fetch] cp=C, K=2880.0, dte=30, mid=1091.6000
# [next fetch] cp=P, K=2880.0, dte=30, mid=1.6250
# [next fetch] cp=C, K=3840.0, dte=21, mid=153.6000
# [day 9/21] 2021-03-17 -> 2021-03-18
# [pick_one] cp=C, K=2880.0, dte=30, mid=1091.6000, delta=0.9935, vega=18.0944, spread=6.4000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=30, mid=1.6250, delta=-0.0085, vega=26.2912, spread=0.1500, OI=1356, vol=8
# [pick_one] cp=C, K=3840.0, dte=21, mid=153.6000, delta=0.7857, vega=277.5048, spread=1.4000, OI=3, vol=0
# [next fetch] cp=C, K=2880.0, dte=29, mid=1037.2500
# [next fetch] cp=P, K=2880.0, dte=29, mid=2.5500
# [next fetch] cp=C, K=3840.0, dte=22, mid=116.4500
# [day 10/21] 2021-03-18 -> 2021-03-19
# [pick_one] cp=C, K=2880.0, dte=29, mid=1037.2500, delta=0.9914, vega=25.2943, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=29, mid=2.5500, delta=-0.0126, vega=36.0017, spread=0.2000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=22, mid=116.4500, delta=0.6702, vega=348.0356, spread=1.3000, OI=40, vol=0
# [next fetch] cp=C, K=2880.0, dte=28, mid=1032.1500
# [next fetch] cp=P, K=2880.0, dte=28, mid=1.7500
# [next fetch] cp=C, K=3840.0, dte=21, mid=107.9000
# [day 11/21] 2021-03-19 -> 2021-03-22
# [pick_one] cp=C, K=2880.0, dte=28, mid=1032.1500, delta=0.9905, vega=25.3650, spread=5.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=28, mid=1.7500, delta=-0.0095, vega=27.5584, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=107.9000, delta=0.6727, vega=338.4355, spread=0.8000, OI=40, vol=2
# [next fetch] cp=C, K=2880.0, dte=25, mid=1058.7500
# [next fetch] cp=P, K=2880.0, dte=25, mid=1.1000
# [next fetch] cp=C, K=3840.0, dte=21, mid=124.1000
# [day 12/21] 2021-03-22 -> 2021-03-23
# [pick_one] cp=C, K=2880.0, dte=25, mid=1058.7500, delta=0.9937, vega=16.4848, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=25, mid=1.1000, delta=-0.0064, vega=18.6146, spread=0.1000, OI=1356, vol=11
# [pick_one] cp=C, K=3840.0, dte=21, mid=124.1000, delta=0.7398, vega=306.2481, spread=1.0000, OI=10, vol=1
# [next fetch] cp=C, K=2880.0, dte=24, mid=1027.2500
# [next fetch] cp=P, K=2880.0, dte=24, mid=1.5750
# [next fetch] cp=C, K=3840.0, dte=20, mid=102.5500
# [day 13/21] 2021-03-23 -> 2021-03-24
# [pick_one] cp=C, K=2880.0, dte=24, mid=1027.2500, delta=0.9913, vega=20.7148, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=24, mid=1.5750, delta=-0.0088, vega=23.8022, spread=0.1500, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=20, mid=102.5500, delta=0.6683, vega=331.5707, spread=0.9000, OI=11, vol=2
# [next fetch] cp=C, K=2880.0, dte=23, mid=1011.1500
# [next fetch] cp=P, K=2880.0, dte=23, mid=1.5500
# [next fetch] cp=C, K=3840.0, dte=21, mid=94.1500
# [day 14/21] 2021-03-24 -> 2021-03-25
# [pick_one] cp=C, K=2880.0, dte=23, mid=1011.1500, delta=0.9900, vega=25.9306, spread=4.9000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=23, mid=1.5500, delta=-0.0088, vega=23.2558, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=94.1500, delta=0.6245, vega=353.8736, spread=0.7000, OI=3, vol=1
# [next fetch] cp=C, K=2880.0, dte=22, mid=1030.7000
# [next fetch] cp=P, K=2880.0, dte=22, mid=1.2000
# [next fetch] cp=C, K=3840.0, dte=22, mid=106.4500
# [day 15/21] 2021-03-25 -> 2021-03-26
# [pick_one] cp=C, K=2880.0, dte=22, mid=1030.7000, delta=0.9936, vega=17.2463, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=22, mid=1.2000, delta=-0.0071, vega=18.8446, spread=0.1000, OI=1356, vol=15
# [pick_one] cp=C, K=3840.0, dte=22, mid=106.4500, delta=0.6715, vega=338.9983, spread=2.5000, OI=929, vol=5
# [next fetch] cp=C, K=2880.0, dte=21, mid=1087.2500
# [next fetch] cp=P, K=2880.0, dte=21, mid=0.9250
# [next fetch] cp=C, K=3840.0, dte=21, mid=149.1000
# [day 16/21] 2021-03-26 -> 2021-03-29
# [pick_one] cp=C, K=2880.0, dte=21, mid=1087.2500, delta=0.9941, vega=10.7369, spread=8.1000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=21, mid=0.9250, delta=-0.0054, vega=14.8642, spread=0.1500, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=149.1000, delta=0.7772, vega=275.8024, spread=7.8000, OI=928, vol=22
# [next fetch] cp=C, K=2880.0, dte=18, mid=1088.9500
# [next fetch] cp=P, K=2880.0, dte=18, mid=0.7000
# [next fetch] cp=C, K=3840.0, dte=21, mid=155.3000
# [day 17/21] 2021-03-29 -> 2021-03-30
# [pick_one] cp=C, K=2880.0, dte=18, mid=1088.9500, delta=0.9963, vega=8.0759, spread=4.7000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=18, mid=0.7000, delta=-0.0043, vega=11.2564, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=155.3000, delta=0.7634, vega=293.2901, spread=0.8000, OI=292, vol=3
# [next fetch] cp=C, K=2880.0, dte=17, mid=1069.6000
# [next fetch] cp=P, K=2880.0, dte=17, mid=0.4500
# [next fetch] cp=C, K=3840.0, dte=20, mid=135.6500
# [day 18/21] 2021-03-30 -> 2021-03-31
# [pick_one] cp=C, K=2880.0, dte=17, mid=1069.6000, delta=0.9952, vega=6.4268, spread=7.6000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=17, mid=0.4500, delta=-0.0031, vega=8.0036, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=20, mid=135.6500, delta=0.7478, vega=294.0688, spread=0.9000, OI=292, vol=9
# [next fetch] cp=C, K=2880.0, dte=16, mid=1100.8000
# [next fetch] cp=P, K=2880.0, dte=16, mid=0.3000
# [next fetch] cp=C, K=3840.0, dte=21, mid=159.7000
# [day 19/21] 2021-03-31 -> 2021-04-01
# [pick_one] cp=C, K=2880.0, dte=16, mid=1100.8000, delta=0.9726, vega=50.8738, spread=6.8000, OI=0, vol=0
# [pick_one] cp=P, K=2880.0, dte=16, mid=0.3000, delta=-0.0022, vega=5.6619, spread=0.1000, OI=1356, vol=0
# [pick_one] cp=C, K=3840.0, dte=21, mid=159.7000, delta=0.7676, vega=291.0102, spread=7.8000, OI=0, vol=0
# [next fetch] cp=C, K=2880.0, dte=15, mid=1138.0000
# [next fetch] MISSING next-day row for cp=P, K=2880.0
# [next fetch] cp=C, K=3840.0, dte=22, mid=192.8500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=0.75, freq=1, start_idx=42
#
# --- Window 4/31 (start_idx=63) ---
# [get_window_dates] start=2021-04-06 end=2021-05-05 len=22
# [choose_strike_for_m0] spot0=4073.9400, m0=0.750, target=3055.4550 -> K=3060.0
# [nearest_atm_strike] spot0=4073.9400 -> K_ATM=4075.0
# [day 1/21] 2021-04-06 -> 2021-04-07
# [pick_one] cp=C, K=3060.0, dte=24, mid=1010.2500, delta=0.9939, vega=15.0437, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=24, mid=1.0000, delta=-0.0063, vega=18.4628, spread=0.1000, OI=73, vol=33
# [pick_one] cp=C, K=4075.0, dte=20, mid=47.0500, delta=0.4893, vega=379.9243, spread=0.5000, OI=1603, vol=61
# [next fetch] cp=C, K=3060.0, dte=23, mid=1017.5500
# [next fetch] cp=P, K=3060.0, dte=23, mid=0.6750
# [next fetch] cp=C, K=4075.0, dte=21, mid=51.7500
# [init] V0=Π0=1011.250000
# [day 2/21] 2021-04-07 -> 2021-04-08
# [pick_one] cp=C, K=3060.0, dte=23, mid=1017.5500, delta=0.9968, vega=7.9129, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=23, mid=0.6750, delta=-0.0045, vega=13.5922, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=21, mid=51.7500, delta=0.5141, vega=389.9119, spread=0.5000, OI=246, vol=53
# [next fetch] cp=C, K=3060.0, dte=22, mid=1034.9000
# [next fetch] cp=P, K=3060.0, dte=22, mid=0.5750
# [next fetch] cp=C, K=4075.0, dte=22, mid=64.4500
# [day 3/21] 2021-04-08 -> 2021-04-09
# [pick_one] cp=C, K=3060.0, dte=22, mid=1034.9000, delta=0.9959, vega=10.1611, spread=4.8000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=22, mid=0.5750, delta=-0.0039, vega=11.7163, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=22, mid=64.4500, delta=0.5633, vega=395.8829, spread=0.5000, OI=3528, vol=125
# [next fetch] cp=C, K=3060.0, dte=21, mid=1066.2000
# [next fetch] cp=P, K=3060.0, dte=21, mid=0.4000
# [next fetch] cp=C, K=4075.0, dte=21, mid=84.7500
# [day 4/21] 2021-04-09 -> 2021-04-12
# [pick_one] cp=C, K=3060.0, dte=21, mid=1066.2000, delta=0.9991, vega=0.8668, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=21, mid=0.4000, delta=-0.0028, vega=8.6054, spread=0.1000, OI=106, vol=0
# [pick_one] cp=C, K=4075.0, dte=21, mid=84.7500, delta=0.6498, vega=366.4778, spread=0.7000, OI=4212, vol=28
# [next fetch] cp=C, K=3060.0, dte=18, mid=1068.3500
# [next fetch] MISSING next-day row for cp=P, K=3060.0
# [next fetch] cp=C, K=4075.0, dte=21, mid=86.3500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=0.75, freq=1, start_idx=63
#
# --- Window 5/31 (start_idx=84) ---
# [get_window_dates] start=2021-05-05 end=2021-06-04 len=22
# [choose_strike_for_m0] spot0=4167.5900, m0=0.750, target=3125.6925 -> K=3125.0
# [nearest_atm_strike] spot0=4167.5900 -> K_ATM=4170.0
# [day 1/21] 2021-05-05 -> 2021-05-06
# [pick_one] cp=C, K=3125.0, dte=23, mid=1037.2000, delta=0.9943, vega=12.8332, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=1.0750, delta=-0.0065, vega=19.0771, spread=0.1500, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=54.4000, delta=0.4852, vega=398.0158, spread=0.4000, OI=20, vol=17
# [next fetch] cp=C, K=3125.0, dte=22, mid=1069.6500
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.0000
# [next fetch] cp=C, K=4170.0, dte=22, mid=73.7500
# [init] V0=Π0=1038.275000
# [day 2/21] 2021-05-06 -> 2021-05-07
# [pick_one] cp=C, K=3125.0, dte=22, mid=1069.6500, delta=0.9928, vega=15.6709, spread=6.9000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.0000, delta=-0.0060, vega=17.4198, spread=0.1000, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=73.7500, delta=0.5680, vega=404.5576, spread=0.5000, OI=136, vol=23
# [next fetch] cp=C, K=3125.0, dte=21, mid=1103.5500
# [next fetch] cp=P, K=3125.0, dte=21, mid=0.5750
# [next fetch] cp=C, K=4170.0, dte=21, mid=92.1000
# [day 3/21] 2021-05-07 -> 2021-05-10
# [pick_one] cp=C, K=3125.0, dte=21, mid=1103.5500, delta=0.9970, vega=6.2641, spread=3.5000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=0.5750, delta=-0.0037, vega=11.2171, spread=0.1500, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=92.1000, delta=0.6607, vega=371.0004, spread=0.6000, OI=142, vol=20
# [next fetch] cp=C, K=3125.0, dte=18, mid=1061.2500
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.8500
# [next fetch] cp=C, K=4170.0, dte=22, mid=69.8000
# [day 4/21] 2021-05-10 -> 2021-05-11
# [pick_one] cp=C, K=3125.0, dte=18, mid=1061.2500, delta=0.9949, vega=11.8647, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.8500, delta=-0.0053, vega=14.1006, spread=0.1000, OI=1591, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=69.8000, delta=0.5470, vega=407.0247, spread=0.6000, OI=50, vol=3
# [next fetch] cp=C, K=3125.0, dte=24, mid=1024.7500
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=4170.0, dte=21, mid=54.0000
# [day 5/21] 2021-05-11 -> 2021-05-12
# [pick_one] cp=C, K=3125.0, dte=24, mid=1024.7500, delta=0.9896, vega=26.7794, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.7750, delta=-0.0098, vega=27.7688, spread=0.1500, OI=549, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=54.0000, delta=0.4526, vega=394.1425, spread=0.8000, OI=52, vol=2
# [next fetch] cp=C, K=3125.0, dte=23, mid=942.6000
# [next fetch] cp=P, K=3125.0, dte=23, mid=4.5000
# [next fetch] cp=C, K=4170.0, dte=21, mid=30.9000
# [day 6/21] 2021-05-12 -> 2021-05-13
# [pick_one] cp=C, K=3125.0, dte=23, mid=942.6000, delta=0.9782, vega=52.9032, spread=7.0000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=4.5000, delta=-0.0213, vega=52.1592, spread=0.2000, OI=549, vol=139
# [pick_one] cp=C, K=4170.0, dte=21, mid=30.9000, delta=0.2845, vega=330.5731, spread=0.8000, OI=61, vol=11
# [next fetch] cp=C, K=3125.0, dte=22, mid=987.3000
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.9250
# [next fetch] cp=C, K=4170.0, dte=22, mid=41.7500
# [day 7/21] 2021-05-13 -> 2021-05-14
# [pick_one] cp=C, K=3125.0, dte=22, mid=987.3000, delta=0.9900, vega=25.8619, spread=4.6000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.9250, delta=-0.0108, vega=28.6693, spread=0.1500, OI=568, vol=36
# [pick_one] cp=C, K=4170.0, dte=22, mid=41.7500, delta=0.3701, vega=381.1077, spread=0.5000, OI=220, vol=69
# [next fetch] cp=C, K=3125.0, dte=21, mid=1047.7500
# [next fetch] cp=P, K=3125.0, dte=21, mid=1.0250
# [next fetch] cp=C, K=4170.0, dte=21, mid=58.6000
# [day 8/21] 2021-05-14 -> 2021-05-17
# [pick_one] cp=C, K=3125.0, dte=21, mid=1047.7500, delta=0.9935, vega=16.9325, spread=7.1000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=1.0250, delta=-0.0062, vega=17.5284, spread=0.1500, OI=512, vol=200
# [pick_one] cp=C, K=4170.0, dte=21, mid=58.6000, delta=0.5117, vega=399.0094, spread=0.6000, OI=223, vol=25
# [next fetch] cp=C, K=3125.0, dte=18, mid=1035.9500
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.7500
# [next fetch] cp=C, K=4170.0, dte=21, mid=53.2500
# [day 9/21] 2021-05-17 -> 2021-05-18
# [pick_one] cp=C, K=3125.0, dte=18, mid=1035.9500, delta=0.9954, vega=10.6692, spread=3.9000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.7500, delta=-0.0049, vega=13.0749, spread=0.1000, OI=614, vol=60
# [pick_one] cp=C, K=4170.0, dte=21, mid=53.2500, delta=0.4801, vega=397.6131, spread=0.5000, OI=54, vol=3
# [next fetch] cp=C, K=3125.0, dte=24, mid=1005.1000
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.7750
# [next fetch] cp=C, K=4170.0, dte=22, mid=41.7500
# [day 10/21] 2021-05-18 -> 2021-05-19
# [pick_one] cp=C, K=3125.0, dte=24, mid=1005.1000, delta=0.9888, vega=31.2462, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.7750, delta=-0.0099, vega=28.0747, spread=0.1500, OI=133, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=41.7500, delta=0.3979, vega=390.9903, spread=0.5000, OI=722, vol=21
# [next fetch] cp=C, K=3125.0, dte=23, mid=987.8000
# [next fetch] cp=P, K=3125.0, dte=23, mid=2.0750
# [next fetch] cp=C, K=4170.0, dte=21, mid=33.8000
# [day 11/21] 2021-05-19 -> 2021-05-20
# [pick_one] cp=C, K=3125.0, dte=23, mid=987.8000, delta=0.9910, vega=22.4545, spread=4.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=2.0750, delta=-0.0114, vega=30.8129, spread=0.1500, OI=133, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=33.8000, delta=0.3516, vega=366.0490, spread=0.6000, OI=732, vol=22
# [next fetch] cp=C, K=3125.0, dte=22, mid=1029.8000
# [next fetch] cp=P, K=3125.0, dte=22, mid=1.4250
# [next fetch] cp=C, K=4170.0, dte=20, mid=48.4500
# [day 12/21] 2021-05-20 -> 2021-05-21
# [pick_one] cp=C, K=3125.0, dte=22, mid=1029.8000, delta=0.9909, vega=21.6483, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=1.4250, delta=-0.0082, vega=22.8081, spread=0.1500, OI=133, vol=20
# [pick_one] cp=C, K=4170.0, dte=20, mid=48.4500, delta=0.4601, vega=386.0010, spread=0.5000, OI=734, vol=33
# [next fetch] cp=C, K=3125.0, dte=21, mid=1027.6500
# [next fetch] cp=P, K=3125.0, dte=21, mid=1.1250
# [next fetch] cp=C, K=4170.0, dte=21, mid=48.8000
# [day 13/21] 2021-05-21 -> 2021-05-24
# [pick_one] cp=C, K=3125.0, dte=21, mid=1027.6500, delta=0.9937, vega=15.1588, spread=7.3000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=1.1250, delta=-0.0068, vega=18.9229, spread=0.1500, OI=148, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=48.8000, delta=0.4563, vega=394.9427, spread=0.4000, OI=358, vol=55
# [next fetch] cp=C, K=3125.0, dte=18, mid=1070.6000
# [next fetch] cp=P, K=3125.0, dte=18, mid=0.6500
# [next fetch] cp=C, K=4170.0, dte=21, mid=66.4500
# [day 14/21] 2021-05-24 -> 2021-05-25
# [pick_one] cp=C, K=3125.0, dte=18, mid=1070.6000, delta=0.9950, vega=12.0900, spread=3.8000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=18, mid=0.6500, delta=-0.0042, vega=11.5647, spread=0.1000, OI=148, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=66.4500, delta=0.5772, vega=393.7023, spread=0.5000, OI=234, vol=4
# [next fetch] cp=C, K=3125.0, dte=17, mid=1061.1000
# [next fetch] cp=P, K=3125.0, dte=24, mid=1.3750
# [next fetch] cp=C, K=4170.0, dte=20, mid=60.1000
# [day 15/21] 2021-05-25 -> 2021-05-26
# [pick_one] cp=C, K=3125.0, dte=17, mid=1061.1000, delta=0.9973, vega=6.1691, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=24, mid=1.3750, delta=-0.0077, vega=22.3729, spread=0.1500, OI=4390, vol=40
# [pick_one] cp=C, K=4170.0, dte=20, mid=60.1000, delta=0.5511, vega=387.5296, spread=0.6000, OI=230, vol=40
# [next fetch] cp=C, K=3125.0, dte=23, mid=1066.4000
# [next fetch] cp=P, K=3125.0, dte=23, mid=1.0000
# [next fetch] cp=C, K=4170.0, dte=21, mid=64.5500
# [day 16/21] 2021-05-26 -> 2021-05-27
# [pick_one] cp=C, K=3125.0, dte=23, mid=1066.4000, delta=0.9950, vega=11.5237, spread=4.8000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=23, mid=1.0000, delta=-0.0060, vega=17.4478, spread=0.1000, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=64.5500, delta=0.5682, vega=395.0381, spread=0.5000, OI=50, vol=24
# [next fetch] cp=C, K=3125.0, dte=22, mid=1077.3000
# [next fetch] cp=P, K=3125.0, dte=22, mid=0.9500
# [next fetch] cp=C, K=4170.0, dte=22, mid=70.9000
# [day 17/21] 2021-05-27 -> 2021-05-28
# [pick_one] cp=C, K=3125.0, dte=22, mid=1077.3000, delta=0.9928, vega=20.1444, spread=4.8000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=22, mid=0.9500, delta=-0.0057, vega=16.3479, spread=0.1000, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=22, mid=70.9000, delta=0.5971, vega=390.0166, spread=0.6000, OI=11780, vol=2
# [next fetch] cp=C, K=3125.0, dte=21, mid=1078.5000
# [next fetch] cp=P, K=3125.0, dte=21, mid=0.8250
# [next fetch] cp=C, K=4170.0, dte=21, mid=69.3500
# [day 18/21] 2021-05-28 -> 2021-06-01
# [pick_one] cp=C, K=3125.0, dte=21, mid=1078.5000, delta=0.9959, vega=11.0014, spread=5.4000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=21, mid=0.8250, delta=-0.0051, vega=14.4121, spread=0.1500, OI=4352, vol=3
# [pick_one] cp=C, K=4170.0, dte=21, mid=69.3500, delta=0.6071, vega=378.1925, spread=0.7000, OI=11779, vol=204
# [next fetch] cp=C, K=3125.0, dte=17, mid=1073.2000
# [next fetch] cp=P, K=3125.0, dte=17, mid=0.6750
# [next fetch] cp=C, K=4170.0, dte=20, mid=68.8500
# [day 19/21] 2021-06-01 -> 2021-06-02
# [pick_one] cp=C, K=3125.0, dte=17, mid=1073.2000, delta=0.9952, vega=9.7702, spread=4.4000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=17, mid=0.6750, delta=-0.0043, vega=11.1887, spread=0.1500, OI=4352, vol=0
# [pick_one] cp=C, K=4170.0, dte=20, mid=68.8500, delta=0.5869, vega=382.5142, spread=0.5000, OI=57, vol=2
# [next fetch] cp=C, K=3125.0, dte=16, mid=1080.9000
# [next fetch] cp=P, K=3125.0, dte=16, mid=0.4500
# [next fetch] cp=C, K=4170.0, dte=21, mid=73.7500
# [day 20/21] 2021-06-02 -> 2021-06-03
# [pick_one] cp=C, K=3125.0, dte=16, mid=1080.9000, delta=0.9972, vega=5.9183, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=3125.0, dte=16, mid=0.4500, delta=-0.0031, vega=8.2795, spread=0.1000, OI=690, vol=0
# [pick_one] cp=C, K=4170.0, dte=21, mid=73.7500, delta=0.6108, vega=386.7365, spread=0.7000, OI=7, vol=5
# [next fetch] cp=C, K=3125.0, dte=15, mid=1067.3500
# [next fetch] cp=P, K=3125.0, dte=15, mid=0.4000
# [next fetch] cp=C, K=4170.0, dte=22, mid=69.1500
# [day 21/21] 2021-06-03 -> 2021-06-04
# [pick_one] cp=C, K=3125.0, dte=15, mid=1067.3500, delta=0.9995, vega=0.9748, spread=4.1000, OI=1684, vol=0
# [pick_one] cp=P, K=3125.0, dte=15, mid=0.4000, delta=-0.0028, vega=7.1512, spread=0.1000, OI=4352, vol=1
# [pick_one] cp=C, K=4170.0, dte=22, mid=69.1500, delta=0.5671, vega=404.6990, spread=0.5000, OI=135, vol=7
# [next fetch] cp=C, K=3125.0, dte=26, mid=1102.7500
# [next fetch] cp=P, K=3125.0, dte=26, mid=0.9750
# [next fetch] cp=C, K=4170.0, dte=21, mid=88.6500
# [pick_one] cp=C, K=3125.0, dte=15, mid=1067.3500, delta=0.9995, vega=0.9748, spread=4.1000, OI=1684, vol=0
# [next fetch] cp=C, K=3125.0, dte=26, mid=1102.7500
# [pick_one] cp=P, K=3125.0, dte=15, mid=0.4000, delta=-0.0028, vega=7.1512, spread=0.1000, OI=4352, vol=1
# [next fetch] cp=P, K=3125.0, dte=26, mid=0.9750
# [window done] m0=0.75, freq=1, Z_T=4.578360, V_T=1103.725000, Π_T=1099.146640
#
# --- Window 6/31 (start_idx=105) ---
# [get_window_dates] start=2021-06-04 end=2021-07-06 len=22
# [choose_strike_for_m0] spot0=4229.8900, m0=0.750, target=3172.4175 -> K=3170.0
# [nearest_atm_strike] spot0=4229.8900 -> K_ATM=4230.0
# [day 1/21] 2021-06-04 -> 2021-06-07
# [pick_one] cp=C, K=3170.0, dte=26, mid=1058.5000, delta=0.9943, vega=16.6529, spread=3.8000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=26, mid=1.0750, delta=-0.0064, vega=20.3008, spread=0.1500, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=21, mid=46.4000, delta=0.4997, vega=404.5940, spread=0.4000, OI=500, vol=100
# [next fetch] cp=C, K=3170.0, dte=23, mid=1056.0000
# [next fetch] cp=P, K=3170.0, dte=23, mid=0.8000
# [next fetch] cp=C, K=4230.0, dte=21, mid=43.5500
# [init] V0=Π0=1059.575000
# [day 2/21] 2021-06-07 -> 2021-06-08
# [pick_one] cp=C, K=3170.0, dte=23, mid=1056.0000, delta=0.9961, vega=11.4438, spread=3.6000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=23, mid=0.8000, delta=-0.0051, vega=15.4977, spread=0.1000, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=21, mid=43.5500, delta=0.4914, vega=404.2849, spread=0.5000, OI=610, vol=15
# [next fetch] cp=C, K=3170.0, dte=22, mid=1056.8500
# [next fetch] cp=P, K=3170.0, dte=22, mid=0.8500
# [next fetch] cp=C, K=4230.0, dte=20, mid=44.2000
# [day 3/21] 2021-06-08 -> 2021-06-09
# [pick_one] cp=C, K=3170.0, dte=22, mid=1056.8500, delta=0.9941, vega=16.4354, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=22, mid=0.8500, delta=-0.0053, vega=15.8246, spread=0.1000, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=20, mid=44.2000, delta=0.4934, vega=394.6295, spread=0.6000, OI=616, vol=36
# [next fetch] cp=C, K=3170.0, dte=21, mid=1050.4500
# [next fetch] cp=P, K=3170.0, dte=21, mid=0.9000
# [next fetch] cp=C, K=4230.0, dte=21, mid=45.7500
# [day 4/21] 2021-06-09 -> 2021-06-10
# [pick_one] cp=C, K=3170.0, dte=21, mid=1050.4500, delta=0.9951, vega=14.4622, spread=3.7000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=21, mid=0.9000, delta=-0.0056, vega=16.1599, spread=0.1000, OI=550, vol=0
# ...
# [pick_one] cp=C, K=4240.0, dte=18, mid=5.5000, delta=0.0819, vega=131.1705, spread=0.2000, OI=2030, vol=151
# [pick_one] cp=P, K=4240.0, dte=18, mid=222.7500, delta=-0.9130, vega=136.4957, spread=3.9000, OI=130, vol=0
# [pick_one] cp=C, K=3855.0, dte=18, mid=187.8500, delta=0.8143, vega=231.4846, spread=1.9000, OI=469, vol=0
# [next fetch] cp=C, K=4240.0, dte=24, mid=14.6000
# [next fetch] cp=P, K=4240.0, dte=24, mid=171.9000
# [next fetch] cp=C, K=3855.0, dte=24, mid=244.2000
# [day 19/21] 2023-01-31 -> 2023-02-01
# [pick_one] cp=C, K=4240.0, dte=24, mid=14.6000, delta=0.1735, vega=267.9258, spread=0.4000, OI=53, vol=8
# [pick_one] cp=P, K=4240.0, dte=24, mid=171.9000, delta=-0.8160, vega=277.1247, spread=3.2000, OI=0, vol=0
# [pick_one] cp=C, K=3855.0, dte=24, mid=244.2000, delta=0.8610, vega=230.3993, spread=3.4000, OI=0, vol=0
# [next fetch] cp=C, K=4240.0, dte=23, mid=20.2000
# [next fetch] cp=P, K=4240.0, dte=23, mid=135.7500
# [next fetch] cp=C, K=3855.0, dte=23, mid=279.2000
# [day 20/21] 2023-02-01 -> 2023-02-02
# [pick_one] cp=C, K=4240.0, dte=23, mid=20.2000, delta=0.2338, vega=316.7776, spread=0.4000, OI=53, vol=363
# [pick_one] cp=P, K=4240.0, dte=23, mid=135.7500, delta=-0.7547, vega=324.5401, spread=2.9000, OI=0, vol=25
# [pick_one] cp=C, K=3855.0, dte=23, mid=279.2000, delta=0.9125, vega=163.2576, spread=3.2000, OI=0, vol=0
# [next fetch] cp=C, K=4240.0, dte=22, mid=39.2500
# [next fetch] cp=P, K=4240.0, dte=22, mid=96.7000
# [next fetch] cp=C, K=3855.0, dte=22, mid=334.1000
# [day 21/21] 2023-02-02 -> 2023-02-03
# [pick_one] cp=C, K=4240.0, dte=22, mid=39.2500, delta=0.3714, vega=387.6430, spread=0.5000, OI=250, vol=516
# [pick_one] cp=P, K=4240.0, dte=22, mid=96.7000, delta=-0.6206, vega=389.8836, spread=0.6000, OI=25, vol=0
# [pick_one] cp=C, K=3855.0, dte=22, mid=334.1000, delta=0.9498, vega=104.2482, spread=3.2000, OI=0, vol=0
# [next fetch] cp=C, K=4240.0, dte=21, mid=24.6500
# [next fetch] cp=P, K=4240.0, dte=21, mid=122.7500
# [next fetch] cp=C, K=3855.0, dte=21, mid=294.3500
# [pick_one] cp=C, K=4240.0, dte=22, mid=39.2500, delta=0.3714, vega=387.6430, spread=0.5000, OI=250, vol=516
# [next fetch] cp=C, K=4240.0, dte=21, mid=24.6500
# [pick_one] cp=P, K=4240.0, dte=22, mid=96.7000, delta=-0.6206, vega=389.8836, spread=0.6000, OI=25, vol=0
# [next fetch] cp=P, K=4240.0, dte=21, mid=122.7500
# [window done] m0=1.1, freq=5, Z_T=14.538507, V_T=147.400000, Π_T=132.861493
#
# --- Window 26/31 (start_idx=525) ---
# [get_window_dates] start=2023-02-03 end=2023-03-07 len=22
# [choose_strike_for_m0] spot0=4136.4800, m0=1.100, target=4550.1280 -> K=4550.0
# [nearest_atm_strike] spot0=4136.4800 -> K_ATM=4135.0
# [day 1/21] 2023-02-03 -> 2023-02-06
# [pick_one] cp=C, K=4550.0, dte=21, mid=0.3500, delta=0.0069, vega=19.2017, spread=0.1000, OI=0, vol=6
# [pick_one] cp=P, K=4550.0, dte=21, mid=407.2500, delta=-0.9751, vega=56.5748, spread=5.3000, OI=0, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=68.9500, delta=0.5285, vega=394.5449, spread=0.5000, OI=155, vol=20
# [next fetch] cp=C, K=4550.0, dte=25, mid=0.4000
# [next fetch] cp=P, K=4550.0, dte=22, mid=433.9500
# [next fetch] cp=C, K=4135.0, dte=21, mid=55.8500
# [init] V0=Π0=407.600000
# [day 2/21] 2023-02-06 -> 2023-02-07
# [pick_one] cp=C, K=4550.0, dte=25, mid=0.4000, delta=0.0074, vega=22.0193, spread=0.1000, OI=9, vol=23
# [pick_one] cp=P, K=4550.0, dte=22, mid=433.9500, delta=-0.9699, vega=67.1143, spread=5.1000, OI=24, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=55.8500, delta=0.4635, vega=391.4530, spread=0.5000, OI=1, vol=23
# [next fetch] cp=C, K=4550.0, dte=21, mid=0.4000
# [next fetch] cp=P, K=4550.0, dte=21, mid=377.2000
# [next fetch] cp=C, K=4135.0, dte=21, mid=85.7000
# [day 3/21] 2023-02-07 -> 2023-02-08
# [pick_one] cp=C, K=4550.0, dte=21, mid=0.4000, delta=0.0082, vega=22.3284, spread=0.1000, OI=1179, vol=2
# [pick_one] cp=P, K=4550.0, dte=21, mid=377.2000, delta=-0.9836, vega=40.3762, spread=4.8000, OI=24, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=85.7000, delta=0.5991, vega=385.9909, spread=0.4000, OI=429, vol=2
# [next fetch] cp=C, K=4550.0, dte=23, mid=0.3000
# [next fetch] cp=P, K=4550.0, dte=20, mid=425.2000
# [next fetch] cp=C, K=4135.0, dte=21, mid=62.5000
# [day 4/21] 2023-02-08 -> 2023-02-09
# [pick_one] cp=C, K=4550.0, dte=23, mid=0.3000, delta=0.0060, vega=17.4441, spread=0.1000, OI=10, vol=12
# [pick_one] cp=P, K=4550.0, dte=20, mid=425.2000, delta=-0.9801, vega=45.6023, spread=4.8000, OI=24, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=62.5000, delta=0.4854, vega=393.5943, spread=0.4000, OI=13, vol=11
# [next fetch] MISSING next-day row for cp=C, K=4550.0
# [next fetch] cp=P, K=4550.0, dte=22, mid=463.4500
# [next fetch] cp=C, K=4135.0, dte=21, mid=48.4000
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=525
#
# --- Window 27/31 (start_idx=546) ---
# [get_window_dates] start=2023-03-07 end=2023-04-05 len=22
# [choose_strike_for_m0] spot0=3986.3700, m0=1.100, target=4385.0070 -> K=4385.0
# [nearest_atm_strike] spot0=3986.3700 -> K_ATM=3985.0
# [day 1/21] 2023-03-07 -> 2023-03-08
# [pick_one] cp=C, K=4385.0, dte=24, mid=0.6500, delta=0.0118, vega=31.4138, spread=0.1000, OI=405, vol=0
# [pick_one] cp=P, K=4385.0, dte=24, mid=388.8500, delta=-0.9823, vega=43.9104, spread=2.7000, OI=1, vol=0
# [pick_one] cp=C, K=3985.0, dte=21, mid=77.4500, delta=0.5296, vega=380.2586, spread=0.5000, OI=6, vol=2
# [next fetch] cp=C, K=4385.0, dte=23, mid=0.6000
# [next fetch] cp=P, K=4385.0, dte=23, mid=384.5000
# [next fetch] cp=C, K=3985.0, dte=21, mid=77.8500
# [init] V0=Π0=389.500000
# [day 2/21] 2023-03-08 -> 2023-03-09
# [pick_one] cp=C, K=4385.0, dte=23, mid=0.6000, delta=0.0112, vega=29.3741, spread=0.1000, OI=405, vol=4
# [pick_one] cp=P, K=4385.0, dte=23, mid=384.5000, delta=-0.9792, vega=49.3001, spread=4.6000, OI=1, vol=0
# [pick_one] cp=C, K=3985.0, dte=21, mid=77.8500, delta=0.5414, vega=379.7197, spread=0.5000, OI=6, vol=17
# [next fetch] MISSING next-day row for cp=C, K=4385.0
# [next fetch] cp=P, K=4385.0, dte=22, mid=456.1500
# [next fetch] cp=C, K=3985.0, dte=21, mid=52.1500
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=546
#
# --- Window 28/31 (start_idx=567) ---
# [get_window_dates] start=2023-04-05 end=2023-05-05 len=22
# [choose_strike_for_m0] spot0=4090.3800, m0=1.100, target=4499.4180 -> K=4500.0
# [nearest_atm_strike] spot0=4090.3800 -> K_ATM=4090.0
# [day 1/21] 2023-04-05 -> 2023-04-06
# [pick_one] cp=C, K=4500.0, dte=27, mid=0.4000, delta=0.0079, vega=24.0245, spread=0.1000, OI=44, vol=2
# [pick_one] cp=P, K=4500.0, dte=21, mid=401.1000, delta=-0.9781, vega=50.5897, spread=3.2000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=64.4000, delta=0.5320, vega=390.0097, spread=0.4000, OI=1, vol=1
# [next fetch] cp=C, K=4500.0, dte=22, mid=0.2250
# [next fetch] cp=P, K=4500.0, dte=21, mid=385.7000
# [next fetch] cp=C, K=4090.0, dte=21, mid=71.7500
# [init] V0=Π0=401.500000
# [day 2/21] 2023-04-06 -> 2023-04-10
# [pick_one] cp=C, K=4500.0, dte=22, mid=0.2250, delta=0.0051, vega=14.7282, spread=0.0500, OI=6656, vol=16
# [pick_one] cp=P, K=4500.0, dte=21, mid=385.7000, delta=-0.9815, vega=44.0327, spread=6.2000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=71.7500, delta=0.5727, vega=386.1545, spread=0.5000, OI=8, vol=0
# [next fetch] cp=C, K=4500.0, dte=23, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=21, mid=384.1500
# [next fetch] cp=C, K=4090.0, dte=21, mid=73.9000
# [day 3/21] 2023-04-10 -> 2023-04-11
# [pick_one] cp=C, K=4500.0, dte=23, mid=0.3000, delta=0.0064, vega=18.6572, spread=0.1000, OI=17, vol=1
# [pick_one] cp=P, K=4500.0, dte=21, mid=384.1500, delta=-0.9662, vega=73.1232, spread=5.1000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=73.9000, delta=0.5798, vega=385.0432, spread=0.4000, OI=18, vol=17
# [next fetch] cp=C, K=4500.0, dte=22, mid=0.3500
# [next fetch] cp=P, K=4500.0, dte=21, mid=381.1500
# [next fetch] cp=C, K=4090.0, dte=21, mid=76.4500
# [day 4/21] 2023-04-11 -> 2023-04-12
# [pick_one] cp=C, K=4500.0, dte=22, mid=0.3500, delta=0.0073, vega=20.4097, spread=0.1000, OI=17, vol=1
# [pick_one] cp=P, K=4500.0, dte=21, mid=381.1500, delta=-0.9847, vega=37.5545, spread=5.9000, OI=40, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=76.4500, delta=0.5816, vega=384.8603, spread=0.5000, OI=71, vol=1
# [next fetch] cp=C, K=4500.0, dte=23, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=21, mid=398.4500
# [next fetch] cp=C, K=4090.0, dte=21, mid=69.4000
# [day 5/21] 2023-04-12 -> 2023-04-13
# [pick_one] cp=C, K=4500.0, dte=23, mid=0.3000, delta=0.0063, vega=18.1150, spread=0.1000, OI=1342, vol=228
# [pick_one] cp=P, K=4500.0, dte=21, mid=398.4500, delta=-0.9826, vega=41.7061, spread=7.5000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=69.4000, delta=0.5367, vega=389.8226, spread=0.8000, OI=20, vol=0
# [next fetch] cp=C, K=4500.0, dte=21, mid=0.4000
# [next fetch] cp=P, K=4500.0, dte=21, mid=343.5500
# [next fetch] cp=C, K=4090.0, dte=21, mid=102.2500
# [day 6/21] 2023-04-13 -> 2023-04-14
# [pick_one] cp=C, K=4500.0, dte=21, mid=0.4000, delta=0.0088, vega=23.6574, spread=0.1000, OI=3, vol=15
# [pick_one] cp=P, K=4500.0, dte=21, mid=343.5500, delta=-0.9830, vega=41.6385, spread=5.7000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=102.2500, delta=0.6681, vega=360.9203, spread=0.5000, OI=14, vol=8
# [next fetch] cp=C, K=4500.0, dte=21, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=19, mid=352.2500
# [next fetch] cp=C, K=4090.0, dte=21, mid=95.9500
# [day 7/21] 2023-04-14 -> 2023-04-17
# [pick_one] cp=C, K=4500.0, dte=21, mid=0.3000, delta=0.0069, vega=18.9767, spread=0.1000, OI=1553, vol=151
# [pick_one] cp=P, K=4500.0, dte=19, mid=352.2500, delta=-0.9932, vega=17.9235, spread=5.7000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=95.9500, delta=0.6516, vega=367.0049, spread=0.5000, OI=288, vol=97
# [next fetch] cp=C, K=4500.0, dte=21, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=21, mid=339.7000
# [next fetch] cp=C, K=4090.0, dte=21, mid=102.0000
# [day 8/21] 2023-04-17 -> 2023-04-18
# [pick_one] cp=C, K=4500.0, dte=21, mid=0.3000, delta=0.0070, vega=19.5134, spread=0.1000, OI=17, vol=4
# [pick_one] cp=P, K=4500.0, dte=21, mid=339.7000, delta=-0.9730, vega=61.6381, spread=5.6000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=102.0000, delta=0.6877, vega=352.2447, spread=0.4000, OI=11, vol=4
# [next fetch] cp=C, K=4500.0, dte=22, mid=0.4000
# [next fetch] cp=P, K=4500.0, dte=27, mid=330.9000
# [next fetch] cp=C, K=4090.0, dte=21, mid=107.9000
# [day 9/21] 2023-04-18 -> 2023-04-19
# [pick_one] cp=C, K=4500.0, dte=22, mid=0.4000, delta=0.0090, vega=24.7283, spread=0.1000, OI=59, vol=0
# [pick_one] cp=P, K=4500.0, dte=27, mid=330.9000, delta=-0.9879, vega=35.3329, spread=5.2000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=107.9000, delta=0.6900, vega=351.6089, spread=3.6000, OI=1, vol=2
# [next fetch] cp=C, K=4500.0, dte=23, mid=0.3250
# [next fetch] cp=P, K=4500.0, dte=21, mid=335.9000
# [next fetch] cp=C, K=4090.0, dte=21, mid=106.3500
# [day 10/21] 2023-04-19 -> 2023-04-20
# [pick_one] cp=C, K=4500.0, dte=23, mid=0.3250, delta=0.0076, vega=21.8109, spread=0.0500, OI=167, vol=59
# [pick_one] cp=P, K=4500.0, dte=21, mid=335.9000, delta=-0.9762, vega=55.4699, spread=3.2000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=106.3500, delta=0.6902, vega=351.3775, spread=3.1000, OI=19, vol=14
# [next fetch] cp=C, K=4500.0, dte=28, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=21, mid=363.6500
# [next fetch] cp=C, K=4090.0, dte=21, mid=89.4000
# [day 11/21] 2023-04-20 -> 2023-04-21
# [pick_one] cp=C, K=4500.0, dte=28, mid=0.3000, delta=0.0067, vega=21.5275, spread=0.1000, OI=6, vol=1
# [pick_one] cp=P, K=4500.0, dte=21, mid=363.6500, delta=-0.9631, vega=78.8803, spread=5.9000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=89.4000, delta=0.6272, vega=374.5828, spread=0.6000, OI=4, vol=3
# [next fetch] cp=C, K=4500.0, dte=28, mid=0.3000
# [next fetch] cp=P, K=4500.0, dte=21, mid=355.9500
# [next fetch] cp=C, K=4090.0, dte=21, mid=92.5000
# [day 12/21] 2023-04-21 -> 2023-04-24
# [pick_one] cp=C, K=4500.0, dte=28, mid=0.3000, delta=0.0068, vega=21.8320, spread=0.1000, OI=437, vol=18
# [pick_one] cp=P, K=4500.0, dte=21, mid=355.9500, delta=-0.9869, vega=33.2157, spread=4.3000, OI=1, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=92.5000, delta=0.6421, vega=370.1194, spread=0.4000, OI=84, vol=4
# [next fetch] cp=C, K=4500.0, dte=25, mid=0.2250
# [next fetch] cp=P, K=4500.0, dte=21, mid=354.7000
# [next fetch] cp=C, K=4090.0, dte=21, mid=92.4000
# [day 13/21] 2023-04-24 -> 2023-04-25
# [pick_one] cp=C, K=4500.0, dte=25, mid=0.2250, delta=0.0054, vega=16.4745, spread=0.0500, OI=13896, vol=72
# [pick_one] cp=P, K=4500.0, dte=21, mid=354.7000, delta=-0.9700, vega=66.8718, spread=3.8000, OI=0, vol=0
# [pick_one] cp=C, K=4090.0, dte=21, mid=92.4000, delta=0.6520, vega=366.5639, spread=0.4000, OI=41, vol=6
# [next fetch] MISSING next-day row for cp=C, K=4500.0
# [next fetch] cp=P, K=4500.0, dte=21, mid=417.1500
# [next fetch] cp=C, K=4090.0, dte=21, mid=61.5000
# [one_day_step] Missing next-day leg(s).
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=567
#
# --- Window 29/31 (start_idx=588) ---
# [get_window_dates] start=2023-05-05 end=2023-06-06 len=22
# [choose_strike_for_m0] spot0=4136.2500, m0=1.100, target=4549.8750 -> K=4550.0
# [nearest_atm_strike] spot0=4136.2500 -> K_ATM=4135.0
# [day 1/21] 2023-05-05 -> 2023-05-08
# [pick_one] MISSING leg for cp=C, K=4550.0
# [pick_one] cp=P, K=4550.0, dte=26, mid=407.8500, delta=-0.9465, vega=118.3718, spread=5.3000, OI=49, vol=0
# [pick_one] cp=C, K=4135.0, dte=21, mid=58.9500, delta=0.5348, vega=394.0391, spread=0.5000, OI=220, vol=19
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=588
#
# --- Window 30/31 (start_idx=609) ---
# [get_window_dates] start=2023-06-06 end=2023-07-07 len=22
# [choose_strike_for_m0] spot0=4283.8500, m0=1.100, target=4712.2350 -> K=4710.0
# [nearest_atm_strike] spot0=4283.8500 -> K_ATM=4285.0
# [day 1/21] 2023-06-06 -> 2023-06-07
# [pick_one] cp=C, K=4710.0, dte=24, mid=0.1750, delta=0.0039, vega=12.7150, spread=0.0500, OI=0, vol=1
# [pick_one] MISSING leg for cp=P, K=4710.0
# [pick_one] cp=C, K=4285.0, dte=21, mid=51.1000, delta=0.5415, vega=407.7029, spread=0.4000, OI=2, vol=2
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=609
#
# --- Window 31/31 (start_idx=630) ---
# [get_window_dates] start=2023-07-07 end=2023-08-07 len=22
# [choose_strike_for_m0] spot0=4398.9500, m0=1.100, target=4838.8450 -> K=4850.0
# [nearest_atm_strike] spot0=4398.9500 -> K_ATM=4400.0
# [day 1/21] 2023-07-07 -> 2023-07-10
# [pick_one] MISSING leg for cp=C, K=4850.0
# [pick_one] cp=P, K=4850.0, dte=21, mid=438.4000, delta=-0.9903, vega=27.3633, spread=4.4000, OI=0, vol=0
# [pick_one] cp=C, K=4400.0, dte=21, mid=56.0000, delta=0.5402, vega=418.7880, spread=0.4000, OI=997, vol=106
# [one_day_step] Missing leg(s) at current day.
# [run_single_window] Step failed; abort window.
# [run_experiment_with_freqs] FAILED m0=1.1, freq=5, start_idx=630
# Results shape: (120, 12)
#        start        end    m0  rebalance_every  K_straddle  K_hedge        V0       V_T         Pi_T  tracking_error  pnl_unhedged  pnl_hedged
# 0 2021-01-04 2021-02-03  0.75                1      2775.0   3700.0   928.350  1057.125  1058.521598       -1.396598       128.775  130.171598
# 1 2021-02-03 2021-03-05  0.75                1      2875.0   3830.0   958.025   966.875   967.299376       -0.424376         8.850    9.274376
# 2 2021-05-05 2021-06-04  0.75                1      3125.0   4170.0  1038.275  1103.725  1099.146640        4.578360        65.450   60.871640
# 3 2021-06-04 2021-07-06  0.75                1      3170.0   4230.0  1059.575  1172.850  1172.521881        0.328119       113.275  112.946881
# 4 2021-08-04 2021-09-02  0.75                1      3300.0   4405.0  1101.500  1235.400  1234.626664        0.773336       133.900  133.126664

# %%
# === D) Summary table ===
summary_tbl = summarize_results_verbose(results_df)
summary_tbl
# Out:
#           mean    median    std_dev   VaR_5pct  VaR_2p5pct   VaR_1pct
# m0
# 0.75 -1.954603 -0.587878   6.274122 -12.810983  -15.087399 -17.021013
# 0.80 -2.995612 -2.894352   8.401970 -19.095211  -20.354818 -20.589791
# 0.90  0.832098 -1.689304  25.505963 -39.419673  -43.349691 -43.772563
# 1.10 -3.702167 -2.966233  11.939291 -19.368675  -22.293116 -24.047780

# %%
from scipy.stats import skew

def compute_cvar(x: pd.Series, alpha: float = 0.05) -> float:
    """
    CVaR / Expected Shortfall at level alpha:
    average of the worst alpha fraction (lower tail).
    For tracking error (Z_T = V_T - Pi_T):
    positive means under-hedged at expiry, negative means over-hedged.
    We'll look at absolute magnitude tail, which is more symmetric risk.
    """
    x = x.dropna().astype(float)
    if x.empty:
        return np.nan
    # tail of absolute error
    abs_err = x.abs().sort_values(ascending=False)
    cutoff = max(1, int(np.ceil(alpha * len(abs_err))))
    return abs_err.iloc[:cutoff].mean()

def summarize_performance(results_df: pd.DataFrame) -> pd.DataFrame:
    """
    Group by (m0, rebalance_every) and compute:
      - hedging error stats on tracking_error
      - RMSHE
      - CVaR 5%
      - avg hedged pnl
    """
    rows = []
    for (m0, freq), grp in results_df.groupby(['m0','rebalance_every']):
        te = grp['tracking_error'].astype(float)

        mean_te   = te.mean()
        var_te    = te.var(ddof=1)
        skew_te   = skew(te, bias=False) if len(te) > 2 else np.nan
        rmshe     = np.sqrt((te**2).mean())
        cvar_5    = compute_cvar(te, alpha=0.05)

        avg_unhedged = grp['pnl_unhedged'].mean()
        avg_hedged   = grp['pnl_hedged'].mean()

        rows.append(dict(
            m0=m0,
            rebalance_every=freq,
            mean_tracking_error=mean_te,
            var_tracking_error=var_te,
            skew_tracking_error=skew_te,
            RMSHE=rmshe,
            CVaR5_abs_tracking_error=cvar_5,
            avg_unhedged_pnl=avg_unhedged,
            avg_hedged_pnl=avg_hedged,
            avg_cost_adjusted_edge=avg_hedged - avg_unhedged
        ))
    return pd.DataFrame(rows).sort_values(['m0','rebalance_every'])

perf_summary = summarize_performance(results_df)
display(perf_summary)
# Out:
#      m0  rebalance_every  mean_tracking_error  var_tracking_error  skew_tracking_error      RMSHE  CVaR5_abs_tracking_error  avg_unhedged_pnl  avg_hedged_pnl  \
# 0  0.75                1            -1.634648           29.222539            -2.703185   5.444881                 18.310088        -42.142308      -40.507660
# 1  0.75                5            -2.274558           52.565247             0.114949   7.327713                 13.153785        -42.142308      -39.867750
# 2  0.80                1            -0.884495           83.343353             0.001059   8.863942                 20.746439         -7.303333       -6.418838
# 3  0.80                5            -5.106729           53.334896            -0.687668   8.709645                 20.206273         -7.303333       -2.196604
# 4  0.90                1             0.178048          299.394811            -0.579388  16.967950                 40.021740          8.337500        8.159452
# 5  0.90                5             1.486148         1026.845891             1.552052  31.457280                 86.698399          8.337500        6.851352
# 6  1.10                1            -5.871664          213.248527             0.323796  14.566522                 25.217556       -151.170833     -145.299169
# 7  1.10                5            -1.532670           89.058009             0.675539   8.750091                 14.583228       -151.170833     -149.638163
#
#    avg_cost_adjusted_edge
# 0                1.634648
# 1                2.274558
# 2                0.884495
# 3                5.106729
# 4               -0.178048
# 5               -1.486148
# 6                5.871664
# 7                1.532670

# %%
# === E) Plot: per-window PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['pnl_unhedged'], label='Unhedged PnL')
plt.plot(res['end'], res['pnl_hedged'], label='Hedged PnL')
plt.title('Per-Window PnL (Unhedged vs Hedged)- Daily rebalance')
plt.xlabel('Window End Date'); plt.ylabel('PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === F) Plot: cumulative PnL ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
res['cum_unhedged'] = res['pnl_unhedged'].cumsum()
res['cum_hedged']   = res['pnl_hedged'].cumsum()
plt.figure()
plt.plot(res['end'], res['cum_unhedged'], label='Cumulative Unhedged')
plt.plot(res['end'], res['cum_hedged'], label='Cumulative Hedged')
plt.title('Cumulative PnL over Non-overlapping Windows - Daily Rebalance')
plt.xlabel('Window End Date'); plt.ylabel('Cumulative PnL (index pts)'); plt.legend(); plt.xticks(rotation=30); plt.tight_layout(); plt.show()

# %%
# === G) Plots: tracking error ===
res = results_df.sort_values('end').reset_index(drop=True).copy()
plt.figure()
plt.plot(res['end'], res['tracking_error'])
plt.title('Tracking Error Z_T per Window - Daily Rebalance'); plt.xlabel('Window End Date'); plt.ylabel('Z_T (index pts)')
plt.xticks(rotation=30); plt.tight_layout(); plt.show()

plt.figure()
results_df.boxplot(column='tracking_error', by='m0')
plt.title('Tracking Error by m0'); plt.suptitle(''); plt.xlabel('m0'); plt.ylabel('Z_T (index pts)')
plt.tight_layout(); plt.show()

# %%
# === Helper: get day-level timeline for a chosen results row ===
def get_timeline_for_row(df_slice, results, idx=0):
    row = results.iloc[idx]
    dates_arr = np.sort(df_slice['date'].unique())
    si = int(np.where(dates_arr == pd.Timestamp(row['start']))[0][0])
    out = run_single_window(df_slice, start_idx=si, m0=float(row['m0']))
    if out is None:
        raise RuntimeError("Window failed; check console logs for the failing day/leg.")
    return out['timeline'], out['summary']

# Example:
# tl, summ = get_timeline_for_row(df_1m_bt, results_df, idx=0)
# tl.head()

# %%
fig, ax = plt.subplots()
for m0 in sorted(results_df['m0'].unique()):
    sub = perf_summary[perf_summary['m0'] == m0]
    ax.bar(
        [f"{m0}-freq{int(f)}" for f in sub['rebalance_every']],
        sub['RMSHE'],
        alpha=0.7,
        label=f"m0={m0}"
    )
ax.set_title("RMSHE by m0 and Hedge Frequency")
ax.set_ylabel("RMSHE (abs index pts)")
ax.set_xticklabels([f"{m0}-f{int(f)}" for m0 in perf_summary['m0'] for f in perf_summary[perf_summary['m0']==m0]['rebalance_every']], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/lf/j1p7b9893pb19dwl2jcxhw900000gn/T/ipykernel_8526/2901913625.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([f"{m0}-f{int(f)}" for m0 in perf_summary['m0'] for f in perf_summary[perf_summary['m0']==m0]['rebalance_every']], rotation=45)

# %%
plt.figure()
results_df.boxplot(
    column='tracking_error',
    by='rebalance_every'
)
plt.title("Tracking Error Distribution by Hedge Frequency")
plt.suptitle("")
plt.xlabel("rebalance_every (1=daily, 5=weekly)")
plt.ylabel("Z_T (index pts)")
plt.tight_layout()
plt.show()

# %%
# sort results by end date so time flows on x
res_sorted = results_df.sort_values('end').copy()

plt.figure()
for freq in sorted(res_sorted['rebalance_every'].unique()):
    subf = res_sorted[res_sorted['rebalance_every']==freq].copy()
    subf['cum_hedged']   = subf['pnl_hedged'].cumsum()
    subf['cum_unhedged'] = subf['pnl_unhedged'].cumsum()

    plt.plot(subf['end'], subf['cum_unhedged'], label=f"unhedged freq={freq}", linestyle='--')
    plt.plot(subf['end'], subf['cum_hedged'],   label=f"hedged freq={freq}",   linestyle='-')

plt.title("Cumulative PnL by Hedge Frequency")
plt.xlabel("Window End Date")
plt.ylabel("Cumulative PnL (index pts)")
plt.xticks(rotation=30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
results_df.to_csv('results_deltavega.csv', index=False)
print("Delta results saved to results_deltavega.csv")
# Out:
# Delta results saved to results_deltavega.csv
