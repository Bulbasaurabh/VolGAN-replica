# %%
# %pip install pandas

# %%
import pandas as pd

# %%
# Load the CSV file in chunks to handle large file size
# Uncomment the code below if you don't have the converted parquet dataset yet

# chunksize = 100000
# dfs = []
# for chunk in pd.read_csv("../data/e26juuijngi0v0m4.csv", chunksize=chunksize): # or wherever your file is
#     dfs.append(chunk)

# options_df = pd.concat(dfs, ignore_index=True)

# %%
# options_df.head()

# %%
# options_df.info()

# %%
# Uncomment the code below if you don't have the converted parquet dataset yet

# useful_cols = [
#     "optionid",       # unique contract identifier
#     "ticker",         # underlying symbol (e.g. SPX)
#     "date",           # trade date
#     "exdate",         # expiration date
#     "cp_flag",        # call or put
#     "strike_price",   # strike
#     "best_bid",       # market bid
#     "best_offer",     # market ask
#     "volume",         # trading volume
#     "open_interest",  # outstanding contracts
#     "impl_volatility",# implied volatility
#     "delta",          # sensitivity to underlying
#     "gamma",          # curvature
#     "vega",           # sensitivity to volatility
#     "theta"           # time decay
# ]

# options_df[useful_cols].to_parquet(
#     "../data/options_dataset.parquet", 
#     index=False, 
#     compression="snappy"
# )

# %%
options_df = pd.read_parquet("../data/options_dataset.parquet")

# %%
options_df.head()
# Out:
#    optionid ticker        date      exdate cp_flag  strike_price  best_bid  \
# 0  10000760    SPX  2000-01-03  2000-01-22       P       1505000    55.250
# 1  10007866    SPX  2000-01-03  2000-01-22       P       1545000    89.625
# 2  10010807    SPX  2000-01-03  2000-03-18       C        750000   706.500
# 3  10011763    SPX  2000-01-03  2000-09-16       C       1450000   135.750
# 4  10016917    SPX  2000-01-03  2000-06-17       P       1350000    40.750
#
#    best_offer  volume  open_interest  impl_volatility     delta     gamma  \
# 0      57.250       0             50         0.212891 -0.734362  0.004767
# 1      91.625       0              0         0.233571 -0.858130  0.002975
# 2     708.500       0           1916              NaN       NaN       NaN
# 3     137.750       0           2365         0.229435  0.608151  0.001353
# 4      42.750     290          14570         0.252872 -0.256190  0.001296
#
#         vega      theta
# 0  105.97850 -162.13980
# ...

# %%
options_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36251366 entries, 0 to 36251365
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   optionid         int64
#  1   ticker           object
#  2   date             object
#  3   exdate           object
#  4   cp_flag          object
#  5   strike_price     int64
#  6   best_bid         float64
#  7   best_offer       float64
#  8   volume           int64
#  9   open_interest    int64
#  10  impl_volatility  float64
#  11  delta            float64
#  12  gamma            float64
#  13  vega             float64
#  14  theta            float64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 4.1+ GB
