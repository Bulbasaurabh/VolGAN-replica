# %% [markdown]
# # Delta–Vega Hedging for One‑Month SPX Straddles (2000–2023)
#
# This notebook implements the **delta–vega hedging** experiment described in the *Data‑driven hedging with generative models* (Cont & Vuletić, 2025) paper for a portfolio consisting of a one‑month **long straddle** with strike \(K = m_0 S_0\) where \(m_0 \in \{0.75, 0.8, 0.9, 1.1, 1.2, 1.25\}\. We follow their setup for **non‑overlapping one‑month windows** (≈21 trading days, \(\Delta t = 1/252\)), **ATM option as the volatility‑sensitive hedge**, and **self‑financing accounting** with transaction costs proxied by **half the bid‑ask spread**.
#
# > Key hedge ratios (delta–vega hedging):
# > - Portfolio vega: \(\kappa^V_t = \sum_{i\in P} \psi_i\,\kappa^{(i)}_t\) where the straddle is long 1 call and long 1 put (\(\psi_i=+1\)).
# > - Option hedge ratio: \(\varphi^{(1)}_t = \kappa^V_t / \kappa^H_t\) using an **ATM** one‑month option as \(H\).
# > - Underlying hedge ratio: \(\varphi^{(0)}_t = \Delta^V_t - \varphi^{(1)}_t\,\Delta^H_t\).

# %%
# === 1) Imports & configuration ===
import os
import math
import json
import warnings
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

# yfinance for spot (will gracefully degrade if no internet)
try:
    import yfinance as yf
except Exception as e:
    yf = None
    warnings.warn(f'yfinance import failed ({e}). Spot fallback logic will be used.')

pd.set_option('display.max_columns', 200)

# Paths
OPTIONS_PARQUET = "../data/options_dataset.parquet"  # <-- adjust if needed

# Underlying ticker for SPX index on Yahoo
UNDERLYING_TICKER = "^GSPC"

# Experiment parameters
TRADING_DAYS_PER_MONTH = 21   # non-overlapping windows
DT = 1/252                    # day length
M0_SET = [0.75, 0.8, 0.9, 1.1, 1.2, 1.25]

# Hedging ATM moneyness target and maturity target (≈ one month)
HEDGE_TARGET_MONEYNESS = 1.0
TARGET_DTE = (TRADING_DAYS_PER_MONTH, TRADING_DAYS_PER_MONTH + 2)  # small tolerance

# Columns expected in the parquet
EXPECTED_COLS = [
    "optionid","ticker","date","exdate","cp_flag","strike_price","best_bid","best_offer",
    "volume","open_interest","impl_volatility","delta","gamma","vega","theta"
]

# %%
# === 2) Load option chain (OptionMetrics‑style) & basic cleaning ===
df = pd.read_parquet(OPTIONS_PARQUET)
missing = [c for c in EXPECTED_COLS if c not in df.columns]
if missing:
    raise ValueError(f"Parquet is missing required columns: {missing}")

# Parse dates
df['date'] = pd.to_datetime(df['date'])
df['exdate'] = pd.to_datetime(df['exdate'])

# Compute mid prices and DTE (trading days proxy: business days distance)
df['mid'] = (df['best_bid'] + df['best_offer']) / 2.0
df['dte'] = (df['exdate'] - df['date']).dt.days

# Filter to SPX (rename if your ticker differs)
df = df[df['ticker'] == 'SPX'].copy()

# Remove obviously bad rows
df = df[df['dte'] >= 0]
df = df[~df['mid'].isna()]

print(df[['date','exdate','cp_flag','strike_price','mid','impl_volatility','delta','vega']].head())
print(f"Rows after cleaning: {len(df):,}")

# --- OPRA strike scaling auto-fix (apply once, before any moneyness calc) ---
# If strikes look like 1,505,000 instead of 1,505.00, divide by 1,000
if df['strike_price'].median() > 1e4:     # heuristic: clearly too large for SPX
    df['strike_price'] = df['strike_price'] / 1000.0

# Optional sanity checks
print(
    "Sanity check — strikes:",
    "min", round(df['strike_price'].min(), 2),
    "median", round(df['strike_price'].median(), 2),
    "max", round(df['strike_price'].max(), 2),
)
# Out:
#         date     exdate cp_flag  strike_price      mid  impl_volatility  \
# 0 2000-01-03 2000-01-22       P       1505000   56.250         0.212891
# 1 2000-01-03 2000-01-22       P       1545000   90.625         0.233571
# 2 2000-01-03 2000-03-18       C        750000  707.500              NaN
# 3 2000-01-03 2000-09-16       C       1450000  136.750         0.229435
# 4 2000-01-03 2000-06-17       P       1350000   41.750         0.252872
#
#       delta       vega
# 0 -0.734362  105.97850
# 1 -0.858130   72.57848
# 2       NaN        NaN
# 3  0.608151  461.04910
# 4 -0.256190  313.84440
# Rows after cleaning: 36,251,366
# Sanity check — strikes: min 50.0 median 2650.0 max 12000.0

# %%
# === 3) Spot loader (primary: yfinance; fallback: implied spot via moneyness if available) ===

def fetch_spot_history(start: pd.Timestamp, end: pd.Timestamp, ticker: str = UNDERLYING_TICKER) -> Optional[pd.Series]:
    """Fetch daily close spot from yfinance; returns a Series indexed by date (normalized to date)."""
    if yf is None:
        return None
    try:
        hist = yf.download(ticker, start=start - pd.Timedelta(days=5), end=end + pd.Timedelta(days=5), progress=False)
        if hist is None or hist.empty:
            return None
        s = hist['Adj Close'].copy()
        s.index = pd.to_datetime(s.index).tz_localize(None).normalize()
        s.name = 'spot'
        return s
    except Exception as e:
        warnings.warn(f"yfinance download failed: {e}")
        return None

def infer_spot_from_chain(day_df: pd.DataFrame) -> Optional[float]:
    """Fallback: estimate spot as strike closest to where call and put deltas are symmetric around ATM (crude)."""
    if day_df.empty:
        return None
    # Use minimum |delta_call + delta_put + 0| around ATM candidates
    piv = day_df.pivot_table(index='strike_price', columns='cp_flag', values='delta', aggfunc='mean')
    if {'C','P'}.issubset(piv.columns):
        score = (piv['C'] + piv['P']).abs()  # near zero when ATM (Delta_C ≈ 0.5, Delta_P ≈ -0.5)
        k_star = score.idxmin()
        return float(k_star)  # SPX options are in index points; ATM strike ~ spot
    # Otherwise, take mid of strikes weighted by vega as proxy
    grp = day_df.groupby('strike_price')['vega'].sum()
    if grp.empty:
        return None
    return float(grp.idxmax())

# Build a daily spot series spanning the options sample
start_date = df['date'].min().normalize()
end_date = df['date'].max().normalize()

spot_series = fetch_spot_history(start_date, end_date)
if spot_series is None:
    warnings.warn("Falling back to spot inference per day from option chain (coarse).")
    spot_series = (
        df.groupby('date', as_index=False)
          .apply(lambda g: pd.Series({'spot': infer_spot_from_chain(g.droplevel(0) if isinstance(g.index, pd.MultiIndex) else g)}))
          .set_index('date')['spot']
    )

spot_series = spot_series.sort_index().dropna()
spot_series.head(), spot_series.index.min(), spot_series.index.max()
# Out:
# /var/folders/nn/tnz4z0cd38bby_992b16sj8h0000gn/T/ipykernel_51804/2911395699.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   hist = yf.download(ticker, start=start - pd.Timedelta(days=5), end=end + pd.Timedelta(days=5), progress=False)
# /var/folders/nn/tnz4z0cd38bby_992b16sj8h0000gn/T/ipykernel_51804/2911395699.py:16: UserWarning: yfinance download failed: 'Adj Close'
#   warnings.warn(f"yfinance download failed: {e}")
# /var/folders/nn/tnz4z0cd38bby_992b16sj8h0000gn/T/ipykernel_51804/2911395699.py:41: UserWarning: Falling back to spot inference per day from option chain (coarse).
#   warnings.warn("Falling back to spot inference per day from option chain (coarse).")
# /var/folders/nn/tnz4z0cd38bby_992b16sj8h0000gn/T/ipykernel_51804/2911395699.py:44: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: pd.Series({'spot': infer_spot_from_chain(g.droplevel(0) if isinstance(g.index, pd.MultiIndex) else g)}))
# (date
#  2000-01-03    1500.0
#  2000-01-04    1410.0
#  2000-01-05    1410.0
#  2000-01-06    1425.0
#  2000-01-07    1500.0
#  Name: spot, dtype: float64,
#  Timestamp('2000-01-03 00:00:00'),
#  Timestamp('2023-08-31 00:00:00'))

# %%
# === 4) Join spot, compute moneyness m = K / S_t, select near-1M instruments ===
df = df.merge(spot_series.rename('spot'), left_on='date', right_index=True, how='inner')
df['moneyness'] = df['strike_price'] / df['spot']

# Keep ≈ 1-month options (tolerance window)
df_1m = df[(df['dte'] >= TARGET_DTE[0]) & (df['dte'] <= TARGET_DTE[1])].copy()

print(df_1m[['date','cp_flag','strike_price','spot','moneyness','dte','mid','delta','vega']].head())
print(f"1M rows: {len(df_1m):,}")

# 1) moneyness sanity: should mostly be in a reasonable band around ATM
print(df_1m['moneyness'].describe())

# 2) alignment of spot and “ATM” strike at d0:
sample_day = df_1m['date'].min()
d0 = df_1m[df_1m['date'] == sample_day]
print("Sample d0 spot:", float(d0['spot'].iloc[0]))
print("Closest ATM strike:", d0.loc[(d0['strike_price'] - d0['spot']).abs().idxmin(), 'strike_price'])

# Clean & quality screens to prevent NaNs during hedging
df_1m = df_1m.replace([np.inf, -np.inf], np.nan)

# Require valid quotes and greeks
df_1m = df_1m.dropna(subset=['mid','delta','vega','best_bid','best_offer'])

# Guard against inverted quotes; compute spreads
df_1m = df_1m[df_1m['best_offer'] >= df_1m['best_bid']].copy()
df_1m['spread'] = (df_1m['best_offer'] - df_1m['best_bid']).clip(lower=0)
df_1m['rel_spread'] = (df_1m['spread'] / df_1m['mid']).replace([np.inf,-np.inf], np.nan)

# Basic liquidity: tighten to avoid dusty quotes (tune thresholds as needed)
liq_mask = (
    (df_1m['mid'] > 0.05) &
    (df_1m['rel_spread'] <= 0.35) &          # avoid super-wide quotes
    df_1m['delta'].between(-1.1, 1.1) &
    (df_1m['vega'] > 0)                      # exclude zero/negative vega rows (bad data)
)
df_1m = df_1m[liq_mask].copy()

print("After quality screens:", len(df_1m))
# Out:
#            date cp_flag  strike_price    spot  moneyness  dte     mid  \
# 9002 2000-01-27       C        1475.0  1415.0   1.042403   23   3.750
# 9005 2000-01-27       P        1350.0  1415.0   0.954064   23  12.250
# 9008 2000-01-27       C        1575.0  1415.0   1.113074   23   0.250
# 9019 2000-01-27       C        1465.0  1415.0   1.035336   23   5.625
# 9022 2000-01-27       C        1400.0  1415.0   0.989399   23  30.750
#
#          delta       vega
# 9002  0.127699   71.74142
# 9005 -0.244565  107.83600
# 9008  0.010723    9.72553
# 9019  0.172484   87.69729
# 9022  0.529561  136.60340
# 1M rows: 1,377,412
# count    1.377412e+06
# mean     9.146768e-01
# std      1.882587e-01
# min      2.125399e-02
# 25%      8.351254e-01
# 50%      9.443231e-01
# 75%      1.020408e+00
# max      2.666667e+00
# Name: moneyness, dtype: float64
# Sample d0 spot: 1415.0
# Closest ATM strike: 1420.0
# After quality screens: 1044345

# %%
VEGA_FLOOR = 5.0

def choose_strike_for_m0(spot0: float, m0: float, available_strikes: np.ndarray) -> float:
    """Pick strike closest to m0 * spot0."""
    target = float(m0) * float(spot0)
    idx = np.abs(available_strikes - target).argmin()
    K = float(available_strikes[idx])
    print(f"[choose_strike_for_m0] spot0={spot0:.4f}, m0={m0:.3f}, target={target:.4f} -> K={K}")
    return K

def nearest_atm_strike(spot0: float, available_strikes: np.ndarray) -> float:
    """Pick strike closest to spot0."""
    idx = np.abs(available_strikes - float(spot0)).argmin()
    K = float(available_strikes[idx])
    print(f"[nearest_atm_strike] spot0={spot0:.4f} -> K_ATM={K}")
    return K

# %%
# Pick a concrete date (you can change this)
debug_date = df_1m['date'].min()
day_df = df_1m[df_1m['date'] == debug_date].copy()

print(f"[debug day] date={debug_date.date()}, rows={len(day_df)}")
print(day_df[['date','cp_flag','strike_price','spot','moneyness','dte','mid','delta','vega']].head())

# Extract spot and available strikes for this day
if day_df.empty:
    raise RuntimeError("No rows found for debug_date. Change `debug_date` to a date that exists.")
spot0 = float(day_df['spot'].iloc[0])
strikes_today = np.sort(day_df['strike_price'].unique())
print(f"[debug day] spot0={spot0}, strikes count={len(strikes_today)}, min={strikes_today.min()}, max={strikes_today.max()}")
# Out:
# [debug day] date=2000-01-27, rows=56
#            date cp_flag  strike_price    spot  moneyness  dte     mid  \
# 9002 2000-01-27       C        1475.0  1415.0   1.042403   23   3.750
# 9005 2000-01-27       P        1350.0  1415.0   0.954064   23  12.250
# 9019 2000-01-27       C        1465.0  1415.0   1.035336   23   5.625
# 9022 2000-01-27       C        1400.0  1415.0   0.989399   23  30.750
# 9025 2000-01-27       C        1425.0  1415.0   1.007067   23  17.875
#
#          delta       vega
# 9002  0.127699   71.74142
# 9005 -0.244565  107.83600
# 9019  0.172484   87.69729
# 9022  0.529561  136.60340
# 9025  0.386221  131.37020
# [debug day] spot0=1415.0, strikes count=31, min=1100.0, max=1520.0

# %%
# Choose m0 and view chosen strikes
m0 = 0.90  # <- change to test other values
K_straddle = choose_strike_for_m0(spot0, m0, strikes_today)
K_hedge = nearest_atm_strike(spot0, strikes_today)

# Show how many rows exist exactly at those strikes
c_straddle_rows = day_df[(day_df['strike_price'] == K_straddle) & (day_df['cp_flag'] == 'C')]
p_straddle_rows = day_df[(day_df['strike_price'] == K_straddle) & (day_df['cp_flag'] == 'P')]
hedge_call_rows = day_df[(day_df['strike_price'] == K_hedge) & (day_df['cp_flag'] == 'C')]
hedge_put_rows  = day_df[(day_df['strike_price'] == K_hedge) & (day_df['cp_flag'] == 'P')]

print(f"[counts] straddle K={K_straddle}: C={len(c_straddle_rows)}, P={len(p_straddle_rows)}")
print(f"[counts] hedge K_ATM={K_hedge}: C={len(hedge_call_rows)}, P={len(hedge_put_rows)}")
# Out:
# [choose_strike_for_m0] spot0=1415.0000, m0=0.900, target=1273.5000 -> K=1275.0
# [nearest_atm_strike] spot0=1415.0000 -> K_ATM=1410.0
# [counts] straddle K=1275.0: C=1, P=1
# [counts] hedge K_ATM=1410.0: C=1, P=1

# %%
# Helper: pick ONE row for (strike, cp_flag) with explicit sorting preference
def pick_one(day_df: pd.DataFrame, strike: float, cp_flag: str) -> pd.Series | None:
    sub = day_df[(day_df['strike_price'] == strike) & (day_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[pick_one] MISSING leg for cp={cp_flag}, K={strike}")
        return None
    # drop rows with bad/NaN greeks or quotes
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','vega','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[pick_one] All candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])  # avoid NaN rel spread rows

    # tighten selection
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[pick_one] No clean candidate after filters for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[pick_one] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, "
          f"mid={chosen['mid']:.4f}, delta={chosen['delta']:.4f}, vega={chosen['vega']:.4f}, "
          f"spread={chosen['spread']:.4f}, OI={int(chosen['open_interest'])}, vol={int(chosen['volume'])}")
    return chosen

# Pick straddle legs
row_C = pick_one(day_df, K_straddle, 'C')
row_P = pick_one(day_df, K_straddle, 'P')

# Pick hedge leg: prefer ATM Call; if missing, try ATM Put
row_H = pick_one(day_df, K_hedge, 'C')
if row_H is None:
    row_H = pick_one(day_df, K_hedge, 'P')

if (row_C is None) or (row_P is None) or (row_H is None):
    raise RuntimeError("One or more legs are missing. Check printed diagnostics above.")
# Out:
# [pick_one] cp=C, K=1275.0, dte=23, mid=133.2500, delta=0.9010, vega=59.8041, spread=2.0000, OI=28, vol=20
# [pick_one] cp=P, K=1275.0, dte=23, mid=3.7500, delta=-0.0813, vega=51.6505, spread=0.7500, OI=10439, vol=1628
# [pick_one] cp=C, K=1410.0, dte=23, mid=25.1250, delta=0.4737, vega=136.6808, spread=2.0000, OI=21, vol=11

# %%
def half_spread(row: pd.Series) -> float:
    hs = float(max(0.0, (row['best_offer'] - row['best_bid']) / 2.0))
    print(f"[half_spread] {row['cp_flag']} K={row['strike_price']} -> half-spread={hs:.4f}")
    return hs

def pnl_from_price_change(qty: float, price_t: float, price_t1: float) -> float:
    pnl = float(qty) * (float(price_t1) - float(price_t))
    print(f"[pnl] qty={qty}, from {price_t:.4f} to {price_t1:.4f} -> pnl={pnl:.6f}")
    return pnl

def self_financing_rebalance_cost(prev_qty: float, new_qty: float, half_spread_val: float) -> float:
    cost = abs(float(new_qty - prev_qty)) * float(half_spread_val)
    print(f"[rebalance_cost] prev={prev_qty:.6f}, new={new_qty:.6f}, half_spread={half_spread_val:.6f} -> cost={cost:.6f}")
    return cost

# %%
# Portfolio greeks (long 1C + 1P)
psi_C = 1.0
psi_P = 1.0
Delta_V = psi_C * row_C['delta'] + psi_P * row_P['delta']
Vega_V  = psi_C * row_C['vega']  + psi_P * row_P['vega']

# Hedge greeks
Delta_H = row_H['delta']
Vega_H  = row_H['vega']

# Apply vega floor for stability (optional)
Vega_H_eff = np.sign(Vega_H) * max(abs(Vega_H), VEGA_FLOOR)

phi_opt = Vega_V / Vega_H_eff if not np.isclose(Vega_H_eff, 0.0) else 0.0
phi_under = Delta_V - phi_opt * Delta_H

print(f"[hedge ratios] ΔV={Delta_V:.6f}, κV={Vega_V:.6f} | ΔH={Delta_H:.6f}, κH={Vega_H:.6f} "
      f"-> φ1 (opt)={phi_opt:.6f}, φ0 (under)={phi_under:.6f}")
# Out:
# [hedge ratios] ΔV=0.819772, κV=111.454610 | ΔH=0.473654, κH=136.680800 -> φ1 (opt)=0.815437, φ0 (under)=0.433537

# %%
# Find the next business date present in df_1m
dates_all = np.sort(df_1m['date'].unique())
try:
    idx = np.where(dates_all == debug_date)[0][0]
    next_date = pd.Timestamp(dates_all[idx+1])
except Exception:
    raise RuntimeError("No next date available after debug_date. Pick a different debug_date.")

print(f"[next day] current={debug_date.date()} -> next={next_date.date()}")

next_df = df_1m[df_1m['date'] == next_date].copy()
if next_df.empty:
    raise RuntimeError("No rows for next_date; cannot compute next-day P&L.")

# Try to fetch the SAME instruments on next day (same strikes + same cp_flags)
def fetch_next_row(next_df, strike, cp_flag):
    sub = next_df[(next_df['strike_price'] == strike) & (next_df['cp_flag'] == cp_flag)].copy()
    if sub.empty:
        print(f"[next fetch] MISSING next-day row for cp={cp_flag}, K={strike}")
        return None
    sub = sub.replace([np.inf, -np.inf], np.nan).dropna(subset=['mid','delta','vega','best_bid','best_offer'])
    sub = sub[sub['best_offer'] >= sub['best_bid']].copy()
    if sub.empty:
        print(f"[next fetch] All next-day candidates invalid for cp={cp_flag}, K={strike}")
        return None

    sub['spread'] = (sub['best_offer'] - sub['best_bid']).clip(lower=0)
    sub['rel_spread'] = (sub['spread'] / sub['mid']).replace([np.inf,-np.inf], np.nan)
    sub['dte_dist'] = (sub['dte'] - 21).abs()
    sub = sub.dropna(subset=['rel_spread'])
    sub = sub[(sub['rel_spread'] <= 0.35) & (sub['mid'] > 0.05)]
    if sub.empty:
        print(f"[next fetch] No clean next-day candidate for cp={cp_flag}, K={strike}")
        return None

    sub = sub.sort_values(by=['dte_dist','open_interest','volume','rel_spread'],
                          ascending=[True, False, False, True])
    chosen = sub.iloc[0]
    print(f"[next fetch] cp={cp_flag}, K={strike}, dte={int(chosen['dte'])}, mid={chosen['mid']:.4f}")
    return chosen

row_C_next = fetch_next_row(next_df, row_C['strike_price'], 'C') if row_C is not None else None
row_P_next = fetch_next_row(next_df, row_P['strike_price'], 'P') if row_P is not None else None
row_H_next = fetch_next_row(next_df, row_H['strike_price'], row_H['cp_flag']) if row_H is not None else None

if (row_C_next is None) or (row_P_next is None) or (row_H_next is None):
    raise RuntimeError("One or more next-day rows are missing — now you know exactly which one.")
# Out:
# [next day] current=2000-01-27 -> next=2000-01-28
# [next fetch] cp=C, K=1275.0, dte=22, mid=94.6250
# [next fetch] cp=P, K=1275.0, dte=22, mid=8.5000
# [next fetch] cp=C, K=1410.0, dte=22, mid=11.1875

# %%
# Half-spread cost on the hedge option (at today's quote)
hs_H = half_spread(row_H)

# Option hedge P&L (hedge option only)
pnl_opt = pnl_from_price_change(phi_opt, row_H['mid'], row_H_next['mid'])

# Underlying P&L (using spot as mid; you can add costs if you like)
s_t  = float(row_C['spot'])   # equals row_P['spot'] == row_H['spot']
s_t1 = float(row_C_next['spot'])
pnl_under = pnl_from_price_change(phi_under, s_t, s_t1)

# Rebalance cost on the option (assume coming from 0 -> phi_opt today)
cost_opt = self_financing_rebalance_cost(0.0, phi_opt, hs_H)

print(f"[mini-step] pnl_opt={pnl_opt:.6f}, pnl_under={pnl_under:.6f}, cost_opt={cost_opt:.6f}, "
      f"daily_total={pnl_opt + pnl_under - cost_opt:.6f}")
# Out:
# [half_spread] C K=1410.0 -> half-spread=1.0000
# [pnl] qty=0.8154372084447852, from 25.1250 to 11.1875 -> pnl=-11.365156
# [pnl] qty=0.43353690447129367, from 1415.0000 to 1400.0000 -> pnl=-6.503054
# [rebalance_cost] prev=0.000000, new=0.815437, half_spread=1.000000 -> cost=0.815437
# [mini-step] pnl_opt=-11.365156, pnl_under=-6.503054, cost_opt=0.815437, daily_total=-18.683647

# %%
# === 6A) Build a single non-overlapping 1M window (≈21 trading days) ===
TRADING_DAYS_PER_MONTH = 21  # must match earlier

def get_window_dates(df_all: pd.DataFrame, start_idx: int) -> list[pd.Timestamp] | None:
    dates = np.sort(df_all['date'].unique())
    if start_idx + TRADING_DAYS_PER_MONTH >= len(dates):
        print(f"[get_window_dates] Not enough dates from start_idx={start_idx}.")
        return None
    # include end day (t+21) for next-day P&L on the last trading day
    days = list(dates[start_idx : start_idx + TRADING_DAYS_PER_MONTH + 1])
    print(f"[get_window_dates] start={pd.Timestamp(days[0]).date()} end={pd.Timestamp(days[-1]).date()} "
          f"len={len(days)} (includes final valuation day).")
    return days

# %%
# === 6B) One step (day t -> t+1) with verbose checks ===
# Requires: pick_one(), half_spread(), pnl_from_price_change(), self_financing_rebalance_cost()
#           choose_strike_for_m0(), nearest_atm_strike(), VEGA_FLOOR

def one_day_step(df_all: pd.DataFrame,
                 d: pd.Timestamp,
                 d_next: pd.Timestamp,
                 K_straddle: float,
                 K_hedge: float,
                 phi_opt_prev: float,
                 phi_under_prev: float) -> dict | None:
    """Compute hedge ratios, P&L, and costs for one day. Returns a dict of metrics or None on failure."""
    day = df_all[df_all['date'] == d].copy()
    day_next = df_all[df_all['date'] == d_next].copy()

    if day.empty or day_next.empty:
        print(f"[one_day_step] Missing day data: d empty={day.empty}, d_next empty={day_next.empty}")
        return None

    # Pick current legs (straddle C/P, hedge preferring call; fallback to put)
    row_C = pick_one(day, K_straddle, 'C')
    row_P = pick_one(day, K_straddle, 'P')
    row_H = pick_one(day, K_hedge, 'C')
    if row_H is None:
        row_H = pick_one(day, K_hedge, 'P')

    if (row_C is None) or (row_P is None) or (row_H is None):
        print("[one_day_step] Missing at least one leg on current day.")
        return None

    # Greeks and values at t
    psi_C, psi_P = 1.0, 1.0
    V_t   = psi_C*row_C['mid'] + psi_P*row_P['mid']
    dV_t  = psi_C*row_C['delta'] + psi_P*row_P['delta']
    kV_t  = psi_C*row_C['vega']  + psi_P*row_P['vega']
    dH_t  = row_H['delta']
    kH_t  = row_H['vega']s

    # --- NaN / invalid greeks & prices guard (INSERT THIS BLOCK) ---
    vals = [V_t, dV_t, kV_t, dH_t, kH_t, row_H['mid']]
    if not all(np.isfinite(v) for v in vals):
        print(f"[one_day_step] Non-finite greeks/prices at {pd.Timestamp(d).date()} — skipping window.")
        return None

    # Safe hedge vega: floor to avoid exploding ratios
    if (not np.isfinite(kH_t)) or np.isclose(kH_t, 0.0):
        print(f"[one_day_step] Hedge vega invalid at {pd.Timestamp(d).date()} — using floor.")
    kH_eff = np.sign(kH_t) * max(abs(kH_t) if np.isfinite(kH_t) else 0.0, VEGA_FLOOR)

    if not np.isfinite(kV_t):
        print(f"[one_day_step] Portfolio vega NaN at {pd.Timestamp(d).date()} — skipping window.")
        return None


    # Hedge ratios with vega floor for stability
    kH_eff = np.sign(kH_t) * max(abs(kH_t), VEGA_FLOOR)
    phi_opt   = (kV_t / kH_eff) if not np.isclose(kH_eff, 0.0) else 0.0
    phi_under = dV_t - phi_opt * dH_t

    print(f"[ratios @ {pd.Timestamp(d).date()}] "
          f"V={V_t:.4f} ΔV={dV_t:.6f} κV={kV_t:.6f} | "
          f"ΔH={dH_t:.6f} κH={kH_t:.6f} -> φ1={phi_opt:.6f}, φ0={phi_under:.6f}")

    # Fetch next-day rows for P&L
    row_C_next = fetch_next_row(day_next, row_C['strike_price'], 'C')
    row_P_next = fetch_next_row(day_next, row_P['strike_price'], 'P')
    row_H_next = fetch_next_row(day_next, row_H['strike_price'], row_H['cp_flag'])

    if (row_C_next is None) or (row_P_next is None) or (row_H_next is None):
        print("[one_day_step] Missing at least one leg on next day.")
        return None

    # Underlying P&L via spot
    s_t  = float(row_C['spot'])
    s_t1 = float(row_C_next['spot'])

    # Costs and P&L
    hs_H = half_spread(row_H)
    pnl_opt   = pnl_from_price_change(phi_opt, row_H['mid'], row_H_next['mid'])
    pnl_under = pnl_from_price_change(phi_under, s_t, s_t1)
    cost_opt  = self_financing_rebalance_cost(phi_opt_prev, phi_opt, hs_H)
    cost_under = 0.0

    pnl_unhedged = (psi_C*(row_C_next['mid'] - row_C['mid']) +
                    psi_P*(row_P_next['mid'] - row_P['mid']))

    out = dict(
        date=pd.Timestamp(d),
        spot=s_t,
        K_straddle=K_straddle,
        K_hedge=K_hedge,
        V_t=float(V_t),
        dV_t=float(dV_t), kV_t=float(kV_t),
        H_cp=row_H['cp_flag'],
        H_mid=float(row_H['mid']),
        dH_t=float(dH_t), kH_t=float(kH_t),
        phi_opt=float(phi_opt), phi_under=float(phi_under),
        cost_opt=float(cost_opt), cost_under=float(cost_under),
        pnl_opt=float(pnl_opt), pnl_under=float(pnl_under),
        pnl_unhedged=float(pnl_unhedged)
    )
    return out

# %%
# === 6C) Run a single window with day-by-day progress ===
def run_single_window(df_all: pd.DataFrame, start_idx: int, m0: float) -> dict | None:
    days = get_window_dates(df_all, start_idx)
    if days is None:
        return None
    d0 = days[0]

    day0 = df_all[df_all['date'] == d0].copy()
    if day0.empty:
        print(f"[run_single_window] No rows on start day {d0}.")
        return None

    # Choose strikes at inception
    spot0 = float(day0['spot'].iloc[0])
    strikes0 = np.sort(day0['strike_price'].unique())
    K_straddle = choose_strike_for_m0(spot0, m0, strikes0)
    K_hedge    = nearest_atm_strike(spot0, strikes0)

    # State
    phi_opt_prev = 0.0
    phi_under_prev = 0.0
    records = []

    # Initialize book Π_0 = V_0 on first step
    V0 = None
    Pi_t = None

    for t in range(len(days)-1):
        d, d_next = pd.Timestamp(days[t]), pd.Timestamp(days[t+1])
        print(f"\n[day {t+1}/{len(days)-1}] {d.date()} -> {d_next.date()}")

        step = one_day_step(df_all, d, d_next, K_straddle, K_hedge,
                            phi_opt_prev, phi_under_prev)
        if step is None:
            print("[run_single_window] Step failed, aborting this window.")
            return None

        # Initialize V0 and Π (self-financing book)
        if V0 is None:
            V0 = step['V_t']
            Pi_t = V0
            print(f"[init] V0=Π0={V0:.6f}")

        # Update Π_t -> Π_{t+1}
        Pi_t1 = (Pi_t
                 + step['pnl_opt']
                 + step['pnl_under']
                 - step['cost_opt']
                 - step['cost_under'])
        step['Pi_t'] = float(Pi_t)
        step['Pi_t1'] = float(Pi_t1)

        records.append(step)

        # advance hedge states
        phi_opt_prev = step['phi_opt']
        phi_under_prev = step['phi_under']
        Pi_t = Pi_t1

    # Final valuation (use last next-day rows captured by the final step)
    if not records:
        print("[run_single_window] No records collected.")
        return None

    # Reconstruct last day's instrument rows to price V_T
    last_day = pd.Timestamp(days[-2])
    final_day = pd.Timestamp(days[-1])
    day_last = df_all[df_all['date'] == last_day]
    day_final = df_all[df_all['date'] == final_day]

    # Pick the same straddle legs at last_day and price them at final_day
    row_C_last = pick_one(day_last, K_straddle, 'C');  row_C_fin = fetch_next_row(day_final, K_straddle, 'C')
    row_P_last = pick_one(day_last, K_straddle, 'P');  row_P_fin = fetch_next_row(day_final, K_straddle, 'P')
    if (row_C_last is None) or (row_P_last is None) or (row_C_fin is None) or (row_P_fin is None):
        print("[run_single_window] Final valuation missing legs.")
        return None

    V_T = float(row_C_fin['mid'] + row_P_fin['mid'])
    Pi_T = float(records[-1]['Pi_t1'])
    tracking_error = V_T - Pi_T
    pnl_unhedged_total = V_T - float(records[0]['V_t'])
    pnl_hedged_total   = Pi_T - float(records[0]['V_t'])

    timeline = pd.DataFrame(records)
    summary = dict(
        start=days[0], end=days[-1], m0=float(m0),
        K_straddle=float(K_straddle), K_hedge=float(K_hedge),
        V0=float(records[0]['V_t']), V_T=float(V_T),
        Pi_T=float(Pi_T),
        tracking_error=float(tracking_error),
        pnl_unhedged=float(pnl_unhedged_total),
        pnl_hedged=float(pnl_hedged_total)
    )
    print(f"\n[window done] m0={m0}, Z_T={tracking_error:.6f}, V_T={V_T:.6f}, Π_T={Pi_T:.6f}")
    return dict(timeline=timeline, summary=summary)

# %%
# === 7) Multi-window experiment with clear progress prints ===
def run_experiment_verbose(df_all: pd.DataFrame,
                           m0_list: list[float],
                           max_windows: int = 52,
                           stop_on_fail: bool = False) -> pd.DataFrame:
    dates = np.sort(df_all['date'].unique())
    start_indices = list(range(0, len(dates) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
    start_indices = start_indices[:max_windows]

    results = []
    for m0 in m0_list:
        print(f"\n===== m0={m0} =====")
        for i, si in enumerate(start_indices, 1):
            print(f"\n--- Window {i}/{len(start_indices)} (start_idx={si}) ---")
            out = run_single_window(df_all, si, m0)
            if out is None:
                print(f"[run_experiment_verbose] Window failed for m0={m0}, start_idx={si}.")
                if stop_on_fail:
                    return pd.DataFrame(results)
                else:
                    continue
            results.append(out['summary'])
    return pd.DataFrame(results)

# EXAMPLE quick test: 1 window, one m0, stop on first failure
# results_df = run_experiment_verbose(df_1m, m0_list=[0.9], max_windows=1, stop_on_fail=True)
# display(results_df.head())

# %%
# === 8) Diagnostics & summary ===
def summarize_results_verbose(results_df: pd.DataFrame) -> pd.DataFrame:
    if results_df is None or results_df.empty:
        print("[summarize_results_verbose] No results to summarize.")
        return pd.DataFrame()
    g = results_df.groupby('m0')
    out = g['tracking_error'].agg(['mean','median','std']).rename(columns={'std':'std_dev'})
    out['VaR_5pct']   = g['tracking_error'].quantile(0.05)
    out['VaR_2p5pct'] = g['tracking_error'].quantile(0.025)
    out['VaR_1pct']   = g['tracking_error'].quantile(0.01)
    return out

# After a run:
# summary_tbl = summarize_results_verbose(results_df)
# display(summary_tbl)

# %%
# Use your already-built df_1m (the ~1-month slice with spot + moneyness).
start_backtest = pd.Timestamp("2021-01-01")

df_1m_bt = df_1m[df_1m['date'] >= start_backtest].copy()
df_1m_bt = df_1m_bt.sort_values('date')

print("Backtest date range:", df_1m_bt['date'].min().date(), "→", df_1m_bt['date'].max().date())
print("Rows:", len(df_1m_bt))
# Out:
# Backtest date range: 2021-01-04 → 2023-08-31
# Rows: 427318

# %%
# Calendar and window starts (non-overlapping 21 trading days)
TRADING_DAYS_PER_MONTH = 21  # keep consistent

dates_bt = np.sort(df_1m_bt['date'].unique())
start_indices_bt = list(range(0, len(dates_bt) - TRADING_DAYS_PER_MONTH - 1, TRADING_DAYS_PER_MONTH))
max_windows_bt = len(start_indices_bt)

print(f"Candidate non-overlapping windows in backtest range: {max_windows_bt}")
if max_windows_bt == 0:
    raise RuntimeError("No full 1M windows available after 2021-01-01. Check data coverage.")
# Out:
# Candidate non-overlapping windows in backtest range: 31

# %%
# Choose which straddle moneyness you want to evaluate (paper set)
m0_list = [0.75, 0.8, 0.9, 1.1, 1.2, 1.25]

# Run across all available windows since 2021-01-01
results_df = run_experiment_verbose(
    df_all=df_1m_bt,
    m0_list=m0_list,
    max_windows=max_windows_bt,  # use everything available
    stop_on_fail=False           # continue even if one window fails (you'll see which)
)

print("Results shape:", results_df.shape)
display(results_df.head(10))
# Out:
# ===== m0=0.75 =====
#
# --- Window 1/31 (start_idx=0) ---
# [get_window_dates] start=2021-01-04 end=2021-02-03 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3705.0000, m0=0.750, target=2778.7500 -> K=2800.0
# [nearest_atm_strike] spot0=3705.0000 -> K_ATM=3705.0
#
# [day 1/21] 2021-01-04 -> 2021-01-05
# [pick_one] cp=C, K=2800.0, dte=21, mid=902.4000, delta=0.9869, vega=29.5673, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.2500, delta=-0.0130, vega=29.6517, spread=0.2000, OI=122, vol=3
# [pick_one] cp=C, K=3705.0, dte=21, mid=68.4500, delta=0.4987, vega=354.0529, spread=0.7000, OI=7, vol=1
# [ratios @ 2021-01-04] V=904.6500 ΔV=0.973918 κV=59.218980 | ΔH=0.498739 κH=354.052900 -> φ1=0.167260, φ0=0.890499
# [next fetch] cp=C, K=2800.0, dte=22, mid=927.0500
# [next fetch] cp=P, K=2800.0, dte=22, mid=2.0000
# [next fetch] cp=C, K=3705.0, dte=22, mid=82.9500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.16726025969565564, from 68.4500 to 82.9500 -> pnl=2.425274
# [pnl] qty=0.8904987853396483, from 3705.0000 to 3730.0000 -> pnl=22.262470
# [rebalance_cost] prev=0.000000, new=0.167260, half_spread=0.350000 -> cost=0.058541
# [init] V0=Π0=904.650000
#
# [day 2/21] 2021-01-05 -> 2021-01-06
# [pick_one] cp=C, K=2800.0, dte=22, mid=927.0500, delta=0.9887, vega=25.9799, spread=9.9000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=2.0000, delta=-0.0116, vega=27.6549, spread=0.2000, OI=76, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=82.9500, delta=0.5539, vega=361.4652, spread=0.5000, OI=3, vol=2
# [ratios @ 2021-01-05] V=929.0500 ΔV=0.977194 κV=53.634770 | ΔH=0.553945 κH=361.465200 -> φ1=0.148382, φ0=0.894999
# [next fetch] cp=C, K=2800.0, dte=21, mid=951.5500
# [next fetch] cp=P, K=2800.0, dte=21, mid=2.3500
# [next fetch] cp=C, K=3705.0, dte=21, mid=99.6000
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.14838155927596905, from 82.9500 to 99.6000 -> pnl=2.470553
# [pnl] qty=0.8949987771468734, from 3730.0000 to 3755.0000 -> pnl=22.374969
# [rebalance_cost] prev=0.167260, new=0.148382, half_spread=0.250000 -> cost=0.004720
#
# [day 3/21] 2021-01-06 -> 2021-01-07
# [pick_one] cp=C, K=2800.0, dte=21, mid=951.5500, delta=0.9835, vega=36.9885, spread=15.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.3500, delta=-0.0128, vega=29.6788, spread=0.3000, OI=76, vol=2
# [pick_one] cp=C, K=3705.0, dte=21, mid=99.6000, delta=0.5998, vega=347.3597, spread=1.2000, OI=5, vol=2
# [ratios @ 2021-01-06] V=953.9000 ΔV=0.970661 κV=66.667320 | ΔH=0.599847 κH=347.359700 -> φ1=0.191926, φ0=0.855535
# [next fetch] cp=C, K=2800.0, dte=22, mid=1005.8500
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.3500
# [next fetch] cp=C, K=3705.0, dte=22, mid=135.5000
# [half_spread] C K=3705.0 -> half-spread=0.6000
# [pnl] qty=0.19192589123032985, from 99.6000 to 135.5000 -> pnl=6.890139
# [pnl] qty=0.8555348299231603, from 3755.0000 to 3805.0000 -> pnl=42.776741
# [rebalance_cost] prev=0.148382, new=0.191926, half_spread=0.600000 -> cost=0.026127
#
# [day 4/21] 2021-01-07 -> 2021-01-08
# [pick_one] cp=C, K=2800.0, dte=22, mid=1005.8500, delta=0.9900, vega=24.9735, spread=5.3000, OI=12, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.3500, delta=-0.0079, vega=20.2422, spread=0.2000, OI=1732, vol=64
# [pick_one] cp=C, K=3705.0, dte=22, mid=135.5000, delta=0.7075, vega=320.9311, spread=1.4000, OI=110, vol=6
# [ratios @ 2021-01-07] V=1007.2000 ΔV=0.982062 κV=45.215720 | ΔH=0.707532 κH=320.931100 -> φ1=0.140889, φ0=0.882378
# [next fetch] cp=C, K=2800.0, dte=21, mid=1026.2000
# [next fetch] cp=P, K=2800.0, dte=21, mid=0.8750
# [next fetch] cp=C, K=3705.0, dte=21, mid=150.1000
# [half_spread] C K=3705.0 -> half-spread=0.7000
# [pnl] qty=0.14088918150967608, from 135.5000 to 150.1000 -> pnl=2.056982
# [pnl] qty=0.8823783956280958, from 3805.0000 to 3830.0000 -> pnl=22.059460
# [rebalance_cost] prev=0.191926, new=0.140889, half_spread=0.700000 -> cost=0.035726
#
# [day 5/21] 2021-01-08 -> 2021-01-11
# [pick_one] cp=C, K=2800.0, dte=21, mid=1026.2000, delta=0.9925, vega=19.1112, spread=5.8000, OI=12, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=0.8750, delta=-0.0055, vega=14.4201, spread=0.1500, OI=1790, vol=68
# [pick_one] cp=C, K=3705.0, dte=21, mid=150.1000, delta=0.7452, vega=294.4450, spread=0.6000, OI=108, vol=0
# [ratios @ 2021-01-08] V=1027.0750 ΔV=0.986958 κV=33.531260 | ΔH=0.745233 κH=294.445000 -> φ1=0.113880, φ0=0.902091
# [next fetch] cp=C, K=2800.0, dte=21, mid=999.1500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.1000
# [next fetch] cp=C, K=3705.0, dte=21, mid=134.0500
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.11387953607634704, from 150.1000 to 134.0500 -> pnl=-1.827767
# [pnl] qty=0.9020912116912156, from 3830.0000 to 3800.0000 -> pnl=-27.062736
# [rebalance_cost] prev=0.140889, new=0.113880, half_spread=0.300000 -> cost=0.008103
#
# [day 6/21] 2021-01-11 -> 2021-01-12
# [pick_one] cp=C, K=2800.0, dte=21, mid=999.1500, delta=0.9897, vega=23.5147, spread=11.7000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.1000, delta=-0.0068, vega=17.2133, spread=0.1000, OI=1582, vol=11
# [pick_one] cp=C, K=3705.0, dte=21, mid=134.0500, delta=0.6880, vega=322.0426, spread=0.7000, OI=29, vol=0
# [ratios @ 2021-01-11] V=1000.2500 ΔV=0.982971 κV=40.727990 | ΔH=0.687970 κH=322.042600 -> φ1=0.126468, φ0=0.895965
# [next fetch] cp=C, K=2800.0, dte=22, mid=1006.6000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.1750
# [next fetch] cp=C, K=3705.0, dte=22, mid=139.1500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.12646770955146927, from 134.0500 to 139.1500 -> pnl=0.644985
# [pnl] qty=0.8959650098598757, from 3800.0000 to 3805.0000 -> pnl=4.479825
# [rebalance_cost] prev=0.113880, new=0.126468, half_spread=0.350000 -> cost=0.004406
#
# [day 7/21] 2021-01-12 -> 2021-01-13
# [pick_one] cp=C, K=2800.0, dte=22, mid=1006.6000, delta=0.9779, vega=49.1087, spread=8.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.1750, delta=-0.0071, vega=18.4085, spread=0.1500, OI=917, vol=4
# [pick_one] cp=C, K=3705.0, dte=22, mid=139.1500, delta=0.6901, vega=329.1651, spread=0.7000, OI=0, vol=0
# [ratios @ 2021-01-12] V=1007.7750 ΔV=0.970835 κV=67.517210 | ΔH=0.690149 κH=329.165100 -> φ1=0.205117, φ0=0.829274
# [next fetch] cp=C, K=2800.0, dte=21, mid=1012.4000
# [next fetch] cp=P, K=2800.0, dte=21, mid=0.9750
# [next fetch] cp=C, K=3705.0, dte=21, mid=139.9500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.20511655093447026, from 139.1500 to 139.9500 -> pnl=0.164093
# [pnl] qty=0.8292740174891263, from 3805.0000 to 3810.0000 -> pnl=4.146370
# [rebalance_cost] prev=0.126468, new=0.205117, half_spread=0.350000 -> cost=0.027527
#
# [day 8/21] 2021-01-13 -> 2021-01-14
# [pick_one] cp=C, K=2800.0, dte=21, mid=1012.4000, delta=0.9878, vega=28.8869, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=0.9750, delta=-0.0061, vega=15.7007, spread=0.1500, OI=921, vol=5
# [pick_one] cp=C, K=3705.0, dte=21, mid=139.9500, delta=0.7177, vega=308.8590, spread=0.5000, OI=0, vol=0
# [ratios @ 2021-01-13] V=1013.3750 ΔV=0.981762 κV=44.587630 | ΔH=0.717659 κH=308.859000 -> φ1=0.144362, φ0=0.878159
# [next fetch] cp=C, K=2800.0, dte=22, mid=997.3000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.5750
# [next fetch] cp=C, K=3705.0, dte=22, mid=134.7000
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.14436241132685143, from 139.9500 to 134.7000 -> pnl=-0.757903
# [pnl] qty=0.878159016249583, from 3810.0000 to 3800.0000 -> pnl=-8.781590
# [rebalance_cost] prev=0.205117, new=0.144362, half_spread=0.250000 -> cost=0.015189
#
# [day 9/21] 2021-01-14 -> 2021-01-15
# [pick_one] cp=C, K=2800.0, dte=22, mid=997.3000, delta=0.9911, vega=22.4524, spread=7.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.5750, delta=-0.0090, vega=22.6085, spread=0.1500, OI=1289, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=134.7000, delta=0.6817, vega=332.5009, spread=3.8000, OI=4, vol=0
# [ratios @ 2021-01-14] V=998.8750 ΔV=0.982108 κV=45.060850 | ΔH=0.681674 κH=332.500900 -> φ1=0.135521, φ0=0.889727
# [next fetch] cp=C, K=2800.0, dte=21, mid=967.9500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.6250
# [next fetch] cp=C, K=3705.0, dte=21, mid=111.1500
# [half_spread] C K=3705.0 -> half-spread=1.9000
# [pnl] qty=0.13552098655973563, from 134.7000 to 111.1500 -> pnl=-3.191519
# [pnl] qty=0.8897268670078787, from 3800.0000 to 3775.0000 -> pnl=-22.243172
# [rebalance_cost] prev=0.144362, new=0.135521, half_spread=1.900000 -> cost=0.016799
#
# [day 10/21] 2021-01-15 -> 2021-01-19
# [pick_one] cp=C, K=2800.0, dte=21, mid=967.9500, delta=0.9939, vega=14.8018, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.6250, delta=-0.0095, vega=22.9297, spread=0.1500, OI=1289, vol=0
# [pick_one] cp=C, K=3705.0, dte=21, mid=111.1500, delta=0.6371, vega=338.8777, spread=0.7000, OI=4, vol=9
# [ratios @ 2021-01-15] V=969.5750 ΔV=0.984437 κV=37.731420 | ΔH=0.637126 κH=338.877700 -> φ1=0.111342, φ0=0.913498
# [next fetch] cp=C, K=2800.0, dte=22, mid=997.7500
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.5000
# [next fetch] cp=C, K=3705.0, dte=22, mid=133.1000
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.11134229251437908, from 111.1500 to 133.1000 -> pnl=2.443963
# [pnl] qty=0.9134979305394837, from 3775.0000 to 3800.0000 -> pnl=22.837448
# [rebalance_cost] prev=0.135521, new=0.111342, half_spread=0.350000 -> cost=0.008463
#
# [day 11/21] 2021-01-19 -> 2021-01-20
# [pick_one] cp=C, K=2800.0, dte=22, mid=997.7500, delta=0.9931, vega=16.4332, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.5000, delta=-0.0086, vega=21.8534, spread=0.1000, OI=21, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=133.1000, delta=0.6879, vega=329.6244, spread=3.2000, OI=2, vol=1
# [ratios @ 2021-01-19] V=999.2500 ΔV=0.984501 κV=38.286540 | ΔH=0.687851 κH=329.624400 -> φ1=0.116152, φ0=0.904606
# [next fetch] cp=C, K=2800.0, dte=21, mid=1052.4500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0250
# [next fetch] cp=C, K=3705.0, dte=21, mid=172.5000
# [half_spread] C K=3705.0 -> half-spread=1.6000
# [pnl] qty=0.11615202029946814, from 133.1000 to 172.5000 -> pnl=4.576390
# [pnl] qty=0.9046057166849906, from 3800.0000 to 3855.0000 -> pnl=49.753314
# [rebalance_cost] prev=0.111342, new=0.116152, half_spread=1.600000 -> cost=0.007696
#
# [day 12/21] 2021-01-20 -> 2021-01-21
# [pick_one] cp=C, K=2800.0, dte=21, mid=1052.4500, delta=0.9957, vega=11.4378, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.0250, delta=-0.0061, vega=15.8948, spread=0.1500, OI=21, vol=0
# [pick_one] cp=C, K=3705.0, dte=21, mid=172.5000, delta=0.7812, vega=272.6492, spread=0.6000, OI=3, vol=0
# [ratios @ 2021-01-20] V=1053.4750 ΔV=0.989657 κV=27.332670 | ΔH=0.781209 κH=272.649200 -> φ1=0.100248, φ0=0.911342
# [next fetch] cp=C, K=2800.0, dte=22, mid=1053.6000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.0500
# [next fetch] cp=C, K=3705.0, dte=22, mid=174.8500
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.100248487800441, from 172.5000 to 174.8500 -> pnl=0.235584
# [pnl] qty=0.9113419790939052, from 3855.0000 to 3855.0000 -> pnl=0.000000
# [rebalance_cost] prev=0.116152, new=0.100248, half_spread=0.300000 -> cost=0.004771
#
# [day 13/21] 2021-01-21 -> 2021-01-22
# [pick_one] cp=C, K=2800.0, dte=22, mid=1053.6000, delta=0.9950, vega=13.3365, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.0500, delta=-0.0062, vega=16.5387, spread=0.1000, OI=1604, vol=1
# [pick_one] cp=C, K=3705.0, dte=22, mid=174.8500, delta=0.7772, vega=282.0517, spread=0.7000, OI=9, vol=0
# [ratios @ 2021-01-21] V=1054.6500 ΔV=0.988832 κV=29.875120 | ΔH=0.777166 κH=282.051700 -> φ1=0.105921, φ0=0.906514
# [next fetch] cp=C, K=2800.0, dte=21, mid=1044.1500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0750
# [next fetch] cp=C, K=3705.0, dte=21, mid=165.3500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.10592072304474677, from 174.8500 to 165.3500 -> pnl=-1.006247
# [pnl] qty=0.9065140153542064, from 3855.0000 to 3845.0000 -> pnl=-9.065140
# [rebalance_cost] prev=0.100248, new=0.105921, half_spread=0.350000 -> cost=0.001985
#
# [day 14/21] 2021-01-22 -> 2021-01-25
# [pick_one] cp=C, K=2800.0, dte=21, mid=1044.1500, delta=0.9877, vega=29.3790, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.0750, delta=-0.0064, vega=16.5276, spread=0.1500, OI=1603, vol=20
# [pick_one] cp=C, K=3705.0, dte=21, mid=165.3500, delta=0.7636, vega=284.0965, spread=0.5000, OI=9, vol=0
# [ratios @ 2021-01-22] V=1045.2250 ΔV=0.981338 κV=45.906640 | ΔH=0.763582 κH=284.096500 -> φ1=0.161588, φ0=0.857952
# [next fetch] cp=C, K=2800.0, dte=22, mid=1053.5000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.3000
# [next fetch] cp=C, K=3705.0, dte=22, mid=175.9500
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.16158819274436678, from 165.3500 to 175.9500 -> pnl=1.712835
# [pnl] qty=0.8579521646078709, from 3845.0000 to 3855.0000 -> pnl=8.579522
# [rebalance_cost] prev=0.105921, new=0.161588, half_spread=0.250000 -> cost=0.013917
#
# [day 15/21] 2021-01-25 -> 2021-01-26
# [pick_one] cp=C, K=2800.0, dte=22, mid=1053.5000, delta=0.9933, vega=15.9821, spread=10.4000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.3000, delta=-0.0073, vega=19.2094, spread=0.2000, OI=493, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=175.9500, delta=0.7716, vega=285.6297, spread=1.1000, OI=0, vol=0
# [ratios @ 2021-01-25] V=1054.8000 ΔV=0.985922 κV=35.191470 | ΔH=0.771597 κH=285.629700 -> φ1=0.123207, φ0=0.890856
# [next fetch] cp=C, K=2800.0, dte=21, mid=1046.5500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.2000
# [next fetch] cp=C, K=3705.0, dte=21, mid=170.0000
# [half_spread] C K=3705.0 -> half-spread=0.5500
# [pnl] qty=0.12320662031994573, from 175.9500 to 170.0000 -> pnl=-0.733079
# [pnl] qty=0.8908561413809909, from 3855.0000 to 3850.0000 -> pnl=-4.454281
# [rebalance_cost] prev=0.161588, new=0.123207, half_spread=0.550000 -> cost=0.021110
#
# [day 16/21] 2021-01-26 -> 2021-01-27
# [pick_one] cp=C, K=2800.0, dte=21, mid=1046.5500, delta=0.9944, vega=12.3167, spread=9.9000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.2000, delta=-0.0069, vega=17.8124, spread=0.2000, OI=493, vol=15
# [pick_one] cp=C, K=3705.0, dte=21, mid=170.0000, delta=0.7643, vega=283.3810, spread=0.6000, OI=0, vol=0
# [ratios @ 2021-01-26] V=1047.7500 ΔV=0.987482 κV=30.129150 | ΔH=0.764337 κH=283.381000 -> φ1=0.106320, φ0=0.906217
# [next fetch] cp=C, K=2800.0, dte=21, mid=953.0000
# [next fetch] cp=P, K=2800.0, dte=21, mid=3.7500
# [next fetch] cp=C, K=3705.0, dte=21, mid=122.3000
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.10632028964538907, from 170.0000 to 122.3000 -> pnl=-5.071478
# [pnl] qty=0.9062174687733123, from 3850.0000 to 3760.0000 -> pnl=-81.559572
# [rebalance_cost] prev=0.123207, new=0.106320, half_spread=0.300000 -> cost=0.005066
#
# [day 17/21] 2021-01-27 -> 2021-01-28
# [pick_one] cp=C, K=2800.0, dte=21, mid=953.0000, delta=0.9830, vega=37.2551, spread=14.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=3.7500, delta=-0.0182, vega=40.1225, spread=0.5000, OI=27, vol=17
# [pick_one] cp=C, K=3705.0, dte=21, mid=122.3000, delta=0.5847, vega=350.6339, spread=1.0000, OI=0, vol=0
# [ratios @ 2021-01-27] V=956.7500 ΔV=0.964850 κV=77.377600 | ΔH=0.584717 κH=350.633900 -> φ1=0.220679, φ0=0.835815
# [next fetch] cp=C, K=2800.0, dte=22, mid=992.0000
# [next fetch] cp=P, K=2800.0, dte=22, mid=3.1500
# [next fetch] cp=C, K=3705.0, dte=22, mid=141.5000
# [half_spread] C K=3705.0 -> half-spread=0.5000
# [pnl] qty=0.22067917563019435, from 122.3000 to 141.5000 -> pnl=4.237040
# [pnl] qty=0.8358151344630396, from 3760.0000 to 3800.0000 -> pnl=33.432605
# [rebalance_cost] prev=0.106320, new=0.220679, half_spread=0.500000 -> cost=0.057179
#
# [day 18/21] 2021-01-28 -> 2021-01-29
# [pick_one] cp=C, K=2800.0, dte=22, mid=992.0000, delta=0.9769, vega=50.4544, spread=10.8000, OI=10, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=3.1500, delta=-0.0154, vega=35.2004, spread=0.3000, OI=9451, vol=61
# [pick_one] cp=C, K=3705.0, dte=22, mid=141.5000, delta=0.6457, vega=337.8396, spread=1.2000, OI=260, vol=0
# [ratios @ 2021-01-28] V=995.1500 ΔV=0.961456 κV=85.654850 | ΔH=0.645670 κH=337.839600 -> φ1=0.253537, φ0=0.797755
# [next fetch] cp=C, K=2800.0, dte=21, mid=918.7500
# [next fetch] cp=P, K=2800.0, dte=21, mid=3.5500
# [next fetch] cp=C, K=3705.0, dte=21, mid=97.2500
# [half_spread] C K=3705.0 -> half-spread=0.6000
# [pnl] qty=0.253537033550833, from 141.5000 to 97.2500 -> pnl=-11.219014
# [pnl] qty=0.7977547435472336, from 3800.0000 to 3725.0000 -> pnl=-59.831606
# [rebalance_cost] prev=0.220679, new=0.253537, half_spread=0.600000 -> cost=0.019715
#
# [day 19/21] 2021-01-29 -> 2021-02-01
# [pick_one] cp=C, K=2800.0, dte=21, mid=918.7500, delta=0.9791, vega=44.7418, spread=8.9000, OI=10, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=3.5500, delta=-0.0180, vega=38.5520, spread=0.5000, OI=9422, vol=1104
# [pick_one] cp=C, K=3705.0, dte=21, mid=97.2500, delta=0.5287, vega=345.9557, spread=1.9000, OI=260, vol=465
# [ratios @ 2021-01-29] V=922.3000 ΔV=0.961084 κV=83.293760 | ΔH=0.528730 κH=345.955700 -> φ1=0.240764, φ0=0.833785
# [next fetch] cp=C, K=2800.0, dte=21, mid=975.2000
# [next fetch] cp=P, K=2800.0, dte=21, mid=2.4250
# [next fetch] cp=C, K=3705.0, dte=21, mid=126.3500
# [half_spread] C K=3705.0 -> half-spread=0.9500
# [pnl] qty=0.2407642365771109, from 97.2500 to 126.3500 -> pnl=7.006239
# [pnl] qty=0.833784725194584, from 3725.0000 to 3780.0000 -> pnl=45.858160
# [rebalance_cost] prev=0.253537, new=0.240764, half_spread=0.950000 -> cost=0.012134
#
# [day 20/21] 2021-02-01 -> 2021-02-02
# [pick_one] cp=C, K=2800.0, dte=21, mid=975.2000, delta=0.9873, vega=29.1530, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.4250, delta=-0.0128, vega=29.8922, spread=0.2500, OI=62, vol=1
# [pick_one] cp=C, K=3705.0, dte=21, mid=126.3500, delta=0.6316, vega=341.1375, spread=2.1000, OI=3, vol=0
# [ratios @ 2021-02-01] V=977.6250 ΔV=0.974461 κV=59.045180 | ΔH=0.631576 κH=341.137500 -> φ1=0.173083, φ0=0.865146
# [next fetch] cp=C, K=2800.0, dte=22, mid=1025.4000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.8250
# [next fetch] cp=C, K=3705.0, dte=22, mid=159.4500
# [half_spread] C K=3705.0 -> half-spread=1.0500
# [pnl] qty=0.17308322890330147, from 126.3500 to 159.4500 -> pnl=5.729055
# [pnl] qty=0.8651457866221685, from 3780.0000 to 3830.0000 -> pnl=43.257289
# [rebalance_cost] prev=0.240764, new=0.173083, half_spread=1.050000 -> cost=0.071065
#
# [day 21/21] 2021-02-02 -> 2021-02-03
# [pick_one] cp=C, K=2800.0, dte=22, mid=1025.4000, delta=0.9905, vega=22.4487, spread=8.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.8250, delta=-0.0098, vega=24.6170, spread=0.1500, OI=450, vol=200
# [pick_one] cp=C, K=3705.0, dte=22, mid=159.4500, delta=0.7156, vega=318.1250, spread=0.7000, OI=1, vol=0
# [ratios @ 2021-02-02] V=1027.2250 ΔV=0.980659 κV=47.065730 | ΔH=0.715568 κH=318.125000 -> φ1=0.147947, φ0=0.874793
# [next fetch] cp=C, K=2800.0, dte=21, mid=1031.3500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0000
# [next fetch] cp=C, K=3705.0, dte=21, mid=157.5500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.14794728487229863, from 159.4500 to 157.5500 -> pnl=-0.281100
# [pnl] qty=0.8747926572584991, from 3830.0000 to 3835.0000 -> pnl=4.373963
# [rebalance_cost] prev=0.173083, new=0.147947, half_spread=0.350000 -> cost=0.008798
# [pick_one] cp=C, K=2800.0, dte=22, mid=1025.4000, delta=0.9905, vega=22.4487, spread=8.2000, OI=0, vol=0
# [next fetch] cp=C, K=2800.0, dte=21, mid=1031.3500
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.8250, delta=-0.0098, vega=24.6170, spread=0.1500, OI=450, vol=200
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0000
#
# [window done] m0=0.75, Z_T=-1.570033, V_T=1032.350000, Π_T=1033.920033
#
# --- Window 2/31 (start_idx=21) ---
# [get_window_dates] start=2021-02-03 end=2021-03-05 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3835.0000, m0=0.750, target=2876.2500 -> K=2875.0
# [nearest_atm_strike] spot0=3835.0000 -> K_ATM=3835.0
#
# [day 1/21] 2021-02-03 -> 2021-02-04
# [pick_one] cp=C, K=2875.0, dte=23, mid=956.3000, delta=0.9897, vega=25.7522, spread=4.2000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=1.7250, delta=-0.0101, vega=25.7549, spread=0.1500, OI=120, vol=9
# [pick_one] cp=C, K=3835.0, dte=21, mid=60.3000, delta=0.4965, vega=366.5009, spread=0.6000, OI=6, vol=32
# [ratios @ 2021-02-03] V=958.0250 ΔV=0.979671 κV=51.507050 | ΔH=0.496541 κH=366.500900 -> φ1=0.140537, φ0=0.909888
# [next fetch] cp=C, K=2875.0, dte=22, mid=989.6500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.1250
# [next fetch] cp=C, K=3835.0, dte=22, mid=79.4000
# [half_spread] C K=3835.0 -> half-spread=0.3000
# [pnl] qty=0.14053730836677344, from 60.3000 to 79.4000 -> pnl=2.684263
# [pnl] qty=0.9098884643662539, from 3835.0000 to 3870.0000 -> pnl=31.846096
# [rebalance_cost] prev=0.000000, new=0.140537, half_spread=0.300000 -> cost=0.042161
# [init] V0=Π0=958.025000
#
# [day 2/21] 2021-02-04 -> 2021-02-05
# [pick_one] cp=C, K=2875.0, dte=22, mid=989.6500, delta=0.9912, vega=17.7303, spread=4.3000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.1250, delta=-0.0070, vega=18.4054, spread=0.1500, OI=129, vol=0
# [pick_one] cp=C, K=3835.0, dte=22, mid=79.4000, delta=0.5777, vega=370.9495, spread=0.4000, OI=121, vol=21
# [ratios @ 2021-02-04] V=990.7750 ΔV=0.984222 κV=36.135620 | ΔH=0.577739 κH=370.949500 -> φ1=0.097414, φ0=0.927942
# [next fetch] cp=C, K=2875.0, dte=21, mid=1009.3500
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.8000
# [next fetch] cp=C, K=3835.0, dte=21, mid=89.0000
# [half_spread] C K=3835.0 -> half-spread=0.2000
# [pnl] qty=0.0974138528290239, from 79.4000 to 89.0000 -> pnl=0.935173
# [pnl] qty=0.9279422180804126, from 3870.0000 to 3890.0000 -> pnl=18.558844
# [rebalance_cost] prev=0.140537, new=0.097414, half_spread=0.200000 -> cost=0.008625
#
# [day 3/21] 2021-02-05 -> 2021-02-08
# [pick_one] cp=C, K=2875.0, dte=21, mid=1009.3500, delta=0.9944, vega=12.9261, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.8000, delta=-0.0052, vega=13.9687, spread=0.1000, OI=129, vol=6
# [pick_one] cp=C, K=3835.0, dte=21, mid=89.0000, delta=0.6307, vega=351.2990, spread=0.4000, OI=111, vol=0
# [ratios @ 2021-02-05] V=1010.1500 ΔV=0.989153 κV=26.894830 | ΔH=0.630749 κH=351.299000 -> φ1=0.076558, φ0=0.940864
# [next fetch] MISSING next-day row for cp=C, K=2875.0
# [next fetch] MISSING next-day row for cp=P, K=2875.0
# [next fetch] cp=C, K=3835.0, dte=21, mid=106.8000
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=21.
#
# --- Window 3/31 (start_idx=42) ---
# [get_window_dates] start=2021-03-05 end=2021-04-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3850.0000, m0=0.750, target=2887.5000 -> K=2875.0
# [nearest_atm_strike] spot0=3850.0000 -> K_ATM=3850.0
#
# [day 1/21] 2021-03-05 -> 2021-03-08
# [pick_one] cp=C, K=2875.0, dte=21, mid=965.1000, delta=0.9891, vega=24.3534, spread=4.8000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=1.7750, delta=-0.0102, vega=24.9639, spread=0.2500, OI=1451, vol=10
# [pick_one] cp=C, K=3850.0, dte=21, mid=66.8000, delta=0.4836, vega=366.9897, spread=0.8000, OI=1154, vol=454
# [ratios @ 2021-03-05] V=966.8750 ΔV=0.978932 κV=49.317340 | ΔH=0.483582 κH=366.989700 -> φ1=0.134383, φ0=0.913947
# [next fetch] cp=C, K=2875.0, dte=23, mid=951.3500
# [next fetch] cp=P, K=2875.0, dte=23, mid=2.1750
# [next fetch] cp=C, K=3850.0, dte=21, mid=63.1500
# [half_spread] C K=3850.0 -> half-spread=0.4000
# [pnl] qty=0.1343834445489887, from 66.8000 to 63.1500 -> pnl=-0.490500
# [pnl] qty=0.9139465851181109, from 3850.0000 to 3830.0000 -> pnl=-18.278932
# [rebalance_cost] prev=0.000000, new=0.134383, half_spread=0.400000 -> cost=0.053753
# [init] V0=Π0=966.875000
#
# [day 2/21] 2021-03-08 -> 2021-03-09
# [pick_one] cp=C, K=2875.0, dte=23, mid=951.3500, delta=0.9780, vega=50.3349, spread=6.1000, OI=945, vol=0
# [pick_one] cp=P, K=2875.0, dte=23, mid=2.1750, delta=-0.0121, vega=30.2264, spread=0.2500, OI=597, vol=0
# [pick_one] cp=C, K=3850.0, dte=21, mid=63.1500, delta=0.4510, vega=362.9064, spread=4.1000, OI=595, vol=15
# [ratios @ 2021-03-08] V=953.5250 ΔV=0.965883 κV=80.561290 | ΔH=0.450977 κH=362.906400 -> φ1=0.221989, φ0=0.865771
# [next fetch] cp=C, K=2875.0, dte=22, mid=999.7500
# [next fetch] cp=P, K=2875.0, dte=22, mid=1.2750
# [next fetch] cp=C, K=3850.0, dte=22, mid=88.5000
# [half_spread] C K=3850.0 -> half-spread=2.0500
# [pnl] qty=0.22198916855696124, from 63.1500 to 88.5000 -> pnl=5.627425
# [pnl] qty=0.8657709907316873, from 3830.0000 to 3880.0000 -> pnl=43.288550
# [rebalance_cost] prev=0.134383, new=0.221989, half_spread=2.050000 -> cost=0.179592
#
# [day 3/21] 2021-03-09 -> 2021-03-10
# [pick_one] cp=C, K=2875.0, dte=22, mid=999.7500, delta=0.9913, vega=21.1592, spread=6.1000, OI=945, vol=0
# [pick_one] cp=P, K=2875.0, dte=22, mid=1.2750, delta=-0.0076, vega=19.9706, spread=0.1500, OI=597, vol=1
# [pick_one] cp=C, K=3850.0, dte=22, mid=88.5000, delta=0.5582, vega=375.2579, spread=0.8000, OI=2430, vol=30
# [ratios @ 2021-03-09] V=1001.0250 ΔV=0.983670 κV=41.129770 | ΔH=0.558241 κH=375.257900 -> φ1=0.109604, φ0=0.922485
# [next fetch] cp=C, K=2875.0, dte=21, mid=1023.1000
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.9750
# [next fetch] cp=C, K=3850.0, dte=21, mid=98.5000
# [half_spread] C K=3850.0 -> half-spread=0.4000
# [pnl] qty=0.1096040083366666, from 88.5000 to 98.5000 -> pnl=1.096040
# [pnl] qty=0.9224845487821309, from 3880.0000 to 3905.0000 -> pnl=23.062114
# [rebalance_cost] prev=0.221989, new=0.109604, half_spread=0.400000 -> cost=0.044954
#
# [day 4/21] 2021-03-10 -> 2021-03-11
# [pick_one] cp=C, K=2875.0, dte=21, mid=1023.1000, delta=0.9964, vega=9.2441, spread=6.6000, OI=945, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.9750, delta=-0.0060, vega=15.9504, spread=0.1500, OI=596, vol=0
# [pick_one] cp=C, K=3850.0, dte=21, mid=98.5000, delta=0.6127, vega=357.9037, spread=0.6000, OI=2417, vol=14
# [ratios @ 2021-03-10] V=1024.0750 ΔV=0.990368 κV=25.194496 | ΔH=0.612748 κH=357.903700 -> φ1=0.070395, φ0=0.947234
# [next fetch] cp=C, K=2875.0, dte=21, mid=1060.4500
# [next fetch] cp=P, K=2875.0, dte=21, mid=0.8250
# [next fetch] cp=C, K=3850.0, dte=21, mid=123.4500
# [half_spread] C K=3850.0 -> half-spread=0.3000
# [pnl] qty=0.07039462291113503, from 98.5000 to 123.4500 -> pnl=1.756346
# [pnl] qty=0.9472338356004477, from 3905.0000 to 3940.0000 -> pnl=33.153184
# [rebalance_cost] prev=0.109604, new=0.070395, half_spread=0.300000 -> cost=0.011763
#
# [day 5/21] 2021-03-11 -> 2021-03-15
# [pick_one] cp=C, K=2875.0, dte=21, mid=1060.4500, delta=0.9959, vega=8.6556, spread=5.5000, OI=0, vol=0
# [pick_one] cp=P, K=2875.0, dte=21, mid=0.8250, delta=-0.0051, vega=13.8745, spread=0.1500, OI=572, vol=0
# [pick_one] cp=C, K=3850.0, dte=21, mid=123.4500, delta=0.6862, vega=334.3787, spread=0.7000, OI=488, vol=58
# [ratios @ 2021-03-11] V=1061.2750 ΔV=0.990769 κV=22.530096 | ΔH=0.686194 κH=334.378700 -> φ1=0.067379, φ0=0.944534
# [next fetch] MISSING next-day row for cp=C, K=2875.0
# [next fetch] MISSING next-day row for cp=P, K=2875.0
# [next fetch] cp=C, K=3850.0, dte=21, mid=138.0500
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=42.
#
# --- Window 4/31 (start_idx=63) ---
# [get_window_dates] start=2021-04-07 end=2021-05-06 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4080.0000, m0=0.750, target=3060.0000 -> K=3060.0
# [nearest_atm_strike] spot0=4080.0000 -> K_ATM=4080.0
#
# [day 1/21] 2021-04-07 -> 2021-04-08
# [pick_one] cp=C, K=3060.0, dte=23, mid=1017.5500, delta=0.9968, vega=7.9129, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=23, mid=0.6750, delta=-0.0045, vega=13.5922, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4080.0, dte=21, mid=48.8500, delta=0.4983, vega=390.1662, spread=0.5000, OI=38, vol=24
# [ratios @ 2021-04-07] V=1018.2250 ΔV=0.992247 κV=21.505091 | ΔH=0.498267 κH=390.166200 -> φ1=0.055118, φ0=0.964784
# [next fetch] cp=C, K=3060.0, dte=22, mid=1034.9000
# [next fetch] cp=P, K=3060.0, dte=22, mid=0.5750
# [next fetch] cp=C, K=4080.0, dte=22, mid=61.2000
# [half_spread] C K=4080.0 -> half-spread=0.2500
# [pnl] qty=0.05511777032454374, from 48.8500 to 61.2000 -> pnl=0.680704
# [pnl] qty=0.9647836339337006, from 4080.0000 to 4100.0000 -> pnl=19.295673
# [rebalance_cost] prev=0.000000, new=0.055118, half_spread=0.250000 -> cost=0.013779
# [init] V0=Π0=1018.225000
#
# [day 2/21] 2021-04-08 -> 2021-04-09
# [pick_one] cp=C, K=3060.0, dte=22, mid=1034.9000, delta=0.9959, vega=10.1611, spread=4.8000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=22, mid=0.5750, delta=-0.0039, vega=11.7163, spread=0.1500, OI=106, vol=0
# [pick_one] cp=C, K=4080.0, dte=22, mid=61.2000, delta=0.5491, vega=397.9157, spread=0.4000, OI=703, vol=39
# [ratios @ 2021-04-08] V=1035.4750 ΔV=0.992003 κV=21.877380 | ΔH=0.549056 κH=397.915700 -> φ1=0.054980, φ0=0.961816
# [next fetch] cp=C, K=3060.0, dte=21, mid=1066.2000
# [next fetch] cp=P, K=3060.0, dte=21, mid=0.4000
# [next fetch] cp=C, K=4080.0, dte=21, mid=81.0500
# [half_spread] C K=4080.0 -> half-spread=0.2000
# [pnl] qty=0.054979936705186555, from 61.2000 to 81.0500 -> pnl=1.091352
# [pnl] qty=0.9618159358723972, from 4100.0000 to 4130.0000 -> pnl=28.854478
# [rebalance_cost] prev=0.055118, new=0.054980, half_spread=0.200000 -> cost=0.000028
#
# [day 3/21] 2021-04-09 -> 2021-04-12
# [pick_one] cp=C, K=3060.0, dte=21, mid=1066.2000, delta=0.9991, vega=0.8668, spread=5.6000, OI=0, vol=0
# [pick_one] cp=P, K=3060.0, dte=21, mid=0.4000, delta=-0.0028, vega=8.6054, spread=0.1000, OI=106, vol=0
# [pick_one] cp=C, K=4080.0, dte=21, mid=81.0500, delta=0.6376, vega=370.9578, spread=0.7000, OI=756, vol=61
# [ratios @ 2021-04-09] V=1066.6000 ΔV=0.996248 κV=9.472167 | ΔH=0.637559 κH=370.957800 -> φ1=0.025534, φ0=0.979968
# [next fetch] MISSING next-day row for cp=C, K=3060.0
# [next fetch] MISSING next-day row for cp=P, K=3060.0
# [next fetch] cp=C, K=4080.0, dte=21, mid=82.6000
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=63.
#
# --- Window 5/31 (start_idx=84) ---
# [get_window_dates] start=2021-05-06 end=2021-06-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4200.0000, m0=0.750, target=3150.0000 -> K=3150.0
# [nearest_atm_strike] spot0=4200.0000 -> K_ATM=4200.0
#
# [day 1/21] 2021-05-06 -> 2021-05-07
# [pick_one] cp=C, K=3150.0, dte=22, mid=1044.3500, delta=0.9943, vega=11.7265, spread=6.1000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=22, mid=1.0750, delta=-0.0065, vega=18.7132, spread=0.1500, OI=2948, vol=0
# [pick_one] cp=C, K=4200.0, dte=22, mid=54.1000, delta=0.4888, vega=410.5974, spread=0.4000, OI=4914, vol=105
# [ratios @ 2021-05-06] V=1045.4250 ΔV=0.987812 κV=30.439690 | ΔH=0.488750 κH=410.597400 -> φ1=0.074135, φ0=0.951578
# [next fetch] cp=C, K=3150.0, dte=21, mid=1078.5500
# [next fetch] cp=P, K=3150.0, dte=21, mid=0.6000
# [next fetch] cp=C, K=4200.0, dte=21, mid=69.7000
# [half_spread] C K=4200.0 -> half-spread=0.2000
# [pnl] qty=0.07413512603830419, from 54.1000 to 69.7000 -> pnl=1.156508
# [pnl] qty=0.9515784571487788, from 4200.0000 to 4230.0000 -> pnl=28.547354
# [rebalance_cost] prev=0.000000, new=0.074135, half_spread=0.200000 -> cost=0.014827
# [init] V0=Π0=1045.425000
#
# [day 2/21] 2021-05-07 -> 2021-05-10
# [pick_one] cp=C, K=3150.0, dte=21, mid=1078.5500, delta=0.9970, vega=6.3707, spread=3.7000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=21, mid=0.6000, delta=-0.0039, vega=11.8118, spread=0.1000, OI=2948, vol=0
# [pick_one] cp=C, K=4200.0, dte=21, mid=69.7000, delta=0.5881, vega=394.5487, spread=0.6000, OI=4940, vol=518
# [ratios @ 2021-05-07] V=1079.1500 ΔV=0.993041 κV=18.182516 | ΔH=0.588088 κH=394.548700 -> φ1=0.046084, φ0=0.965939
# [next fetch] cp=C, K=3150.0, dte=22, mid=1036.5000
# [next fetch] cp=P, K=3150.0, dte=22, mid=1.0250
# [next fetch] cp=C, K=4200.0, dte=22, mid=50.9500
# [half_spread] C K=4200.0 -> half-spread=0.3000
# [pnl] qty=0.04608433889149806, from 69.7000 to 50.9500 -> pnl=-0.864081
# [pnl] qty=0.9659393533099766, from 4230.0000 to 4190.0000 -> pnl=-38.637574
# [rebalance_cost] prev=0.074135, new=0.046084, half_spread=0.300000 -> cost=0.008415
#
# [day 3/21] 2021-05-10 -> 2021-05-11
# [pick_one] cp=C, K=3150.0, dte=22, mid=1036.5000, delta=0.9932, vega=17.6095, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=22, mid=1.0250, delta=-0.0063, vega=18.1792, spread=0.1500, OI=6, vol=58
# [pick_one] cp=C, K=4200.0, dte=22, mid=50.9500, delta=0.4669, vega=408.5476, spread=0.5000, OI=299, vol=121
# [ratios @ 2021-05-10] V=1037.5250 ΔV=0.986945 κV=35.788730 | ΔH=0.466935 κH=408.547600 -> φ1=0.087600, φ0=0.946042
# [next fetch] cp=C, K=3150.0, dte=21, mid=1000.6500
# [next fetch] cp=P, K=3150.0, dte=21, mid=1.3750
# [next fetch] cp=C, K=4200.0, dte=21, mid=37.9500
# [half_spread] C K=4200.0 -> half-spread=0.2500
# [pnl] qty=0.0875999026796388, from 50.9500 to 37.9500 -> pnl=-1.138799
# [pnl] qty=0.9460415394422829, from 4190.0000 to 4155.0000 -> pnl=-33.111454
# [rebalance_cost] prev=0.046084, new=0.087600, half_spread=0.250000 -> cost=0.010379
#
# [day 4/21] 2021-05-11 -> 2021-05-12
# [pick_one] cp=C, K=3150.0, dte=21, mid=1000.6500, delta=0.9844, vega=36.7367, spread=6.3000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=21, mid=1.3750, delta=-0.0082, vega=22.2721, spread=0.1500, OI=64, vol=3
# [pick_one] cp=C, K=4200.0, dte=21, mid=37.9500, delta=0.3718, vega=376.3505, spread=0.7000, OI=308, vol=103
# [ratios @ 2021-05-11] V=1002.0250 ΔV=0.976179 κV=59.008780 | ΔH=0.371809 κH=376.350500 -> φ1=0.156792, φ0=0.917882
# [next fetch] cp=C, K=3150.0, dte=21, mid=917.7500
# [next fetch] cp=P, K=3150.0, dte=21, mid=4.0000
# [next fetch] cp=C, K=4200.0, dte=21, mid=20.6000
# [half_spread] C K=4200.0 -> half-spread=0.3500
# [pnl] qty=0.15679208610058976, from 37.9500 to 20.6000 -> pnl=-2.720343
# [pnl] qty=0.9178822912590259, from 4155.0000 to 4070.0000 -> pnl=-78.019995
# [rebalance_cost] prev=0.087600, new=0.156792, half_spread=0.350000 -> cost=0.024217
#
# [day 5/21] 2021-05-12 -> 2021-05-13
# [pick_one] cp=C, K=3150.0, dte=21, mid=917.7500, delta=0.9774, vega=52.2420, spread=7.5000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=21, mid=4.0000, delta=-0.0200, vega=47.2827, spread=0.2000, OI=5, vol=35
# [pick_one] cp=C, K=4200.0, dte=21, mid=20.6000, delta=0.2181, vega=287.0966, spread=0.8000, OI=169, vol=17
# [ratios @ 2021-05-12] V=921.7500 ΔV=0.957358 κV=99.524730 | ΔH=0.218063 κH=287.096600 -> φ1=0.346659, φ0=0.881764
# [next fetch] cp=C, K=3150.0, dte=22, mid=962.4500
# [next fetch] cp=P, K=3150.0, dte=22, mid=2.0500
# [next fetch] cp=C, K=4200.0, dte=22, mid=28.4000
# [half_spread] C K=4200.0 -> half-spread=0.4000
# [pnl] qty=0.34665938224277126, from 20.6000 to 28.4000 -> pnl=2.703943
# [pnl] qty=0.8817644151299946, from 4070.0000 to 4115.0000 -> pnl=39.679399
# [rebalance_cost] prev=0.156792, new=0.346659, half_spread=0.400000 -> cost=0.075947
#
# [day 6/21] 2021-05-13 -> 2021-05-14
# [pick_one] cp=C, K=3150.0, dte=22, mid=962.4500, delta=0.9890, vega=28.0076, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=22, mid=2.0500, delta=-0.0116, vega=30.5440, spread=0.1000, OI=1569, vol=22
# [pick_one] cp=C, K=4200.0, dte=22, mid=28.4000, delta=0.2931, vega=347.2471, spread=0.4000, OI=1115, vol=174
# [ratios @ 2021-05-13] V=964.5000 ΔV=0.977471 κV=58.551620 | ΔH=0.293125 κH=347.247100 -> φ1=0.168617, φ0=0.928045
# [next fetch] cp=C, K=3150.0, dte=21, mid=1023.1500
# [next fetch] cp=P, K=3150.0, dte=21, mid=1.0750
# [next fetch] cp=C, K=4200.0, dte=21, mid=40.8000
# [half_spread] C K=4200.0 -> half-spread=0.2000
# [pnl] qty=0.1686165845589495, from 28.4000 to 40.8000 -> pnl=2.090846
# [pnl] qty=0.9280452636511579, from 4115.0000 to 4175.0000 -> pnl=55.682716
# [rebalance_cost] prev=0.346659, new=0.168617, half_spread=0.200000 -> cost=0.035609
#
# [day 7/21] 2021-05-14 -> 2021-05-17
# [pick_one] cp=C, K=3150.0, dte=21, mid=1023.1500, delta=0.9915, vega=21.9716, spread=6.9000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=21, mid=1.0750, delta=-0.0066, vega=18.5094, spread=0.1500, OI=1554, vol=73
# [pick_one] cp=C, K=4200.0, dte=21, mid=40.8000, delta=0.4232, vega=391.8114, spread=0.6000, OI=1130, vol=526
# [ratios @ 2021-05-14] V=1024.2250 ΔV=0.984858 κV=40.480990 | ΔH=0.423195 κH=391.811400 -> φ1=0.103318, φ0=0.941135
# [next fetch] cp=C, K=3150.0, dte=21, mid=1011.1000
# [next fetch] cp=P, K=3150.0, dte=21, mid=0.9250
# [next fetch] cp=C, K=4200.0, dte=21, mid=36.4000
# [half_spread] C K=4200.0 -> half-spread=0.3000
# [pnl] qty=0.1033175400205303, from 40.8000 to 36.4000 -> pnl=-0.454597
# [pnl] qty=0.9411345336510116, from 4175.0000 to 4165.0000 -> pnl=-9.411345
# [rebalance_cost] prev=0.168617, new=0.103318, half_spread=0.300000 -> cost=0.019590
#
# [day 8/21] 2021-05-17 -> 2021-05-18
# [pick_one] cp=C, K=3150.0, dte=21, mid=1011.1000, delta=0.9940, vega=15.0998, spread=5.0000, OI=0, vol=0
# [pick_one] cp=P, K=3150.0, dte=21, mid=0.9250, delta=-0.0059, vega=16.7565, spread=0.1500, OI=16, vol=0
# [pick_one] cp=C, K=4200.0, dte=21, mid=36.4000, delta=0.3905, vega=383.0903, spread=0.4000, OI=394, vol=96
# [ratios @ 2021-05-17] V=1012.0250 ΔV=0.988075 κV=31.856330 | ΔH=0.390534 κH=383.090300 -> φ1=0.083156, φ0=0.955600
# [next fetch] MISSING next-day row for cp=C, K=3150.0
# [next fetch] MISSING next-day row for cp=P, K=3150.0
# [next fetch] cp=C, K=4200.0, dte=22, mid=27.7000
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=84.
#
# --- Window 6/31 (start_idx=105) ---
# [get_window_dates] start=2021-06-07 end=2021-07-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4230.0000, m0=0.750, target=3172.5000 -> K=3170.0
# [nearest_atm_strike] spot0=4230.0000 -> K_ATM=4230.0
#
# [day 1/21] 2021-06-07 -> 2021-06-08
# [pick_one] cp=C, K=3170.0, dte=23, mid=1056.0000, delta=0.9961, vega=11.4438, spread=3.6000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=23, mid=0.8000, delta=-0.0051, vega=15.4977, spread=0.1000, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=21, mid=43.5500, delta=0.4914, vega=404.2849, spread=0.5000, OI=610, vol=15
# [ratios @ 2021-06-07] V=1056.8000 ΔV=0.991057 κV=26.941510 | ΔH=0.491400 κH=404.284900 -> φ1=0.066640, φ0=0.958310
# [next fetch] cp=C, K=3170.0, dte=22, mid=1056.8500
# [next fetch] cp=P, K=3170.0, dte=22, mid=0.8500
# [next fetch] cp=C, K=4230.0, dte=22, mid=47.5500
# [half_spread] C K=4230.0 -> half-spread=0.2500
# [pnl] qty=0.0666399116068891, from 43.5500 to 47.5500 -> pnl=0.266560
# [pnl] qty=0.9583101474363748, from 4230.0000 to 4230.0000 -> pnl=0.000000
# [rebalance_cost] prev=0.000000, new=0.066640, half_spread=0.250000 -> cost=0.016660
# [init] V0=Π0=1056.800000
#
# [day 2/21] 2021-06-08 -> 2021-06-09
# [pick_one] cp=C, K=3170.0, dte=22, mid=1056.8500, delta=0.9941, vega=16.4354, spread=4.1000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=22, mid=0.8500, delta=-0.0053, vega=15.8246, spread=0.1000, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=22, mid=47.5500, delta=0.4928, vega=413.8269, spread=0.5000, OI=462, vol=493
# [ratios @ 2021-06-08] V=1057.7000 ΔV=0.988813 κV=32.260010 | ΔH=0.492834 κH=413.826900 -> φ1=0.077955, φ0=0.950394
# [next fetch] cp=C, K=3170.0, dte=21, mid=1050.4500
# [next fetch] cp=P, K=3170.0, dte=21, mid=0.9000
# [next fetch] cp=C, K=4230.0, dte=21, mid=45.7500
# [half_spread] C K=4230.0 -> half-spread=0.2500
# [pnl] qty=0.07795532383225934, from 47.5500 to 45.7500 -> pnl=-0.140320
# [pnl] qty=0.9503939659344524, from 4230.0000 to 4225.0000 -> pnl=-4.751970
# [rebalance_cost] prev=0.066640, new=0.077955, half_spread=0.250000 -> cost=0.002829
#
# [day 3/21] 2021-06-09 -> 2021-06-10
# [pick_one] cp=C, K=3170.0, dte=21, mid=1050.4500, delta=0.9951, vega=14.4622, spread=3.7000, OI=0, vol=0
# [pick_one] cp=P, K=3170.0, dte=21, mid=0.9000, delta=-0.0056, vega=16.1599, spread=0.1000, OI=550, vol=0
# [pick_one] cp=C, K=4230.0, dte=21, mid=45.7500, delta=0.4738, vega=402.9023, spread=0.3000, OI=762, vol=481
# [ratios @ 2021-06-09] V=1051.3500 ΔV=0.989477 κV=30.622100 | ΔH=0.473777 κH=402.902300 -> φ1=0.076004, φ0=0.953468
# [next fetch] MISSING next-day row for cp=C, K=3170.0
# [next fetch] MISSING next-day row for cp=P, K=3170.0
# [next fetch] cp=C, K=4230.0, dte=22, mid=51.3500
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=105.
#
# --- Window 7/31 (start_idx=126) ---
# [get_window_dates] start=2021-07-07 end=2021-08-05 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4355.0000, m0=0.750, target=3266.2500 -> K=3270.0
# [nearest_atm_strike] spot0=4355.0000 -> K_ATM=4355.0
#
# [day 1/21] 2021-07-07 -> 2021-07-08
# [pick_one] cp=C, K=3270.0, dte=23, mid=1085.4500, delta=0.9949, vega=13.8010, spread=2.9000, OI=0, vol=0
# [pick_one] cp=P, K=3270.0, dte=23, mid=0.7500, delta=-0.0047, vega=14.9577, spread=0.1000, OI=117, vol=0
# [pick_one] cp=C, K=4355.0, dte=21, mid=46.0000, delta=0.5074, vega=416.7013, spread=0.4000, OI=23, vol=29
# [ratios @ 2021-07-07] V=1086.2000 ΔV=0.990194 κV=28.758670 | ΔH=0.507367 κH=416.701300 -> φ1=0.069015, φ0=0.955178
# [next fetch] cp=C, K=3270.0, dte=22, mid=1048.2000
# [next fetch] cp=P, K=3270.0, dte=22, mid=1.3000
# [next fetch] cp=C, K=4355.0, dte=22, mid=35.9000
# [half_spread] C K=4355.0 -> half-spread=0.2000
# [pnl] qty=0.06901507146725964, from 46.0000 to 35.9000 -> pnl=-0.697052
# [pnl] qty=0.9551780302348709, from 4355.0000 to 4320.0000 -> pnl=-33.431231
# [rebalance_cost] prev=0.000000, new=0.069015, half_spread=0.200000 -> cost=0.013803
# [init] V0=Π0=1086.200000
#
# [day 2/21] 2021-07-08 -> 2021-07-09
# [pick_one] cp=C, K=3270.0, dte=22, mid=1048.2000, delta=0.9931, vega=18.2010, spread=7.0000, OI=0, vol=5
# [pick_one] cp=P, K=3270.0, dte=22, mid=1.3000, delta=-0.0075, vega=22.0422, spread=0.1000, OI=117, vol=0
# [pick_one] cp=C, K=4355.0, dte=22, mid=35.9000, delta=0.3929, vega=407.6049, spread=0.4000, OI=465, vol=221
# [ratios @ 2021-07-08] V=1049.5000 ΔV=0.985526 κV=40.243220 | ΔH=0.392943 κH=407.604900 -> φ1=0.098731, φ0=0.946730
# [next fetch] cp=C, K=3270.0, dte=21, mid=1096.7500
# [next fetch] cp=P, K=3270.0, dte=21, mid=0.6500
# [next fetch] cp=C, K=4355.0, dte=21, mid=53.6000
# [half_spread] C K=4355.0 -> half-spread=0.2000
# [pnl] qty=0.09873095244929588, from 35.9000 to 53.6000 -> pnl=1.747538
# [pnl] qty=0.9467303633517163, from 4320.0000 to 4370.0000 -> pnl=47.336518
# [rebalance_cost] prev=0.069015, new=0.098731, half_spread=0.200000 -> cost=0.005943
#
# [day 3/21] 2021-07-09 -> 2021-07-12
# [pick_one] cp=C, K=3270.0, dte=21, mid=1096.7500, delta=0.9959, vega=10.3715, spread=2.9000, OI=5, vol=5
# [pick_one] cp=P, K=3270.0, dte=21, mid=0.6500, delta=-0.0041, vega=12.8069, spread=0.1000, OI=117, vol=40
# [pick_one] cp=C, K=4355.0, dte=21, mid=53.6000, delta=0.5427, vega=415.3485, spread=0.4000, OI=495, vol=354
# [ratios @ 2021-07-09] V=1097.4000 ΔV=0.991790 κV=23.178340 | ΔH=0.542727 κH=415.348500 -> φ1=0.055805, φ0=0.961503
# [next fetch] MISSING next-day row for cp=C, K=3270.0
# [next fetch] MISSING next-day row for cp=P, K=3270.0
# [next fetch] cp=C, K=4355.0, dte=21, mid=63.5000
# [one_day_step] Missing at least one leg on next day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=0.75, start_idx=126.
#
# --- Window 8/31 (start_idx=147) ---
# [get_window_dates] start=2021-08-05 end=2021-09-03 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4425.0000, m0=0.750, target=3318.7500 -> K=3325.0
# [nearest_atm_strike] spot0=4425.0000 -> K_ATM=4425.0
#
# [day 1/21] 2021-08-05 -> 2021-08-06
# [pick_one] cp=C, K=3325.0, dte=22, mid=1098.8500, delta=0.9952, vega=11.1570, spread=3.7000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=22, mid=0.7000, delta=-0.0044, vega=14.0184, spread=0.1000, OI=83, vol=0
# [pick_one] cp=C, K=4425.0, dte=22, mid=51.1500, delta=0.5003, vega=433.2155, spread=0.3000, OI=1494, vol=159
# [ratios @ 2021-08-05] V=1099.5500 ΔV=0.990849 κV=25.175390 | ΔH=0.500309 κH=433.215500 -> φ1=0.058113, φ0=0.961775
# [next fetch] cp=C, K=3325.0, dte=21, mid=1107.8000
# [next fetch] cp=P, K=3325.0, dte=21, mid=0.5000
# [next fetch] cp=C, K=4425.0, dte=21, mid=51.8000
# [half_spread] C K=4425.0 -> half-spread=0.1500
# [pnl] qty=0.05811285607278594, from 51.1500 to 51.8000 -> pnl=0.037773
# [pnl] qty=0.9617746150910805, from 4425.0000 to 4435.0000 -> pnl=9.617746
# [rebalance_cost] prev=0.000000, new=0.058113, half_spread=0.150000 -> cost=0.008717
# [init] V0=Π0=1099.550000
#
# [day 2/21] 2021-08-06 -> 2021-08-09
# [pick_one] cp=C, K=3325.0, dte=21, mid=1107.8000, delta=0.9965, vega=8.4438, spread=3.0000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=21, mid=0.5000, delta=-0.0033, vega=10.6603, spread=0.1000, OI=83, vol=10
# [pick_one] cp=C, K=4425.0, dte=21, mid=51.8000, delta=0.5298, vega=422.9066, spread=0.4000, OI=1581, vol=448
# [ratios @ 2021-08-06] V=1108.3000 ΔV=0.993156 κV=19.104044 | ΔH=0.529757 κH=422.906600 -> φ1=0.045173, φ0=0.969225
# [next fetch] cp=C, K=3325.0, dte=22, mid=1103.5500
# [next fetch] cp=P, K=3325.0, dte=22, mid=0.6500
# [next fetch] cp=C, K=4425.0, dte=21, mid=49.9000
# [half_spread] C K=4425.0 -> half-spread=0.2000
# [pnl] qty=0.0451731989994954, from 51.8000 to 49.9000 -> pnl=-0.085829
# [pnl] qty=0.9692251816176243, from 4435.0000 to 4430.0000 -> pnl=-4.846126
# [rebalance_cost] prev=0.058113, new=0.045173, half_spread=0.200000 -> cost=0.002588
#
# [day 3/21] 2021-08-09 -> 2021-08-10
# [pick_one] cp=C, K=3325.0, dte=22, mid=1103.5500, delta=0.9963, vega=9.0608, spread=3.1000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=22, mid=0.6500, delta=-0.0041, vega=13.2504, spread=0.1000, OI=1071, vol=0
# [pick_one] cp=C, K=4425.0, dte=21, mid=49.9000, delta=0.5175, vega=423.3448, spread=0.6000, OI=768, vol=4
# [ratios @ 2021-08-09] V=1104.2000 ΔV=0.992185 κV=22.311193 | ΔH=0.517486 κH=423.344800 -> φ1=0.052702, φ0=0.964912
# [next fetch] cp=C, K=3325.0, dte=21, mid=1106.3500
# [next fetch] cp=P, K=3325.0, dte=21, mid=0.5500
# [next fetch] cp=C, K=4425.0, dte=21, mid=52.2000
# [half_spread] C K=4425.0 -> half-spread=0.3000
# [pnl] qty=0.05270217798824976, from 49.9000 to 52.2000 -> pnl=0.121215
# [pnl] qty=0.9649123607215726, from 4430.0000 to 4435.0000 -> pnl=4.824562
# [rebalance_cost] prev=0.045173, new=0.052702, half_spread=0.300000 -> cost=0.002259
#
# [day 4/21] 2021-08-10 -> 2021-08-11
# [pick_one] cp=C, K=3325.0, dte=21, mid=1106.3500, delta=0.9969, vega=6.0531, spread=4.5000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=21, mid=0.5500, delta=-0.0036, vega=11.4417, spread=0.1000, OI=1071, vol=0
# [pick_one] cp=C, K=4425.0, dte=21, mid=52.2000, delta=0.5249, vega=423.1327, spread=0.6000, OI=1074, vol=171
# [ratios @ 2021-08-10] V=1106.9000 ΔV=0.993325 κV=17.494767 | ΔH=0.524867 κH=423.132700 -> φ1=0.041346, φ0=0.971624
# [next fetch] cp=C, K=3325.0, dte=23, mid=1118.3000
# [next fetch] cp=P, K=3325.0, dte=23, mid=0.7000
# [next fetch] cp=C, K=4425.0, dte=21, mid=58.9000
# [half_spread] C K=4425.0 -> half-spread=0.3000
# [pnl] qty=0.041345816572436966, from 52.2000 to 58.9000 -> pnl=0.277017
# [pnl] qty=0.9716239452930747, from 4435.0000 to 4450.0000 -> pnl=14.574359
# [rebalance_cost] prev=0.052702, new=0.041346, half_spread=0.300000 -> cost=0.003407
#
# [day 5/21] 2021-08-11 -> 2021-08-12
# [pick_one] cp=C, K=3325.0, dte=23, mid=1118.3000, delta=0.9963, vega=8.7942, spread=3.4000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=23, mid=0.7000, delta=-0.0043, vega=14.1833, spread=0.1000, OI=488, vol=0
# [pick_one] cp=C, K=4425.0, dte=21, mid=58.9000, delta=0.5652, vega=419.4029, spread=0.4000, OI=333, vol=8
# [ratios @ 2021-08-11] V=1119.0000 ΔV=0.992017 κV=22.977532 | ΔH=0.565237 κH=419.402900 -> φ1=0.054786, φ0=0.961050
# [next fetch] cp=C, K=3325.0, dte=22, mid=1132.0500
# [next fetch] cp=P, K=3325.0, dte=22, mid=0.6500
# [next fetch] cp=C, K=4425.0, dte=22, mid=69.0000
# [half_spread] C K=4425.0 -> half-spread=0.2000
# [pnl] qty=0.0547862973765799, from 58.9000 to 69.0000 -> pnl=0.553342
# [pnl] qty=0.9610497576297541, from 4450.0000 to 4460.0000 -> pnl=9.610498
# [rebalance_cost] prev=0.041346, new=0.054786, half_spread=0.200000 -> cost=0.002688
#
# [day 6/21] 2021-08-12 -> 2021-08-13
# [pick_one] cp=C, K=3325.0, dte=22, mid=1132.0500, delta=0.9959, vega=10.2261, spread=3.3000, OI=0, vol=0
# [pick_one] cp=P, K=3325.0, dte=22, mid=0.6500, delta=-0.0040, vega=13.0504, spread=0.1000, OI=488, vol=0
# ...
# [choose_strike_for_m0] spot0=4595.0000, m0=1.250, target=5743.7500 -> K=5050.0
# [nearest_atm_strike] spot0=4595.0000 -> K_ATM=4595.0
#
# [day 1/21] 2021-12-06 -> 2021-12-07
# [pick_one] MISSING leg for cp=C, K=5050.0
# [pick_one] cp=P, K=5050.0, dte=21, mid=460.6500, delta=-0.9982, vega=4.5441, spread=7.3000, OI=0, vol=0
# [pick_one] cp=C, K=4595.0, dte=21, mid=83.2000, delta=0.4987, vega=439.1390, spread=1.0000, OI=0, vol=1
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=231.
#
# --- Window 13/31 (start_idx=252) ---
# [get_window_dates] start=2022-01-05 end=2022-02-04 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4705.0000, m0=1.250, target=5881.2500 -> K=5080.0
# [nearest_atm_strike] spot0=4705.0000 -> K_ATM=4705.0
#
# [day 1/21] 2022-01-05 -> 2022-01-06
# [pick_one] cp=C, K=5080.0, dte=23, mid=0.3000, delta=0.0064, vega=21.3547, spread=0.1000, OI=25, vol=0
# [pick_one] MISSING leg for cp=P, K=5080.0
# [pick_one] cp=C, K=4705.0, dte=21, mid=68.3500, delta=0.5005, vega=449.8052, spread=0.7000, OI=13, vol=1
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=252.
#
# --- Window 14/31 (start_idx=273) ---
# [get_window_dates] start=2022-02-04 end=2022-03-08 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4505.0000, m0=1.250, target=5631.2500 -> K=5600.0
# [nearest_atm_strike] spot0=4505.0000 -> K_ATM=4505.0
#
# [day 1/21] 2022-02-04 -> 2022-02-07
# [pick_one] MISSING leg for cp=C, K=5600.0
# [pick_one] cp=P, K=5600.0, dte=21, mid=1099.9500, delta=-0.9955, vega=13.2481, spread=7.5000, OI=0, vol=0
# [pick_one] cp=C, K=4505.0, dte=21, mid=81.5000, delta=0.5000, vega=430.4991, spread=0.8000, OI=192, vol=6
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=273.
#
# --- Window 15/31 (start_idx=294) ---
# [get_window_dates] start=2022-03-08 end=2022-04-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4180.0000, m0=1.250, target=5225.0000 -> K=4895.0
# [nearest_atm_strike] spot0=4180.0000 -> K_ATM=4180.0
#
# [day 1/21] 2022-03-08 -> 2022-03-09
# [pick_one] MISSING leg for cp=C, K=4895.0
# [pick_one] cp=P, K=4895.0, dte=23, mid=730.1500, delta=-0.9972, vega=3.7742, spread=6.7000, OI=29, vol=0
# [pick_one] cp=C, K=4180.0, dte=22, mid=117.1000, delta=0.4950, vega=407.8038, spread=0.8000, OI=0, vol=0
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=294.
#
# --- Window 16/31 (start_idx=315) ---
# [get_window_dates] start=2022-04-07 end=2022-05-09 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4505.0000, m0=1.250, target=5631.2500 -> K=5600.0
# [nearest_atm_strike] spot0=4505.0000 -> K_ATM=4505.0
#
# [day 1/21] 2022-04-07 -> 2022-04-08
# [pick_one] MISSING leg for cp=C, K=5600.0
# [pick_one] cp=P, K=5600.0, dte=22, mid=1098.8000, delta=-0.9958, vega=13.6556, spread=7.0000, OI=4, vol=0
# [pick_one] cp=C, K=4505.0, dte=22, mid=73.0000, delta=0.5005, vega=440.7489, spread=0.6000, OI=262, vol=424
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=315.
#
# --- Window 17/31 (start_idx=336) ---
# [get_window_dates] start=2022-05-09 end=2022-06-08 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4010.0000, m0=1.250, target=5012.5000 -> K=5000.0
# [nearest_atm_strike] spot0=4010.0000 -> K_ATM=4010.0
#
# [day 1/21] 2022-05-09 -> 2022-05-10
# [pick_one] MISSING leg for cp=C, K=5000.0
# [pick_one] cp=P, K=5000.0, dte=23, mid=1009.4500, delta=-0.9966, vega=8.5741, spread=7.7000, OI=0, vol=0
# [pick_one] cp=C, K=4010.0, dte=22, mid=109.9500, delta=0.4885, vega=390.5111, spread=0.9000, OI=13, vol=13
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=336.
#
# --- Window 18/31 (start_idx=357) ---
# [get_window_dates] start=2022-06-08 end=2022-07-11 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4120.0000, m0=1.250, target=5150.0000 -> K=4750.0
# [nearest_atm_strike] spot0=4120.0000 -> K_ATM=4120.0
#
# [day 1/21] 2022-06-08 -> 2022-06-09
# [pick_one] cp=C, K=4750.0, dte=22, mid=0.2250, delta=0.0034, vega=10.4316, spread=0.0500, OI=12341, vol=13
# [pick_one] MISSING leg for cp=P, K=4750.0
# [pick_one] cp=C, K=4120.0, dte=21, mid=82.2500, delta=0.4940, vega=393.1687, spread=0.5000, OI=2, vol=3
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=357.
#
# --- Window 19/31 (start_idx=378) ---
# [get_window_dates] start=2022-07-11 end=2022-08-09 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3875.0000, m0=1.250, target=4843.7500 -> K=4800.0
# [nearest_atm_strike] spot0=3875.0000 -> K_ATM=3875.0
#
# [day 1/21] 2022-07-11 -> 2022-07-12
# [pick_one] MISSING leg for cp=C, K=4800.0
# [pick_one] cp=P, K=4800.0, dte=21, mid=946.1500, delta=-0.9937, vega=13.8350, spread=7.1000, OI=0, vol=0
# [pick_one] cp=C, K=3875.0, dte=21, mid=77.8000, delta=0.4722, vega=367.5736, spread=0.6000, OI=173, vol=0
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=378.
#
# --- Window 20/31 (start_idx=399) ---
# [get_window_dates] start=2022-08-09 end=2022-09-08 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4130.0000, m0=1.250, target=5162.5000 -> K=5200.0
# [nearest_atm_strike] spot0=4130.0000 -> K_ATM=4130.0
#
# [day 1/21] 2022-08-09 -> 2022-08-10
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=22, mid=1078.8500, delta=-0.9913, vega=19.3786, spread=3.7000, OI=0, vol=0
# [pick_one] cp=C, K=4130.0, dte=22, mid=72.3000, delta=0.4889, vega=402.9066, spread=0.4000, OI=182, vol=98
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=399.
#
# --- Window 21/31 (start_idx=420) ---
# [get_window_dates] start=2022-09-08 end=2022-10-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4025.0000, m0=1.250, target=5031.2500 -> K=5030.0
# [nearest_atm_strike] spot0=4025.0000 -> K_ATM=4025.0
#
# [day 1/21] 2022-09-08 -> 2022-09-09
# [pick_one] MISSING leg for cp=C, K=5030.0
# [pick_one] cp=P, K=5030.0, dte=22, mid=1024.7500, delta=-0.9881, vega=26.2352, spread=6.5000, OI=17, vol=0
# [pick_one] cp=C, K=4025.0, dte=22, mid=73.1000, delta=0.4708, vega=390.6437, spread=0.4000, OI=2172, vol=211
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=420.
#
# --- Window 22/31 (start_idx=441) ---
# [get_window_dates] start=2022-10-07 end=2022-11-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3660.0000, m0=1.250, target=4575.0000 -> K=4325.0
# [nearest_atm_strike] spot0=3660.0000 -> K_ATM=3660.0
#
# [day 1/21] 2022-10-07 -> 2022-10-10
# [pick_one] cp=C, K=4325.0, dte=21, mid=0.3000, delta=0.0042, vega=10.8339, spread=0.1000, OI=24, vol=0
# [pick_one] MISSING leg for cp=P, K=4325.0
# [pick_one] cp=C, K=3660.0, dte=21, mid=91.2000, delta=0.4907, vega=348.1907, spread=0.6000, OI=47, vol=172
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=441.
#
# --- Window 23/31 (start_idx=462) ---
# [get_window_dates] start=2022-11-07 end=2022-12-07 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3820.0000, m0=1.250, target=4775.0000 -> K=4770.0
# [nearest_atm_strike] spot0=3820.0000 -> K_ATM=3820.0
#
# [day 1/21] 2022-11-07 -> 2022-11-08
# [pick_one] MISSING leg for cp=C, K=4770.0
# [pick_one] cp=P, K=4770.0, dte=23, mid=957.0500, delta=-0.9950, vega=11.5435, spread=6.1000, OI=10, vol=0
# [pick_one] cp=C, K=3820.0, dte=21, mid=78.3500, delta=0.4942, vega=364.0104, spread=0.5000, OI=5, vol=1
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=462.
#
# --- Window 24/31 (start_idx=483) ---
# [get_window_dates] start=2022-12-07 end=2023-01-09 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3945.0000, m0=1.250, target=4931.2500 -> K=5000.0
# [nearest_atm_strike] spot0=3945.0000 -> K_ATM=3945.0
#
# [day 1/21] 2022-12-07 -> 2022-12-08
# [pick_one] MISSING leg for cp=C, K=5000.0
# [pick_one] cp=P, K=5000.0, dte=21, mid=1056.7500, delta=-0.9986, vega=3.0372, spread=5.1000, OI=2, vol=0
# [pick_one] cp=C, K=3945.0, dte=21, mid=78.4000, delta=0.5021, vega=376.2804, spread=0.6000, OI=10, vol=2
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=483.
#
# --- Window 25/31 (start_idx=504) ---
# [get_window_dates] start=2023-01-09 end=2023-02-08 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3910.0000, m0=1.250, target=4887.5000 -> K=4900.0
# [nearest_atm_strike] spot0=3910.0000 -> K_ATM=3910.0
#
# [day 1/21] 2023-01-09 -> 2023-01-10
# [pick_one] MISSING leg for cp=C, K=4900.0
# [pick_one] cp=P, K=4900.0, dte=22, mid=996.5000, delta=-0.9985, vega=4.2851, spread=5.6000, OI=0, vol=0
# [pick_one] cp=C, K=3910.0, dte=21, mid=67.0500, delta=0.4888, vega=372.2558, spread=0.5000, OI=45, vol=4
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=504.
#
# --- Window 26/31 (start_idx=525) ---
# [get_window_dates] start=2023-02-08 end=2023-03-10 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4130.0000, m0=1.250, target=5162.5000 -> K=5200.0
# [nearest_atm_strike] spot0=4130.0000 -> K_ATM=4130.0
#
# [day 1/21] 2023-02-08 -> 2023-02-09
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=22, mid=1073.4500, delta=-0.9837, vega=40.2744, spread=18.1000, OI=0, vol=0
# [pick_one] cp=C, K=4130.0, dte=21, mid=65.1500, delta=0.4973, vega=393.8412, spread=0.5000, OI=15, vol=38
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=525.
#
# --- Window 27/31 (start_idx=546) ---
# [get_window_dates] start=2023-03-10 end=2023-04-12 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3880.0000, m0=1.250, target=4850.0000 -> K=4415.0
# [nearest_atm_strike] spot0=3880.0000 -> K_ATM=3880.0
#
# [day 1/21] 2023-03-10 -> 2023-03-13
# [pick_one] MISSING leg for cp=C, K=4415.0
# [pick_one] cp=P, K=4415.0, dte=21, mid=544.2500, delta=-0.9984, vega=3.8441, spread=7.1000, OI=11, vol=1
# [pick_one] cp=C, K=3880.0, dte=21, mid=79.3500, delta=0.4910, vega=369.2911, spread=0.9000, OI=124, vol=172
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=546.
#
# --- Window 28/31 (start_idx=567) ---
# [get_window_dates] start=2023-04-12 end=2023-05-11 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4105.0000, m0=1.250, target=5131.2500 -> K=5200.0
# [nearest_atm_strike] spot0=4105.0000 -> K_ATM=4105.0
#
# [day 1/21] 2023-04-12 -> 2023-04-13
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=22, mid=1094.8500, delta=-0.9970, vega=9.0237, spread=7.7000, OI=0, vol=0
# [pick_one] cp=C, K=4105.0, dte=21, mid=60.7500, delta=0.4989, vega=391.4857, spread=0.5000, OI=7, vol=28
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=567.
#
# --- Window 29/31 (start_idx=588) ---
# [get_window_dates] start=2023-05-11 end=2023-06-12 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4150.0000, m0=1.250, target=5187.5000 -> K=5200.0
# [nearest_atm_strike] spot0=4150.0000 -> K_ATM=4150.0
#
# [day 1/21] 2023-05-11 -> 2023-05-12
# [pick_one] MISSING leg for cp=C, K=5200.0
# [pick_one] cp=P, K=5200.0, dte=21, mid=1060.0000, delta=-0.9825, vega=41.9156, spread=8.4000, OI=0, vol=0
# [pick_one] cp=C, K=4150.0, dte=21, mid=42.8500, delta=0.4716, vega=394.1022, spread=0.3000, OI=54, vol=28
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=588.
#
# --- Window 30/31 (start_idx=609) ---
# [get_window_dates] start=2023-06-12 end=2023-07-13 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4360.0000, m0=1.250, target=5450.0000 -> K=5400.0
# [nearest_atm_strike] spot0=4360.0000 -> K_ATM=4360.0
#
# [day 1/21] 2023-06-12 -> 2023-06-13
# [pick_one] MISSING leg for cp=C, K=5400.0
# [pick_one] cp=P, K=5400.0, dte=21, mid=1048.3500, delta=-0.9899, vega=27.6530, spread=2.9000, OI=0, vol=0
# [pick_one] cp=C, K=4360.0, dte=21, mid=40.9000, delta=0.4708, vega=414.0319, spread=0.6000, OI=55, vol=182
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=609.
#
# --- Window 31/31 (start_idx=630) ---
# [get_window_dates] start=2023-07-13 end=2023-08-11 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=4530.0000, m0=1.250, target=5662.5000 -> K=4850.0
# [nearest_atm_strike] spot0=4530.0000 -> K_ATM=4530.0
#
# [day 1/21] 2023-07-13 -> 2023-07-14
# [pick_one] cp=C, K=4850.0, dte=22, mid=0.3500, delta=0.0082, vega=24.7271, spread=0.1000, OI=38, vol=44
# [pick_one] MISSING leg for cp=P, K=4850.0
# [pick_one] cp=C, K=4530.0, dte=21, mid=43.5000, delta=0.4802, vega=431.0406, spread=0.4000, OI=45, vol=5
# [one_day_step] Missing at least one leg on current day.
# [run_single_window] Step failed, aborting this window.
# [run_experiment_verbose] Window failed for m0=1.25, start_idx=630.
# Results shape: (10, 11)
#        start        end    m0  K_straddle  K_hedge        V0       V_T  \
# 0 2021-01-04 2021-02-03  0.75      2800.0   3705.0   904.650  1032.350
# 1 2021-11-03 2021-12-06  0.75      3500.0   4660.0  1158.000  1097.700
# 2 2022-05-09 2022-06-08  0.75      3000.0   4010.0   997.050  1111.550
# 3 2021-08-05 2021-09-03  0.80      3550.0   4425.0   875.825   986.800
# 4 2021-12-06 2022-01-05  0.80      3675.0   4595.0   925.800  1031.525
# 5 2022-05-09 2022-06-08  0.80      3200.0   4010.0   802.100   912.525
# 6 2021-02-03 2021-03-05  0.90      3450.0   3835.0   399.100   413.300
# 7 2022-07-11 2022-08-09  0.90      3500.0   3875.0   374.100   623.975
# 8 2022-11-07 2022-12-07  1.10      4200.0   3820.0   391.525   268.800
# 9 2023-01-09 2023-02-08  1.10      4300.0   3910.0   399.975   193.850
#
#           Pi_T  tracking_error  pnl_unhedged  pnl_hedged
# 0  1033.920033       -1.570033       127.700  129.270033
# 1  1093.580176        4.119824       -60.300  -64.419824
# 2  1104.583956        6.966044       114.500  107.533956
# 3   983.600729        3.199271       110.975  107.775729
# 4  1034.623796       -3.098796       105.725  108.823796
# 5   906.761314        5.763686       110.425  104.661314
# 6   411.411846        1.888154        14.200   12.311846
# 7   617.132294        6.842706       249.875  243.032294
# 8   250.735852       18.064148      -122.725 -140.789148
# 9   196.112400       -2.262400      -206.125 -203.862600

# %%
# Identify bad result rows (any NaNs in Pi_T / tracking_error / pnl_hedged)
bad = results_df[results_df[['Pi_T','tracking_error','pnl_hedged']].isna().any(axis=1)]
print(f"Bad rows with NaNs: {len(bad)}")
display(bad)

# Map start dates to start_idx in the backtest calendar and re-run single windows verbosely
dates_bt = np.sort(df_1m_bt['date'].unique())

for _, r in bad.iterrows():
    start_ts = pd.Timestamp(r['start'])
    m0v = float(r['m0'])
    try:
        start_idx = int(np.where(dates_bt == start_ts)[0][0])
    except Exception:
        print("Could not map start date to index:", start_ts)
        continue

    print(f"\n=== Re-running window starting {start_ts.date()} for m0={m0v} ===")
    out = run_single_window(df_1m_bt, start_idx=start_idx, m0=m0v)
    if out is None:
        print("Window re-run failed (see above prints for the exact day/leg that broke).")
    else:
        print("Window re-run succeeded; showing summary:")
        display(pd.DataFrame([out['summary']]))
# Out:
# Bad rows with NaNs: 0
# Empty DataFrame
# Columns: [start, end, m0, K_straddle, K_hedge, V0, V_T, Pi_T, tracking_error, pnl_unhedged, pnl_hedged]
# Index: []

# %%
summary_tbl = summarize_results_verbose(results_df)
display(summary_tbl)
# Out:
#           mean    median    std_dev  VaR_5pct  VaR_2p5pct  VaR_1pct
# m0
# 0.75  3.171945  4.119824   4.346264 -1.001048   -1.285540 -1.456236
# 0.80  1.954720  3.199271   4.560436 -2.468989   -2.783893 -2.972835
# 0.90  4.365430  4.365430   3.503397  2.135882    2.012018  1.937700
# 1.10  7.900874  7.900874  14.373040 -1.246072   -1.754236 -2.059134

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sort by window end-date so the x-axis is chronological
res = results_df.sort_values('end').reset_index(drop=True).copy()

plt.figure()
plt.plot(res['end'], res['pnl_unhedged'], label='Unhedged PnL')
plt.plot(res['end'], res['pnl_hedged'], label='Hedged PnL')
plt.title('Per-Window PnL (Unhedged vs Hedged)')
plt.xlabel('Window End Date')
plt.ylabel('PnL (index pts)')
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
res = results_df.sort_values('end').reset_index(drop=True).copy()

res['cum_unhedged'] = res['pnl_unhedged'].cumsum()
res['cum_hedged']   = res['pnl_hedged'].cumsum()

plt.figure()
plt.plot(res['end'], res['cum_unhedged'], label='Cumulative Unhedged')
plt.plot(res['end'], res['cum_hedged'], label='Cumulative Hedged')
plt.title('Cumulative PnL over Non-overlapping Windows')
plt.xlabel('Window End Date')
plt.ylabel('Cumulative PnL (index pts)')
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
res = results_df.sort_values('end').reset_index(drop=True).copy()

plt.figure()
plt.plot(res['end'], res['tracking_error'])
plt.title('Tracking Error Z_T = V_T - Π_T (per window)')
plt.xlabel('Window End Date')
plt.ylabel('Tracking Error (index pts)')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# Boxplot of tracking error by m0
plt.figure()
results_df.boxplot(column='tracking_error', by='m0')
plt.title('Tracking Error by m0')
plt.suptitle('')
plt.xlabel('m0')
plt.ylabel('Z_T (index pts)')
plt.tight_layout()
plt.show()

# %%
# Compute statistics per m0
perf = results_df.groupby('m0').agg(
    windows       = ('tracking_error', 'count'),
    te_mean       = ('tracking_error', 'mean'),
    te_median     = ('tracking_error', 'median'),
    te_std        = ('tracking_error', 'std'),
    hedged_mean   = ('pnl_hedged', 'mean'),
    hedged_std    = ('pnl_hedged', 'std'),
    unhedged_mean = ('pnl_unhedged', 'mean'),
    unhedged_std  = ('pnl_unhedged', 'std')
).reset_index()

# "Monthly" windows; annualize Sharpe by sqrt(12)
perf['hedged_sharpe_ann']   = perf['hedged_mean']   / perf['hedged_std']   * np.sqrt(12)
perf['unhedged_sharpe_ann'] = perf['unhedged_mean'] / perf['unhedged_std'] * np.sqrt(12)

# Hit rate: how often hedging reduces |Z_T| vs 0 (optional)
# (By design, smaller |Z_T| is better; you can also compare |pnl_hedged - pnl_unhedged| reductions if desired.)
# Here we just keep core stats.
perf = perf.fillna(0.0)
perf
# Out:
#      m0  windows   te_mean  te_median     te_std  hedged_mean  hedged_std  \
# 0  0.75        3  3.171945   4.119824   4.346264    57.461388  106.110258
# 1  0.80        3  1.954720   3.199271   4.560436   107.086946    2.165036
# 2  0.90        2  4.365430   4.365430   3.503397   127.672070  163.143994
# 3  1.10        2  7.900874   7.900874  14.373040  -172.325874   44.599666
#
#    unhedged_mean  unhedged_std  hedged_sharpe_ann  unhedged_sharpe_ann
# 0      60.633333    104.939093           1.875899             2.001542
# 1     109.041667      2.885452         171.341313           130.908922
# 2     132.037500    166.647391           2.710912             2.744665
# 3    -164.425000     58.972706         -13.384727            -9.658450

# %%
plt.figure()
results_df['tracking_error'].hist(bins=50)
plt.title('Tracking Error Distribution (All Windows)')
plt.xlabel('Z_T (index pts)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

# --- Choose WHICH window to inspect ---
# Option 1: by row index in results_df (change idx as you like)
idx = 0  # e.g., inspect the first successful window
row = results_df.iloc[idx]

# Option 2 (alternative): pick by m0 and earliest end date
# m0_pick = 0.9
# row = results_df[results_df['m0'] == m0_pick].sort_values('end').iloc[0]

print("Inspecting window:", dict(start=row['start'], end=row['end'], m0=row['m0']))

# --- Map its start date to a start_idx in the backtest calendar used for df_1m_bt ---
dates_bt = np.sort(df_1m_bt['date'].unique())
try:
    start_idx = int(np.where(dates_bt == pd.Timestamp(row['start']))[0][0])
except Exception:
    raise RuntimeError(f"Could not map start date {row['start']} to an index in df_1m_bt. "
                       "Check that df_1m_bt covers this date.")

# --- Re-run that single window to get the per-day timeline ---
out_window = run_single_window(df_1m_bt, start_idx=start_idx, m0=float(row['m0']))
if out_window is None:
    raise RuntimeError("Re-run of the selected window failed (see printed logs above). Choose another window.")

timeline = out_window['timeline'].sort_values('date').reset_index(drop=True)
display(timeline.head(10))
# Out:
# Inspecting window: {'start': Timestamp('2021-01-04 00:00:00'), 'end': Timestamp('2021-02-03 00:00:00'), 'm0': np.float64(0.75)}
# [get_window_dates] start=2021-01-04 end=2021-02-03 len=22 (includes final valuation day).
# [choose_strike_for_m0] spot0=3705.0000, m0=0.750, target=2778.7500 -> K=2800.0
# [nearest_atm_strike] spot0=3705.0000 -> K_ATM=3705.0
#
# [day 1/21] 2021-01-04 -> 2021-01-05
# [pick_one] cp=C, K=2800.0, dte=21, mid=902.4000, delta=0.9869, vega=29.5673, spread=6.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.2500, delta=-0.0130, vega=29.6517, spread=0.2000, OI=122, vol=3
# [pick_one] cp=C, K=3705.0, dte=21, mid=68.4500, delta=0.4987, vega=354.0529, spread=0.7000, OI=7, vol=1
# [ratios @ 2021-01-04] V=904.6500 ΔV=0.973918 κV=59.218980 | ΔH=0.498739 κH=354.052900 -> φ1=0.167260, φ0=0.890499
# [next fetch] cp=C, K=2800.0, dte=22, mid=927.0500
# [next fetch] cp=P, K=2800.0, dte=22, mid=2.0000
# [next fetch] cp=C, K=3705.0, dte=22, mid=82.9500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.16726025969565564, from 68.4500 to 82.9500 -> pnl=2.425274
# [pnl] qty=0.8904987853396483, from 3705.0000 to 3730.0000 -> pnl=22.262470
# [rebalance_cost] prev=0.000000, new=0.167260, half_spread=0.350000 -> cost=0.058541
# [init] V0=Π0=904.650000
#
# [day 2/21] 2021-01-05 -> 2021-01-06
# [pick_one] cp=C, K=2800.0, dte=22, mid=927.0500, delta=0.9887, vega=25.9799, spread=9.9000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=2.0000, delta=-0.0116, vega=27.6549, spread=0.2000, OI=76, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=82.9500, delta=0.5539, vega=361.4652, spread=0.5000, OI=3, vol=2
# [ratios @ 2021-01-05] V=929.0500 ΔV=0.977194 κV=53.634770 | ΔH=0.553945 κH=361.465200 -> φ1=0.148382, φ0=0.894999
# [next fetch] cp=C, K=2800.0, dte=21, mid=951.5500
# [next fetch] cp=P, K=2800.0, dte=21, mid=2.3500
# [next fetch] cp=C, K=3705.0, dte=21, mid=99.6000
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.14838155927596905, from 82.9500 to 99.6000 -> pnl=2.470553
# [pnl] qty=0.8949987771468734, from 3730.0000 to 3755.0000 -> pnl=22.374969
# [rebalance_cost] prev=0.167260, new=0.148382, half_spread=0.250000 -> cost=0.004720
#
# [day 3/21] 2021-01-06 -> 2021-01-07
# [pick_one] cp=C, K=2800.0, dte=21, mid=951.5500, delta=0.9835, vega=36.9885, spread=15.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.3500, delta=-0.0128, vega=29.6788, spread=0.3000, OI=76, vol=2
# [pick_one] cp=C, K=3705.0, dte=21, mid=99.6000, delta=0.5998, vega=347.3597, spread=1.2000, OI=5, vol=2
# [ratios @ 2021-01-06] V=953.9000 ΔV=0.970661 κV=66.667320 | ΔH=0.599847 κH=347.359700 -> φ1=0.191926, φ0=0.855535
# [next fetch] cp=C, K=2800.0, dte=22, mid=1005.8500
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.3500
# [next fetch] cp=C, K=3705.0, dte=22, mid=135.5000
# [half_spread] C K=3705.0 -> half-spread=0.6000
# [pnl] qty=0.19192589123032985, from 99.6000 to 135.5000 -> pnl=6.890139
# [pnl] qty=0.8555348299231603, from 3755.0000 to 3805.0000 -> pnl=42.776741
# [rebalance_cost] prev=0.148382, new=0.191926, half_spread=0.600000 -> cost=0.026127
#
# [day 4/21] 2021-01-07 -> 2021-01-08
# [pick_one] cp=C, K=2800.0, dte=22, mid=1005.8500, delta=0.9900, vega=24.9735, spread=5.3000, OI=12, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.3500, delta=-0.0079, vega=20.2422, spread=0.2000, OI=1732, vol=64
# [pick_one] cp=C, K=3705.0, dte=22, mid=135.5000, delta=0.7075, vega=320.9311, spread=1.4000, OI=110, vol=6
# [ratios @ 2021-01-07] V=1007.2000 ΔV=0.982062 κV=45.215720 | ΔH=0.707532 κH=320.931100 -> φ1=0.140889, φ0=0.882378
# [next fetch] cp=C, K=2800.0, dte=21, mid=1026.2000
# [next fetch] cp=P, K=2800.0, dte=21, mid=0.8750
# [next fetch] cp=C, K=3705.0, dte=21, mid=150.1000
# [half_spread] C K=3705.0 -> half-spread=0.7000
# [pnl] qty=0.14088918150967608, from 135.5000 to 150.1000 -> pnl=2.056982
# [pnl] qty=0.8823783956280958, from 3805.0000 to 3830.0000 -> pnl=22.059460
# [rebalance_cost] prev=0.191926, new=0.140889, half_spread=0.700000 -> cost=0.035726
#
# [day 5/21] 2021-01-08 -> 2021-01-11
# [pick_one] cp=C, K=2800.0, dte=21, mid=1026.2000, delta=0.9925, vega=19.1112, spread=5.8000, OI=12, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=0.8750, delta=-0.0055, vega=14.4201, spread=0.1500, OI=1790, vol=68
# [pick_one] cp=C, K=3705.0, dte=21, mid=150.1000, delta=0.7452, vega=294.4450, spread=0.6000, OI=108, vol=0
# [ratios @ 2021-01-08] V=1027.0750 ΔV=0.986958 κV=33.531260 | ΔH=0.745233 κH=294.445000 -> φ1=0.113880, φ0=0.902091
# [next fetch] cp=C, K=2800.0, dte=21, mid=999.1500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.1000
# [next fetch] cp=C, K=3705.0, dte=21, mid=134.0500
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.11387953607634704, from 150.1000 to 134.0500 -> pnl=-1.827767
# [pnl] qty=0.9020912116912156, from 3830.0000 to 3800.0000 -> pnl=-27.062736
# [rebalance_cost] prev=0.140889, new=0.113880, half_spread=0.300000 -> cost=0.008103
#
# [day 6/21] 2021-01-11 -> 2021-01-12
# [pick_one] cp=C, K=2800.0, dte=21, mid=999.1500, delta=0.9897, vega=23.5147, spread=11.7000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.1000, delta=-0.0068, vega=17.2133, spread=0.1000, OI=1582, vol=11
# [pick_one] cp=C, K=3705.0, dte=21, mid=134.0500, delta=0.6880, vega=322.0426, spread=0.7000, OI=29, vol=0
# [ratios @ 2021-01-11] V=1000.2500 ΔV=0.982971 κV=40.727990 | ΔH=0.687970 κH=322.042600 -> φ1=0.126468, φ0=0.895965
# [next fetch] cp=C, K=2800.0, dte=22, mid=1006.6000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.1750
# [next fetch] cp=C, K=3705.0, dte=22, mid=139.1500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.12646770955146927, from 134.0500 to 139.1500 -> pnl=0.644985
# [pnl] qty=0.8959650098598757, from 3800.0000 to 3805.0000 -> pnl=4.479825
# [rebalance_cost] prev=0.113880, new=0.126468, half_spread=0.350000 -> cost=0.004406
#
# [day 7/21] 2021-01-12 -> 2021-01-13
# [pick_one] cp=C, K=2800.0, dte=22, mid=1006.6000, delta=0.9779, vega=49.1087, spread=8.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.1750, delta=-0.0071, vega=18.4085, spread=0.1500, OI=917, vol=4
# [pick_one] cp=C, K=3705.0, dte=22, mid=139.1500, delta=0.6901, vega=329.1651, spread=0.7000, OI=0, vol=0
# [ratios @ 2021-01-12] V=1007.7750 ΔV=0.970835 κV=67.517210 | ΔH=0.690149 κH=329.165100 -> φ1=0.205117, φ0=0.829274
# [next fetch] cp=C, K=2800.0, dte=21, mid=1012.4000
# [next fetch] cp=P, K=2800.0, dte=21, mid=0.9750
# [next fetch] cp=C, K=3705.0, dte=21, mid=139.9500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.20511655093447026, from 139.1500 to 139.9500 -> pnl=0.164093
# [pnl] qty=0.8292740174891263, from 3805.0000 to 3810.0000 -> pnl=4.146370
# [rebalance_cost] prev=0.126468, new=0.205117, half_spread=0.350000 -> cost=0.027527
#
# [day 8/21] 2021-01-13 -> 2021-01-14
# [pick_one] cp=C, K=2800.0, dte=21, mid=1012.4000, delta=0.9878, vega=28.8869, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=0.9750, delta=-0.0061, vega=15.7007, spread=0.1500, OI=921, vol=5
# [pick_one] cp=C, K=3705.0, dte=21, mid=139.9500, delta=0.7177, vega=308.8590, spread=0.5000, OI=0, vol=0
# [ratios @ 2021-01-13] V=1013.3750 ΔV=0.981762 κV=44.587630 | ΔH=0.717659 κH=308.859000 -> φ1=0.144362, φ0=0.878159
# [next fetch] cp=C, K=2800.0, dte=22, mid=997.3000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.5750
# [next fetch] cp=C, K=3705.0, dte=22, mid=134.7000
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.14436241132685143, from 139.9500 to 134.7000 -> pnl=-0.757903
# [pnl] qty=0.878159016249583, from 3810.0000 to 3800.0000 -> pnl=-8.781590
# [rebalance_cost] prev=0.205117, new=0.144362, half_spread=0.250000 -> cost=0.015189
#
# [day 9/21] 2021-01-14 -> 2021-01-15
# [pick_one] cp=C, K=2800.0, dte=22, mid=997.3000, delta=0.9911, vega=22.4524, spread=7.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.5750, delta=-0.0090, vega=22.6085, spread=0.1500, OI=1289, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=134.7000, delta=0.6817, vega=332.5009, spread=3.8000, OI=4, vol=0
# [ratios @ 2021-01-14] V=998.8750 ΔV=0.982108 κV=45.060850 | ΔH=0.681674 κH=332.500900 -> φ1=0.135521, φ0=0.889727
# [next fetch] cp=C, K=2800.0, dte=21, mid=967.9500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.6250
# [next fetch] cp=C, K=3705.0, dte=21, mid=111.1500
# [half_spread] C K=3705.0 -> half-spread=1.9000
# [pnl] qty=0.13552098655973563, from 134.7000 to 111.1500 -> pnl=-3.191519
# [pnl] qty=0.8897268670078787, from 3800.0000 to 3775.0000 -> pnl=-22.243172
# [rebalance_cost] prev=0.144362, new=0.135521, half_spread=1.900000 -> cost=0.016799
#
# [day 10/21] 2021-01-15 -> 2021-01-19
# [pick_one] cp=C, K=2800.0, dte=21, mid=967.9500, delta=0.9939, vega=14.8018, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.6250, delta=-0.0095, vega=22.9297, spread=0.1500, OI=1289, vol=0
# [pick_one] cp=C, K=3705.0, dte=21, mid=111.1500, delta=0.6371, vega=338.8777, spread=0.7000, OI=4, vol=9
# [ratios @ 2021-01-15] V=969.5750 ΔV=0.984437 κV=37.731420 | ΔH=0.637126 κH=338.877700 -> φ1=0.111342, φ0=0.913498
# [next fetch] cp=C, K=2800.0, dte=22, mid=997.7500
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.5000
# [next fetch] cp=C, K=3705.0, dte=22, mid=133.1000
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.11134229251437908, from 111.1500 to 133.1000 -> pnl=2.443963
# [pnl] qty=0.9134979305394837, from 3775.0000 to 3800.0000 -> pnl=22.837448
# [rebalance_cost] prev=0.135521, new=0.111342, half_spread=0.350000 -> cost=0.008463
#
# [day 11/21] 2021-01-19 -> 2021-01-20
# [pick_one] cp=C, K=2800.0, dte=22, mid=997.7500, delta=0.9931, vega=16.4332, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.5000, delta=-0.0086, vega=21.8534, spread=0.1000, OI=21, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=133.1000, delta=0.6879, vega=329.6244, spread=3.2000, OI=2, vol=1
# [ratios @ 2021-01-19] V=999.2500 ΔV=0.984501 κV=38.286540 | ΔH=0.687851 κH=329.624400 -> φ1=0.116152, φ0=0.904606
# [next fetch] cp=C, K=2800.0, dte=21, mid=1052.4500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0250
# [next fetch] cp=C, K=3705.0, dte=21, mid=172.5000
# [half_spread] C K=3705.0 -> half-spread=1.6000
# [pnl] qty=0.11615202029946814, from 133.1000 to 172.5000 -> pnl=4.576390
# [pnl] qty=0.9046057166849906, from 3800.0000 to 3855.0000 -> pnl=49.753314
# [rebalance_cost] prev=0.111342, new=0.116152, half_spread=1.600000 -> cost=0.007696
#
# [day 12/21] 2021-01-20 -> 2021-01-21
# [pick_one] cp=C, K=2800.0, dte=21, mid=1052.4500, delta=0.9957, vega=11.4378, spread=5.3000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.0250, delta=-0.0061, vega=15.8948, spread=0.1500, OI=21, vol=0
# [pick_one] cp=C, K=3705.0, dte=21, mid=172.5000, delta=0.7812, vega=272.6492, spread=0.6000, OI=3, vol=0
# [ratios @ 2021-01-20] V=1053.4750 ΔV=0.989657 κV=27.332670 | ΔH=0.781209 κH=272.649200 -> φ1=0.100248, φ0=0.911342
# [next fetch] cp=C, K=2800.0, dte=22, mid=1053.6000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.0500
# [next fetch] cp=C, K=3705.0, dte=22, mid=174.8500
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.100248487800441, from 172.5000 to 174.8500 -> pnl=0.235584
# [pnl] qty=0.9113419790939052, from 3855.0000 to 3855.0000 -> pnl=0.000000
# [rebalance_cost] prev=0.116152, new=0.100248, half_spread=0.300000 -> cost=0.004771
#
# [day 13/21] 2021-01-21 -> 2021-01-22
# [pick_one] cp=C, K=2800.0, dte=22, mid=1053.6000, delta=0.9950, vega=13.3365, spread=5.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.0500, delta=-0.0062, vega=16.5387, spread=0.1000, OI=1604, vol=1
# [pick_one] cp=C, K=3705.0, dte=22, mid=174.8500, delta=0.7772, vega=282.0517, spread=0.7000, OI=9, vol=0
# [ratios @ 2021-01-21] V=1054.6500 ΔV=0.988832 κV=29.875120 | ΔH=0.777166 κH=282.051700 -> φ1=0.105921, φ0=0.906514
# [next fetch] cp=C, K=2800.0, dte=21, mid=1044.1500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0750
# [next fetch] cp=C, K=3705.0, dte=21, mid=165.3500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.10592072304474677, from 174.8500 to 165.3500 -> pnl=-1.006247
# [pnl] qty=0.9065140153542064, from 3855.0000 to 3845.0000 -> pnl=-9.065140
# [rebalance_cost] prev=0.100248, new=0.105921, half_spread=0.350000 -> cost=0.001985
#
# [day 14/21] 2021-01-22 -> 2021-01-25
# [pick_one] cp=C, K=2800.0, dte=21, mid=1044.1500, delta=0.9877, vega=29.3790, spread=5.1000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.0750, delta=-0.0064, vega=16.5276, spread=0.1500, OI=1603, vol=20
# [pick_one] cp=C, K=3705.0, dte=21, mid=165.3500, delta=0.7636, vega=284.0965, spread=0.5000, OI=9, vol=0
# [ratios @ 2021-01-22] V=1045.2250 ΔV=0.981338 κV=45.906640 | ΔH=0.763582 κH=284.096500 -> φ1=0.161588, φ0=0.857952
# [next fetch] cp=C, K=2800.0, dte=22, mid=1053.5000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.3000
# [next fetch] cp=C, K=3705.0, dte=22, mid=175.9500
# [half_spread] C K=3705.0 -> half-spread=0.2500
# [pnl] qty=0.16158819274436678, from 165.3500 to 175.9500 -> pnl=1.712835
# [pnl] qty=0.8579521646078709, from 3845.0000 to 3855.0000 -> pnl=8.579522
# [rebalance_cost] prev=0.105921, new=0.161588, half_spread=0.250000 -> cost=0.013917
#
# [day 15/21] 2021-01-25 -> 2021-01-26
# [pick_one] cp=C, K=2800.0, dte=22, mid=1053.5000, delta=0.9933, vega=15.9821, spread=10.4000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.3000, delta=-0.0073, vega=19.2094, spread=0.2000, OI=493, vol=0
# [pick_one] cp=C, K=3705.0, dte=22, mid=175.9500, delta=0.7716, vega=285.6297, spread=1.1000, OI=0, vol=0
# [ratios @ 2021-01-25] V=1054.8000 ΔV=0.985922 κV=35.191470 | ΔH=0.771597 κH=285.629700 -> φ1=0.123207, φ0=0.890856
# [next fetch] cp=C, K=2800.0, dte=21, mid=1046.5500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.2000
# [next fetch] cp=C, K=3705.0, dte=21, mid=170.0000
# [half_spread] C K=3705.0 -> half-spread=0.5500
# [pnl] qty=0.12320662031994573, from 175.9500 to 170.0000 -> pnl=-0.733079
# [pnl] qty=0.8908561413809909, from 3855.0000 to 3850.0000 -> pnl=-4.454281
# [rebalance_cost] prev=0.161588, new=0.123207, half_spread=0.550000 -> cost=0.021110
#
# [day 16/21] 2021-01-26 -> 2021-01-27
# [pick_one] cp=C, K=2800.0, dte=21, mid=1046.5500, delta=0.9944, vega=12.3167, spread=9.9000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=1.2000, delta=-0.0069, vega=17.8124, spread=0.2000, OI=493, vol=15
# [pick_one] cp=C, K=3705.0, dte=21, mid=170.0000, delta=0.7643, vega=283.3810, spread=0.6000, OI=0, vol=0
# [ratios @ 2021-01-26] V=1047.7500 ΔV=0.987482 κV=30.129150 | ΔH=0.764337 κH=283.381000 -> φ1=0.106320, φ0=0.906217
# [next fetch] cp=C, K=2800.0, dte=21, mid=953.0000
# [next fetch] cp=P, K=2800.0, dte=21, mid=3.7500
# [next fetch] cp=C, K=3705.0, dte=21, mid=122.3000
# [half_spread] C K=3705.0 -> half-spread=0.3000
# [pnl] qty=0.10632028964538907, from 170.0000 to 122.3000 -> pnl=-5.071478
# [pnl] qty=0.9062174687733123, from 3850.0000 to 3760.0000 -> pnl=-81.559572
# [rebalance_cost] prev=0.123207, new=0.106320, half_spread=0.300000 -> cost=0.005066
#
# [day 17/21] 2021-01-27 -> 2021-01-28
# [pick_one] cp=C, K=2800.0, dte=21, mid=953.0000, delta=0.9830, vega=37.2551, spread=14.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=3.7500, delta=-0.0182, vega=40.1225, spread=0.5000, OI=27, vol=17
# [pick_one] cp=C, K=3705.0, dte=21, mid=122.3000, delta=0.5847, vega=350.6339, spread=1.0000, OI=0, vol=0
# [ratios @ 2021-01-27] V=956.7500 ΔV=0.964850 κV=77.377600 | ΔH=0.584717 κH=350.633900 -> φ1=0.220679, φ0=0.835815
# [next fetch] cp=C, K=2800.0, dte=22, mid=992.0000
# [next fetch] cp=P, K=2800.0, dte=22, mid=3.1500
# [next fetch] cp=C, K=3705.0, dte=22, mid=141.5000
# [half_spread] C K=3705.0 -> half-spread=0.5000
# [pnl] qty=0.22067917563019435, from 122.3000 to 141.5000 -> pnl=4.237040
# [pnl] qty=0.8358151344630396, from 3760.0000 to 3800.0000 -> pnl=33.432605
# [rebalance_cost] prev=0.106320, new=0.220679, half_spread=0.500000 -> cost=0.057179
#
# [day 18/21] 2021-01-28 -> 2021-01-29
# [pick_one] cp=C, K=2800.0, dte=22, mid=992.0000, delta=0.9769, vega=50.4544, spread=10.8000, OI=10, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=3.1500, delta=-0.0154, vega=35.2004, spread=0.3000, OI=9451, vol=61
# [pick_one] cp=C, K=3705.0, dte=22, mid=141.5000, delta=0.6457, vega=337.8396, spread=1.2000, OI=260, vol=0
# [ratios @ 2021-01-28] V=995.1500 ΔV=0.961456 κV=85.654850 | ΔH=0.645670 κH=337.839600 -> φ1=0.253537, φ0=0.797755
# [next fetch] cp=C, K=2800.0, dte=21, mid=918.7500
# [next fetch] cp=P, K=2800.0, dte=21, mid=3.5500
# [next fetch] cp=C, K=3705.0, dte=21, mid=97.2500
# [half_spread] C K=3705.0 -> half-spread=0.6000
# [pnl] qty=0.253537033550833, from 141.5000 to 97.2500 -> pnl=-11.219014
# [pnl] qty=0.7977547435472336, from 3800.0000 to 3725.0000 -> pnl=-59.831606
# [rebalance_cost] prev=0.220679, new=0.253537, half_spread=0.600000 -> cost=0.019715
#
# [day 19/21] 2021-01-29 -> 2021-02-01
# [pick_one] cp=C, K=2800.0, dte=21, mid=918.7500, delta=0.9791, vega=44.7418, spread=8.9000, OI=10, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=3.5500, delta=-0.0180, vega=38.5520, spread=0.5000, OI=9422, vol=1104
# [pick_one] cp=C, K=3705.0, dte=21, mid=97.2500, delta=0.5287, vega=345.9557, spread=1.9000, OI=260, vol=465
# [ratios @ 2021-01-29] V=922.3000 ΔV=0.961084 κV=83.293760 | ΔH=0.528730 κH=345.955700 -> φ1=0.240764, φ0=0.833785
# [next fetch] cp=C, K=2800.0, dte=21, mid=975.2000
# [next fetch] cp=P, K=2800.0, dte=21, mid=2.4250
# [next fetch] cp=C, K=3705.0, dte=21, mid=126.3500
# [half_spread] C K=3705.0 -> half-spread=0.9500
# [pnl] qty=0.2407642365771109, from 97.2500 to 126.3500 -> pnl=7.006239
# [pnl] qty=0.833784725194584, from 3725.0000 to 3780.0000 -> pnl=45.858160
# [rebalance_cost] prev=0.253537, new=0.240764, half_spread=0.950000 -> cost=0.012134
#
# [day 20/21] 2021-02-01 -> 2021-02-02
# [pick_one] cp=C, K=2800.0, dte=21, mid=975.2000, delta=0.9873, vega=29.1530, spread=5.8000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=21, mid=2.4250, delta=-0.0128, vega=29.8922, spread=0.2500, OI=62, vol=1
# [pick_one] cp=C, K=3705.0, dte=21, mid=126.3500, delta=0.6316, vega=341.1375, spread=2.1000, OI=3, vol=0
# [ratios @ 2021-02-01] V=977.6250 ΔV=0.974461 κV=59.045180 | ΔH=0.631576 κH=341.137500 -> φ1=0.173083, φ0=0.865146
# [next fetch] cp=C, K=2800.0, dte=22, mid=1025.4000
# [next fetch] cp=P, K=2800.0, dte=22, mid=1.8250
# [next fetch] cp=C, K=3705.0, dte=22, mid=159.4500
# [half_spread] C K=3705.0 -> half-spread=1.0500
# [pnl] qty=0.17308322890330147, from 126.3500 to 159.4500 -> pnl=5.729055
# [pnl] qty=0.8651457866221685, from 3780.0000 to 3830.0000 -> pnl=43.257289
# [rebalance_cost] prev=0.240764, new=0.173083, half_spread=1.050000 -> cost=0.071065
#
# [day 21/21] 2021-02-02 -> 2021-02-03
# [pick_one] cp=C, K=2800.0, dte=22, mid=1025.4000, delta=0.9905, vega=22.4487, spread=8.2000, OI=0, vol=0
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.8250, delta=-0.0098, vega=24.6170, spread=0.1500, OI=450, vol=200
# [pick_one] cp=C, K=3705.0, dte=22, mid=159.4500, delta=0.7156, vega=318.1250, spread=0.7000, OI=1, vol=0
# [ratios @ 2021-02-02] V=1027.2250 ΔV=0.980659 κV=47.065730 | ΔH=0.715568 κH=318.125000 -> φ1=0.147947, φ0=0.874793
# [next fetch] cp=C, K=2800.0, dte=21, mid=1031.3500
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0000
# [next fetch] cp=C, K=3705.0, dte=21, mid=157.5500
# [half_spread] C K=3705.0 -> half-spread=0.3500
# [pnl] qty=0.14794728487229863, from 159.4500 to 157.5500 -> pnl=-0.281100
# [pnl] qty=0.8747926572584991, from 3830.0000 to 3835.0000 -> pnl=4.373963
# [rebalance_cost] prev=0.173083, new=0.147947, half_spread=0.350000 -> cost=0.008798
# [pick_one] cp=C, K=2800.0, dte=22, mid=1025.4000, delta=0.9905, vega=22.4487, spread=8.2000, OI=0, vol=0
# [next fetch] cp=C, K=2800.0, dte=21, mid=1031.3500
# [pick_one] cp=P, K=2800.0, dte=22, mid=1.8250, delta=-0.0098, vega=24.6170, spread=0.1500, OI=450, vol=200
# [next fetch] cp=P, K=2800.0, dte=21, mid=1.0000
#
# [window done] m0=0.75, Z_T=-1.570033, V_T=1032.350000, Π_T=1033.920033
#         date    spot  K_straddle  K_hedge       V_t      dV_t      kV_t H_cp  \
# 0 2021-01-04  3705.0      2800.0   3705.0   904.650  0.973918  59.21898    C
# 1 2021-01-05  3730.0      2800.0   3705.0   929.050  0.977194  53.63477    C
# 2 2021-01-06  3755.0      2800.0   3705.0   953.900  0.970661  66.66732    C
# 3 2021-01-07  3805.0      2800.0   3705.0  1007.200  0.982062  45.21572    C
# 4 2021-01-08  3830.0      2800.0   3705.0  1027.075  0.986958  33.53126    C
# 5 2021-01-11  3800.0      2800.0   3705.0  1000.250  0.982971  40.72799    C
# 6 2021-01-12  3805.0      2800.0   3705.0  1007.775  0.970835  67.51721    C
# 7 2021-01-13  3810.0      2800.0   3705.0  1013.375  0.981762  44.58763    C
# 8 2021-01-14  3800.0      2800.0   3705.0   998.875  0.982108  45.06085    C
# 9 2021-01-15  3775.0      2800.0   3705.0   969.575  0.984437  37.73142    C
#
#     H_mid      dH_t      kH_t   phi_opt  phi_under  cost_opt  cost_under  \
# 0   68.45  0.498739  354.0529  0.167260   0.890499  0.058541         0.0
# 1   82.95  0.553945  361.4652  0.148382   0.894999  0.004720         0.0
# 2   99.60  0.599847  347.3597  0.191926   0.855535  0.026127         0.0
# 3  135.50  0.707532  320.9311  0.140889   0.882378  0.035726         0.0
# 4  150.10  0.745233  294.4450  0.113880   0.902091  0.008103         0.0
# 5  134.05  0.687970  322.0426  0.126468   0.895965  0.004406         0.0
# 6  139.15  0.690149  329.1651  0.205117   0.829274  0.027527         0.0
# 7  139.95  0.717659  308.8590  0.144362   0.878159  0.015189         0.0
# 8  134.70  0.681674  332.5009  0.135521   0.889727  0.016799         0.0
# 9  111.15  0.637126  338.8777  0.111342   0.913498  0.008463         0.0
#
#     pnl_opt  pnl_under  pnl_unhedged         Pi_t        Pi_t1
# 0  2.425274  22.262470        24.400   904.650000   929.279202
# 1  2.470553  22.374969        24.850   929.279202   954.120005
# 2  6.890139  42.776741        53.300   954.120005  1003.760759
# 3  2.056982  22.059460        19.875  1003.760759  1027.841476
# 4 -1.827767 -27.062736       -26.825  1027.841476   998.942870
# 5  0.644985   4.479825         7.525   998.942870  1004.063274
# 6  0.164093   4.146370         5.600  1004.063274  1008.346211
# 7 -0.757903  -8.781590       -14.500  1008.346211   998.791529
# 8 -3.191519 -22.243172       -29.300   998.791529   973.340040
# 9  2.443963  22.837448        29.675   973.340040   998.612989

# %%
# Requires: timeline = out_window['timeline']
tl = timeline.copy()

# Residuals after hedge (what's left unhedged)
tl['delta_residual'] = tl['dV_t'] - (tl['phi_opt']*tl['dH_t'] + tl['phi_under'])
tl['vega_residual']  = tl['kV_t'] - (tl['phi_opt']*tl['kH_t'])

# 7a) Delta residual over days
plt.figure()
plt.plot(tl['date'], tl['delta_residual'])
plt.title('Daily Delta Residual (Post-Hedge)')
plt.xlabel('Date')
plt.ylabel('Residual Delta')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# 7b) Vega residual over days
plt.figure()
plt.plot(tl['date'], tl['vega_residual'])
plt.title('Daily Vega Residual (Post-Hedge)')
plt.xlabel('Date')
plt.ylabel('Residual Vega')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
tl = timeline.copy()

plt.figure()
plt.plot(tl['date'], tl['phi_opt'])
plt.title('Daily Hedge Ratio: φ₁ (Option Units)')
plt.xlabel('Date')
plt.ylabel('φ₁')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

plt.figure()
plt.plot(tl['date'], tl['phi_under'])
plt.title('Daily Hedge Ratio: φ₀ (Underlying Units)')
plt.xlabel('Date')
plt.ylabel('φ₀')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
tl = timeline.copy()
tl = tl.sort_values('date').reset_index(drop=True)

# Per-day hedge P&L net of costs
tl['pnl_net'] = tl['pnl_opt'] + tl['pnl_under'] - tl['cost_opt'] - tl['cost_under']
tl['cum_pnl_net'] = tl['pnl_net'].cumsum()

plt.figure()
plt.plot(tl['date'], tl['cum_pnl_net'])
plt.title('Cumulative Hedged P&L within Window (self-financing book)')
plt.xlabel('Date')
plt.ylabel('Cumulative P&L (index pts)')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
